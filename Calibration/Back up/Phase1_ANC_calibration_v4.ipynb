# %%
import random
import numpy as np
import streamlit as st
import math
from parameters import get_parameters
from global_func import odds_prob


# Initialize parameters
P = {}  # dict to restore probabilities
n = {}  # dict to restore counts
E = {}  # dict to restore effects
S = {}  # dict to restore supplies and capacities
OR = {}  # dict to restore odds ratio
M = {}  # dict to restore maternal outcomes

#known parameters
param = get_parameters()
LB_tot = np.array([23729, 18196, 20709, 5126])
P["highrisk_all"] = 0.26                                              # high risk pregnancies among all live births
P["ANC"] = 0.56

# Calibration criteria
P["home_all"] = param["home_all_target"]
P["l23_all"] = param["l23_all_target"]
P["l45_all"] = param["l45_all_target"]
P["home_anc"] = param["home_anc_target"]

# %%
random.seed(0)
def f_ANC_LB_effect(P_home_noANC, P_l45_fac, P_home_lowrisk, P_L23_highrisk, Sen_traditional, Spec_traditional):
    # Initialize parameters

    GA = param['GA_sequence']
    GA_n = len(GA)
    n["GA"] = param["GA_distribution"]
    P["GA"] = n["GA"] / np.sum(n["GA"])
    PT_mask = np.array([1] * 10 + [0] * 8, dtype=bool)
    FT_mask = ~PT_mask
    P["GA"][PT_mask] = P["GA"][PT_mask] * param["PT_scale"]  # scale P[GA|PT] to match kenya level
    P_mult = (1 - np.sum(P["GA"][PT_mask])) / np.sum(P["GA"][FT_mask])
    P["GA"][FT_mask] *= P_mult

    OR["ANC"] = param["OR_preterm_ANC"]
    Preterm_rate = np.sum(P["GA"][PT_mask])  # overall preterm rate

    preterm_anc_noanc = odds_prob(OR["ANC"], Preterm_rate, P["ANC"])
    P["GA_anc"] = P["GA"].copy()
    P_scale_anc = preterm_anc_noanc[0] / Preterm_rate
    P["GA_anc"][PT_mask] *= P_scale_anc
    P_mult = (1 - preterm_anc_noanc[0]) / np.sum(P["GA_anc"][FT_mask])
    P["GA_anc"][FT_mask] *= P_mult

    P["GA_noanc"] = P["GA"].copy()
    P_scale_noanc = preterm_anc_noanc[1] / Preterm_rate
    P["GA_noanc"][PT_mask] *= P_scale_noanc
    P_mult = (1 - preterm_anc_noanc[1]) / np.sum(P["GA_noanc"][FT_mask])
    P["GA_noanc"][FT_mask] *= P_mult

    E["Preterm_LMP"] = np.zeros(3)
    E["Preterm_LMP"][0], E["Preterm_LMP"][1] = param['E_Preterm_LMP'][0], param['E_Preterm_LMP'][1]
    E["Preterm_LMP"][2] = 1 - (E["Preterm_LMP"][0] + E["Preterm_LMP"][1])
    E["Postterm_LMP"] = np.zeros(3)
    E["Postterm_LMP"][0], E["Postterm_LMP"][1] = param['E_Postterm_LMP'][0], param['E_Postterm_LMP'][1]
    E["Postterm_LMP"][2] = 1 - (E["Postterm_LMP"][0] + E["Postterm_LMP"][1])

    P_fac_noANC = 1 - P_home_noANC
    P_L45_noANC = P_fac_noANC * P_l45_fac
    P_L23_noANC = P_fac_noANC - P_L45_noANC

    # Initialize counters
    n["highrisk"] = np.zeros(4)                                           #number of high-risk pregnancies by facility levels
    n["ANC"] = np.zeros(4)                                                #number of 4+ANC by facility levels
    n["LB_L"] = np.zeros(4)                                               #number of delivery location by facility levels
    M["PT"] = np.zeros(4)
    M["Postterm"] = np.zeros(4)
    M["GA"] = np.zeros((4, GA_n))  # GA distributions by facility levels

    for k_LB in range(np.sum(LB_tot)):
        i_risk = np.random.binomial(1, P["highrisk_all"])
        i_ANC = np.random.binomial(1, P["ANC"])
        if i_ANC:
            P_GA = P["GA_anc"]
        else:
            P_GA = P["GA_noanc"]
        i_jGA = np.searchsorted(np.cumsum(P_GA), np.random.rand())  # % actual index of GA
        i_GA = GA[i_jGA]  # % actual GA

        if i_GA < 37:
            i_term_status = 0   #% 0 = preterm, 1 = full term, 2 = postterm
        elif i_GA >= 43:
            i_term_status = 2
        else:
            i_term_status = 1

        if i_ANC == 0:
            i_loc = np.random.choice([0, 1, 2], p=[P_home_noANC, P_L23_noANC, P_L45_noANC])
        else:
            # Risk stratification
            if i_risk:
                i_risk_pred = 1 if np.random.random() < Sen_traditional else 0
            else:
                i_risk_pred = 0 if np.random.random() < Spec_traditional else 1

            # Gestational age estimation
            i_preterm_pred = 1 if np.random.random() < E["Preterm_LMP"][i_term_status] else 0
            i_postterm_pred = 1 if np.random.random() < E["Postterm_LMP"][i_term_status] else 0

            if i_risk_pred or i_preterm_pred == 1 or i_postterm_pred == 1:
                i_loc = np.random.choice([0, 1, 2], p=[0, P_L23_highrisk, 1 - P_L23_highrisk])
            else:
                i_loc = np.random.choice([0, 1, 2], p=[P_home_lowrisk, (1 - P_home_lowrisk) * 0.89, (1 - P_home_lowrisk) * 0.11])

        # assume among all live births at L45, 5126/(20709 + 5126) going to L5
        P_l5_l45 = 5126 / (20709 + 5126)
        if i_loc == 2 and np.random.random() < P_l5_l45:
            i_loc = 3

        # restore results
        n["highrisk"][i_loc] += i_risk
        n["ANC"][i_loc]      += i_ANC
        n["LB_L"][i_loc]     += 1
        M["GA"][i_loc, i_jGA] += 1
        M["PT"][i_loc] += i_term_status == 0
        M["Postterm"][i_loc] += i_term_status == 2

    # Predicted outcomes
    P_home_all = n["LB_L"][0] / np.sum(LB_tot)
    P_l23_all = n["LB_L"][1] / np.sum(LB_tot)
    P_l45_all = (n["LB_L"][2] + n["LB_L"][3]) / np.sum(LB_tot)
    P_home_anc = n["ANC"][0] / np.sum(n["ANC"])
    P_l23_anc = n["ANC"][1] / np.sum(n["ANC"])
    P_l45_anc = (n["ANC"][2] + n["ANC"][3]) / np.sum(n["ANC"])
    P_preterm_fac = np.sum(M["PT"][1:]) / np.sum(n["LB_L"][1:])
    P_preterm_home = M["PT"][0] / n["LB_L"][0]
    P_preterm_l23 = M["PT"][1] / n["LB_L"][1]
    P_preterm_l45 = (M["PT"][2] + M["PT"][3]) / n["LB_L"][2:4].sum()

    return P_home_all, P_l23_all, P_l45_all, P_home_anc, P_l23_anc, P_l45_anc, P_preterm_fac, P_preterm_home, P_preterm_l23, P_preterm_l45

# %%
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# Calibration targets
target_values = {
    "P_home_all": P["home_all"],
    "P_l23_all": P["l23_all"],
    "P_l45_all": P["l45_all"],
    "P_home_anc": P["home_anc"],
}

target_weights = {
    "P_home_all": (P["home_all"], 1),   # ±1% tolerance
    "P_l23_all":  (P["l23_all"], 1),
    "P_l45_all":  (P["l45_all"], 1),
    "P_home_anc": (P["home_anc"], 1),
}

def weighted_rmse(df_results, target_weights):
    weighted_errors = []
    for metric, (target, accepted_pct) in target_weights.items():
        simulated = df_results.get(metric, 0)
        error = simulated - target
        accepted_abs_error = target * (accepted_pct / 100)
        if accepted_abs_error == 0:  # safeguard
            continue
        normalized_error = error / accepted_abs_error
        weighted_errors.append(normalized_error**2)
    return math.sqrt(sum(weighted_errors) / len(weighted_errors))

# Define parameter space
param_space = [
    Real(0.5, 1, name='P_home_noANC'),
    Real(0.1, 0.5, name='P_l45_fac'),
    Real(0.1, 0.5, name='P_home_lowrisk'),
    Real(0.1, 0.4, name='P_L23_highrisk'),
    Real(0.6, 0.8, name='Sen_traditional'),
    Real(0.6, 0.8, name='Spec_traditional')
]

# Seeds for reproducibility
total_runs = 10
seeds = np.random.default_rng(2025).integers(low=0, high=1e6, size=total_runs)

# Track RMSE history
rmse_history = []

@use_named_args(param_space)
def objective(**params):
    # --- Constraint check: Sen must be greater than Spec ---
    if params['Sen_traditional'] <= params['Spec_traditional']:
        print("\n⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.")
        objective.last_df_results = {}
        return 10.0  # Penalty loss

    results = []
    for run in range(total_runs):
        np.random.seed(seeds[run])
        res = f_ANC_LB_effect(
            params['P_home_noANC'],
            params['P_l45_fac'],
            params['P_home_lowrisk'],
            params['P_L23_highrisk'],
            params['Sen_traditional'],
            params['Spec_traditional']
        )
        results.append(res)

    # Average across runs
    mean_results = np.mean(results, axis=0)
    df_results = {
        "P_home_all": mean_results[0],
        "P_l23_all": mean_results[1],
        "P_l45_all": mean_results[2],
        "P_home_anc": mean_results[3],
    }

    # Save last results for early stopper
    objective.last_df_results = df_results

    # Weighted RMSE
    rmse = weighted_rmse(df_results, target_weights)

    # Print status
    print("\n--- Calibration Iteration ---")
    print("Parameters:")
    for k, v in params.items():
        print(f"  {k:22s}: {v:.4f}")
    print("\nTarget vs Simulated Outcomes:")
    for k in target_values:
        sim = df_results[k]
        target = target_values[k]
        error = sim - target
        rel_error = error / target
        print(f"  {k:22s} | Sim: {sim:.4f}, Target: {target:.4f}, RelErr: {rel_error:+.2%}")
    print(f"\nRMSE Loss: {rmse:.6f}")
    print("-----------------------------\n")

    return rmse

class EarlyStopper:
    def __init__(self, threshold_rmse=0.6, relative_threshold=0.05):
        self.threshold_rmse = threshold_rmse
        self.relative_threshold = relative_threshold
        self.best_loss = float('inf')
        self.best_params = None
        self.best_df_results = None

    def meets_relative_criteria(self, sim_results):
        for metric, (target, accepted_pct) in target_weights.items():
            sim = sim_results.get(metric, 0)
            rel_error = abs(sim - target) / target
            if rel_error > (accepted_pct / 100):
                return False
        return True

    def meets_param_constraints(self, param_list):
        if param_list is None:
            return False
        names = [d.name for d in param_space]
        p = dict(zip(names, param_list))
        return p['Sen_traditional'] > p['Spec_traditional']

    def __call__(self, *args, **kwargs):
        loss = objective(*args, **kwargs)
        rmse_history.append(loss)

        if loss < self.best_loss:
            self.best_loss = loss
            self.best_params = list(args[0]) if args else None
            self.best_df_results = getattr(objective, "last_df_results", {})

        if (self.best_loss < self.threshold_rmse
            and self.meets_relative_criteria(self.best_df_results)
            and self.meets_param_constraints(self.best_params)):
            print(f"\n⏹️ Early stopping: RMSE={self.best_loss:.6f} and Sen>Spec satisfied.")
            raise StopIteration

        return loss

def save_results(best_params, best_loss, rmse_history, param_space):
    param_names = [dim.name for dim in param_space]
    best_param_dict = dict(zip(param_names, best_params))
    best_param_dict["Best RMSE"] = best_loss
    df_best = pd.DataFrame([best_param_dict])
    df_best.to_csv("best_parameters_ANC_v4.csv", index=False)

    pd.DataFrame({"Iteration": range(1, len(rmse_history)+1), "RMSE": rmse_history}).to_csv("rmse_history_ANC_v4.csv", index=False)

    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(rmse_history)+1), rmse_history, marker='o')
    plt.xlabel("Iteration")
    plt.ylabel("RMSE Loss")
    plt.title("RMSE Loss Over Iterations")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("rmse_plot_ANC_v4.png")
    plt.close()

def optimize_model():
    early_stopper = EarlyStopper(threshold_rmse=0.6, relative_threshold=0.05)
    try:
        result = gp_minimize(
            func=early_stopper,
            dimensions=param_space,
            n_calls=1000,
            random_state=42,
            n_random_starts=20,
            acq_func="EI",
            verbose=True
        )
        print("\n✅ Optimization completed.")
        print("Best Parameters:", result.x)
        print("Best Loss:", result.fun)
        save_results(result.x, result.fun, rmse_history, param_space)
        return result

    except StopIteration:
        print("\n✅ Optimization stopped early.")
        print(f"Best RMSE achieved: {early_stopper.best_loss:.6f}")
        if early_stopper.best_params is not None:
            print("Best Parameters:")
            for name, val in zip([d.name for d in param_space], early_stopper.best_params):
                print(f"  {name:22s}: {val:.4f}")
            save_results(early_stopper.best_params, early_stopper.best_loss, rmse_history, param_space)
        return None

if __name__ == "__main__":
    optimize_model()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8983
#   P_l45_fac             : 0.1734
#   P_home_lowrisk        : 0.4119
#   P_L23_highrisk        : 0.2791
#   Sen_traditional       : 0.6892
#   Spec_traditional      : 0.6200
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4917, Target: 0.3500, RelErr: +40.48%
#   P_l23_all              | Sim: 0.2497, Target: 0.3920, RelErr: -36.31%
#   P_l45_all              | Sim: 0.2587, Target: 0.2580, RelErr: +0.26%
#   P_home_anc             | Sim: 0.1709, Target: 0.0700, RelErr: +144.09%
#
# RMSE Loss: 77.003318
# -----------------------------
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 6.6797
# Function value obtained: 77.0033
# Current minimum: 77.0033
# Iteration No: 2 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 10.0000
# Iteration No: 3 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9693
#   P_l45_fac             : 0.1003
#   P_home_lowrisk        : 0.4969
#   P_L23_highrisk        : 0.2852
#   Sen_traditional       : 0.7223
#   Spec_traditional      : 0.6014
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5378, Target: 0.3500, RelErr: +53.67%
#   P_l23_all              | Sim: 0.2074, Target: 0.3920, RelErr: -47.09%
#   P_l45_all              | Sim: 0.2548, Target: 0.2580, RelErr: -1.26%
#   P_home_anc             | Sim: 0.1976, Target: 0.0700, RelErr: +182.22%
#
# RMSE Loss: 97.857869
# -----------------------------
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 6.6200
# Function value obtained: 97.8579
# Current minimum: 10.0000
# Iteration No: 4 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5115
#   P_l45_fac             : 0.3099
#   P_home_lowrisk        : 0.2599
#   P_L23_highrisk        : 0.1140
#   Sen_traditional       : 0.7948
#   Spec_traditional      : 0.6466
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2860, Target: 0.3500, RelErr: -18.30%
#   P_l23_all              | Sim: 0.3358, Target: 0.3920, RelErr: -14.35%
#   P_l45_all              | Sim: 0.3783, Target: 0.2580, RelErr: +46.62%
#   P_home_anc             | Sim: 0.1073, Target: 0.0700, RelErr: +53.31%
#
# RMSE Loss: 37.269361
# -----------------------------
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 6.5832
# Function value obtained: 37.2694
# Current minimum: 10.0000
# Iteration No: 5 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 10.0000
# Iteration No: 6 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8402
#   P_l45_fac             : 0.2802
#   P_home_lowrisk        : 0.1053
#   P_L23_highrisk        : 0.3827
#   Sen_traditional       : 0.7127
#   Spec_traditional      : 0.6771
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3964, Target: 0.3500, RelErr: +13.26%
#   P_l23_all              | Sim: 0.3673, Target: 0.3920, RelErr: -6.30%
#   P_l45_all              | Sim: 0.2363, Target: 0.2580, RelErr: -8.41%
#   P_home_anc             | Sim: 0.0475, Target: 0.0700, RelErr: -32.21%
#
# RMSE Loss: 18.192522
# -----------------------------
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 6.6164
# Function value obtained: 18.1925
# Current minimum: 10.0000
# Iteration No: 7 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 10.0000
# Iteration No: 8 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5867
#   P_l45_fac             : 0.2564
#   P_home_lowrisk        : 0.1729
#   P_L23_highrisk        : 0.3266
#   Sen_traditional       : 0.6850
#   Spec_traditional      : 0.6416
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3006, Target: 0.3500, RelErr: -14.11%
#   P_l23_all              | Sim: 0.4166, Target: 0.3920, RelErr: +6.27%
#   P_l45_all              | Sim: 0.2828, Target: 0.2580, RelErr: +9.62%
#   P_home_anc             | Sim: 0.0749, Target: 0.0700, RelErr: +6.98%
#
# RMSE Loss: 9.742500
# -----------------------------
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 6.7232
# Function value obtained: 9.7425
# Current minimum: 9.7425
# Iteration No: 9 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 10 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8636
#   P_l45_fac             : 0.2306
#   P_home_lowrisk        : 0.3282
#   P_L23_highrisk        : 0.2563
#   Sen_traditional       : 0.7922
#   Spec_traditional      : 0.7689
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4687, Target: 0.3500, RelErr: +33.92%
#   P_l23_all              | Sim: 0.2814, Target: 0.3920, RelErr: -28.22%
#   P_l45_all              | Sim: 0.2499, Target: 0.2580, RelErr: -3.13%
#   P_home_anc             | Sim: 0.1580, Target: 0.0700, RelErr: +125.65%
#
# RMSE Loss: 66.605831
# -----------------------------
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 6.6685
# Function value obtained: 66.6058
# Current minimum: 9.7425
# Iteration No: 11 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8737
#   P_l45_fac             : 0.3159
#   P_home_lowrisk        : 0.3347
#   P_L23_highrisk        : 0.3896
#   Sen_traditional       : 0.7214
#   Spec_traditional      : 0.6552
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4655, Target: 0.3500, RelErr: +33.01%
#   P_l23_all              | Sim: 0.3045, Target: 0.3920, RelErr: -22.32%
#   P_l45_all              | Sim: 0.2299, Target: 0.2580, RelErr: -10.87%
#   P_home_anc             | Sim: 0.1442, Target: 0.0700, RelErr: +106.06%
#
# RMSE Loss: 56.909019
# -----------------------------
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 7.0202
# Function value obtained: 56.9090
# Current minimum: 9.7425
# Iteration No: 12 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6481
#   P_l45_fac             : 0.1661
#   P_home_lowrisk        : 0.1063
#   P_L23_highrisk        : 0.2270
#   Sen_traditional       : 0.6790
#   Spec_traditional      : 0.6587
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3117, Target: 0.3500, RelErr: -10.95%
#   P_l23_all              | Sim: 0.3966, Target: 0.3920, RelErr: +1.17%
#   P_l45_all              | Sim: 0.2917, Target: 0.2580, RelErr: +13.08%
#   P_home_anc             | Sim: 0.0471, Target: 0.0700, RelErr: -32.69%
#
# RMSE Loss: 18.446893
# -----------------------------
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 6.9224
# Function value obtained: 18.4469
# Current minimum: 9.7425
# Iteration No: 13 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 0.0004
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 14 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 15 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8344
#   P_l45_fac             : 0.3664
#   P_home_lowrisk        : 0.3365
#   P_L23_highrisk        : 0.1824
#   Sen_traditional       : 0.7122
#   Spec_traditional      : 0.6766
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4512, Target: 0.3500, RelErr: +28.91%
#   P_l23_all              | Sim: 0.2487, Target: 0.3920, RelErr: -36.56%
#   P_l45_all              | Sim: 0.3001, Target: 0.2580, RelErr: +16.33%
#   P_home_anc             | Sim: 0.1499, Target: 0.0700, RelErr: +114.20%
#
# RMSE Loss: 62.211222
# -----------------------------
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 6.7768
# Function value obtained: 62.2112
# Current minimum: 9.7425
# Iteration No: 16 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9859
#   P_l45_fac             : 0.4396
#   P_home_lowrisk        : 0.3887
#   P_L23_highrisk        : 0.1708
#   Sen_traditional       : 0.6512
#   Spec_traditional      : 0.6081
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5256, Target: 0.3500, RelErr: +50.16%
#   P_l23_all              | Sim: 0.1850, Target: 0.3920, RelErr: -52.80%
#   P_l45_all              | Sim: 0.2894, Target: 0.2580, RelErr: +12.18%
#   P_home_anc             | Sim: 0.1621, Target: 0.0700, RelErr: +131.60%
#
# RMSE Loss: 75.449552
# -----------------------------
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 6.7180
# Function value obtained: 75.4496
# Current minimum: 9.7425
# Iteration No: 17 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8553
#   P_l45_fac             : 0.1444
#   P_home_lowrisk        : 0.2757
#   P_L23_highrisk        : 0.1605
#   Sen_traditional       : 0.7792
#   Spec_traditional      : 0.6951
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4458, Target: 0.3500, RelErr: +27.36%
#   P_l23_all              | Sim: 0.2626, Target: 0.3920, RelErr: -33.01%
#   P_l45_all              | Sim: 0.2916, Target: 0.2580, RelErr: +13.03%
#   P_home_anc             | Sim: 0.1220, Target: 0.0700, RelErr: +74.29%
#
# RMSE Loss: 43.377667
# -----------------------------
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 6.7871
# Function value obtained: 43.3777
# Current minimum: 9.7425
# Iteration No: 18 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7816
#   P_l45_fac             : 0.3782
#   P_home_lowrisk        : 0.1557
#   P_L23_highrisk        : 0.2813
#   Sen_traditional       : 0.7080
#   Spec_traditional      : 0.6406
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3814, Target: 0.3500, RelErr: +8.97%
#   P_l23_all              | Sim: 0.3288, Target: 0.3920, RelErr: -16.11%
#   P_l45_all              | Sim: 0.2898, Target: 0.2580, RelErr: +12.31%
#   P_home_anc             | Sim: 0.0665, Target: 0.0700, RelErr: -5.02%
#
# RMSE Loss: 11.366820
# -----------------------------
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 6.8127
# Function value obtained: 11.3668
# Current minimum: 9.7425
# Iteration No: 19 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9714
#   P_l45_fac             : 0.3395
#   P_home_lowrisk        : 0.3779
#   P_L23_highrisk        : 0.3641
#   Sen_traditional       : 0.7249
#   Spec_traditional      : 0.6591
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5188, Target: 0.3500, RelErr: +48.23%
#   P_l23_all              | Sim: 0.2577, Target: 0.3920, RelErr: -34.26%
#   P_l45_all              | Sim: 0.2235, Target: 0.2580, RelErr: -13.37%
#   P_home_anc             | Sim: 0.1629, Target: 0.0700, RelErr: +132.78%
#
# RMSE Loss: 72.989344
# -----------------------------
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 6.8213
# Function value obtained: 72.9893
# Current minimum: 9.7425
# Iteration No: 20 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5527
#   P_l45_fac             : 0.2826
#   P_home_lowrisk        : 0.1874
#   P_L23_highrisk        : 0.2250
#   Sen_traditional       : 0.7767
#   Spec_traditional      : 0.6649
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2889, Target: 0.3500, RelErr: -17.45%
#   P_l23_all              | Sim: 0.3851, Target: 0.3920, RelErr: -1.77%
#   P_l45_all              | Sim: 0.3260, Target: 0.2580, RelErr: +26.37%
#   P_home_anc             | Sim: 0.0802, Target: 0.0700, RelErr: +14.60%
#
# RMSE Loss: 17.438248
# -----------------------------
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 6.8648
# Function value obtained: 17.4382
# Current minimum: 9.7425
# Iteration No: 21 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.1536
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 22 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.1748
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 23 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.1299
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 24 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.1600
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 25 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.1623
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7268
#   Spec_traditional      : 0.6256
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2437, Target: 0.3500, RelErr: -30.37%
#   P_l23_all              | Sim: 0.5001, Target: 0.3920, RelErr: +27.57%
#   P_l45_all              | Sim: 0.2562, Target: 0.2580, RelErr: -0.68%
#   P_home_anc             | Sim: 0.0417, Target: 0.0700, RelErr: -40.38%
#
# RMSE Loss: 28.778469
# -----------------------------
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 6.9870
# Function value obtained: 28.7785
# Current minimum: 9.7425
# Iteration No: 26 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.1773
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 27 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.3835
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 28 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.1739
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 29 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.1691
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 30 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7973
#   P_l45_fac             : 0.3788
#   P_home_lowrisk        : 0.3118
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7194
#   Spec_traditional      : 0.6068
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4216, Target: 0.3500, RelErr: +20.44%
#   P_l23_all              | Sim: 0.3271, Target: 0.3920, RelErr: -16.56%
#   P_l45_all              | Sim: 0.2514, Target: 0.2580, RelErr: -2.58%
#   P_home_anc             | Sim: 0.1259, Target: 0.0700, RelErr: +79.90%
#
# RMSE Loss: 42.080454
# -----------------------------
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 7.5157
# Function value obtained: 42.0805
# Current minimum: 9.7425
# Iteration No: 31 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 0.2561
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 32 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 0.2957
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 33 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.2611
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 34 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.4052
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 35 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.2717
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 36 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.3005
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 37 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.2776
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 38 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.2964
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 39 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.2935
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 40 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.2418
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 41 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 0.2668
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 42 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.2669
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 43 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.2762
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 44 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 0.2130
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 45 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.3436
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 46 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.3051
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 47 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.2835
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 48 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7893
#   Spec_traditional      : 0.7026
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2462, Target: 0.3500, RelErr: -29.67%
#   P_l23_all              | Sim: 0.4325, Target: 0.3920, RelErr: +10.33%
#   P_l45_all              | Sim: 0.3213, Target: 0.2580, RelErr: +24.55%
#   P_home_anc             | Sim: 0.0447, Target: 0.0700, RelErr: -36.10%
#
# RMSE Loss: 26.892408
# -----------------------------
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 7.0161
# Function value obtained: 26.8924
# Current minimum: 9.7425
# Iteration No: 49 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 0.3290
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 50 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 0.3267
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 51 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.2702
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 52 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6750
#   P_l45_fac             : 0.1323
#   P_home_lowrisk        : 0.1297
#   P_L23_highrisk        : 0.3355
#   Sen_traditional       : 0.7828
#   Spec_traditional      : 0.6785
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3288, Target: 0.3500, RelErr: -6.06%
#   P_l23_all              | Sim: 0.4179, Target: 0.3920, RelErr: +6.61%
#   P_l45_all              | Sim: 0.2533, Target: 0.2580, RelErr: -1.82%
#   P_home_anc             | Sim: 0.0570, Target: 0.0700, RelErr: -18.55%
#
# RMSE Loss: 10.343568
# -----------------------------
#
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 7.4739
# Function value obtained: 10.3436
# Current minimum: 9.7425
# Iteration No: 53 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7509
#   P_l45_fac             : 0.3994
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.3702
#   Sen_traditional       : 0.6874
#   Spec_traditional      : 0.6802
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3560, Target: 0.3500, RelErr: +1.72%
#   P_l23_all              | Sim: 0.3820, Target: 0.3920, RelErr: -2.56%
#   P_l45_all              | Sim: 0.2620, Target: 0.2580, RelErr: +1.55%
#   P_home_anc             | Sim: 0.0460, Target: 0.0700, RelErr: -34.33%
#
# RMSE Loss: 17.253846
# -----------------------------
#
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 7.2532
# Function value obtained: 17.2538
# Current minimum: 9.7425
# Iteration No: 54 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.3756
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 55 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.4149
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 56 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7792
#   Spec_traditional      : 0.6576
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4640, Target: 0.3500, RelErr: +32.57%
#   P_l23_all              | Sim: 0.3177, Target: 0.3920, RelErr: -18.96%
#   P_l45_all              | Sim: 0.2183, Target: 0.2580, RelErr: -15.38%
#   P_home_anc             | Sim: 0.0425, Target: 0.0700, RelErr: -39.23%
#
# RMSE Loss: 28.261836
# -----------------------------
#
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 7.0640
# Function value obtained: 28.2618
# Current minimum: 9.7425
# Iteration No: 57 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.3281
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 58 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9785
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1573
#   P_L23_highrisk        : 0.3779
#   Sen_traditional       : 0.7649
#   Spec_traditional      : 0.7564
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4727, Target: 0.3500, RelErr: +35.04%
#   P_l23_all              | Sim: 0.3194, Target: 0.3920, RelErr: -18.51%
#   P_l45_all              | Sim: 0.2079, Target: 0.2580, RelErr: -19.41%
#   P_home_anc             | Sim: 0.0754, Target: 0.0700, RelErr: +7.76%
#
# RMSE Loss: 22.404895
# -----------------------------
#
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 7.0112
# Function value obtained: 22.4049
# Current minimum: 9.7425
# Iteration No: 59 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.3180
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 60 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.2881
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 61 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.2940
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 62 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.3344
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 63 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 0.3484
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 64 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.3723
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 65 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.3161
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 66 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.4133
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 67 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 0.3475
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 68 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.3116
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 69 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.3962
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 70 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.3812
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 71 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 0.4255
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 72 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.4145
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 73 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.3885
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 74 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 0.3703
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 75 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 0.4838
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 76 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 0.3687
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 77 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 0.3578
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 78 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.2644
#   Sen_traditional       : 0.7860
#   Spec_traditional      : 0.6615
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2439, Target: 0.3500, RelErr: -30.31%
#   P_l23_all              | Sim: 0.4722, Target: 0.3920, RelErr: +20.45%
#   P_l45_all              | Sim: 0.2839, Target: 0.2580, RelErr: +10.04%
#   P_home_anc             | Sim: 0.0426, Target: 0.0700, RelErr: -39.20%
#
# RMSE Loss: 27.269248
# -----------------------------
#
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 7.1999
# Function value obtained: 27.2692
# Current minimum: 9.7425
# Iteration No: 79 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1365
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7665
#   Spec_traditional      : 0.6842
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4737, Target: 0.3500, RelErr: +35.35%
#   P_l23_all              | Sim: 0.3137, Target: 0.3920, RelErr: -19.98%
#   P_l45_all              | Sim: 0.2126, Target: 0.2580, RelErr: -17.59%
#   P_home_anc             | Sim: 0.0604, Target: 0.0700, RelErr: -13.76%
#
# RMSE Loss: 23.170051
# -----------------------------
#
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 7.1193
# Function value obtained: 23.1701
# Current minimum: 9.7425
# Iteration No: 80 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1576
#   P_L23_highrisk        : 0.3990
#   Sen_traditional       : 0.7922
#   Spec_traditional      : 0.6604
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2575, Target: 0.3500, RelErr: -26.41%
#   P_l23_all              | Sim: 0.5030, Target: 0.3920, RelErr: +28.32%
#   P_l45_all              | Sim: 0.2394, Target: 0.2580, RelErr: -7.19%
#   P_home_anc             | Sim: 0.0667, Target: 0.0700, RelErr: -4.76%
#
# RMSE Loss: 19.837962
# -----------------------------
#
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 6.9489
# Function value obtained: 19.8380
# Current minimum: 9.7425
# Iteration No: 81 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 0.4263
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 82 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.2165
#   P_home_lowrisk        : 0.1581
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6955
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2564, Target: 0.3500, RelErr: -26.73%
#   P_l23_all              | Sim: 0.4749, Target: 0.3920, RelErr: +21.14%
#   P_l45_all              | Sim: 0.2687, Target: 0.2580, RelErr: +4.14%
#   P_home_anc             | Sim: 0.0640, Target: 0.0700, RelErr: -8.50%
#
# RMSE Loss: 17.685734
# -----------------------------
#
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 6.9905
# Function value obtained: 17.6857
# Current minimum: 9.7425
# Iteration No: 83 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 0.4262
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 84 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 0.4378
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 85 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 0.4225
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 86 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 0.4362
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 87 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 0.4738
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 88 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 0.4727
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 89 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 0.4020
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 90 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 0.4775
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 91 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 0.4372
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 92 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 0.5088
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 93 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 0.5177
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 94 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 0.5347
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 95 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1382
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6858
#   Spec_traditional      : 0.6278
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4733, Target: 0.3500, RelErr: +35.23%
#   P_l23_all              | Sim: 0.3098, Target: 0.3920, RelErr: -20.98%
#   P_l45_all              | Sim: 0.2170, Target: 0.2580, RelErr: -15.91%
#   P_home_anc             | Sim: 0.0588, Target: 0.0700, RelErr: -15.96%
#
# RMSE Loss: 23.392150
# -----------------------------
#
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 7.0836
# Function value obtained: 23.3922
# Current minimum: 9.7425
# Iteration No: 96 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 0.4926
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 97 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1833
#   P_L23_highrisk        : 0.3603
#   Sen_traditional       : 0.6884
#   Spec_traditional      : 0.6663
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2655, Target: 0.3500, RelErr: -24.13%
#   P_l23_all              | Sim: 0.4911, Target: 0.3920, RelErr: +25.29%
#   P_l45_all              | Sim: 0.2433, Target: 0.2580, RelErr: -5.69%
#   P_home_anc             | Sim: 0.0813, Target: 0.0700, RelErr: +16.12%
#
# RMSE Loss: 19.455430
# -----------------------------
#
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 7.0576
# Function value obtained: 19.4554
# Current minimum: 9.7425
# Iteration No: 98 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.2303
#   P_home_lowrisk        : 0.1530
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6790
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4771, Target: 0.3500, RelErr: +36.30%
#   P_l23_all              | Sim: 0.3081, Target: 0.3920, RelErr: -21.40%
#   P_l45_all              | Sim: 0.2148, Target: 0.2580, RelErr: -16.73%
#   P_home_anc             | Sim: 0.0662, Target: 0.0700, RelErr: -5.47%
#
# RMSE Loss: 22.833725
# -----------------------------
#
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 7.1258
# Function value obtained: 22.8337
# Current minimum: 9.7425
# Iteration No: 99 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 0.5283
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 100 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 0.5329
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 101 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 101 ended. Search finished for the next optimal point.
# Time taken: 0.5040
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 102 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 102 ended. Search finished for the next optimal point.
# Time taken: 0.5226
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 103 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 103 ended. Search finished for the next optimal point.
# Time taken: 0.4916
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 104 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 104 ended. Search finished for the next optimal point.
# Time taken: 0.5066
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 105 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 105 ended. Search finished for the next optimal point.
# Time taken: 0.5640
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 106 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 106 ended. Search finished for the next optimal point.
# Time taken: 0.5202
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 107 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 107 ended. Search finished for the next optimal point.
# Time taken: 0.5599
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 108 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 108 ended. Search finished for the next optimal point.
# Time taken: 0.5607
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 109 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 109 ended. Search finished for the next optimal point.
# Time taken: 0.5664
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 110 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 110 ended. Search finished for the next optimal point.
# Time taken: 0.5414
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 111 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 111 ended. Search finished for the next optimal point.
# Time taken: 0.6471
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 112 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8453
#   P_l45_fac             : 0.3597
#   P_home_lowrisk        : 0.3131
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6841
#   Spec_traditional      : 0.6817
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4514, Target: 0.3500, RelErr: +28.97%
#   P_l23_all              | Sim: 0.3207, Target: 0.3920, RelErr: -18.18%
#   P_l45_all              | Sim: 0.2278, Target: 0.2580, RelErr: -11.69%
#   P_home_anc             | Sim: 0.1422, Target: 0.0700, RelErr: +103.10%
#
# RMSE Loss: 54.627392
# -----------------------------
#
# Iteration No: 112 ended. Search finished for the next optimal point.
# Time taken: 7.2856
# Function value obtained: 54.6274
# Current minimum: 9.7425
# Iteration No: 113 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 113 ended. Search finished for the next optimal point.
# Time taken: 0.5734
# Function value obtained: 10.0000
# Current minimum: 9.7425
# Iteration No: 114 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# ...
# Current minimum: 2.2951
# Iteration No: 965 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7081
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1811
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7709
#   Spec_traditional      : 0.6117
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3520, Target: 0.3500, RelErr: +0.57%
#   P_l23_all              | Sim: 0.4122, Target: 0.3920, RelErr: +5.14%
#   P_l45_all              | Sim: 0.2358, Target: 0.2580, RelErr: -8.59%
#   P_home_anc             | Sim: 0.0717, Target: 0.0700, RelErr: +2.37%
#
# RMSE Loss: 5.152559
# -----------------------------
#
# Iteration No: 965 ended. Search finished for the next optimal point.
# Time taken: 43.0088
# Function value obtained: 5.1526
# Current minimum: 2.2951
# Iteration No: 966 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 966 ended. Search finished for the next optimal point.
# Time taken: 35.2115
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 967 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 967 ended. Search finished for the next optimal point.
# Time taken: 33.7274
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 968 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 968 ended. Search finished for the next optimal point.
# Time taken: 33.6066
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 969 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 969 ended. Search finished for the next optimal point.
# Time taken: 39.0806
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 970 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 970 ended. Search finished for the next optimal point.
# Time taken: 38.8109
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 971 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 971 ended. Search finished for the next optimal point.
# Time taken: 35.3630
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 972 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6827
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1565
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7710
#   Spec_traditional      : 0.7114
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3407, Target: 0.3500, RelErr: -2.65%
#   P_l23_all              | Sim: 0.3819, Target: 0.3920, RelErr: -2.57%
#   P_l45_all              | Sim: 0.2773, Target: 0.2580, RelErr: +7.49%
#   P_home_anc             | Sim: 0.0709, Target: 0.0700, RelErr: +1.34%
#
# RMSE Loss: 4.226697
# -----------------------------
#
# Iteration No: 972 ended. Search finished for the next optimal point.
# Time taken: 43.5256
# Function value obtained: 4.2267
# Current minimum: 2.2951
# Iteration No: 973 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7102
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1493
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7790
#   Spec_traditional      : 0.7179
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3512, Target: 0.3500, RelErr: +0.35%
#   P_l23_all              | Sim: 0.3779, Target: 0.3920, RelErr: -3.59%
#   P_l45_all              | Sim: 0.2709, Target: 0.2580, RelErr: +4.98%
#   P_home_anc             | Sim: 0.0683, Target: 0.0700, RelErr: -2.47%
#
# RMSE Loss: 3.314415
# -----------------------------
#
# Iteration No: 973 ended. Search finished for the next optimal point.
# Time taken: 45.3819
# Function value obtained: 3.3144
# Current minimum: 2.2951
# Iteration No: 974 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6714
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1386
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7712
#   Spec_traditional      : 0.7150
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3314, Target: 0.3500, RelErr: -5.31%
#   P_l23_all              | Sim: 0.3888, Target: 0.3920, RelErr: -0.83%
#   P_l45_all              | Sim: 0.2798, Target: 0.2580, RelErr: +8.46%
#   P_home_anc             | Sim: 0.0634, Target: 0.0700, RelErr: -9.42%
#
# RMSE Loss: 6.876126
# -----------------------------
#
# Iteration No: 974 ended. Search finished for the next optimal point.
# Time taken: 44.3364
# Function value obtained: 6.8761
# Current minimum: 2.2951
# Iteration No: 975 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 975 ended. Search finished for the next optimal point.
# Time taken: 38.7242
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 976 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 976 ended. Search finished for the next optimal point.
# Time taken: 33.8866
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 977 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 977 ended. Search finished for the next optimal point.
# Time taken: 38.1455
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 978 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 978 ended. Search finished for the next optimal point.
# Time taken: 35.9644
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 979 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 979 ended. Search finished for the next optimal point.
# Time taken: 39.0204
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 980 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 980 ended. Search finished for the next optimal point.
# Time taken: 39.2518
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 981 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7432
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1617
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7859
#   Spec_traditional      : 0.7193
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3689, Target: 0.3500, RelErr: +5.41%
#   P_l23_all              | Sim: 0.3679, Target: 0.3920, RelErr: -6.15%
#   P_l45_all              | Sim: 0.2632, Target: 0.2580, RelErr: +2.01%
#   P_home_anc             | Sim: 0.0738, Target: 0.0700, RelErr: +5.40%
#
# RMSE Loss: 5.008072
# -----------------------------
#
# Iteration No: 981 ended. Search finished for the next optimal point.
# Time taken: 45.4729
# Function value obtained: 5.0081
# Current minimum: 2.2951
# Iteration No: 982 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 982 ended. Search finished for the next optimal point.
# Time taken: 41.0136
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 983 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 983 ended. Search finished for the next optimal point.
# Time taken: 36.4342
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 984 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5584
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1418
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7445
#   Spec_traditional      : 0.7197
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2832, Target: 0.3500, RelErr: -19.09%
#   P_l23_all              | Sim: 0.4146, Target: 0.3920, RelErr: +5.76%
#   P_l45_all              | Sim: 0.3023, Target: 0.2580, RelErr: +17.15%
#   P_home_anc             | Sim: 0.0659, Target: 0.0700, RelErr: -5.88%
#
# RMSE Loss: 13.476285
# -----------------------------
#
# Iteration No: 984 ended. Search finished for the next optimal point.
# Time taken: 44.2859
# Function value obtained: 13.4763
# Current minimum: 2.2951
# Iteration No: 985 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 985 ended. Search finished for the next optimal point.
# Time taken: 37.7753
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 986 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 986 ended. Search finished for the next optimal point.
# Time taken: 37.2592
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 987 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 987 ended. Search finished for the next optimal point.
# Time taken: 40.8917
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 988 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7144
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1903
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3556, Target: 0.3500, RelErr: +1.59%
#   P_l23_all              | Sim: 0.4056, Target: 0.3920, RelErr: +3.46%
#   P_l45_all              | Sim: 0.2389, Target: 0.2580, RelErr: -7.41%
#   P_home_anc             | Sim: 0.0730, Target: 0.0700, RelErr: +4.25%
#
# RMSE Loss: 4.676724
# -----------------------------
#
# Iteration No: 988 ended. Search finished for the next optimal point.
# Time taken: 48.0116
# Function value obtained: 4.6767
# Current minimum: 2.2951
# Iteration No: 989 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 989 ended. Search finished for the next optimal point.
# Time taken: 38.6387
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 990 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 990 ended. Search finished for the next optimal point.
# Time taken: 42.1342
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 991 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 991 ended. Search finished for the next optimal point.
# Time taken: 38.3389
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 992 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7608
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1642
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7802
#   Spec_traditional      : 0.6828
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3752, Target: 0.3500, RelErr: +7.20%
#   P_l23_all              | Sim: 0.3598, Target: 0.3920, RelErr: -8.21%
#   P_l45_all              | Sim: 0.2650, Target: 0.2580, RelErr: +2.71%
#   P_home_anc             | Sim: 0.0719, Target: 0.0700, RelErr: +2.73%
#
# RMSE Loss: 5.791924
# -----------------------------
#
# Iteration No: 992 ended. Search finished for the next optimal point.
# Time taken: 44.9977
# Function value obtained: 5.7919
# Current minimum: 2.2951
# Iteration No: 993 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7546
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1675
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7743
#   Spec_traditional      : 0.6065
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3692, Target: 0.3500, RelErr: +5.48%
#   P_l23_all              | Sim: 0.3958, Target: 0.3920, RelErr: +0.96%
#   P_l45_all              | Sim: 0.2351, Target: 0.2580, RelErr: -8.89%
#   P_home_anc             | Sim: 0.0660, Target: 0.0700, RelErr: -5.75%
#
# RMSE Loss: 5.979257
# -----------------------------
#
# Iteration No: 993 ended. Search finished for the next optimal point.
# Time taken: 47.8669
# Function value obtained: 5.9793
# Current minimum: 2.2951
# Iteration No: 994 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7219
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1416
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7880
#   Spec_traditional      : 0.7295
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3545, Target: 0.3500, RelErr: +1.30%
#   P_l23_all              | Sim: 0.3783, Target: 0.3920, RelErr: -3.50%
#   P_l45_all              | Sim: 0.2672, Target: 0.2580, RelErr: +3.55%
#   P_home_anc             | Sim: 0.0657, Target: 0.0700, RelErr: -6.21%
#
# RMSE Loss: 4.036350
# -----------------------------
#
# Iteration No: 994 ended. Search finished for the next optimal point.
# Time taken: 47.4740
# Function value obtained: 4.0364
# Current minimum: 2.2951
# Iteration No: 995 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 995 ended. Search finished for the next optimal point.
# Time taken: 39.7342
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 996 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 996 ended. Search finished for the next optimal point.
# Time taken: 40.7297
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 997 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 997 ended. Search finished for the next optimal point.
# Time taken: 42.2091
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 998 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 998 ended. Search finished for the next optimal point.
# Time taken: 39.7181
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 999 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 999 ended. Search finished for the next optimal point.
# Time taken: 149.5864
# Function value obtained: 10.0000
# Current minimum: 2.2951
# Iteration No: 1000 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 1000 ended. Search finished for the next optimal point.
# Time taken: 935.0357
# Function value obtained: 10.0000
# Current minimum: 2.2951
#
# ✅ Optimization completed.
# Best Parameters: [0.6912241105663863, 0.17439872220451108, 0.17373731125804384, 0.3750854942082509, 0.7862156803567945, 0.6]
# Best Loss: 2.2950747529396693
