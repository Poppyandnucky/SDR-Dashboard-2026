# %%
import random
import numpy as np
import streamlit as st
import math
from parameters import get_parameters
from global_func import odds_prob


# Initialize parameters
P = {}  # dict to restore probabilities
n = {}  # dict to restore counts
E = {}  # dict to restore effects
S = {}  # dict to restore supplies and capacities
OR = {}  # dict to restore odds ratio
M = {}  # dict to restore maternal outcomes

#known parameters
param = get_parameters()
LB_tot = np.array([23729, 18196, 20709, 5126])
P["highrisk_all"] = 0.26                                              # high risk pregnancies among all live births
P["ANC"] = 0.56

# Calibration criteria
P["home_all"] = param["home_all_target"]
P["l23_all"] = param["l23_all_target"]
P["l45_all"] = param["l45_all_target"]
P["home_anc"] = param["home_anc_target"]

# %%
random.seed(0)
def f_ANC_LB_effect(P_home_noANC, P_l45_fac, P_home_lowrisk, P_L23_highrisk, Sen_traditional, Spec_traditional):
    # Initialize parameters

    GA = param['GA_sequence']
    GA_n = len(GA)
    n["GA"] = param["GA_distribution"]
    P["GA"] = n["GA"] / np.sum(n["GA"])
    PT_mask = np.array([1] * 10 + [0] * 8, dtype=bool)
    FT_mask = ~PT_mask
    P["GA"][PT_mask] = P["GA"][PT_mask] * param["PT_scale"]  # scale P[GA|PT] to match kenya level
    P_mult = (1 - np.sum(P["GA"][PT_mask])) / np.sum(P["GA"][FT_mask])
    P["GA"][FT_mask] *= P_mult

    OR["ANC"] = param["OR_preterm_ANC"]
    Preterm_rate = np.sum(P["GA"][PT_mask])  # overall preterm rate

    preterm_anc_noanc = odds_prob(OR["ANC"], Preterm_rate, P["ANC"])
    P["GA_anc"] = P["GA"].copy()
    P_scale_anc = preterm_anc_noanc[0] / Preterm_rate
    P["GA_anc"][PT_mask] *= P_scale_anc
    P_mult = (1 - preterm_anc_noanc[0]) / np.sum(P["GA_anc"][FT_mask])
    P["GA_anc"][FT_mask] *= P_mult

    P["GA_noanc"] = P["GA"].copy()
    P_scale_noanc = preterm_anc_noanc[1] / Preterm_rate
    P["GA_noanc"][PT_mask] *= P_scale_noanc
    P_mult = (1 - preterm_anc_noanc[1]) / np.sum(P["GA_noanc"][FT_mask])
    P["GA_noanc"][FT_mask] *= P_mult

    E["Preterm_LMP"] = np.zeros(3)
    E["Preterm_LMP"][0], E["Preterm_LMP"][1] = param['E_Preterm_LMP'][0], param['E_Preterm_LMP'][1]
    E["Preterm_LMP"][2] = 1 - (E["Preterm_LMP"][0] + E["Preterm_LMP"][1])
    E["Postterm_LMP"] = np.zeros(3)
    E["Postterm_LMP"][0], E["Postterm_LMP"][1] = param['E_Postterm_LMP'][0], param['E_Postterm_LMP'][1]
    E["Postterm_LMP"][2] = 1 - (E["Postterm_LMP"][0] + E["Postterm_LMP"][1])

    P_fac_noANC = 1 - P_home_noANC
    P_L45_noANC = P_fac_noANC * P_l45_fac
    P_L23_noANC = P_fac_noANC - P_L45_noANC

    # Initialize counters
    n["highrisk"] = np.zeros(4)                                           #number of high-risk pregnancies by facility levels
    n["ANC"] = np.zeros(4)                                                #number of 4+ANC by facility levels
    n["LB_L"] = np.zeros(4)                                               #number of delivery location by facility levels
    M["PT"] = np.zeros(4)
    M["Postterm"] = np.zeros(4)
    M["GA"] = np.zeros((4, GA_n))  # GA distributions by facility levels

    for k_LB in range(np.sum(LB_tot)):
        i_risk = np.random.binomial(1, P["highrisk_all"])
        i_ANC = np.random.binomial(1, P["ANC"])
        if i_ANC:
            P_GA = P["GA_anc"]
        else:
            P_GA = P["GA_noanc"]
        i_jGA = np.searchsorted(np.cumsum(P_GA), np.random.rand())  # % actual index of GA
        i_GA = GA[i_jGA]  # % actual GA

        if i_GA < 37:
            i_term_status = 0   #% 0 = preterm, 1 = full term, 2 = postterm
        elif i_GA >= 43:
            i_term_status = 2
        else:
            i_term_status = 1

        if i_ANC == 0:
            i_loc = np.random.choice([0, 1, 2], p=[P_home_noANC, P_L23_noANC, P_L45_noANC])
        else:
            # Risk stratification
            if i_risk:
                i_risk_pred = 1 if np.random.random() < Sen_traditional else 0
            else:
                i_risk_pred = 0 if np.random.random() < Spec_traditional else 1

            # Gestational age estimation
            i_preterm_pred = 1 if np.random.random() < E["Preterm_LMP"][i_term_status] else 0
            i_postterm_pred = 1 if np.random.random() < E["Postterm_LMP"][i_term_status] else 0

            if i_risk_pred or i_preterm_pred == 1 or i_postterm_pred == 1:
                i_loc = np.random.choice([0, 1, 2], p=[0, P_L23_highrisk, 1 - P_L23_highrisk])
            else:
                i_loc = np.random.choice([0, 1, 2], p=[P_home_lowrisk, (1 - P_home_lowrisk) * 0.89, (1 - P_home_lowrisk) * 0.11])

        # assume among all live births at L45, 5126/(20709 + 5126) going to L5
        P_l5_l45 = 5126 / (20709 + 5126)
        if i_loc == 2 and np.random.random() < P_l5_l45:
            i_loc = 3

        # restore results
        n["highrisk"][i_loc] += i_risk
        n["ANC"][i_loc]      += i_ANC
        n["LB_L"][i_loc]     += 1
        M["GA"][i_loc, i_jGA] += 1
        M["PT"][i_loc] += i_term_status == 0
        M["Postterm"][i_loc] += i_term_status == 2

    # Predicted outcomes
    P_home_all = n["LB_L"][0] / np.sum(LB_tot)
    P_l23_all = n["LB_L"][1] / np.sum(LB_tot)
    P_l45_all = (n["LB_L"][2] + n["LB_L"][3]) / np.sum(LB_tot)
    P_home_anc = n["ANC"][0] / np.sum(n["ANC"])
    P_l23_anc = n["ANC"][1] / np.sum(n["ANC"])
    P_l45_anc = (n["ANC"][2] + n["ANC"][3]) / np.sum(n["ANC"])
    P_preterm_fac = np.sum(M["PT"][1:]) / np.sum(n["LB_L"][1:])
    P_preterm_home = M["PT"][0] / n["LB_L"][0]
    P_preterm_l23 = M["PT"][1] / n["LB_L"][1]
    P_preterm_l45 = (M["PT"][2] + M["PT"][3]) / n["LB_L"][2:4].sum()

    return P_home_all, P_l23_all, P_l45_all, P_home_anc, P_l23_anc, P_l45_anc, P_preterm_fac, P_preterm_home, P_preterm_l23, P_preterm_l45

# %%
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# Calibration targets
target_values = {
    "P_home_all": P["home_all"],
    "P_l23_all": P["l23_all"],
    "P_l45_all": P["l45_all"],
    "P_home_anc": P["home_anc"],
}

target_weights = {
    "P_home_all": (P["home_all"], 1),   # ±5% tolerance
    "P_l23_all":  (P["l23_all"], 1),
    "P_l45_all":  (P["l45_all"], 1),
    "P_home_anc": (P["home_anc"], 1),
}

def weighted_rmse(df_results, target_weights):
    weighted_errors = []
    for metric, (target, accepted_pct) in target_weights.items():
        simulated = df_results.get(metric, 0)
        error = simulated - target
        accepted_abs_error = target * (accepted_pct / 100)
        if accepted_abs_error == 0:  # safeguard
            continue
        normalized_error = error / accepted_abs_error
        weighted_errors.append(normalized_error**2)
    return math.sqrt(sum(weighted_errors) / len(weighted_errors))

# Define parameter space
param_space = [
    Real(0.5, 1, name='P_home_noANC'),
    Real(0.1, 0.5, name='P_l45_fac'),
    Real(0.1, 0.5, name='P_home_lowrisk'),
    Real(0.1, 0.4, name='P_L23_highrisk'),
    Real(0.6, 0.8, name='Sen_traditional'),
    Real(0.6, 0.8, name='Spec_traditional')
]

# Seeds for reproducibility
total_runs = 10
seeds = np.random.default_rng(2025).integers(low=0, high=1e6, size=total_runs)

# Track RMSE history
rmse_history = []

@use_named_args(param_space)
def objective(**params):
    results = []
    for run in range(total_runs):
        np.random.seed(seeds[run])
        res = f_ANC_LB_effect(
            params['P_home_noANC'],
            params['P_l45_fac'],
            params['P_home_lowrisk'],
            params['P_L23_highrisk'],
            params['Sen_traditional'],
            params['Spec_traditional']
        )
        results.append(res)

    # Average across runs
    mean_results = np.mean(results, axis=0)
    df_results = {
        "P_home_all": mean_results[0],
        "P_l23_all": mean_results[1],
        "P_l45_all": mean_results[2],
        "P_home_anc": mean_results[3],
    }

    # Save last results for early stopper
    objective.last_df_results = df_results

    # Compute relative RMSE
    #rel_sq_err = [((df_results[k] - target_values[k]) / target_values[k]) ** 2 for k in target_values]
    #rmse = math.sqrt(sum(rel_sq_err) / len(rel_sq_err))
    rmse = weighted_rmse(df_results, target_weights)

    # Print status
    print("\n--- Calibration Iteration ---")
    print("Parameters:")
    for k, v in params.items():
        print(f"  {k:22s}: {v:.4f}")
    print("\nTarget vs Simulated Outcomes:")
    for k in target_values:
        sim = df_results[k]
        target = target_values[k]
        error = sim - target
        rel_error = error / target
        print(f"  {k:22s} | Sim: {sim:.4f}, Target: {target:.4f}, RelErr: {rel_error:+.2%}")
    print(f"\nRMSE Loss: {rmse:.6f}")
    print("-----------------------------\n")

    return rmse

class EarlyStopper:
    def __init__(self, threshold_rmse=0.5, relative_threshold=0.05):
        self.threshold_rmse = threshold_rmse
        self.relative_threshold = relative_threshold
        self.best_loss = float('inf')
        self.best_params = None
        self.best_df_results = None

    # def meets_relative_criteria(self, sim_results):
    #     for k in target_values:
    #         target = target_values[k]
    #         sim = sim_results.get(k, 0)
    #         rel_error = abs(sim - target) / target
    #         if rel_error > self.relative_threshold:
    #             return False
    #     return True
    def meets_relative_criteria(self, sim_results):
        for metric, (target, accepted_pct) in target_weights.items():
            sim = sim_results.get(metric, 0)
            rel_error = abs(sim - target) / target
            if rel_error > (accepted_pct / 100):
                return False
        return True

    def __call__(self, *args, **kwargs):
        loss = objective(*args, **kwargs)
        rmse_history.append(loss)

        if loss < self.best_loss:
            self.best_loss = loss
            self.best_params = args[0] if args else None
            self.best_df_results = getattr(objective, "last_df_results", {})

        if self.best_loss < self.threshold_rmse and self.meets_relative_criteria(self.best_df_results):
            print(f"\n⏹️ Early stopping triggered. RMSE: {self.best_loss:.6f}")
            raise StopIteration

        return loss

def save_results(best_params, best_loss, rmse_history, param_space):
    param_names = [dim.name for dim in param_space]
    best_param_dict = dict(zip(param_names, best_params))
    best_param_dict["Best RMSE"] = best_loss
    df_best = pd.DataFrame([best_param_dict])
    df_best.to_csv("best_parameters_ANC_v3.csv", index=False)

    pd.DataFrame({"Iteration": range(1, len(rmse_history)+1), "RMSE": rmse_history}).to_csv(
        "rmse_history_ANC_v3.csv", index=False)

    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(rmse_history)+1), rmse_history, marker='o')
    plt.xlabel("Iteration")
    plt.ylabel("RMSE Loss")
    plt.title("RMSE Loss Over Iterations")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("rmse_plot_ANC_v3.png")
    plt.close()

def optimize_model():
    early_stopper = EarlyStopper(threshold_rmse=0.05, relative_threshold=0.05)
    try:
        result = gp_minimize(
            func=early_stopper,
            dimensions=param_space,
            n_calls=200,
            random_state=42,
            n_random_starts=20,
            acq_func="EI",
            verbose=True
        )
        print("\n✅ Optimization completed.")
        print("Best Parameters:", result.x)
        print("Best Loss:", result.fun)
        save_results(result.x, result.fun, rmse_history, param_space)
        return result

    except StopIteration:
        print("\n✅ Optimization stopped early.")
        print(f"Best RMSE achieved: {early_stopper.best_loss:.6f}")
        if early_stopper.best_params is not None:
            print("Best Parameters:")
            for name, val in zip([d.name for d in param_space], early_stopper.best_params):
                print(f"  {name:22s}: {val:.4f}")
            save_results(early_stopper.best_params, early_stopper.best_loss, rmse_history, param_space)
        return None

if __name__ == "__main__":
    optimize_model()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8983
#   P_l45_fac             : 0.1734
#   P_home_lowrisk        : 0.4119
#   P_L23_highrisk        : 0.2791
#   Sen_traditional       : 0.6892
#   Spec_traditional      : 0.6200
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4916, Target: 0.3500, RelErr: +40.45%
#   P_l23_all              | Sim: 0.2497, Target: 0.3920, RelErr: -36.31%
#   P_l45_all              | Sim: 0.2588, Target: 0.2580, RelErr: +0.29%
#   P_home_anc             | Sim: 0.1708, Target: 0.0700, RelErr: +144.04%
#
# RMSE Loss: 76.977096
# -----------------------------
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 7.3205
# Function value obtained: 76.9771
# Current minimum: 76.9771
# Iteration No: 2 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7296
#   P_l45_fac             : 0.2335
#   P_home_lowrisk        : 0.1571
#   P_L23_highrisk        : 0.2953
#   Sen_traditional       : 0.6113
#   Spec_traditional      : 0.7444
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3651, Target: 0.3500, RelErr: +4.31%
#   P_l23_all              | Sim: 0.3848, Target: 0.3920, RelErr: -1.85%
#   P_l45_all              | Sim: 0.2502, Target: 0.2580, RelErr: -3.03%
#   P_home_anc             | Sim: 0.0794, Target: 0.0700, RelErr: +13.46%
#
# RMSE Loss: 7.287279
# -----------------------------
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 7.0541
# Function value obtained: 7.2873
# Current minimum: 7.2873
# Iteration No: 3 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9693
#   P_l45_fac             : 0.1003
#   P_home_lowrisk        : 0.4969
#   P_L23_highrisk        : 0.2852
#   Sen_traditional       : 0.7223
#   Spec_traditional      : 0.6014
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5378, Target: 0.3500, RelErr: +53.66%
#   P_l23_all              | Sim: 0.2074, Target: 0.3920, RelErr: -47.09%
#   P_l45_all              | Sim: 0.2548, Target: 0.2580, RelErr: -1.25%
#   P_home_anc             | Sim: 0.1975, Target: 0.0700, RelErr: +182.20%
#
# RMSE Loss: 97.847483
# -----------------------------
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 7.3156
# Function value obtained: 97.8475
# Current minimum: 7.2873
# Iteration No: 4 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5115
#   P_l45_fac             : 0.3099
#   P_home_lowrisk        : 0.2599
#   P_L23_highrisk        : 0.1140
#   Sen_traditional       : 0.7948
#   Spec_traditional      : 0.6466
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2860, Target: 0.3500, RelErr: -18.30%
#   P_l23_all              | Sim: 0.3358, Target: 0.3920, RelErr: -14.35%
#   P_l45_all              | Sim: 0.3783, Target: 0.2580, RelErr: +46.62%
#   P_home_anc             | Sim: 0.1073, Target: 0.0700, RelErr: +53.27%
#
# RMSE Loss: 37.255036
# -----------------------------
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 7.3116
# Function value obtained: 37.2550
# Current minimum: 7.2873
# Iteration No: 5 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5453
#   P_l45_fac             : 0.3474
#   P_home_lowrisk        : 0.2530
#   P_L23_highrisk        : 0.3950
#   Sen_traditional       : 0.6934
#   Spec_traditional      : 0.7720
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3117, Target: 0.3500, RelErr: -10.94%
#   P_l23_all              | Sim: 0.4268, Target: 0.3920, RelErr: +8.88%
#   P_l45_all              | Sim: 0.2615, Target: 0.2580, RelErr: +1.34%
#   P_home_anc             | Sim: 0.1272, Target: 0.0700, RelErr: +81.66%
#
# RMSE Loss: 41.440697
# -----------------------------
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 7.3965
# Function value obtained: 41.4407
# Current minimum: 7.2873
# Iteration No: 6 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8402
#   P_l45_fac             : 0.2802
#   P_home_lowrisk        : 0.1053
#   P_L23_highrisk        : 0.3827
#   Sen_traditional       : 0.7127
#   Spec_traditional      : 0.6771
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3964, Target: 0.3500, RelErr: +13.25%
#   P_l23_all              | Sim: 0.3673, Target: 0.3920, RelErr: -6.31%
#   P_l45_all              | Sim: 0.2363, Target: 0.2580, RelErr: -8.40%
#   P_home_anc             | Sim: 0.0474, Target: 0.0700, RelErr: -32.22%
#
# RMSE Loss: 18.193650
# -----------------------------
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 7.2434
# Function value obtained: 18.1936
# Current minimum: 7.2873
# Iteration No: 7 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5080
#   P_l45_fac             : 0.1924
#   P_home_lowrisk        : 0.1964
#   P_L23_highrisk        : 0.3050
#   Sen_traditional       : 0.7220
#   Spec_traditional      : 0.7666
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2779, Target: 0.3500, RelErr: -20.59%
#   P_l23_all              | Sim: 0.4597, Target: 0.3920, RelErr: +17.26%
#   P_l45_all              | Sim: 0.2624, Target: 0.2580, RelErr: +1.71%
#   P_home_anc             | Sim: 0.0972, Target: 0.0700, RelErr: +38.87%
#
# RMSE Loss: 23.641320
# -----------------------------
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 7.3153
# Function value obtained: 23.6413
# Current minimum: 7.2873
# Iteration No: 8 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5867
#   P_l45_fac             : 0.2564
#   P_home_lowrisk        : 0.1729
#   P_L23_highrisk        : 0.3266
#   Sen_traditional       : 0.6850
#   Spec_traditional      : 0.6416
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3006, Target: 0.3500, RelErr: -14.12%
#   P_l23_all              | Sim: 0.4166, Target: 0.3920, RelErr: +6.28%
#   P_l45_all              | Sim: 0.2828, Target: 0.2580, RelErr: +9.62%
#   P_home_anc             | Sim: 0.0748, Target: 0.0700, RelErr: +6.91%
#
# RMSE Loss: 9.735286
# -----------------------------
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 7.4294
# Function value obtained: 9.7353
# Current minimum: 7.2873
# Iteration No: 9 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7839
#   P_l45_fac             : 0.1125
#   P_home_lowrisk        : 0.4369
#   P_L23_highrisk        : 0.2349
#   Sen_traditional       : 0.6790
#   Spec_traditional      : 0.7853
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4700, Target: 0.3500, RelErr: +34.30%
#   P_l23_all              | Sim: 0.2923, Target: 0.3920, RelErr: -25.43%
#   P_l45_all              | Sim: 0.2376, Target: 0.2580, RelErr: -7.89%
#   P_home_anc             | Sim: 0.2241, Target: 0.0700, RelErr: +220.20%
#
# RMSE Loss: 112.221250
# -----------------------------
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 7.3768
# Function value obtained: 112.2212
# Current minimum: 7.2873
# Iteration No: 10 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8636
#   P_l45_fac             : 0.2306
#   P_home_lowrisk        : 0.3282
#   P_L23_highrisk        : 0.2563
#   Sen_traditional       : 0.7922
#   Spec_traditional      : 0.7689
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4687, Target: 0.3500, RelErr: +33.91%
#   P_l23_all              | Sim: 0.2814, Target: 0.3920, RelErr: -28.22%
#   P_l45_all              | Sim: 0.2499, Target: 0.2580, RelErr: -3.13%
#   P_home_anc             | Sim: 0.1580, Target: 0.0700, RelErr: +125.72%
#
# RMSE Loss: 66.634724
# -----------------------------
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 7.2322
# Function value obtained: 66.6347
# Current minimum: 7.2873
# Iteration No: 11 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8737
#   P_l45_fac             : 0.3159
#   P_home_lowrisk        : 0.3347
#   P_L23_highrisk        : 0.3896
#   Sen_traditional       : 0.7214
#   Spec_traditional      : 0.6552
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4655, Target: 0.3500, RelErr: +33.00%
#   P_l23_all              | Sim: 0.3045, Target: 0.3920, RelErr: -22.31%
#   P_l45_all              | Sim: 0.2300, Target: 0.2580, RelErr: -10.87%
#   P_home_anc             | Sim: 0.1442, Target: 0.0700, RelErr: +106.02%
#
# RMSE Loss: 56.887670
# -----------------------------
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 7.1949
# Function value obtained: 56.8877
# Current minimum: 7.2873
# Iteration No: 12 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6481
#   P_l45_fac             : 0.1661
#   P_home_lowrisk        : 0.1063
#   P_L23_highrisk        : 0.2270
#   Sen_traditional       : 0.6790
#   Spec_traditional      : 0.6587
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3116, Target: 0.3500, RelErr: -10.96%
#   P_l23_all              | Sim: 0.3966, Target: 0.3920, RelErr: +1.18%
#   P_l45_all              | Sim: 0.2917, Target: 0.2580, RelErr: +13.07%
#   P_home_anc             | Sim: 0.0471, Target: 0.0700, RelErr: -32.74%
#
# RMSE Loss: 18.469231
# -----------------------------
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 7.2125
# Function value obtained: 18.4692
# Current minimum: 7.2873
# Iteration No: 13 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5070
#   P_l45_fac             : 0.1795
#   P_home_lowrisk        : 0.3845
#   P_L23_highrisk        : 0.3371
#   Sen_traditional       : 0.7212
#   Spec_traditional      : 0.7853
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3317, Target: 0.3500, RelErr: -5.22%
#   P_l23_all              | Sim: 0.4263, Target: 0.3920, RelErr: +8.75%
#   P_l45_all              | Sim: 0.2420, Target: 0.2580, RelErr: -6.21%
#   P_home_anc             | Sim: 0.1940, Target: 0.0700, RelErr: +177.08%
#
# RMSE Loss: 88.741905
# -----------------------------
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 7.2285
# Function value obtained: 88.7419
# Current minimum: 7.2873
# Iteration No: 14 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8255
#   P_l45_fac             : 0.4660
#   P_home_lowrisk        : 0.4400
#   P_L23_highrisk        : 0.2348
#   Sen_traditional       : 0.6191
#   Spec_traditional      : 0.6742
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4776, Target: 0.3500, RelErr: +36.45%
#   P_l23_all              | Sim: 0.2402, Target: 0.3920, RelErr: -38.72%
#   P_l45_all              | Sim: 0.2822, Target: 0.2580, RelErr: +9.39%
#   P_home_anc             | Sim: 0.2035, Target: 0.0700, RelErr: +190.74%
#
# RMSE Loss: 99.116842
# -----------------------------
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 7.2651
# Function value obtained: 99.1168
# Current minimum: 7.2873
# Iteration No: 15 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8344
#   P_l45_fac             : 0.3664
#   P_home_lowrisk        : 0.3365
#   P_L23_highrisk        : 0.1824
#   Sen_traditional       : 0.7122
#   Spec_traditional      : 0.6766
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4512, Target: 0.3500, RelErr: +28.91%
#   P_l23_all              | Sim: 0.2487, Target: 0.3920, RelErr: -36.57%
#   P_l45_all              | Sim: 0.3002, Target: 0.2580, RelErr: +16.34%
#   P_home_anc             | Sim: 0.1500, Target: 0.0700, RelErr: +114.30%
#
# RMSE Loss: 62.259446
# -----------------------------
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 7.2398
# Function value obtained: 62.2594
# Current minimum: 7.2873
# Iteration No: 16 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9859
#   P_l45_fac             : 0.4396
#   P_home_lowrisk        : 0.3887
#   P_L23_highrisk        : 0.1708
#   Sen_traditional       : 0.6512
#   Spec_traditional      : 0.6081
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5256, Target: 0.3500, RelErr: +50.17%
#   P_l23_all              | Sim: 0.1849, Target: 0.3920, RelErr: -52.82%
#   P_l45_all              | Sim: 0.2895, Target: 0.2580, RelErr: +12.20%
#   P_home_anc             | Sim: 0.1621, Target: 0.0700, RelErr: +131.61%
#
# RMSE Loss: 75.460907
# -----------------------------
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 7.2993
# Function value obtained: 75.4609
# Current minimum: 7.2873
# Iteration No: 17 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8553
#   P_l45_fac             : 0.1444
#   P_home_lowrisk        : 0.2757
#   P_L23_highrisk        : 0.1605
#   Sen_traditional       : 0.7792
#   Spec_traditional      : 0.6951
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4458, Target: 0.3500, RelErr: +27.36%
#   P_l23_all              | Sim: 0.2626, Target: 0.3920, RelErr: -33.01%
#   P_l45_all              | Sim: 0.2917, Target: 0.2580, RelErr: +13.05%
#   P_home_anc             | Sim: 0.1221, Target: 0.0700, RelErr: +74.37%
#
# RMSE Loss: 43.415274
# -----------------------------
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 7.2570
# Function value obtained: 43.4153
# Current minimum: 7.2873
# Iteration No: 18 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7816
#   P_l45_fac             : 0.3782
#   P_home_lowrisk        : 0.1557
#   P_L23_highrisk        : 0.2813
#   Sen_traditional       : 0.7080
#   Spec_traditional      : 0.6406
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3813, Target: 0.3500, RelErr: +8.95%
#   P_l23_all              | Sim: 0.3289, Target: 0.3920, RelErr: -16.10%
#   P_l45_all              | Sim: 0.2898, Target: 0.2580, RelErr: +12.32%
#   P_home_anc             | Sim: 0.0664, Target: 0.0700, RelErr: -5.11%
#
# RMSE Loss: 11.370685
# -----------------------------
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 7.3430
# Function value obtained: 11.3707
# Current minimum: 7.2873
# Iteration No: 19 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9714
#   P_l45_fac             : 0.3395
#   P_home_lowrisk        : 0.3779
#   P_L23_highrisk        : 0.3641
#   Sen_traditional       : 0.7249
#   Spec_traditional      : 0.6591
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5188, Target: 0.3500, RelErr: +48.23%
#   P_l23_all              | Sim: 0.2577, Target: 0.3920, RelErr: -34.26%
#   P_l45_all              | Sim: 0.2235, Target: 0.2580, RelErr: -13.38%
#   P_home_anc             | Sim: 0.1630, Target: 0.0700, RelErr: +132.84%
#
# RMSE Loss: 73.013706
# -----------------------------
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 7.3086
# Function value obtained: 73.0137
# Current minimum: 7.2873
# Iteration No: 20 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5527
#   P_l45_fac             : 0.2826
#   P_home_lowrisk        : 0.1874
#   P_L23_highrisk        : 0.2250
#   Sen_traditional       : 0.7767
#   Spec_traditional      : 0.6649
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2889, Target: 0.3500, RelErr: -17.45%
#   P_l23_all              | Sim: 0.3850, Target: 0.3920, RelErr: -1.77%
#   P_l45_all              | Sim: 0.3260, Target: 0.2580, RelErr: +26.37%
#   P_home_anc             | Sim: 0.0802, Target: 0.0700, RelErr: +14.52%
#
# RMSE Loss: 17.422660
# -----------------------------
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 7.4374
# Function value obtained: 17.4227
# Current minimum: 7.2873
# Iteration No: 21 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1572
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6795
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4816, Target: 0.3500, RelErr: +37.60%
#   P_l23_all              | Sim: 0.3151, Target: 0.3920, RelErr: -19.61%
#   P_l45_all              | Sim: 0.2033, Target: 0.2580, RelErr: -21.22%
#   P_home_anc             | Sim: 0.0743, Target: 0.0700, RelErr: +6.07%
#
# RMSE Loss: 23.902731
# -----------------------------
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 7.4382
# Function value obtained: 23.9027
# Current minimum: 7.2873
# Iteration No: 22 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6770
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1598
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6791
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3403, Target: 0.3500, RelErr: -2.76%
#   P_l23_all              | Sim: 0.4422, Target: 0.3920, RelErr: +12.80%
#   P_l45_all              | Sim: 0.2175, Target: 0.2580, RelErr: -15.71%
#   P_home_anc             | Sim: 0.0753, Target: 0.0700, RelErr: +7.56%
#
# RMSE Loss: 10.901235
# -----------------------------
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 7.4776
# Function value obtained: 10.9012
# Current minimum: 7.2873
# Iteration No: 23 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5933
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1286
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7426
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2980, Target: 0.3500, RelErr: -14.86%
#   P_l23_all              | Sim: 0.4187, Target: 0.3920, RelErr: +6.81%
#   P_l45_all              | Sim: 0.2833, Target: 0.2580, RelErr: +9.81%
#   P_home_anc             | Sim: 0.0655, Target: 0.0700, RelErr: -6.43%
#
# RMSE Loss: 10.057690
# -----------------------------
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 7.4951
# Function value obtained: 10.0577
# Current minimum: 7.2873
# Iteration No: 24 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7305
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1340
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3595, Target: 0.3500, RelErr: +2.71%
#   P_l23_all              | Sim: 0.3859, Target: 0.3920, RelErr: -1.55%
#   P_l45_all              | Sim: 0.2546, Target: 0.2580, RelErr: -1.31%
#   P_home_anc             | Sim: 0.0673, Target: 0.0700, RelErr: -3.88%
#
# RMSE Loss: 2.575512
# -----------------------------
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 7.4505
# Function value obtained: 2.5755
# Current minimum: 2.5755
# Iteration No: 25 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7895
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1378
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3866, Target: 0.3500, RelErr: +10.47%
#   P_l23_all              | Sim: 0.3721, Target: 0.3920, RelErr: -5.07%
#   P_l45_all              | Sim: 0.2412, Target: 0.2580, RelErr: -6.50%
#   P_home_anc             | Sim: 0.0692, Target: 0.0700, RelErr: -1.16%
#
# RMSE Loss: 6.686376
# -----------------------------
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 7.5528
# Function value obtained: 6.6864
# Current minimum: 2.5755
# Iteration No: 26 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7211
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1228
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3518, Target: 0.3500, RelErr: +0.52%
#   P_l23_all              | Sim: 0.3055, Target: 0.3920, RelErr: -22.06%
#   P_l45_all              | Sim: 0.3427, Target: 0.2580, RelErr: +32.82%
#   P_home_anc             | Sim: 0.0616, Target: 0.0700, RelErr: -11.96%
#
# RMSE Loss: 20.658723
# -----------------------------
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 7.7430
# Function value obtained: 20.6587
# Current minimum: 2.5755
# Iteration No: 27 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6895
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3315, Target: 0.3500, RelErr: -5.30%
#   P_l23_all              | Sim: 0.4585, Target: 0.3920, RelErr: +16.96%
#   P_l45_all              | Sim: 0.2101, Target: 0.2580, RelErr: -18.58%
#   P_home_anc             | Sim: 0.0501, Target: 0.0700, RelErr: -28.38%
#
# RMSE Loss: 19.145517
# -----------------------------
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 7.3548
# Function value obtained: 19.1455
# Current minimum: 2.5755
# Iteration No: 28 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6194
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1506
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3054, Target: 0.3500, RelErr: -12.73%
#   P_l23_all              | Sim: 0.3825, Target: 0.3920, RelErr: -2.42%
#   P_l45_all              | Sim: 0.3121, Target: 0.2580, RelErr: +20.96%
#   P_home_anc             | Sim: 0.0580, Target: 0.0700, RelErr: -17.11%
#
# RMSE Loss: 14.999622
# -----------------------------
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 7.6132
# Function value obtained: 14.9996
# Current minimum: 2.5755
# Iteration No: 29 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7647
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1613
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3852, Target: 0.3500, RelErr: +10.05%
#   P_l23_all              | Sim: 0.3799, Target: 0.3920, RelErr: -3.10%
#   P_l45_all              | Sim: 0.2350, Target: 0.2580, RelErr: -8.93%
#   P_home_anc             | Sim: 0.0868, Target: 0.0700, RelErr: +24.06%
#
# RMSE Loss: 13.869966
# -----------------------------
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 7.4513
# Function value obtained: 13.8700
# Current minimum: 2.5755
# Iteration No: 30 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7423
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2430, Target: 0.3500, RelErr: -30.57%
#   P_l23_all              | Sim: 0.4210, Target: 0.3920, RelErr: +7.40%
#   P_l45_all              | Sim: 0.3360, Target: 0.2580, RelErr: +30.23%
#   P_home_anc             | Sim: 0.0396, Target: 0.0700, RelErr: -43.37%
#
# RMSE Loss: 30.754593
# -----------------------------
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 7.3571
# Function value obtained: 30.7546
# Current minimum: 2.5755
# Iteration No: 31 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4699, Target: 0.3500, RelErr: +34.25%
#   P_l23_all              | Sim: 0.3444, Target: 0.3920, RelErr: -12.14%
#   P_l45_all              | Sim: 0.1857, Target: 0.2580, RelErr: -28.03%
#   P_home_anc             | Sim: 0.0537, Target: 0.0700, RelErr: -23.26%
#
# RMSE Loss: 25.725199
# -----------------------------
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 7.7078
# Function value obtained: 25.7252
# Current minimum: 2.5755
# Iteration No: 32 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7543
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1908
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7344
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3746, Target: 0.3500, RelErr: +7.02%
#   P_l23_all              | Sim: 0.3489, Target: 0.3920, RelErr: -10.99%
#   P_l45_all              | Sim: 0.2765, Target: 0.2580, RelErr: +7.18%
#   P_home_anc             | Sim: 0.0754, Target: 0.0700, RelErr: +7.73%
#
# RMSE Loss: 8.388536
# -----------------------------
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 7.6006
# Function value obtained: 8.3885
# Current minimum: 2.5755
# Iteration No: 33 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7494
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1818
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3734, Target: 0.3500, RelErr: +6.70%
#   P_l23_all              | Sim: 0.3563, Target: 0.3920, RelErr: -9.12%
#   P_l45_all              | Sim: 0.2703, Target: 0.2580, RelErr: +4.76%
#   P_home_anc             | Sim: 0.0767, Target: 0.0700, RelErr: +9.57%
#
# RMSE Loss: 7.780824
# -----------------------------
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 7.6722
# Function value obtained: 7.7808
# Current minimum: 2.5755
# Iteration No: 34 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7282
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1613
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7101
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3611, Target: 0.3500, RelErr: +3.16%
#   P_l23_all              | Sim: 0.4176, Target: 0.3920, RelErr: +6.53%
#   P_l45_all              | Sim: 0.2214, Target: 0.2580, RelErr: -14.20%
#   P_home_anc             | Sim: 0.0722, Target: 0.0700, RelErr: +3.20%
#
# RMSE Loss: 8.133201
# -----------------------------
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 7.8140
# Function value obtained: 8.1332
# Current minimum: 2.5755
# Iteration No: 35 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7573
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1707
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6044
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3744, Target: 0.3500, RelErr: +6.96%
#   P_l23_all              | Sim: 0.2586, Target: 0.3920, RelErr: -34.04%
#   P_l45_all              | Sim: 0.3671, Target: 0.2580, RelErr: +42.27%
#   P_home_anc             | Sim: 0.0727, Target: 0.0700, RelErr: +3.88%
#
# RMSE Loss: 27.426326
# -----------------------------
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 7.7792
# Function value obtained: 27.4263
# Current minimum: 2.5755
# Iteration No: 36 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7150
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1529
#   P_L23_highrisk        : 0.3402
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7199
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3535, Target: 0.3500, RelErr: +1.01%
#   P_l23_all              | Sim: 0.3576, Target: 0.3920, RelErr: -8.79%
#   P_l45_all              | Sim: 0.2889, Target: 0.2580, RelErr: +11.98%
#   P_home_anc             | Sim: 0.0692, Target: 0.0700, RelErr: -1.08%
#
# RMSE Loss: 7.465912
# -----------------------------
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 7.7818
# Function value obtained: 7.4659
# Current minimum: 2.5755
# Iteration No: 37 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2486, Target: 0.3500, RelErr: -28.97%
#   P_l23_all              | Sim: 0.3600, Target: 0.3920, RelErr: -8.17%
#   P_l45_all              | Sim: 0.3914, Target: 0.2580, RelErr: +51.71%
#   P_home_anc             | Sim: 0.0502, Target: 0.0700, RelErr: -28.32%
#
# RMSE Loss: 33.100013
# -----------------------------
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 7.4235
# Function value obtained: 33.1000
# Current minimum: 2.5755
# Iteration No: 38 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4688, Target: 0.3500, RelErr: +33.95%
#   P_l23_all              | Sim: 0.2499, Target: 0.3920, RelErr: -36.25%
#   P_l45_all              | Sim: 0.2813, Target: 0.2580, RelErr: +9.02%
#   P_home_anc             | Sim: 0.0496, Target: 0.0700, RelErr: -29.17%
#
# RMSE Loss: 29.151329
# -----------------------------
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 7.5354
# Function value obtained: 29.1513
# Current minimum: 2.5755
# Iteration No: 39 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7416
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1471
#   P_L23_highrisk        : 0.2980
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3709, Target: 0.3500, RelErr: +5.97%
#   P_l23_all              | Sim: 0.3625, Target: 0.3920, RelErr: -7.51%
#   P_l45_all              | Sim: 0.2666, Target: 0.2580, RelErr: +3.32%
#   P_home_anc             | Sim: 0.0794, Target: 0.0700, RelErr: +13.46%
#
# RMSE Loss: 8.428037
# -----------------------------
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 7.5850
# Function value obtained: 8.4280
# Current minimum: 2.5755
# Iteration No: 40 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.2100
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2663, Target: 0.3500, RelErr: -23.91%
#   P_l23_all              | Sim: 0.3974, Target: 0.3920, RelErr: +1.37%
#   P_l45_all              | Sim: 0.3363, Target: 0.2580, RelErr: +30.35%
#   P_home_anc             | Sim: 0.0807, Target: 0.0700, RelErr: +15.30%
#
# RMSE Loss: 20.789912
# -----------------------------
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 7.6526
# Function value obtained: 20.7899
# Current minimum: 2.5755
# Iteration No: 41 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7276
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1587
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7096
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3605, Target: 0.3500, RelErr: +2.99%
#   P_l23_all              | Sim: 0.3705, Target: 0.3920, RelErr: -5.50%
#   P_l45_all              | Sim: 0.2691, Target: 0.2580, RelErr: +4.29%
#   P_home_anc             | Sim: 0.0710, Target: 0.0700, RelErr: +1.46%
#
# RMSE Loss: 3.863454
# -----------------------------
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 7.6884
# Function value obtained: 3.8635
# Current minimum: 2.5755
# Iteration No: 42 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7278
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1562
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7075
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3598, Target: 0.3500, RelErr: +2.79%
#   P_l23_all              | Sim: 0.3707, Target: 0.3920, RelErr: -5.43%
#   P_l45_all              | Sim: 0.2695, Target: 0.2580, RelErr: +4.46%
#   P_home_anc             | Sim: 0.0697, Target: 0.0700, RelErr: -0.37%
#
# RMSE Loss: 3.783592
# -----------------------------
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 7.5329
# Function value obtained: 3.7836
# Current minimum: 2.5755
# Iteration No: 43 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7312
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1543
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7097
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3610, Target: 0.3500, RelErr: +3.14%
#   P_l23_all              | Sim: 0.3707, Target: 0.3920, RelErr: -5.44%
#   P_l45_all              | Sim: 0.2683, Target: 0.2580, RelErr: +4.01%
#   P_home_anc             | Sim: 0.0691, Target: 0.0700, RelErr: -1.22%
#
# RMSE Loss: 3.776604
# -----------------------------
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 7.4724
# Function value obtained: 3.7766
# Current minimum: 2.5755
# Iteration No: 44 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7727
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1570
#   P_L23_highrisk        : 0.3501
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7597
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3817, Target: 0.3500, RelErr: +9.06%
#   P_l23_all              | Sim: 0.3524, Target: 0.3920, RelErr: -10.09%
#   P_l45_all              | Sim: 0.2659, Target: 0.2580, RelErr: +3.05%
#   P_home_anc             | Sim: 0.0745, Target: 0.0700, RelErr: +6.45%
#
# RMSE Loss: 7.660312
# -----------------------------
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 7.5475
# Function value obtained: 7.6603
# Current minimum: 2.5755
# Iteration No: 45 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6664
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1308
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3305, Target: 0.3500, RelErr: -5.57%
#   P_l23_all              | Sim: 0.4005, Target: 0.3920, RelErr: +2.16%
#   P_l45_all              | Sim: 0.2690, Target: 0.2580, RelErr: +4.28%
#   P_home_anc             | Sim: 0.0656, Target: 0.0700, RelErr: -6.24%
#
# RMSE Loss: 4.819634
# -----------------------------
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 7.4887
# Function value obtained: 4.8196
# Current minimum: 2.5755
# Iteration No: 46 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7292
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1914
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3623, Target: 0.3500, RelErr: +3.51%
#   P_l23_all              | Sim: 0.3995, Target: 0.3920, RelErr: +1.91%
#   P_l45_all              | Sim: 0.2382, Target: 0.2580, RelErr: -7.67%
#   P_home_anc             | Sim: 0.0734, Target: 0.0700, RelErr: +4.89%
#
# RMSE Loss: 4.969940
# -----------------------------
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 7.3508
# Function value obtained: 4.9699
# Current minimum: 2.5755
# Iteration No: 47 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7353
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1816
#   P_L23_highrisk        : 0.3243
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3628, Target: 0.3500, RelErr: +3.66%
#   P_l23_all              | Sim: 0.3732, Target: 0.3920, RelErr: -4.79%
#   P_l45_all              | Sim: 0.2640, Target: 0.2580, RelErr: +2.31%
#   P_home_anc             | Sim: 0.0697, Target: 0.0700, RelErr: -0.42%
#
# RMSE Loss: 3.236820
# -----------------------------
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 7.5750
# Function value obtained: 3.2368
# Current minimum: 2.5755
# Iteration No: 48 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7318
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1839
#   P_L23_highrisk        : 0.3196
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3617, Target: 0.3500, RelErr: +3.34%
#   P_l23_all              | Sim: 0.3723, Target: 0.3920, RelErr: -5.02%
#   P_l45_all              | Sim: 0.2660, Target: 0.2580, RelErr: +3.09%
#   P_home_anc             | Sim: 0.0705, Target: 0.0700, RelErr: +0.70%
#
# RMSE Loss: 3.407405
# -----------------------------
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 7.5729
# Function value obtained: 3.4074
# Current minimum: 2.5755
# Iteration No: 49 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7078
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1804
#   P_L23_highrisk        : 0.2794
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3548, Target: 0.3500, RelErr: +1.37%
#   P_l23_all              | Sim: 0.3785, Target: 0.3920, RelErr: -3.44%
#   P_l45_all              | Sim: 0.2667, Target: 0.2580, RelErr: +3.36%
#   P_home_anc             | Sim: 0.0766, Target: 0.0700, RelErr: +9.46%
#
# RMSE Loss: 5.351264
# -----------------------------
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 7.5974
# Function value obtained: 5.3513
# Current minimum: 2.5755
# Iteration No: 50 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6996
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1998
#   P_L23_highrisk        : 0.3341
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3512, Target: 0.3500, RelErr: +0.35%
#   P_l23_all              | Sim: 0.3872, Target: 0.3920, RelErr: -1.21%
#   P_l45_all              | Sim: 0.2615, Target: 0.2580, RelErr: +1.36%
#   P_home_anc             | Sim: 0.0769, Target: 0.0700, RelErr: +9.79%
#
# RMSE Loss: 4.984464
# -----------------------------
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 7.8232
# Function value obtained: 4.9845
# Current minimum: 2.5755
# Iteration No: 51 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7349
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1271
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3619, Target: 0.3500, RelErr: +3.39%
#   P_l23_all              | Sim: 0.3642, Target: 0.3920, RelErr: -7.09%
#   P_l45_all              | Sim: 0.2739, Target: 0.2580, RelErr: +6.17%
#   P_home_anc             | Sim: 0.0683, Target: 0.0700, RelErr: -2.50%
#
# RMSE Loss: 5.149884
# -----------------------------
#
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 7.7698
# Function value obtained: 5.1499
# Current minimum: 2.5755
# Iteration No: 52 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6366
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1483
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3249, Target: 0.3500, RelErr: -7.18%
#   P_l23_all              | Sim: 0.3977, Target: 0.3920, RelErr: +1.44%
#   P_l45_all              | Sim: 0.2775, Target: 0.2580, RelErr: +7.55%
#   P_home_anc             | Sim: 0.0798, Target: 0.0700, RelErr: +14.01%
#
# RMSE Loss: 8.757937
# -----------------------------
#
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 7.7527
# Function value obtained: 8.7579
# Current minimum: 2.5755
# Iteration No: 53 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4650, Target: 0.3500, RelErr: +32.86%
#   P_l23_all              | Sim: 0.2205, Target: 0.3920, RelErr: -43.75%
#   P_l45_all              | Sim: 0.3145, Target: 0.2580, RelErr: +21.90%
#   P_home_anc             | Sim: 0.0426, Target: 0.0700, RelErr: -39.11%
#
# RMSE Loss: 35.365016
# -----------------------------
#
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 7.6394
# Function value obtained: 35.3650
# Current minimum: 2.5755
# Iteration No: 54 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7066
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.3435
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3415, Target: 0.3500, RelErr: -2.44%
#   P_l23_all              | Sim: 0.3939, Target: 0.3920, RelErr: +0.49%
#   P_l45_all              | Sim: 0.2646, Target: 0.2580, RelErr: +2.56%
#   P_home_anc             | Sim: 0.0542, Target: 0.0700, RelErr: -22.62%
#
# RMSE Loss: 11.448030
# -----------------------------
#
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 7.3341
# Function value obtained: 11.4480
# Current minimum: 2.5755
# Iteration No: 55 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7740
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1406
#   P_L23_highrisk        : 0.1851
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3795, Target: 0.3500, RelErr: +8.44%
#   P_l23_all              | Sim: 0.3542, Target: 0.3920, RelErr: -9.64%
#   P_l45_all              | Sim: 0.2662, Target: 0.2580, RelErr: +3.20%
#   P_home_anc             | Sim: 0.0702, Target: 0.0700, RelErr: +0.34%
#
# RMSE Loss: 6.606289
# -----------------------------
#
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 7.6291
# Function value obtained: 6.6063
# Current minimum: 2.5755
# Iteration No: 56 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8247
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1492
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4082, Target: 0.3500, RelErr: +16.63%
#   P_l23_all              | Sim: 0.3225, Target: 0.3920, RelErr: -17.72%
#   P_l45_all              | Sim: 0.2692, Target: 0.2580, RelErr: +4.36%
#   P_home_anc             | Sim: 0.0802, Target: 0.0700, RelErr: +14.54%
#
# RMSE Loss: 14.327702
# -----------------------------
#
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 7.6407
# Function value obtained: 14.3277
# Current minimum: 2.5755
# Iteration No: 57 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7592
#   P_l45_fac             : 0.2446
#   P_home_lowrisk        : 0.1809
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3732, Target: 0.3500, RelErr: +6.64%
#   P_l23_all              | Sim: 0.3744, Target: 0.3920, RelErr: -4.49%
#   P_l45_all              | Sim: 0.2524, Target: 0.2580, RelErr: -2.18%
#   P_home_anc             | Sim: 0.0698, Target: 0.0700, RelErr: -0.36%
#
# RMSE Loss: 4.156365
# -----------------------------
#
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 7.6699
# Function value obtained: 4.1564
# Current minimum: 2.5755
# Iteration No: 58 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6896
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1247
#   P_L23_highrisk        : 0.1893
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3404, Target: 0.3500, RelErr: -2.74%
#   P_l23_all              | Sim: 0.4066, Target: 0.3920, RelErr: +3.74%
#   P_l45_all              | Sim: 0.2529, Target: 0.2580, RelErr: -1.96%
#   P_home_anc             | Sim: 0.0672, Target: 0.0700, RelErr: -4.03%
#
# RMSE Loss: 3.223539
# -----------------------------
#
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 7.7143
# Function value obtained: 3.2235
# Current minimum: 2.5755
# Iteration No: 59 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8091
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1874
#   P_L23_highrisk        : 0.3490
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3965, Target: 0.3500, RelErr: +13.28%
#   P_l23_all              | Sim: 0.3510, Target: 0.3920, RelErr: -10.45%
#   P_l45_all              | Sim: 0.2525, Target: 0.2580, RelErr: -2.13%
#   P_home_anc             | Sim: 0.0717, Target: 0.0700, RelErr: +2.43%
#
# RMSE Loss: 8.601768
# -----------------------------
#
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 7.7589
# Function value obtained: 8.6018
# ...
#   P_home_anc             | Sim: 0.0721, Target: 0.0700, RelErr: +3.02%
#
# RMSE Loss: 2.298844
# -----------------------------
#
# Iteration No: 181 ended. Search finished for the next optimal point.
# Time taken: 7.6867
# Function value obtained: 2.2988
# Current minimum: 0.4366
# Iteration No: 182 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7182
#   P_l45_fac             : 0.1086
#   P_home_lowrisk        : 0.1435
#   P_L23_highrisk        : 0.2620
#   Sen_traditional       : 0.7184
#   Spec_traditional      : 0.7209
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3536, Target: 0.3500, RelErr: +1.03%
#   P_l23_all              | Sim: 0.3883, Target: 0.3920, RelErr: -0.94%
#   P_l45_all              | Sim: 0.2581, Target: 0.2580, RelErr: +0.02%
#   P_home_anc             | Sim: 0.0676, Target: 0.0700, RelErr: -3.46%
#
# RMSE Loss: 1.867092
# -----------------------------
#
# Iteration No: 182 ended. Search finished for the next optimal point.
# Time taken: 7.5946
# Function value obtained: 1.8671
# Current minimum: 0.4366
# Iteration No: 183 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6936
#   P_l45_fac             : 0.1058
#   P_home_lowrisk        : 0.1566
#   P_L23_highrisk        : 0.3082
#   Sen_traditional       : 0.7772
#   Spec_traditional      : 0.6856
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3438, Target: 0.3500, RelErr: -1.78%
#   P_l23_all              | Sim: 0.4013, Target: 0.3920, RelErr: +2.38%
#   P_l45_all              | Sim: 0.2549, Target: 0.2580, RelErr: -1.21%
#   P_home_anc             | Sim: 0.0688, Target: 0.0700, RelErr: -1.66%
#
# RMSE Loss: 1.807156
# -----------------------------
#
# Iteration No: 183 ended. Search finished for the next optimal point.
# Time taken: 7.6191
# Function value obtained: 1.8072
# Current minimum: 0.4366
# Iteration No: 184 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5027
#   P_l45_fac             : 0.1041
#   P_home_lowrisk        : 0.2009
#   P_L23_highrisk        : 0.1102
#   Sen_traditional       : 0.7860
#   Spec_traditional      : 0.7836
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2764, Target: 0.3500, RelErr: -21.04%
#   P_l23_all              | Sim: 0.4221, Target: 0.3920, RelErr: +7.69%
#   P_l45_all              | Sim: 0.3015, Target: 0.2580, RelErr: +16.86%
#   P_home_anc             | Sim: 0.0988, Target: 0.0700, RelErr: +41.12%
#
# RMSE Loss: 24.884008
# -----------------------------
#
# Iteration No: 184 ended. Search finished for the next optimal point.
# Time taken: 7.6931
# Function value obtained: 24.8840
# Current minimum: 0.4366
# Iteration No: 185 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6763
#   P_l45_fac             : 0.3433
#   P_home_lowrisk        : 0.1412
#   P_L23_highrisk        : 0.3519
#   Sen_traditional       : 0.6032
#   Spec_traditional      : 0.7159
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3367, Target: 0.3500, RelErr: -3.81%
#   P_l23_all              | Sim: 0.4035, Target: 0.3920, RelErr: +2.94%
#   P_l45_all              | Sim: 0.2598, Target: 0.2580, RelErr: +0.70%
#   P_home_anc             | Sim: 0.0694, Target: 0.0700, RelErr: -0.82%
#
# RMSE Loss: 2.465165
# -----------------------------
#
# Iteration No: 185 ended. Search finished for the next optimal point.
# Time taken: 7.6784
# Function value obtained: 2.4652
# Current minimum: 0.4366
# Iteration No: 186 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5040
#   P_l45_fac             : 0.4480
#   P_home_lowrisk        : 0.1194
#   P_L23_highrisk        : 0.3994
#   Sen_traditional       : 0.7910
#   Spec_traditional      : 0.7927
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2558, Target: 0.3500, RelErr: -26.92%
#   P_l23_all              | Sim: 0.4495, Target: 0.3920, RelErr: +14.66%
#   P_l45_all              | Sim: 0.2948, Target: 0.2580, RelErr: +14.25%
#   P_home_anc             | Sim: 0.0593, Target: 0.0700, RelErr: -15.29%
#
# RMSE Loss: 18.551387
# -----------------------------
#
# Iteration No: 186 ended. Search finished for the next optimal point.
# Time taken: 7.7974
# Function value obtained: 18.5514
# Current minimum: 0.4366
# Iteration No: 187 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6962
#   P_l45_fac             : 0.1489
#   P_home_lowrisk        : 0.1629
#   P_L23_highrisk        : 0.3108
#   Sen_traditional       : 0.7080
#   Spec_traditional      : 0.6356
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3449, Target: 0.3500, RelErr: -1.45%
#   P_l23_all              | Sim: 0.3904, Target: 0.3920, RelErr: -0.42%
#   P_l45_all              | Sim: 0.2647, Target: 0.2580, RelErr: +2.61%
#   P_home_anc             | Sim: 0.0689, Target: 0.0700, RelErr: -1.64%
#
# RMSE Loss: 1.714820
# -----------------------------
#
# Iteration No: 187 ended. Search finished for the next optimal point.
# Time taken: 7.6676
# Function value obtained: 1.7148
# Current minimum: 0.4366
# Iteration No: 188 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6870
#   P_l45_fac             : 0.2163
#   P_home_lowrisk        : 0.1531
#   P_L23_highrisk        : 0.3009
#   Sen_traditional       : 0.7025
#   Spec_traditional      : 0.6948
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3416, Target: 0.3500, RelErr: -2.40%
#   P_l23_all              | Sim: 0.3915, Target: 0.3920, RelErr: -0.12%
#   P_l45_all              | Sim: 0.2669, Target: 0.2580, RelErr: +3.44%
#   P_home_anc             | Sim: 0.0706, Target: 0.0700, RelErr: +0.83%
#
# RMSE Loss: 2.138421
# -----------------------------
#
# Iteration No: 188 ended. Search finished for the next optimal point.
# Time taken: 7.6807
# Function value obtained: 2.1384
# Current minimum: 0.4366
# Iteration No: 189 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7367
#   P_l45_fac             : 0.4672
#   P_home_lowrisk        : 0.2352
#   P_L23_highrisk        : 0.3963
#   Sen_traditional       : 0.7794
#   Spec_traditional      : 0.6006
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3758, Target: 0.3500, RelErr: +7.38%
#   P_l23_all              | Sim: 0.3450, Target: 0.3920, RelErr: -11.98%
#   P_l45_all              | Sim: 0.2791, Target: 0.2580, RelErr: +8.19%
#   P_home_anc             | Sim: 0.0910, Target: 0.0700, RelErr: +30.01%
#
# RMSE Loss: 17.071199
# -----------------------------
#
# Iteration No: 189 ended. Search finished for the next optimal point.
# Time taken: 7.6617
# Function value obtained: 17.0712
# Current minimum: 0.4366
# Iteration No: 190 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9999
#   P_l45_fac             : 0.4760
#   P_home_lowrisk        : 0.1437
#   P_L23_highrisk        : 0.1456
#   Sen_traditional       : 0.6052
#   Spec_traditional      : 0.7723
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4828, Target: 0.3500, RelErr: +37.96%
#   P_l23_all              | Sim: 0.2598, Target: 0.3920, RelErr: -33.72%
#   P_l45_all              | Sim: 0.2573, Target: 0.2580, RelErr: -0.26%
#   P_home_anc             | Sim: 0.0749, Target: 0.0700, RelErr: +6.94%
#
# RMSE Loss: 25.621639
# -----------------------------
#
# Iteration No: 190 ended. Search finished for the next optimal point.
# Time taken: 7.7030
# Function value obtained: 25.6216
# Current minimum: 0.4366
# Iteration No: 191 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7046
#   P_l45_fac             : 0.1952
#   P_home_lowrisk        : 0.1540
#   P_L23_highrisk        : 0.2893
#   Sen_traditional       : 0.7259
#   Spec_traditional      : 0.6978
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3488, Target: 0.3500, RelErr: -0.35%
#   P_l23_all              | Sim: 0.3844, Target: 0.3920, RelErr: -1.95%
#   P_l45_all              | Sim: 0.2669, Target: 0.2580, RelErr: +3.43%
#   P_home_anc             | Sim: 0.0703, Target: 0.0700, RelErr: +0.47%
#
# RMSE Loss: 1.995255
# -----------------------------
#
# Iteration No: 191 ended. Search finished for the next optimal point.
# Time taken: 7.8947
# Function value obtained: 1.9953
# Current minimum: 0.4366
# Iteration No: 192 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7086
#   P_l45_fac             : 0.2097
#   P_home_lowrisk        : 0.1780
#   P_L23_highrisk        : 0.3364
#   Sen_traditional       : 0.7536
#   Spec_traditional      : 0.6074
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3516, Target: 0.3500, RelErr: +0.47%
#   P_l23_all              | Sim: 0.3774, Target: 0.3920, RelErr: -3.73%
#   P_l45_all              | Sim: 0.2710, Target: 0.2580, RelErr: +5.03%
#   P_home_anc             | Sim: 0.0711, Target: 0.0700, RelErr: +1.57%
#
# RMSE Loss: 3.234764
# -----------------------------
#
# Iteration No: 192 ended. Search finished for the next optimal point.
# Time taken: 7.7888
# Function value obtained: 3.2348
# Current minimum: 0.4366
# Iteration No: 193 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9969
#   P_l45_fac             : 0.1256
#   P_home_lowrisk        : 0.1028
#   P_L23_highrisk        : 0.1080
#   Sen_traditional       : 0.7964
#   Spec_traditional      : 0.7993
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4685, Target: 0.3500, RelErr: +33.86%
#   P_l23_all              | Sim: 0.2525, Target: 0.3920, RelErr: -35.59%
#   P_l45_all              | Sim: 0.2790, Target: 0.2580, RelErr: +8.14%
#   P_home_anc             | Sim: 0.0512, Target: 0.0700, RelErr: -26.90%
#
# RMSE Loss: 28.299256
# -----------------------------
#
# Iteration No: 193 ended. Search finished for the next optimal point.
# Time taken: 7.8675
# Function value obtained: 28.2993
# Current minimum: 0.4366
# Iteration No: 194 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7282
#   P_l45_fac             : 0.1126
#   P_home_lowrisk        : 0.1407
#   P_L23_highrisk        : 0.1799
#   Sen_traditional       : 0.6091
#   Spec_traditional      : 0.7934
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3621, Target: 0.3500, RelErr: +3.45%
#   P_l23_all              | Sim: 0.3809, Target: 0.3920, RelErr: -2.83%
#   P_l45_all              | Sim: 0.2570, Target: 0.2580, RelErr: -0.39%
#   P_home_anc             | Sim: 0.0752, Target: 0.0700, RelErr: +7.48%
#
# RMSE Loss: 4.359199
# -----------------------------
#
# Iteration No: 194 ended. Search finished for the next optimal point.
# Time taken: 7.9251
# Function value obtained: 4.3592
# Current minimum: 0.4366
# Iteration No: 195 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6976
#   P_l45_fac             : 0.2516
#   P_home_lowrisk        : 0.1529
#   P_L23_highrisk        : 0.3487
#   Sen_traditional       : 0.7460
#   Spec_traditional      : 0.6961
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3452, Target: 0.3500, RelErr: -1.37%
#   P_l23_all              | Sim: 0.3968, Target: 0.3920, RelErr: +1.23%
#   P_l45_all              | Sim: 0.2580, Target: 0.2580, RelErr: -0.01%
#   P_home_anc             | Sim: 0.0692, Target: 0.0700, RelErr: -1.15%
#
# RMSE Loss: 1.086079
# -----------------------------
#
# Iteration No: 195 ended. Search finished for the next optimal point.
# Time taken: 7.7723
# Function value obtained: 1.0861
# Current minimum: 0.4366
# Iteration No: 196 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6968
#   P_l45_fac             : 0.2980
#   P_home_lowrisk        : 0.1609
#   P_L23_highrisk        : 0.3983
#   Sen_traditional       : 0.7457
#   Spec_traditional      : 0.6430
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3446, Target: 0.3500, RelErr: -1.54%
#   P_l23_all              | Sim: 0.3981, Target: 0.3920, RelErr: +1.56%
#   P_l45_all              | Sim: 0.2573, Target: 0.2580, RelErr: -0.27%
#   P_home_anc             | Sim: 0.0679, Target: 0.0700, RelErr: -2.97%
#
# RMSE Loss: 1.851416
# -----------------------------
#
# Iteration No: 196 ended. Search finished for the next optimal point.
# Time taken: 7.8924
# Function value obtained: 1.8514
# Current minimum: 0.4366
# Iteration No: 197 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7006
#   P_l45_fac             : 0.3294
#   P_home_lowrisk        : 0.1573
#   P_L23_highrisk        : 0.3705
#   Sen_traditional       : 0.6952
#   Spec_traditional      : 0.6737
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3479, Target: 0.3500, RelErr: -0.59%
#   P_l23_all              | Sim: 0.3907, Target: 0.3920, RelErr: -0.32%
#   P_l45_all              | Sim: 0.2613, Target: 0.2580, RelErr: +1.29%
#   P_home_anc             | Sim: 0.0708, Target: 0.0700, RelErr: +1.09%
#
# RMSE Loss: 0.908070
# -----------------------------
#
# Iteration No: 197 ended. Search finished for the next optimal point.
# Time taken: 7.8780
# Function value obtained: 0.9081
# Current minimum: 0.4366
# Iteration No: 198 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7122
#   P_l45_fac             : 0.2256
#   P_home_lowrisk        : 0.1545
#   P_L23_highrisk        : 0.3540
#   Sen_traditional       : 0.7991
#   Spec_traditional      : 0.6838
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3505, Target: 0.3500, RelErr: +0.14%
#   P_l23_all              | Sim: 0.3926, Target: 0.3920, RelErr: +0.15%
#   P_l45_all              | Sim: 0.2569, Target: 0.2580, RelErr: -0.42%
#   P_home_anc             | Sim: 0.0673, Target: 0.0700, RelErr: -3.87%
#
# RMSE Loss: 1.950419
# -----------------------------
#
# Iteration No: 198 ended. Search finished for the next optimal point.
# Time taken: 7.9747
# Function value obtained: 1.9504
# Current minimum: 0.4366
# Iteration No: 199 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6955
#   P_l45_fac             : 0.2347
#   P_home_lowrisk        : 0.1575
#   P_L23_highrisk        : 0.3480
#   Sen_traditional       : 0.7026
#   Spec_traditional      : 0.6808
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3459, Target: 0.3500, RelErr: -1.16%
#   P_l23_all              | Sim: 0.3981, Target: 0.3920, RelErr: +1.56%
#   P_l45_all              | Sim: 0.2559, Target: 0.2580, RelErr: -0.80%
#   P_home_anc             | Sim: 0.0713, Target: 0.0700, RelErr: +1.90%
#
# RMSE Loss: 1.416974
# -----------------------------
#
# Iteration No: 199 ended. Search finished for the next optimal point.
# Time taken: 7.8207
# Function value obtained: 1.4170
# Current minimum: 0.4366
# Iteration No: 200 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6986
#   P_l45_fac             : 0.2930
#   P_home_lowrisk        : 0.1566
#   P_L23_highrisk        : 0.3495
#   Sen_traditional       : 0.7719
#   Spec_traditional      : 0.7292
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3483, Target: 0.3500, RelErr: -0.50%
#   P_l23_all              | Sim: 0.3932, Target: 0.3920, RelErr: +0.32%
#   P_l45_all              | Sim: 0.2585, Target: 0.2580, RelErr: +0.19%
#   P_home_anc             | Sim: 0.0726, Target: 0.0700, RelErr: +3.77%
#
# RMSE Loss: 1.911847
# -----------------------------
#
# Iteration No: 200 ended. Search finished for the next optimal point.
# Time taken: 8.1047
# Function value obtained: 1.9118
# Current minimum: 0.4366
#
# ✅ Optimization completed.
# Best Parameters: [0.7101114281953853, 0.3204228024060687, 0.13912990665043845, 0.3191565363157117, 0.8, 0.8]
# Best Loss: 0.43664287014477954
