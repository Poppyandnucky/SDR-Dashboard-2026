# %%
import random
import numpy as np
import streamlit as st
import math
from parameters import get_parameters
from global_func import odds_prob


# Initialize parameters
P = {}  # dict to restore probabilities
n = {}  # dict to restore counts
E = {}  # dict to restore effects
S = {}  # dict to restore supplies and capacities
OR = {}  # dict to restore odds ratio
M = {}  # dict to restore maternal outcomes

#known parameters
param = get_parameters()
LB_tot = np.array([23729, 18196, 20709, 5126])
P["highrisk_all"] = 0.26                                              # high risk pregnancies among all live births
P["ANC"] = 0.56

# Calibration criteria
P["home_all"] = param["home_all_target"]
P["l23_all"] = param["l23_all_target"]
P["l45_all"] = param["l45_all_target"]
P["home_anc"] = param["home_anc_target"]

# %%
random.seed(0)
def f_ANC_LB_effect(P_home_noANC, P_l45_fac, P_home_lowrisk, P_L23_highrisk, Sen_traditional, Spec_traditional):
    # Initialize parameters

    GA = param['GA_sequence']
    GA_n = len(GA)
    n["GA"] = param["GA_distribution"]
    P["GA"] = n["GA"] / np.sum(n["GA"])
    PT_mask = np.array([1] * 10 + [0] * 8, dtype=bool)
    FT_mask = ~PT_mask
    P["GA"][PT_mask] = P["GA"][PT_mask] * param["PT_scale"]  # scale P[GA|PT] to match kenya level
    P_mult = (1 - np.sum(P["GA"][PT_mask])) / np.sum(P["GA"][FT_mask])
    P["GA"][FT_mask] *= P_mult

    OR["ANC"] = param["OR_preterm_ANC"]
    Preterm_rate = np.sum(P["GA"][PT_mask])  # overall preterm rate

    preterm_anc_noanc = odds_prob(OR["ANC"], Preterm_rate, P["ANC"])
    P["GA_anc"] = P["GA"].copy()
    P_scale_anc = preterm_anc_noanc[0] / Preterm_rate
    P["GA_anc"][PT_mask] *= P_scale_anc
    P_mult = (1 - preterm_anc_noanc[0]) / np.sum(P["GA_anc"][FT_mask])
    P["GA_anc"][FT_mask] *= P_mult

    P["GA_noanc"] = P["GA"].copy()
    P_scale_noanc = preterm_anc_noanc[1] / Preterm_rate
    P["GA_noanc"][PT_mask] *= P_scale_noanc
    P_mult = (1 - preterm_anc_noanc[1]) / np.sum(P["GA_noanc"][FT_mask])
    P["GA_noanc"][FT_mask] *= P_mult

    E["Preterm_LMP"] = np.zeros(3)
    E["Preterm_LMP"][0], E["Preterm_LMP"][1] = param['E_Preterm_LMP'][0], param['E_Preterm_LMP'][1]
    E["Preterm_LMP"][2] = 1 - (E["Preterm_LMP"][0] + E["Preterm_LMP"][1])
    E["Postterm_LMP"] = np.zeros(3)
    E["Postterm_LMP"][0], E["Postterm_LMP"][1] = param['E_Postterm_LMP'][0], param['E_Postterm_LMP'][1]
    E["Postterm_LMP"][2] = 1 - (E["Postterm_LMP"][0] + E["Postterm_LMP"][1])

    P_fac_noANC = 1 - P_home_noANC
    P_L45_noANC = P_fac_noANC * P_l45_fac
    P_L23_noANC = P_fac_noANC - P_L45_noANC

    # Initialize counters
    n["highrisk"] = np.zeros(4)                                           #number of high-risk pregnancies by facility levels
    n["ANC"] = np.zeros(4)                                                #number of 4+ANC by facility levels
    n["LB_L"] = np.zeros(4)                                               #number of delivery location by facility levels
    M["PT"] = np.zeros(4)
    M["Postterm"] = np.zeros(4)
    M["GA"] = np.zeros((4, GA_n))  # GA distributions by facility levels

    for k_LB in range(np.sum(LB_tot)):
        i_risk = np.random.binomial(1, P["highrisk_all"])
        i_ANC = np.random.binomial(1, P["ANC"])
        if i_ANC:
            P_GA = P["GA_anc"]
        else:
            P_GA = P["GA_noanc"]
        i_jGA = np.searchsorted(np.cumsum(P_GA), np.random.rand())  # % actual index of GA
        i_GA = GA[i_jGA]  # % actual GA

        if i_GA < 37:
            i_term_status = 0   #% 0 = preterm, 1 = full term, 2 = postterm
        elif i_GA >= 43:
            i_term_status = 2
        else:
            i_term_status = 1

        if i_ANC == 0:
            i_loc = np.random.choice([0, 1, 2], p=[P_home_noANC, P_L23_noANC, P_L45_noANC])
        else:
            # Risk stratification
            if i_risk:
                i_risk_pred = 1 if np.random.random() < Sen_traditional else 0
            else:
                i_risk_pred = 0 if np.random.random() < Spec_traditional else 1

            # Gestational age estimation
            i_preterm_pred = 1 if np.random.random() < E["Preterm_LMP"][i_term_status] else 0
            i_postterm_pred = 1 if np.random.random() < E["Postterm_LMP"][i_term_status] else 0

            if i_risk_pred or i_preterm_pred == 1 or i_postterm_pred == 1:
                i_loc = np.random.choice([0, 1, 2], p=[0, P_L23_highrisk, 1 - P_L23_highrisk])
            else:
                i_loc = np.random.choice([0, 1, 2], p=[P_home_lowrisk, (1 - P_home_lowrisk) * 0.89, (1 - P_home_lowrisk) * 0.11])

        # assume among all live births at L45, 5126/(20709 + 5126) going to L5
        P_l5_l45 = 5126 / (20709 + 5126)
        if i_loc == 2 and np.random.random() < P_l5_l45:
            i_loc = 3

        # restore results
        n["highrisk"][i_loc] += i_risk
        n["ANC"][i_loc]      += i_ANC
        n["LB_L"][i_loc]     += 1
        M["GA"][i_loc, i_jGA] += 1
        M["PT"][i_loc] += i_term_status == 0
        M["Postterm"][i_loc] += i_term_status == 2

    # Predicted outcomes
    P_home_all = n["LB_L"][0] / np.sum(LB_tot)
    P_l23_all = n["LB_L"][1] / np.sum(LB_tot)
    P_l45_all = (n["LB_L"][2] + n["LB_L"][3]) / np.sum(LB_tot)
    P_home_anc = n["ANC"][0] / np.sum(n["ANC"])
    P_l23_anc = n["ANC"][1] / np.sum(n["ANC"])
    P_l45_anc = (n["ANC"][2] + n["ANC"][3]) / np.sum(n["ANC"])
    P_preterm_fac = np.sum(M["PT"][1:]) / np.sum(n["LB_L"][1:])
    P_preterm_home = M["PT"][0] / n["LB_L"][0]
    P_preterm_l23 = M["PT"][1] / n["LB_L"][1]
    P_preterm_l45 = (M["PT"][2] + M["PT"][3]) / n["LB_L"][2:4].sum()

    return P_home_all, P_l23_all, P_l45_all, P_home_anc, P_l23_anc, P_l45_anc, P_preterm_fac, P_preterm_home, P_preterm_l23, P_preterm_l45

# %%
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# Calibration targets
target_values = {
    "P_home_all": P["home_all"],
    "P_l23_all": P["l23_all"],
    "P_l45_all": P["l45_all"],
    "P_home_anc": P["home_anc"],
}

target_weights = {
    "P_home_all": (P["home_all"], 5),   # ±5% tolerance
    "P_l23_all":  (P["l23_all"], 5),
    "P_l45_all":  (P["l45_all"], 5),
    "P_home_anc": (P["home_anc"], 5),
}

def weighted_rmse(df_results, target_weights):
    weighted_errors = []
    for metric, (target, accepted_pct) in target_weights.items():
        simulated = df_results.get(metric, 0)
        error = simulated - target
        accepted_abs_error = target * (accepted_pct / 100)
        if accepted_abs_error == 0:  # safeguard
            continue
        normalized_error = error / accepted_abs_error
        weighted_errors.append(normalized_error**2)
    return math.sqrt(sum(weighted_errors) / len(weighted_errors))

# Define parameter space
param_space = [
    Real(0.5, 1, name='P_home_noANC'),
    Real(0.1, 0.5, name='P_l45_fac'),
    Real(0.1, 0.5, name='P_home_lowrisk'),
    Real(0.1, 0.4, name='P_L23_highrisk'),
    Real(0.6, 0.8, name='Sen_traditional'),
    Real(0.6, 0.8, name='Spec_traditional')
]

# Seeds for reproducibility
total_runs = 10
seeds = np.random.default_rng(2025).integers(low=0, high=1e6, size=total_runs)

# Track RMSE history
rmse_history = []

@use_named_args(param_space)
def objective(**params):
    results = []
    for run in range(total_runs):
        np.random.seed(seeds[run])
        res = f_ANC_LB_effect(
            params['P_home_noANC'],
            params['P_l45_fac'],
            params['P_home_lowrisk'],
            params['P_L23_highrisk'],
            params['Sen_traditional'],
            params['Spec_traditional']
        )
        results.append(res)

    # Average across runs
    mean_results = np.mean(results, axis=0)
    df_results = {
        "P_home_all": mean_results[0],
        "P_l23_all": mean_results[1],
        "P_l45_all": mean_results[2],
        "P_home_anc": mean_results[3],
    }

    # Save last results for early stopper
    objective.last_df_results = df_results

    # Compute relative RMSE
    #rel_sq_err = [((df_results[k] - target_values[k]) / target_values[k]) ** 2 for k in target_values]
    #rmse = math.sqrt(sum(rel_sq_err) / len(rel_sq_err))
    rmse = weighted_rmse(df_results, target_weights)

    # Print status
    print("\n--- Calibration Iteration ---")
    print("Parameters:")
    for k, v in params.items():
        print(f"  {k:22s}: {v:.4f}")
    print("\nTarget vs Simulated Outcomes:")
    for k in target_values:
        sim = df_results[k]
        target = target_values[k]
        error = sim - target
        rel_error = error / target
        print(f"  {k:22s} | Sim: {sim:.4f}, Target: {target:.4f}, RelErr: {rel_error:+.2%}")
    print(f"\nRMSE Loss: {rmse:.6f}")
    print("-----------------------------\n")

    return rmse

class EarlyStopper:
    def __init__(self, threshold_rmse=0.5, relative_threshold=0.05):
        self.threshold_rmse = threshold_rmse
        self.relative_threshold = relative_threshold
        self.best_loss = float('inf')
        self.best_params = None
        self.best_df_results = None

    # def meets_relative_criteria(self, sim_results):
    #     for k in target_values:
    #         target = target_values[k]
    #         sim = sim_results.get(k, 0)
    #         rel_error = abs(sim - target) / target
    #         if rel_error > self.relative_threshold:
    #             return False
    #     return True
    def meets_relative_criteria(self, sim_results):
        for metric, (target, accepted_pct) in target_weights.items():
            sim = sim_results.get(metric, 0)
            rel_error = abs(sim - target) / target
            if rel_error > (accepted_pct / 100):
                return False
        return True

    def __call__(self, *args, **kwargs):
        loss = objective(*args, **kwargs)
        rmse_history.append(loss)

        if loss < self.best_loss:
            self.best_loss = loss
            self.best_params = args[0] if args else None
            self.best_df_results = getattr(objective, "last_df_results", {})

        if self.best_loss < self.threshold_rmse and self.meets_relative_criteria(self.best_df_results):
            print(f"\n⏹️ Early stopping triggered. RMSE: {self.best_loss:.6f}")
            raise StopIteration

        return loss

def save_results(best_params, best_loss, rmse_history, param_space):
    param_names = [dim.name for dim in param_space]
    best_param_dict = dict(zip(param_names, best_params))
    best_param_dict["Best RMSE"] = best_loss
    df_best = pd.DataFrame([best_param_dict])
    df_best.to_csv("best_parameters_ANC_v2.csv", index=False)

    pd.DataFrame({"Iteration": range(1, len(rmse_history)+1), "RMSE": rmse_history}).to_csv("rmse_history_ANC_v2.csv", index=False)

    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(rmse_history)+1), rmse_history, marker='o')
    plt.xlabel("Iteration")
    plt.ylabel("RMSE Loss")
    plt.title("RMSE Loss Over Iterations")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("rmse_plot_ANC_v2.png")
    plt.close()

def optimize_model():
    early_stopper = EarlyStopper(threshold_rmse=0.05, relative_threshold=0.05)
    try:
        result = gp_minimize(
            func=early_stopper,
            dimensions=param_space,
            n_calls=200,
            random_state=42,
            n_random_starts=20,
            acq_func="EI",
            verbose=True
        )
        print("\n✅ Optimization completed.")
        print("Best Parameters:", result.x)
        print("Best Loss:", result.fun)
        save_results(result.x, result.fun, rmse_history, param_space)
        return result

    except StopIteration:
        print("\n✅ Optimization stopped early.")
        print(f"Best RMSE achieved: {early_stopper.best_loss:.6f}")
        if early_stopper.best_params is not None:
            print("Best Parameters:")
            for name, val in zip([d.name for d in param_space], early_stopper.best_params):
                print(f"  {name:22s}: {val:.4f}")
            save_results(early_stopper.best_params, early_stopper.best_loss, rmse_history, param_space)
        return None

if __name__ == "__main__":
    optimize_model()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8983
#   P_l45_fac             : 0.1734
#   P_home_lowrisk        : 0.4119
#   P_L23_highrisk        : 0.2791
#   Sen_traditional       : 0.6892
#   Spec_traditional      : 0.6200
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4914, Target: 0.3500, RelErr: +40.40%
#   P_l23_all              | Sim: 0.2495, Target: 0.3920, RelErr: -36.35%
#   P_l45_all              | Sim: 0.2591, Target: 0.2580, RelErr: +0.43%
#   P_home_anc             | Sim: 0.1704, Target: 0.0700, RelErr: +143.42%
#
# RMSE Loss: 15.337386
# -----------------------------
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 6.9490
# Function value obtained: 15.3374
# Current minimum: 15.3374
# Iteration No: 2 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7296
#   P_l45_fac             : 0.2335
#   P_home_lowrisk        : 0.1571
#   P_L23_highrisk        : 0.2953
#   Sen_traditional       : 0.6113
#   Spec_traditional      : 0.7444
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3650, Target: 0.3500, RelErr: +4.27%
#   P_l23_all              | Sim: 0.3844, Target: 0.3920, RelErr: -1.94%
#   P_l45_all              | Sim: 0.2507, Target: 0.2580, RelErr: -2.84%
#   P_home_anc             | Sim: 0.0792, Target: 0.0700, RelErr: +13.13%
#
# RMSE Loss: 1.422938
# -----------------------------
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 7.2377
# Function value obtained: 1.4229
# Current minimum: 1.4229
# Iteration No: 3 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9693
#   P_l45_fac             : 0.1003
#   P_home_lowrisk        : 0.4969
#   P_L23_highrisk        : 0.2852
#   Sen_traditional       : 0.7223
#   Spec_traditional      : 0.6014
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5376, Target: 0.3500, RelErr: +53.59%
#   P_l23_all              | Sim: 0.2073, Target: 0.3920, RelErr: -47.12%
#   P_l45_all              | Sim: 0.2551, Target: 0.2580, RelErr: -1.11%
#   P_home_anc             | Sim: 0.1970, Target: 0.0700, RelErr: +181.46%
#
# RMSE Loss: 19.498708
# -----------------------------
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 7.0070
# Function value obtained: 19.4987
# Current minimum: 1.4229
# Iteration No: 4 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5115
#   P_l45_fac             : 0.3099
#   P_home_lowrisk        : 0.2599
#   P_L23_highrisk        : 0.1140
#   Sen_traditional       : 0.7948
#   Spec_traditional      : 0.6466
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2857, Target: 0.3500, RelErr: -18.37%
#   P_l23_all              | Sim: 0.3355, Target: 0.3920, RelErr: -14.41%
#   P_l45_all              | Sim: 0.3788, Target: 0.2580, RelErr: +46.82%
#   P_home_anc             | Sim: 0.1070, Target: 0.0700, RelErr: +52.82%
#
# RMSE Loss: 7.434049
# -----------------------------
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 7.1237
# Function value obtained: 7.4340
# Current minimum: 1.4229
# Iteration No: 5 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5453
#   P_l45_fac             : 0.3474
#   P_home_lowrisk        : 0.2530
#   P_L23_highrisk        : 0.3950
#   Sen_traditional       : 0.6934
#   Spec_traditional      : 0.7720
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3116, Target: 0.3500, RelErr: -10.97%
#   P_l23_all              | Sim: 0.4267, Target: 0.3920, RelErr: +8.84%
#   P_l45_all              | Sim: 0.2618, Target: 0.2580, RelErr: +1.46%
#   P_home_anc             | Sim: 0.1269, Target: 0.0700, RelErr: +81.23%
#
# RMSE Loss: 8.245214
# -----------------------------
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 6.9611
# Function value obtained: 8.2452
# Current minimum: 1.4229
# Iteration No: 6 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8402
#   P_l45_fac             : 0.2802
#   P_home_lowrisk        : 0.1053
#   P_L23_highrisk        : 0.3827
#   Sen_traditional       : 0.7127
#   Spec_traditional      : 0.6771
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3963, Target: 0.3500, RelErr: +13.24%
#   P_l23_all              | Sim: 0.3670, Target: 0.3920, RelErr: -6.38%
#   P_l45_all              | Sim: 0.2367, Target: 0.2580, RelErr: -8.27%
#   P_home_anc             | Sim: 0.0474, Target: 0.0700, RelErr: -32.32%
#
# RMSE Loss: 3.645619
# -----------------------------
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 7.1931
# Function value obtained: 3.6456
# Current minimum: 1.4229
# Iteration No: 7 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5080
#   P_l45_fac             : 0.1924
#   P_home_lowrisk        : 0.1964
#   P_L23_highrisk        : 0.3050
#   Sen_traditional       : 0.7220
#   Spec_traditional      : 0.7666
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2778, Target: 0.3500, RelErr: -20.64%
#   P_l23_all              | Sim: 0.4594, Target: 0.3920, RelErr: +17.20%
#   P_l45_all              | Sim: 0.2628, Target: 0.2580, RelErr: +1.87%
#   P_home_anc             | Sim: 0.0969, Target: 0.0700, RelErr: +38.41%
#
# RMSE Loss: 4.690962
# -----------------------------
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 7.1268
# Function value obtained: 4.6910
# Current minimum: 1.4229
# Iteration No: 8 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5867
#   P_l45_fac             : 0.2564
#   P_home_lowrisk        : 0.1729
#   P_L23_highrisk        : 0.3266
#   Sen_traditional       : 0.6850
#   Spec_traditional      : 0.6416
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3005, Target: 0.3500, RelErr: -14.14%
#   P_l23_all              | Sim: 0.4164, Target: 0.3920, RelErr: +6.23%
#   P_l45_all              | Sim: 0.2831, Target: 0.2580, RelErr: +9.73%
#   P_home_anc             | Sim: 0.0747, Target: 0.0700, RelErr: +6.67%
#
# RMSE Loss: 1.943754
# -----------------------------
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 7.1252
# Function value obtained: 1.9438
# Current minimum: 1.4229
# Iteration No: 9 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7839
#   P_l45_fac             : 0.1125
#   P_home_lowrisk        : 0.4369
#   P_L23_highrisk        : 0.2349
#   Sen_traditional       : 0.6790
#   Spec_traditional      : 0.7853
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4697, Target: 0.3500, RelErr: +34.20%
#   P_l23_all              | Sim: 0.2921, Target: 0.3920, RelErr: -25.47%
#   P_l45_all              | Sim: 0.2382, Target: 0.2580, RelErr: -7.68%
#   P_home_anc             | Sim: 0.2235, Target: 0.0700, RelErr: +219.29%
#
# RMSE Loss: 22.353282
# -----------------------------
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 7.0359
# Function value obtained: 22.3533
# Current minimum: 1.4229
# Iteration No: 10 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8636
#   P_l45_fac             : 0.2306
#   P_home_lowrisk        : 0.3282
#   P_L23_highrisk        : 0.2563
#   Sen_traditional       : 0.7922
#   Spec_traditional      : 0.7689
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4684, Target: 0.3500, RelErr: +33.82%
#   P_l23_all              | Sim: 0.2812, Target: 0.3920, RelErr: -28.27%
#   P_l45_all              | Sim: 0.2504, Target: 0.2580, RelErr: -2.94%
#   P_home_anc             | Sim: 0.1575, Target: 0.0700, RelErr: +125.00%
#
# RMSE Loss: 13.257324
# -----------------------------
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 7.1162
# Function value obtained: 13.2573
# Current minimum: 1.4229
# Iteration No: 11 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8737
#   P_l45_fac             : 0.3159
#   P_home_lowrisk        : 0.3347
#   P_L23_highrisk        : 0.3896
#   Sen_traditional       : 0.7214
#   Spec_traditional      : 0.6552
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4652, Target: 0.3500, RelErr: +32.93%
#   P_l23_all              | Sim: 0.3044, Target: 0.3920, RelErr: -22.34%
#   P_l45_all              | Sim: 0.2303, Target: 0.2580, RelErr: -10.72%
#   P_home_anc             | Sim: 0.1438, Target: 0.0700, RelErr: +105.37%
#
# RMSE Loss: 11.314446
# -----------------------------
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 7.1453
# Function value obtained: 11.3144
# Current minimum: 1.4229
# Iteration No: 12 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6481
#   P_l45_fac             : 0.1661
#   P_home_lowrisk        : 0.1063
#   P_L23_highrisk        : 0.2270
#   Sen_traditional       : 0.6790
#   Spec_traditional      : 0.6587
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3116, Target: 0.3500, RelErr: -10.97%
#   P_l23_all              | Sim: 0.3962, Target: 0.3920, RelErr: +1.08%
#   P_l45_all              | Sim: 0.2922, Target: 0.2580, RelErr: +13.24%
#   P_home_anc             | Sim: 0.0471, Target: 0.0700, RelErr: -32.77%
#
# RMSE Loss: 3.701989
# -----------------------------
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 7.1863
# Function value obtained: 3.7020
# Current minimum: 1.4229
# Iteration No: 13 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5070
#   P_l45_fac             : 0.1795
#   P_home_lowrisk        : 0.3845
#   P_L23_highrisk        : 0.3371
#   Sen_traditional       : 0.7212
#   Spec_traditional      : 0.7853
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3314, Target: 0.3500, RelErr: -5.31%
#   P_l23_all              | Sim: 0.4262, Target: 0.3920, RelErr: +8.71%
#   P_l45_all              | Sim: 0.2424, Target: 0.2580, RelErr: -6.03%
#   P_home_anc             | Sim: 0.1933, Target: 0.0700, RelErr: +176.19%
#
# RMSE Loss: 17.658658
# -----------------------------
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 6.9760
# Function value obtained: 17.6587
# Current minimum: 1.4229
# Iteration No: 14 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8255
#   P_l45_fac             : 0.4660
#   P_home_lowrisk        : 0.4400
#   P_L23_highrisk        : 0.2348
#   Sen_traditional       : 0.6191
#   Spec_traditional      : 0.6742
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4773, Target: 0.3500, RelErr: +36.37%
#   P_l23_all              | Sim: 0.2401, Target: 0.3920, RelErr: -38.76%
#   P_l45_all              | Sim: 0.2826, Target: 0.2580, RelErr: +9.54%
#   P_home_anc             | Sim: 0.2030, Target: 0.0700, RelErr: +189.99%
#
# RMSE Loss: 19.751458
# -----------------------------
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 7.1218
# Function value obtained: 19.7515
# Current minimum: 1.4229
# Iteration No: 15 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8344
#   P_l45_fac             : 0.3664
#   P_home_lowrisk        : 0.3365
#   P_L23_highrisk        : 0.1824
#   Sen_traditional       : 0.7122
#   Spec_traditional      : 0.6766
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4510, Target: 0.3500, RelErr: +28.85%
#   P_l23_all              | Sim: 0.2484, Target: 0.3920, RelErr: -36.63%
#   P_l45_all              | Sim: 0.3006, Target: 0.2580, RelErr: +16.53%
#   P_home_anc             | Sim: 0.1496, Target: 0.0700, RelErr: +113.69%
#
# RMSE Loss: 12.398652
# -----------------------------
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 7.1067
# Function value obtained: 12.3987
# Current minimum: 1.4229
# Iteration No: 16 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9859
#   P_l45_fac             : 0.4396
#   P_home_lowrisk        : 0.3887
#   P_L23_highrisk        : 0.1708
#   Sen_traditional       : 0.6512
#   Spec_traditional      : 0.6081
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5254, Target: 0.3500, RelErr: +50.13%
#   P_l23_all              | Sim: 0.1847, Target: 0.3920, RelErr: -52.88%
#   P_l45_all              | Sim: 0.2899, Target: 0.2580, RelErr: +12.35%
#   P_home_anc             | Sim: 0.1618, Target: 0.0700, RelErr: +131.16%
#
# RMSE Loss: 15.054738
# -----------------------------
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 7.1270
# Function value obtained: 15.0547
# Current minimum: 1.4229
# Iteration No: 17 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8553
#   P_l45_fac             : 0.1444
#   P_home_lowrisk        : 0.2757
#   P_L23_highrisk        : 0.1605
#   Sen_traditional       : 0.7792
#   Spec_traditional      : 0.6951
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4456, Target: 0.3500, RelErr: +27.31%
#   P_l23_all              | Sim: 0.2623, Target: 0.3920, RelErr: -33.10%
#   P_l45_all              | Sim: 0.2921, Target: 0.2580, RelErr: +13.24%
#   P_home_anc             | Sim: 0.1217, Target: 0.0700, RelErr: +73.83%
#
# RMSE Loss: 8.641344
# -----------------------------
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 7.2247
# Function value obtained: 8.6413
# Current minimum: 1.4229
# Iteration No: 18 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7816
#   P_l45_fac             : 0.3782
#   P_home_lowrisk        : 0.1557
#   P_L23_highrisk        : 0.2813
#   Sen_traditional       : 0.7080
#   Spec_traditional      : 0.6406
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3812, Target: 0.3500, RelErr: +8.92%
#   P_l23_all              | Sim: 0.3286, Target: 0.3920, RelErr: -16.17%
#   P_l45_all              | Sim: 0.2901, Target: 0.2580, RelErr: +12.46%
#   P_home_anc             | Sim: 0.0663, Target: 0.0700, RelErr: -5.34%
#
# RMSE Loss: 2.290758
# -----------------------------
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 7.0051
# Function value obtained: 2.2908
# Current minimum: 1.4229
# Iteration No: 19 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9714
#   P_l45_fac             : 0.3395
#   P_home_lowrisk        : 0.3779
#   P_L23_highrisk        : 0.3641
#   Sen_traditional       : 0.7249
#   Spec_traditional      : 0.6591
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5184, Target: 0.3500, RelErr: +48.12%
#   P_l23_all              | Sim: 0.2577, Target: 0.3920, RelErr: -34.27%
#   P_l45_all              | Sim: 0.2239, Target: 0.2580, RelErr: -13.22%
#   P_home_anc             | Sim: 0.1624, Target: 0.0700, RelErr: +132.06%
#
# RMSE Loss: 14.527147
# -----------------------------
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 7.1414
# Function value obtained: 14.5271
# Current minimum: 1.4229
# Iteration No: 20 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5527
#   P_l45_fac             : 0.2826
#   P_home_lowrisk        : 0.1874
#   P_L23_highrisk        : 0.2250
#   Sen_traditional       : 0.7767
#   Spec_traditional      : 0.6649
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2887, Target: 0.3500, RelErr: -17.50%
#   P_l23_all              | Sim: 0.3849, Target: 0.3920, RelErr: -1.82%
#   P_l45_all              | Sim: 0.3264, Target: 0.2580, RelErr: +26.51%
#   P_home_anc             | Sim: 0.0800, Target: 0.0700, RelErr: +14.26%
#
# RMSE Loss: 3.487035
# -----------------------------
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 7.3166
# Function value obtained: 3.4870
# Current minimum: 1.4229
# Iteration No: 21 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1570
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6820
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4815, Target: 0.3500, RelErr: +37.58%
#   P_l23_all              | Sim: 0.3152, Target: 0.3920, RelErr: -19.59%
#   P_l45_all              | Sim: 0.2033, Target: 0.2580, RelErr: -21.21%
#   P_home_anc             | Sim: 0.0742, Target: 0.0700, RelErr: +6.01%
#
# RMSE Loss: 4.776795
# -----------------------------
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 7.4385
# Function value obtained: 4.7768
# Current minimum: 1.4229
# Iteration No: 22 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6777
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1589
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6873
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3406, Target: 0.3500, RelErr: -2.69%
#   P_l23_all              | Sim: 0.4428, Target: 0.3920, RelErr: +12.95%
#   P_l45_all              | Sim: 0.2166, Target: 0.2580, RelErr: -16.04%
#   P_home_anc             | Sim: 0.0753, Target: 0.0700, RelErr: +7.59%
#
# RMSE Loss: 2.213098
# -----------------------------
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 7.2621
# Function value obtained: 2.2131
# Current minimum: 1.4229
# Iteration No: 23 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5743
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1258
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7482
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2889, Target: 0.3500, RelErr: -17.46%
#   P_l23_all              | Sim: 0.4240, Target: 0.3920, RelErr: +8.16%
#   P_l45_all              | Sim: 0.2871, Target: 0.2580, RelErr: +11.29%
#   P_home_anc             | Sim: 0.0641, Target: 0.0700, RelErr: -8.50%
#
# RMSE Loss: 2.389823
# -----------------------------
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 7.5158
# Function value obtained: 2.3898
# Current minimum: 1.4229
# Iteration No: 24 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7420
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1363
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3650, Target: 0.3500, RelErr: +4.28%
#   P_l23_all              | Sim: 0.3826, Target: 0.3920, RelErr: -2.39%
#   P_l45_all              | Sim: 0.2524, Target: 0.2580, RelErr: -2.17%
#   P_home_anc             | Sim: 0.0682, Target: 0.0700, RelErr: -2.60%
#
# RMSE Loss: 0.595984
# -----------------------------
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 7.5377
# Function value obtained: 0.5960
# Current minimum: 0.5960
# Iteration No: 25 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7839
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1312
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3849, Target: 0.3500, RelErr: +9.96%
#   P_l23_all              | Sim: 0.3049, Target: 0.3920, RelErr: -22.21%
#   P_l45_all              | Sim: 0.3102, Target: 0.2580, RelErr: +20.23%
#   P_home_anc             | Sim: 0.0707, Target: 0.0700, RelErr: +1.02%
#
# RMSE Loss: 3.166794
# -----------------------------
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 7.2467
# Function value obtained: 3.1668
# Current minimum: 0.5960
# Iteration No: 26 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7222
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1430
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3576, Target: 0.3500, RelErr: +2.18%
#   P_l23_all              | Sim: 0.4345, Target: 0.3920, RelErr: +10.85%
#   P_l45_all              | Sim: 0.2078, Target: 0.2580, RelErr: -19.44%
#   P_home_anc             | Sim: 0.0712, Target: 0.0700, RelErr: +1.79%
#
# RMSE Loss: 2.243913
# -----------------------------
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 7.3220
# Function value obtained: 2.2439
# Current minimum: 0.5960
# Iteration No: 27 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1422
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2518, Target: 0.3500, RelErr: -28.07%
#   P_l23_all              | Sim: 0.4099, Target: 0.3920, RelErr: +4.56%
#   P_l45_all              | Sim: 0.3384, Target: 0.2580, RelErr: +31.16%
#   P_home_anc             | Sim: 0.0549, Target: 0.0700, RelErr: -21.59%
#
# RMSE Loss: 4.738517
# -----------------------------
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 7.2977
# Function value obtained: 4.7385
# Current minimum: 0.5960
# Iteration No: 28 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6420
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3105, Target: 0.3500, RelErr: -11.29%
#   P_l23_all              | Sim: 0.4769, Target: 0.3920, RelErr: +21.65%
#   P_l45_all              | Sim: 0.2126, Target: 0.2580, RelErr: -17.59%
#   P_home_anc             | Sim: 0.0501, Target: 0.0700, RelErr: -28.41%
#
# RMSE Loss: 4.138489
# -----------------------------
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 7.5843
# Function value obtained: 4.1385
# Current minimum: 0.5960
# Iteration No: 29 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7478
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1790
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3680, Target: 0.3500, RelErr: +5.14%
#   P_l23_all              | Sim: 0.3497, Target: 0.3920, RelErr: -10.79%
#   P_l45_all              | Sim: 0.2823, Target: 0.2580, RelErr: +9.43%
#   P_home_anc             | Sim: 0.0683, Target: 0.0700, RelErr: -2.41%
#
# RMSE Loss: 1.541516
# -----------------------------
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 7.4087
# Function value obtained: 1.5415
# Current minimum: 0.5960
# Iteration No: 30 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7217
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1616
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7289
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3593, Target: 0.3500, RelErr: +2.64%
#   P_l23_all              | Sim: 0.3730, Target: 0.3920, RelErr: -4.85%
#   P_l45_all              | Sim: 0.2677, Target: 0.2580, RelErr: +3.78%
#   P_home_anc             | Sim: 0.0739, Target: 0.0700, RelErr: +5.60%
#
# RMSE Loss: 0.872812
# -----------------------------
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 7.4040
# Function value obtained: 0.8728
# Current minimum: 0.5960
# Iteration No: 31 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7220
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1586
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7386
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3626, Target: 0.3500, RelErr: +3.60%
#   P_l23_all              | Sim: 0.3823, Target: 0.3920, RelErr: -2.47%
#   P_l45_all              | Sim: 0.2551, Target: 0.2580, RelErr: -1.13%
#   P_home_anc             | Sim: 0.0799, Target: 0.0700, RelErr: +14.19%
#
# RMSE Loss: 1.488665
# -----------------------------
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 7.9852
# Function value obtained: 1.4887
# Current minimum: 0.5960
# Iteration No: 32 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7138
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1590
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7200
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3549, Target: 0.3500, RelErr: +1.40%
#   P_l23_all              | Sim: 0.3742, Target: 0.3920, RelErr: -4.55%
#   P_l45_all              | Sim: 0.2709, Target: 0.2580, RelErr: +5.01%
#   P_home_anc             | Sim: 0.0719, Target: 0.0700, RelErr: +2.71%
#
# RMSE Loss: 0.742977
# -----------------------------
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 7.3299
# Function value obtained: 0.7430
# Current minimum: 0.5960
# Iteration No: 33 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7279
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1615
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3658, Target: 0.3500, RelErr: +4.51%
#   P_l23_all              | Sim: 0.3795, Target: 0.3920, RelErr: -3.18%
#   P_l45_all              | Sim: 0.2547, Target: 0.2580, RelErr: -1.28%
#   P_home_anc             | Sim: 0.0806, Target: 0.0700, RelErr: +15.08%
#
# RMSE Loss: 1.611084
# -----------------------------
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 7.2137
# Function value obtained: 1.6111
# Current minimum: 0.5960
# Iteration No: 34 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7066
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1538
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7048
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3496, Target: 0.3500, RelErr: -0.12%
#   P_l23_all              | Sim: 0.3754, Target: 0.3920, RelErr: -4.24%
#   P_l45_all              | Sim: 0.2750, Target: 0.2580, RelErr: +6.59%
#   P_home_anc             | Sim: 0.0683, Target: 0.0700, RelErr: -2.47%
#
# RMSE Loss: 0.821880
# -----------------------------
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 7.4720
# Function value obtained: 0.8219
# Current minimum: 0.5960
# Iteration No: 35 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7061
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1519
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7068
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3489, Target: 0.3500, RelErr: -0.30%
#   P_l23_all              | Sim: 0.3762, Target: 0.3920, RelErr: -4.04%
#   P_l45_all              | Sim: 0.2749, Target: 0.2580, RelErr: +6.54%
#   P_home_anc             | Sim: 0.0676, Target: 0.0700, RelErr: -3.44%
#
# RMSE Loss: 0.842655
# -----------------------------
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 7.4768
# Function value obtained: 0.8427
# Current minimum: 0.5960
# Iteration No: 36 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7043
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1501
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7093
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3478, Target: 0.3500, RelErr: -0.63%
#   P_l23_all              | Sim: 0.3773, Target: 0.3920, RelErr: -3.75%
#   P_l45_all              | Sim: 0.2749, Target: 0.2580, RelErr: +6.55%
#   P_home_anc             | Sim: 0.0670, Target: 0.0700, RelErr: -4.25%
#
# RMSE Loss: 0.868644
# -----------------------------
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 7.4360
# Function value obtained: 0.8686
# Current minimum: 0.5960
# Iteration No: 37 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8061
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1247
#   P_L23_highrisk        : 0.3274
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3901, Target: 0.3500, RelErr: +11.47%
#   P_l23_all              | Sim: 0.3514, Target: 0.3920, RelErr: -10.35%
#   P_l45_all              | Sim: 0.2584, Target: 0.2580, RelErr: +0.17%
#   P_home_anc             | Sim: 0.0625, Target: 0.0700, RelErr: -10.74%
#
# RMSE Loss: 1.881643
# -----------------------------
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 7.4341
# Function value obtained: 1.8816
# Current minimum: 0.5960
# Iteration No: 38 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6785
#   P_l45_fac             : 0.3669
#   P_home_lowrisk        : 0.1435
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7752
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3377, Target: 0.3500, RelErr: -3.50%
#   P_l23_all              | Sim: 0.4110, Target: 0.3920, RelErr: +4.84%
#   P_l45_all              | Sim: 0.2513, Target: 0.2580, RelErr: -2.59%
#   P_home_anc             | Sim: 0.0696, Target: 0.0700, RelErr: -0.55%
#
# RMSE Loss: 0.653330
# -----------------------------
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 7.4213
# Function value obtained: 0.6533
# Current minimum: 0.5960
# Iteration No: 39 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6719
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1389
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3351, Target: 0.3500, RelErr: -4.24%
#   P_l23_all              | Sim: 0.3967, Target: 0.3920, RelErr: +1.21%
#   P_l45_all              | Sim: 0.2681, Target: 0.2580, RelErr: +3.92%
#   P_home_anc             | Sim: 0.0695, Target: 0.0700, RelErr: -0.70%
#
# RMSE Loss: 0.594088
# -----------------------------
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 7.6502
# Function value obtained: 0.5941
# Current minimum: 0.5941
# Iteration No: 40 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6949
#   P_l45_fac             : 0.4099
#   P_home_lowrisk        : 0.1395
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7514
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3431, Target: 0.3500, RelErr: -1.98%
#   P_l23_all              | Sim: 0.3984, Target: 0.3920, RelErr: +1.63%
#   P_l45_all              | Sim: 0.2585, Target: 0.2580, RelErr: +0.20%
#   P_home_anc             | Sim: 0.0660, Target: 0.0700, RelErr: -5.68%
#
# RMSE Loss: 0.623427
# -----------------------------
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 7.4461
# Function value obtained: 0.6234
# Current minimum: 0.5941
# Iteration No: 41 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6955
#   P_l45_fac             : 0.4208
#   P_home_lowrisk        : 0.1381
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7582
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3435, Target: 0.3500, RelErr: -1.86%
#   P_l23_all              | Sim: 0.3977, Target: 0.3920, RelErr: +1.46%
#   P_l45_all              | Sim: 0.2588, Target: 0.2580, RelErr: +0.31%
#   P_home_anc             | Sim: 0.0658, Target: 0.0700, RelErr: -5.96%
#
# RMSE Loss: 0.642147
# -----------------------------
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 7.3932
# Function value obtained: 0.6421
# Current minimum: 0.5941
# Iteration No: 42 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5561
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1358
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2858, Target: 0.3500, RelErr: -18.35%
#   P_l23_all              | Sim: 0.4320, Target: 0.3920, RelErr: +10.22%
#   P_l45_all              | Sim: 0.2822, Target: 0.2580, RelErr: +9.37%
#   P_home_anc             | Sim: 0.0732, Target: 0.0700, RelErr: +4.56%
#
# RMSE Loss: 2.344801
# -----------------------------
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 7.2795
# Function value obtained: 2.3448
# Current minimum: 0.5941
# Iteration No: 43 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4714, Target: 0.3500, RelErr: +34.68%
#   P_l23_all              | Sim: 0.2648, Target: 0.3920, RelErr: -32.44%
#   P_l45_all              | Sim: 0.2638, Target: 0.2580, RelErr: +2.24%
#   P_home_anc             | Sim: 0.0536, Target: 0.0700, RelErr: -23.41%
#
# RMSE Loss: 5.299050
# -----------------------------
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 7.3642
# Function value obtained: 5.2990
# Current minimum: 0.5941
# Iteration No: 44 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7079
#   P_l45_fac             : 0.3742
#   P_home_lowrisk        : 0.1545
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7227
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3512, Target: 0.3500, RelErr: +0.34%
#   P_l23_all              | Sim: 0.3932, Target: 0.3920, RelErr: +0.31%
#   P_l45_all              | Sim: 0.2556, Target: 0.2580, RelErr: -0.93%
#   P_home_anc             | Sim: 0.0703, Target: 0.0700, RelErr: +0.46%
#
# RMSE Loss: 0.113327
# -----------------------------
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 7.2670
# Function value obtained: 0.1133
# Current minimum: 0.1133
# Iteration No: 45 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7096
#   P_l45_fac             : 0.3332
#   P_home_lowrisk        : 0.1634
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6937
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3528, Target: 0.3500, RelErr: +0.80%
#   P_l23_all              | Sim: 0.3928, Target: 0.3920, RelErr: +0.19%
#   P_l45_all              | Sim: 0.2544, Target: 0.2580, RelErr: -1.38%
#   P_home_anc             | Sim: 0.0719, Target: 0.0700, RelErr: +2.67%
#
# RMSE Loss: 0.311690
# -----------------------------
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 7.3078
# Function value obtained: 0.3117
# Current minimum: 0.1133
# Iteration No: 46 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.2241
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4885, Target: 0.3500, RelErr: +39.57%
#   P_l23_all              | Sim: 0.2856, Target: 0.3920, RelErr: -27.15%
#   P_l45_all              | Sim: 0.2260, Target: 0.2580, RelErr: -12.42%
#   P_home_anc             | Sim: 0.0856, Target: 0.0700, RelErr: +22.24%
#
# RMSE Loss: 5.432884
# -----------------------------
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 7.6871
# Function value obtained: 5.4329
# Current minimum: 0.1133
# Iteration No: 47 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6488
#   P_l45_fac             : 0.3330
#   P_home_lowrisk        : 0.1568
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7160
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3254, Target: 0.3500, RelErr: -7.04%
#   P_l23_all              | Sim: 0.4146, Target: 0.3920, RelErr: +5.78%
#   P_l45_all              | Sim: 0.2600, Target: 0.2580, RelErr: +0.77%
#   P_home_anc             | Sim: 0.0706, Target: 0.0700, RelErr: +0.85%
#
# RMSE Loss: 0.917509
# -----------------------------
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 7.3055
# Function value obtained: 0.9175
# Current minimum: 0.1133
# Iteration No: 48 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2510, Target: 0.3500, RelErr: -28.29%
#   P_l23_all              | Sim: 0.3750, Target: 0.3920, RelErr: -4.33%
#   P_l45_all              | Sim: 0.3740, Target: 0.2580, RelErr: +44.95%
#   P_home_anc             | Sim: 0.0540, Target: 0.0700, RelErr: -22.84%
#
# RMSE Loss: 5.796861
# -----------------------------
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 7.2525
# Function value obtained: 5.7969
# Current minimum: 0.1133
# Iteration No: 49 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7233
#   P_l45_fac             : 0.2418
#   P_home_lowrisk        : 0.1806
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3574, Target: 0.3500, RelErr: +2.12%
#   P_l23_all              | Sim: 0.3862, Target: 0.3920, RelErr: -1.48%
#   P_l45_all              | Sim: 0.2564, Target: 0.2580, RelErr: -0.63%
#   P_home_anc             | Sim: 0.0696, Target: 0.0700, RelErr: -0.63%
#
# RMSE Loss: 0.273406
# -----------------------------
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 7.3579
# Function value obtained: 0.2734
# Current minimum: 0.1133
# Iteration No: 50 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7250
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1451
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3593, Target: 0.3500, RelErr: +2.67%
#   P_l23_all              | Sim: 0.3477, Target: 0.3920, RelErr: -11.30%
#   P_l45_all              | Sim: 0.2930, Target: 0.2580, RelErr: +13.55%
#   P_home_anc             | Sim: 0.0722, Target: 0.0700, RelErr: +3.09%
#
# RMSE Loss: 1.811033
# -----------------------------
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 7.4086
# Function value obtained: 1.8110
# Current minimum: 0.1133
# Iteration No: 51 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7088
#   P_l45_fac             : 0.3019
#   P_home_lowrisk        : 0.1717
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3489, Target: 0.3500, RelErr: -0.31%
#   P_l23_all              | Sim: 0.3850, Target: 0.3920, RelErr: -1.79%
#   P_l45_all              | Sim: 0.2661, Target: 0.2580, RelErr: +3.13%
#   P_home_anc             | Sim: 0.0658, Target: 0.0700, RelErr: -5.95%
#
# RMSE Loss: 0.696555
# -----------------------------
#
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 7.5498
# Function value obtained: 0.6966
# Current minimum: 0.1133
# Iteration No: 52 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7148
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.2013
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3580, Target: 0.3500, RelErr: +2.29%
#   P_l23_all              | Sim: 0.4031, Target: 0.3920, RelErr: +2.82%
#   P_l45_all              | Sim: 0.2389, Target: 0.2580, RelErr: -7.40%
#   P_home_anc             | Sim: 0.0772, Target: 0.0700, RelErr: +10.24%
#
# RMSE Loss: 1.314791
# -----------------------------
#
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 7.5519
# Function value obtained: 1.3148
# Current minimum: 0.1133
# Iteration No: 53 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6979
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1715
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3440, Target: 0.3500, RelErr: -1.71%
#   P_l23_all              | Sim: 0.3114, Target: 0.3920, RelErr: -20.56%
#   P_l45_all              | Sim: 0.3446, Target: 0.2580, RelErr: +33.56%
#   P_home_anc             | Sim: 0.0662, Target: 0.0700, RelErr: -5.41%
#
# RMSE Loss: 3.976675
# -----------------------------
#
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 7.4211
# Function value obtained: 3.9767
# Current minimum: 0.1133
# Iteration No: 54 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7454
#   P_l45_fac             : 0.2955
#   P_home_lowrisk        : 0.1753
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6644
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3694, Target: 0.3500, RelErr: +5.55%
#   P_l23_all              | Sim: 0.3809, Target: 0.3920, RelErr: -2.83%
#   P_l45_all              | Sim: 0.2497, Target: 0.2580, RelErr: -3.23%
#   P_home_anc             | Sim: 0.0740, Target: 0.0700, RelErr: +5.71%
#
# RMSE Loss: 0.904580
# -----------------------------
#
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 7.5702
# Function value obtained: 0.9046
# Current minimum: 0.1133
# Iteration No: 55 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6772
#   P_l45_fac             : 0.3576
#   P_home_lowrisk        : 0.1385
#   P_L23_highrisk        : 0.2736
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3364, Target: 0.3500, RelErr: -3.89%
#   P_l23_all              | Sim: 0.3818, Target: 0.3920, RelErr: -2.61%
#   P_l45_all              | Sim: 0.2818, Target: 0.2580, RelErr: +9.24%
#   P_home_anc             | Sim: 0.0693, Target: 0.0700, RelErr: -1.03%
#
# RMSE Loss: 1.041010
# -----------------------------
#
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 7.5547
# Function value obtained: 1.0410
# Current minimum: 0.1133
# Iteration No: 56 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7195
#   P_l45_fac             : 0.2560
#   P_home_lowrisk        : 0.1602
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3513, Target: 0.3500, RelErr: +0.38%
#   P_l23_all              | Sim: 0.3897, Target: 0.3920, RelErr: -0.59%
#   P_l45_all              | Sim: 0.2590, Target: 0.2580, RelErr: +0.39%
#   P_home_anc             | Sim: 0.0618, Target: 0.0700, RelErr: -11.67%
#
# RMSE Loss: 1.169420
# -----------------------------
#
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 7.5279
# Function value obtained: 1.1694
# Current minimum: 0.1133
# Iteration No: 57 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6867
#   P_l45_fac             : 0.3058
#   P_home_lowrisk        : 0.1984
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3452, Target: 0.3500, RelErr: -1.36%
#   P_l23_all              | Sim: 0.3864, Target: 0.3920, RelErr: -1.43%
#   P_l45_all              | Sim: 0.2684, Target: 0.2580, RelErr: +4.02%
#   P_home_anc             | Sim: 0.0761, Target: 0.0700, RelErr: +8.69%
#
# RMSE Loss: 0.977666
# -----------------------------
#
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 7.4963
# Function value obtained: 0.9777
# Current minimum: 0.1133
# Iteration No: 58 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7117
#   P_l45_fac             : 0.2023
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3408, Target: 0.3500, RelErr: -2.62%
#   P_l23_all              | Sim: 0.3513, Target: 0.3920, RelErr: -10.37%
#   P_l45_all              | Sim: 0.3078, Target: 0.2580, RelErr: +19.32%
#   P_home_anc             | Sim: 0.0498, Target: 0.0700, RelErr: -28.80%
#
# RMSE Loss: 3.629088
# -----------------------------
#
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 7.5757
# Function value obtained: 3.6291
# Current minimum: 0.1133
# Iteration No: 59 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7597
#   P_l45_fac             : 0.3639
#   P_home_lowrisk        : 0.1492
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7309
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3726, Target: 0.3500, RelErr: +6.47%
#   P_l23_all              | Sim: 0.3823, Target: 0.3920, RelErr: -2.46%
#   P_l45_all              | Sim: 0.2450, Target: 0.2580, RelErr: -5.03%
#   P_home_anc             | Sim: 0.0687, Target: 0.0700, RelErr: -1.80%
#
# RMSE Loss: 0.874335
# -----------------------------
#
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 7.6471
# Function value obtained: 0.8743
# Current minimum: 0.1133
# ...
#   P_home_anc             | Sim: 0.0729, Target: 0.0700, RelErr: +4.08%
#
# RMSE Loss: 0.507534
# -----------------------------
#
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 7.9626
# Function value obtained: 0.5075
# Current minimum: 0.1028
# Iteration No: 100 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6865
#   P_l45_fac             : 0.3740
#   P_home_lowrisk        : 0.1205
#   P_L23_highrisk        : 0.2530
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3380, Target: 0.3500, RelErr: -3.43%
#   P_l23_all              | Sim: 0.3876, Target: 0.3920, RelErr: -1.13%
#   P_l45_all              | Sim: 0.2744, Target: 0.2580, RelErr: +6.37%
#   P_home_anc             | Sim: 0.0651, Target: 0.0700, RelErr: -7.03%
#
# RMSE Loss: 1.015261
# -----------------------------
#
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 7.9428
# Function value obtained: 1.0153
# Current minimum: 0.1028
# Iteration No: 101 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6973
#   P_l45_fac             : 0.1377
#   P_home_lowrisk        : 0.1468
#   P_L23_highrisk        : 0.2859
#   Sen_traditional       : 0.6205
#   Spec_traditional      : 0.6811
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3452, Target: 0.3500, RelErr: -1.37%
#   P_l23_all              | Sim: 0.3977, Target: 0.3920, RelErr: +1.46%
#   P_l45_all              | Sim: 0.2571, Target: 0.2580, RelErr: -0.35%
#   P_home_anc             | Sim: 0.0690, Target: 0.0700, RelErr: -1.50%
#
# RMSE Loss: 0.252481
# -----------------------------
#
# Iteration No: 101 ended. Search finished for the next optimal point.
# Time taken: 7.9483
# Function value obtained: 0.2525
# Current minimum: 0.1028
# Iteration No: 102 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6886
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1568
#   P_L23_highrisk        : 0.2773
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6627
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3401, Target: 0.3500, RelErr: -2.84%
#   P_l23_all              | Sim: 0.3892, Target: 0.3920, RelErr: -0.71%
#   P_l45_all              | Sim: 0.2707, Target: 0.2580, RelErr: +4.93%
#   P_home_anc             | Sim: 0.0660, Target: 0.0700, RelErr: -5.74%
#
# RMSE Loss: 0.810880
# -----------------------------
#
# Iteration No: 102 ended. Search finished for the next optimal point.
# Time taken: 8.0833
# Function value obtained: 0.8109
# Current minimum: 0.1028
# Iteration No: 103 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7145
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1418
#   P_L23_highrisk        : 0.2410
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7289
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3536, Target: 0.3500, RelErr: +1.03%
#   P_l23_all              | Sim: 0.3929, Target: 0.3920, RelErr: +0.23%
#   P_l45_all              | Sim: 0.2535, Target: 0.2580, RelErr: -1.75%
#   P_home_anc             | Sim: 0.0705, Target: 0.0700, RelErr: +0.75%
#
# RMSE Loss: 0.217437
# -----------------------------
#
# Iteration No: 103 ended. Search finished for the next optimal point.
# Time taken: 8.0179
# Function value obtained: 0.2174
# Current minimum: 0.1028
# Iteration No: 104 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6946
#   P_l45_fac             : 0.1722
#   P_home_lowrisk        : 0.1379
#   P_L23_highrisk        : 0.2558
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7438
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3441, Target: 0.3500, RelErr: -1.69%
#   P_l23_all              | Sim: 0.3987, Target: 0.3920, RelErr: +1.71%
#   P_l45_all              | Sim: 0.2572, Target: 0.2580, RelErr: -0.32%
#   P_home_anc             | Sim: 0.0698, Target: 0.0700, RelErr: -0.29%
#
# RMSE Loss: 0.244427
# -----------------------------
#
# Iteration No: 104 ended. Search finished for the next optimal point.
# Time taken: 7.9592
# Function value obtained: 0.2444
# Current minimum: 0.1028
# Iteration No: 105 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7248
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1398
#   P_L23_highrisk        : 0.2433
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7239
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3575, Target: 0.3500, RelErr: +2.15%
#   P_l23_all              | Sim: 0.3891, Target: 0.3920, RelErr: -0.75%
#   P_l45_all              | Sim: 0.2534, Target: 0.2580, RelErr: -1.79%
#   P_home_anc             | Sim: 0.0691, Target: 0.0700, RelErr: -1.25%
#
# RMSE Loss: 0.315230
# -----------------------------
#
# Iteration No: 105 ended. Search finished for the next optimal point.
# Time taken: 7.9541
# Function value obtained: 0.3152
# Current minimum: 0.1028
# Iteration No: 106 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6826
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1458
#   P_L23_highrisk        : 0.2378
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7331
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3408, Target: 0.3500, RelErr: -2.63%
#   P_l23_all              | Sim: 0.4045, Target: 0.3920, RelErr: +3.18%
#   P_l45_all              | Sim: 0.2548, Target: 0.2580, RelErr: -1.25%
#   P_home_anc             | Sim: 0.0728, Target: 0.0700, RelErr: +4.00%
#
# RMSE Loss: 0.588528
# -----------------------------
#
# Iteration No: 106 ended. Search finished for the next optimal point.
# Time taken: 8.1575
# Function value obtained: 0.5885
# Current minimum: 0.1028
# Iteration No: 107 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7117
#   P_l45_fac             : 0.2018
#   P_home_lowrisk        : 0.1338
#   P_L23_highrisk        : 0.2626
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7445
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3506, Target: 0.3500, RelErr: +0.18%
#   P_l23_all              | Sim: 0.3920, Target: 0.3920, RelErr: +0.01%
#   P_l45_all              | Sim: 0.2573, Target: 0.2580, RelErr: -0.26%
#   P_home_anc             | Sim: 0.0680, Target: 0.0700, RelErr: -2.85%
#
# RMSE Loss: 0.286895
# -----------------------------
#
# Iteration No: 107 ended. Search finished for the next optimal point.
# Time taken: 7.7432
# Function value obtained: 0.2869
# Current minimum: 0.1028
# Iteration No: 108 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7425
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1377
#   P_L23_highrisk        : 0.2371
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.7153
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3647, Target: 0.3500, RelErr: +4.21%
#   P_l23_all              | Sim: 0.3792, Target: 0.3920, RelErr: -3.27%
#   P_l45_all              | Sim: 0.2561, Target: 0.2580, RelErr: -0.75%
#   P_home_anc             | Sim: 0.0674, Target: 0.0700, RelErr: -3.67%
#
# RMSE Loss: 0.651476
# -----------------------------
#
# Iteration No: 108 ended. Search finished for the next optimal point.
# Time taken: 7.9469
# Function value obtained: 0.6515
# Current minimum: 0.1028
# Iteration No: 109 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7021
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1579
#   P_L23_highrisk        : 0.2628
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6405
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3485, Target: 0.3500, RelErr: -0.41%
#   P_l23_all              | Sim: 0.3864, Target: 0.3920, RelErr: -1.42%
#   P_l45_all              | Sim: 0.2650, Target: 0.2580, RelErr: +2.73%
#   P_home_anc             | Sim: 0.0707, Target: 0.0700, RelErr: +1.02%
#
# RMSE Loss: 0.326675
# -----------------------------
#
# Iteration No: 109 ended. Search finished for the next optimal point.
# Time taken: 8.0623
# Function value obtained: 0.3267
# Current minimum: 0.1028
# Iteration No: 110 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6926
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1690
#   P_L23_highrisk        : 0.2740
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3449, Target: 0.3500, RelErr: -1.44%
#   P_l23_all              | Sim: 0.3849, Target: 0.3920, RelErr: -1.80%
#   P_l45_all              | Sim: 0.2701, Target: 0.2580, RelErr: +4.70%
#   P_home_anc             | Sim: 0.0715, Target: 0.0700, RelErr: +2.21%
#
# RMSE Loss: 0.568332
# -----------------------------
#
# Iteration No: 110 ended. Search finished for the next optimal point.
# Time taken: 8.0761
# Function value obtained: 0.5683
# Current minimum: 0.1028
# Iteration No: 111 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4698, Target: 0.3500, RelErr: +34.23%
#   P_l23_all              | Sim: 0.3440, Target: 0.3920, RelErr: -12.24%
#   P_l45_all              | Sim: 0.1862, Target: 0.2580, RelErr: -27.85%
#   P_home_anc             | Sim: 0.0536, Target: 0.0700, RelErr: -23.45%
#
# RMSE Loss: 5.144905
# -----------------------------
#
# Iteration No: 111 ended. Search finished for the next optimal point.
# Time taken: 8.1246
# Function value obtained: 5.1449
# Current minimum: 0.1028
# Iteration No: 112 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6906
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1892
#   P_L23_highrisk        : 0.3006
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3444, Target: 0.3500, RelErr: -1.59%
#   P_l23_all              | Sim: 0.3810, Target: 0.3920, RelErr: -2.81%
#   P_l45_all              | Sim: 0.2746, Target: 0.2580, RelErr: +6.42%
#   P_home_anc             | Sim: 0.0720, Target: 0.0700, RelErr: +2.93%
#
# RMSE Loss: 0.775764
# -----------------------------
#
# Iteration No: 112 ended. Search finished for the next optimal point.
# Time taken: 7.9472
# Function value obtained: 0.7758
# Current minimum: 0.1028
# Iteration No: 113 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6855
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1534
#   P_L23_highrisk        : 0.2469
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6774
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3420, Target: 0.3500, RelErr: -2.29%
#   P_l23_all              | Sim: 0.3947, Target: 0.3920, RelErr: +0.69%
#   P_l45_all              | Sim: 0.2633, Target: 0.2580, RelErr: +2.05%
#   P_home_anc             | Sim: 0.0722, Target: 0.0700, RelErr: +3.10%
#
# RMSE Loss: 0.441896
# -----------------------------
#
# Iteration No: 113 ended. Search finished for the next optimal point.
# Time taken: 8.2080
# Function value obtained: 0.4419
# Current minimum: 0.1028
# Iteration No: 114 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7203
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1487
#   P_L23_highrisk        : 0.2792
#   Sen_traditional       : 0.6000
#   Spec_traditional      : 0.6453
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3547, Target: 0.3500, RelErr: +1.34%
#   P_l23_all              | Sim: 0.3869, Target: 0.3920, RelErr: -1.29%
#   P_l45_all              | Sim: 0.2584, Target: 0.2580, RelErr: +0.14%
#   P_home_anc             | Sim: 0.0672, Target: 0.0700, RelErr: -3.99%
#
# RMSE Loss: 0.441046
# -----------------------------
#
# Iteration No: 114 ended. Search finished for the next optimal point.
# Time taken: 8.6495
# Function value obtained: 0.4410
# Current minimum: 0.1028
# Iteration No: 115 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5000
#   P_l45_fac             : 0.3132
#   P_home_lowrisk        : 0.5000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6865
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3339, Target: 0.3500, RelErr: -4.60%
#   P_l23_all              | Sim: 0.2835, Target: 0.3920, RelErr: -27.69%
#   P_l45_all              | Sim: 0.3826, Target: 0.2580, RelErr: +48.31%
#   P_home_anc             | Sim: 0.2021, Target: 0.0700, RelErr: +188.71%
#
# RMSE Loss: 19.680935
# -----------------------------
#
# Iteration No: 115 ended. Search finished for the next optimal point.
# Time taken: 8.4753
# Function value obtained: 19.6809
# Current minimum: 0.1028
# Iteration No: 116 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7008
#   P_l45_fac             : 0.2174
#   P_home_lowrisk        : 0.1736
#   P_L23_highrisk        : 0.3392
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6366
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3479, Target: 0.3500, RelErr: -0.61%
#   P_l23_all              | Sim: 0.3822, Target: 0.3920, RelErr: -2.51%
#   P_l45_all              | Sim: 0.2700, Target: 0.2580, RelErr: +4.64%
#   P_home_anc             | Sim: 0.0702, Target: 0.0700, RelErr: +0.33%
#
# RMSE Loss: 0.532118
# -----------------------------
#
# Iteration No: 116 ended. Search finished for the next optimal point.
# Time taken: 8.4373
# Function value obtained: 0.5321
# Current minimum: 0.1028
# Iteration No: 117 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7080
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1573
#   P_L23_highrisk        : 0.2797
#   Sen_traditional       : 0.6838
#   Spec_traditional      : 0.6692
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3509, Target: 0.3500, RelErr: +0.26%
#   P_l23_all              | Sim: 0.3892, Target: 0.3920, RelErr: -0.71%
#   P_l45_all              | Sim: 0.2599, Target: 0.2580, RelErr: +0.73%
#   P_home_anc             | Sim: 0.0705, Target: 0.0700, RelErr: +0.72%
#
# RMSE Loss: 0.127550
# -----------------------------
#
# Iteration No: 117 ended. Search finished for the next optimal point.
# Time taken: 7.9168
# Function value obtained: 0.1275
# Current minimum: 0.1028
# Iteration No: 118 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7052
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1526
#   P_L23_highrisk        : 0.2759
#   Sen_traditional       : 0.6897
#   Spec_traditional      : 0.6873
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3492, Target: 0.3500, RelErr: -0.22%
#   P_l23_all              | Sim: 0.3925, Target: 0.3920, RelErr: +0.12%
#   P_l45_all              | Sim: 0.2583, Target: 0.2580, RelErr: +0.12%
#   P_home_anc             | Sim: 0.0699, Target: 0.0700, RelErr: -0.21%
#
# RMSE Loss: 0.034802
# -----------------------------
#
#
# ⏹️ Early stopping triggered. RMSE: 0.034802
#
# ✅ Optimization stopped early.
# Best RMSE achieved: 0.034802
# Best Parameters:
#   P_home_noANC          : 0.7052
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1526
#   P_L23_highrisk        : 0.2759
#   Sen_traditional       : 0.6897
#   Spec_traditional      : 0.6873
