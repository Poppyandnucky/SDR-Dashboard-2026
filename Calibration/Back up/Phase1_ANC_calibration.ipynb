# %%
import random
import numpy as np
import streamlit as st
import math
from parameters import get_parameters
from global_func import odds_prob


# Initialize parameters
P = {}  # dict to restore probabilities
n = {}  # dict to restore counts
E = {}  # dict to restore effects
S = {}  # dict to restore supplies and capacities
OR = {}  # dict to restore odds ratio
M = {}  # dict to restore maternal outcomes

#known parameters
param = get_parameters()
LB_tot = np.array([23729, 18196, 20709, 5126])
P["highrisk_all"] = 0.26                                              # high risk pregnancies among all live births
P["ANC"] = 0.56

# Calibration criteria
P["home_all"] = param["home_all_target"]
P["l23_all"] = param["l23_all_target"]
P["l45_all"] = param["l45_all_target"]
P["home_anc"] = param["home_anc_target"]

# %%
random.seed(0)
def f_ANC_LB_effect(P_home_noANC, P_l45_fac, P_home_lowrisk, P_L23_highrisk, Sen_traditional, Spec_traditional):
    # Initialize parameters

    GA = param['GA_sequence']
    GA_n = len(GA)
    n["GA"] = param["GA_distribution"]
    P["GA"] = n["GA"] / np.sum(n["GA"])
    PT_mask = np.array([1] * 10 + [0] * 8, dtype=bool)
    FT_mask = ~PT_mask
    P["GA"][PT_mask] = P["GA"][PT_mask] * param["PT_scale"]  # scale P[GA|PT] to match kenya level
    P_mult = (1 - np.sum(P["GA"][PT_mask])) / np.sum(P["GA"][FT_mask])
    P["GA"][FT_mask] *= P_mult

    OR["ANC"] = param["OR_preterm_ANC"]
    Preterm_rate = np.sum(P["GA"][PT_mask])  # overall preterm rate

    preterm_anc_noanc = odds_prob(OR["ANC"], Preterm_rate, P["ANC"])
    P["GA_anc"] = P["GA"].copy()
    P_scale_anc = preterm_anc_noanc[0] / Preterm_rate
    P["GA_anc"][PT_mask] *= P_scale_anc
    P_mult = (1 - preterm_anc_noanc[0]) / np.sum(P["GA_anc"][FT_mask])
    P["GA_anc"][FT_mask] *= P_mult

    P["GA_noanc"] = P["GA"].copy()
    P_scale_noanc = preterm_anc_noanc[1] / Preterm_rate
    P["GA_noanc"][PT_mask] *= P_scale_noanc
    P_mult = (1 - preterm_anc_noanc[1]) / np.sum(P["GA_noanc"][FT_mask])
    P["GA_noanc"][FT_mask] *= P_mult

    E["Preterm_LMP"] = np.zeros(3)
    E["Preterm_LMP"][0], E["Preterm_LMP"][1] = param['E_Preterm_LMP'][0], param['E_Preterm_LMP'][1]
    E["Preterm_LMP"][2] = 1 - (E["Preterm_LMP"][0] + E["Preterm_LMP"][1])
    E["Postterm_LMP"] = np.zeros(3)
    E["Postterm_LMP"][0], E["Postterm_LMP"][1] = param['E_Postterm_LMP'][0], param['E_Postterm_LMP'][1]
    E["Postterm_LMP"][2] = 1 - (E["Postterm_LMP"][0] + E["Postterm_LMP"][1])

    P_fac_noANC = 1 - P_home_noANC
    P_L45_noANC = P_fac_noANC * P_l45_fac
    P_L23_noANC = P_fac_noANC - P_L45_noANC

    # Initialize counters
    n["highrisk"] = np.zeros(4)                                           #number of high-risk pregnancies by facility levels
    n["ANC"] = np.zeros(4)                                                #number of 4+ANC by facility levels
    n["LB_L"] = np.zeros(4)                                               #number of delivery location by facility levels
    M["PT"] = np.zeros(4)
    M["Postterm"] = np.zeros(4)
    M["GA"] = np.zeros((4, GA_n))  # GA distributions by facility levels

    for k_LB in range(np.sum(LB_tot)):
        i_risk = np.random.binomial(1, P["highrisk_all"])
        i_ANC = np.random.binomial(1, P["ANC"])
        if i_ANC:
            P_GA = P["GA_anc"]
        else:
            P_GA = P["GA_noanc"]
        i_jGA = np.searchsorted(np.cumsum(P_GA), np.random.rand())  # % actual index of GA
        i_GA = GA[i_jGA]  # % actual GA

        if i_GA < 37:
            i_term_status = 0   #% 0 = preterm, 1 = full term, 2 = postterm
        elif i_GA >= 43:
            i_term_status = 2
        else:
            i_term_status = 1

        if i_ANC == 0:
            i_loc = np.random.choice([0, 1, 2], p=[P_home_noANC, P_L23_noANC, P_L45_noANC])
        else:
            # Risk stratification
            if i_risk:
                i_risk_pred = 1 if np.random.random() < Sen_traditional else 0
            else:
                i_risk_pred = 0 if np.random.random() < Spec_traditional else 1

            # Gestational age estimation
            i_preterm_pred = 1 if np.random.random() < E["Preterm_LMP"][i_term_status] else 0
            i_postterm_pred = 1 if np.random.random() < E["Postterm_LMP"][i_term_status] else 0

            if i_risk_pred or i_preterm_pred == 1 or i_postterm_pred == 1:
                i_loc = np.random.choice([0, 1, 2], p=[0, P_L23_highrisk, 1 - P_L23_highrisk])
            else:
                i_loc = np.random.choice([0, 1, 2], p=[P_home_lowrisk, (1 - P_home_lowrisk) * 0.89, (1 - P_home_lowrisk) * 0.11])

        # assume among all live births at L45, 5126/(20709 + 5126) going to L5
        P_l5_l45 = 5126 / (20709 + 5126)
        if i_loc == 2 and np.random.random() < P_l5_l45:
            i_loc = 3

        # restore results
        n["highrisk"][i_loc] += i_risk
        n["ANC"][i_loc]      += i_ANC
        n["LB_L"][i_loc]     += 1
        M["GA"][i_loc, i_jGA] += 1
        M["PT"][i_loc] += i_term_status == 0
        M["Postterm"][i_loc] += i_term_status == 2

    # Predicted outcomes
    P_home_all = n["LB_L"][0] / np.sum(LB_tot)
    P_l23_all = n["LB_L"][1] / np.sum(LB_tot)
    P_l45_all = (n["LB_L"][2] + n["LB_L"][3]) / np.sum(LB_tot)
    P_home_anc = n["ANC"][0] / np.sum(n["ANC"])
    P_l23_anc = n["ANC"][1] / np.sum(n["ANC"])
    P_l45_anc = (n["ANC"][2] + n["ANC"][3]) / np.sum(n["ANC"])
    P_preterm_fac = np.sum(M["PT"][1:]) / np.sum(n["LB_L"][1:])
    P_preterm_home = M["PT"][0] / n["LB_L"][0]
    P_preterm_l23 = M["PT"][1] / n["LB_L"][1]
    P_preterm_l45 = (M["PT"][2] + M["PT"][3]) / n["LB_L"][2:4].sum()

    return P_home_all, P_l23_all, P_l45_all, P_home_anc, P_l23_anc, P_l45_anc, P_preterm_fac, P_preterm_home, P_preterm_l23, P_preterm_l45

# %%
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# Calibration targets
target_values = {
    "P_home_all": P["home_all"],
    "P_l23_all": P["l23_all"],
    "P_l45_all": P["l45_all"],
    "P_home_anc": P["home_anc"],
}

target_weights = {
    "P_home_all": (P["home_all"], 5),   # ±5% tolerance
    "P_l23_all":  (P["l23_all"], 5),
    "P_l45_all":  (P["l45_all"], 5),
    "P_home_anc": (P["home_anc"], 5),
}

def weighted_rmse(df_results, target_weights):
    weighted_errors = []
    for metric, (target, accepted_pct) in target_weights.items():
        simulated = df_results.get(metric, 0)
        error = simulated - target
        accepted_abs_error = target * (accepted_pct / 100)
        if accepted_abs_error == 0:  # safeguard
            continue
        normalized_error = error / accepted_abs_error
        weighted_errors.append(normalized_error**2)
    return math.sqrt(sum(weighted_errors) / len(weighted_errors))

# Define parameter space
param_space = [
    Real(0.35, 1, name='P_home_noANC'),
    Real(0.01, 0.5, name='P_l45_fac'),
    Real(0.01, 0.5, name='P_home_lowrisk'),
    Real(0.01, 0.4, name='P_L23_highrisk'),
    Real(0.5, 0.8, name='Sen_traditional'),
    Real(0.5, 0.8, name='Spec_traditional')
]

# Seeds for reproducibility
total_runs = 10
seeds = np.random.default_rng(2025).integers(low=0, high=1e6, size=total_runs)

# Track RMSE history
rmse_history = []

@use_named_args(param_space)
def objective(**params):
    results = []
    for run in range(total_runs):
        np.random.seed(seeds[run])
        res = f_ANC_LB_effect(
            params['P_home_noANC'],
            params['P_l45_fac'],
            params['P_home_lowrisk'],
            params['P_L23_highrisk'],
            params['Sen_traditional'],
            params['Spec_traditional']
        )
        results.append(res)

    # Average across runs
    mean_results = np.mean(results, axis=0)
    df_results = {
        "P_home_all": mean_results[0],
        "P_l23_all": mean_results[1],
        "P_l45_all": mean_results[2],
        "P_home_anc": mean_results[3],
    }

    # Save last results for early stopper
    objective.last_df_results = df_results

    # Compute relative RMSE
    #rel_sq_err = [((df_results[k] - target_values[k]) / target_values[k]) ** 2 for k in target_values]
    #rmse = math.sqrt(sum(rel_sq_err) / len(rel_sq_err))
    rmse = weighted_rmse(df_results, target_weights)

    # Print status
    print("\n--- Calibration Iteration ---")
    print("Parameters:")
    for k, v in params.items():
        print(f"  {k:22s}: {v:.4f}")
    print("\nTarget vs Simulated Outcomes:")
    for k in target_values:
        sim = df_results[k]
        target = target_values[k]
        error = sim - target
        rel_error = error / target
        print(f"  {k:22s} | Sim: {sim:.4f}, Target: {target:.4f}, RelErr: {rel_error:+.2%}")
    print(f"\nRMSE Loss: {rmse:.6f}")
    print("-----------------------------\n")

    return rmse

class EarlyStopper:
    def __init__(self, threshold_rmse=0.05, relative_threshold=0.05):
        self.threshold_rmse = threshold_rmse
        self.relative_threshold = relative_threshold
        self.best_loss = float('inf')
        self.best_params = None
        self.best_df_results = None

    # def meets_relative_criteria(self, sim_results):
    #     for k in target_values:
    #         target = target_values[k]
    #         sim = sim_results.get(k, 0)
    #         rel_error = abs(sim - target) / target
    #         if rel_error > self.relative_threshold:
    #             return False
    #     return True
    def meets_relative_criteria(self, sim_results):
        for metric, (target, accepted_pct) in target_weights.items():
            sim = sim_results.get(metric, 0)
            rel_error = abs(sim - target) / target
            if rel_error > (accepted_pct / 100):
                return False
        return True

    def __call__(self, *args, **kwargs):
        loss = objective(*args, **kwargs)
        rmse_history.append(loss)

        if loss < self.best_loss:
            self.best_loss = loss
            self.best_params = args[0] if args else None
            self.best_df_results = getattr(objective, "last_df_results", {})

        if self.best_loss < self.threshold_rmse and self.meets_relative_criteria(self.best_df_results):
            print(f"\n⏹️ Early stopping triggered. RMSE: {self.best_loss:.6f}")
            raise StopIteration

        return loss

def save_results(best_params, best_loss, rmse_history, param_space):
    param_names = [dim.name for dim in param_space]
    best_param_dict = dict(zip(param_names, best_params))
    best_param_dict["Best RMSE"] = best_loss
    df_best = pd.DataFrame([best_param_dict])
    df_best.to_csv("best_parameters_ANC_v1.csv", index=False)

    pd.DataFrame({"Iteration": range(1, len(rmse_history)+1), "RMSE": rmse_history}).to_csv("rmse_history_ANC_v1.csv", index=False)

    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(rmse_history)+1), rmse_history, marker='o')
    plt.xlabel("Iteration")
    plt.ylabel("RMSE Loss")
    plt.title("RMSE Loss Over Iterations")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("rmse_plot_ANC_v1.png")
    plt.close()

def optimize_model():
    early_stopper = EarlyStopper(threshold_rmse=0.05, relative_threshold=0.05)
    try:
        result = gp_minimize(
            func=early_stopper,
            dimensions=param_space,
            n_calls=200,
            random_state=42,
            n_random_starts=20,
            acq_func="EI",
            verbose=True
        )
        print("\n✅ Optimization completed.")
        print("Best Parameters:", result.x)
        print("Best Loss:", result.fun)
        save_results(result.x, result.fun, rmse_history, param_space)
        return result

    except StopIteration:
        print("\n✅ Optimization stopped early.")
        print(f"Best RMSE achieved: {early_stopper.best_loss:.6f}")
        if early_stopper.best_params is not None:
            print("Best Parameters:")
            for name, val in zip([d.name for d in param_space], early_stopper.best_params):
                print(f"  {name:22s}: {val:.4f}")
            save_results(early_stopper.best_params, early_stopper.best_loss, rmse_history, param_space)
        return None

if __name__ == "__main__":
    optimize_model()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8678
#   P_l45_fac             : 0.0999
#   P_home_lowrisk        : 0.3920
#   P_L23_highrisk        : 0.2428
#   Sen_traditional       : 0.6337
#   Spec_traditional      : 0.5300
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4647, Target: 0.3500, RelErr: +32.77%
#   P_l23_all              | Sim: 0.2513, Target: 0.3920, RelErr: -35.90%
#   P_l45_all              | Sim: 0.2840, Target: 0.2580, RelErr: +10.09%
#   P_home_anc             | Sim: 0.1468, Target: 0.0700, RelErr: +109.70%
#
# RMSE Loss: 12.041133
# -----------------------------
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 6.5193
# Function value obtained: 12.0411
# Current minimum: 12.0411
# Iteration No: 2 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6485
#   P_l45_fac             : 0.1735
#   P_home_lowrisk        : 0.0800
#   P_L23_highrisk        : 0.2638
#   Sen_traditional       : 0.5169
#   Spec_traditional      : 0.7166
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3078, Target: 0.3500, RelErr: -12.05%
#   P_l23_all              | Sim: 0.4328, Target: 0.3920, RelErr: +10.41%
#   P_l45_all              | Sim: 0.2594, Target: 0.2580, RelErr: +0.53%
#   P_home_anc             | Sim: 0.0407, Target: 0.0700, RelErr: -41.81%
#
# RMSE Loss: 4.474493
# -----------------------------
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 6.5645
# Function value obtained: 4.4745
# Current minimum: 4.4745
# Iteration No: 3 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9601
#   P_l45_fac             : 0.0104
#   P_home_lowrisk        : 0.4962
#   P_L23_highrisk        : 0.2508
#   Sen_traditional       : 0.6835
#   Spec_traditional      : 0.5021
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5202, Target: 0.3500, RelErr: +48.62%
#   P_l23_all              | Sim: 0.1960, Target: 0.3920, RelErr: -49.99%
#   P_l45_all              | Sim: 0.2838, Target: 0.2580, RelErr: +10.00%
#   P_home_anc             | Sim: 0.1733, Target: 0.0700, RelErr: +147.56%
#
# RMSE Loss: 16.351580
# -----------------------------
#
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 6.5777
# Function value obtained: 16.3516
# Current minimum: 4.4745
# Iteration No: 4 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.3650
#   P_l45_fac             : 0.2671
#   P_home_lowrisk        : 0.2059
#   P_L23_highrisk        : 0.0282
#   Sen_traditional       : 0.7921
#   Spec_traditional      : 0.5698
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2038, Target: 0.3500, RelErr: -41.76%
#   P_l23_all              | Sim: 0.3587, Target: 0.3920, RelErr: -8.49%
#   P_l45_all              | Sim: 0.4374, Target: 0.2580, RelErr: +69.55%
#   P_home_anc             | Sim: 0.0760, Target: 0.0700, RelErr: +8.60%
#
# RMSE Loss: 8.202152
# -----------------------------
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 6.6036
# Function value obtained: 8.2022
# Current minimum: 4.4745
# Iteration No: 5 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.4089
#   P_l45_fac             : 0.3130
#   P_home_lowrisk        : 0.1974
#   P_L23_highrisk        : 0.3935
#   Sen_traditional       : 0.6400
#   Spec_traditional      : 0.7580
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2362, Target: 0.3500, RelErr: -32.51%
#   P_l23_all              | Sim: 0.4889, Target: 0.3920, RelErr: +24.71%
#   P_l45_all              | Sim: 0.2749, Target: 0.2580, RelErr: +6.55%
#   P_home_anc             | Sim: 0.0996, Target: 0.0700, RelErr: +42.24%
#
# RMSE Loss: 5.911414
# -----------------------------
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 6.6459
# Function value obtained: 5.9114
# Current minimum: 4.4745
# Iteration No: 6 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7922
#   P_l45_fac             : 0.2307
#   P_home_lowrisk        : 0.0165
#   P_L23_highrisk        : 0.3775
#   Sen_traditional       : 0.6690
#   Spec_traditional      : 0.6156
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3530, Target: 0.3500, RelErr: +0.85%
#   P_l23_all              | Sim: 0.3976, Target: 0.3920, RelErr: +1.43%
#   P_l45_all              | Sim: 0.2494, Target: 0.2580, RelErr: -3.33%
#   P_home_anc             | Sim: 0.0069, Target: 0.0700, RelErr: -90.21%
#
# RMSE Loss: 9.028522
# -----------------------------
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 6.7011
# Function value obtained: 9.0285
# Current minimum: 4.4745
# Iteration No: 7 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.3604
#   P_l45_fac             : 0.1231
#   P_home_lowrisk        : 0.1281
#   P_L23_highrisk        : 0.2765
#   Sen_traditional       : 0.6830
#   Spec_traditional      : 0.7500
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.1944, Target: 0.3500, RelErr: -44.46%
#   P_l23_all              | Sim: 0.5384, Target: 0.3920, RelErr: +37.34%
#   P_l45_all              | Sim: 0.2672, Target: 0.2580, RelErr: +3.58%
#   P_home_anc             | Sim: 0.0636, Target: 0.0700, RelErr: -9.18%
#
# RMSE Loss: 5.889469
# -----------------------------
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 6.6762
# Function value obtained: 5.8895
# Current minimum: 4.4745
# Iteration No: 8 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.4627
#   P_l45_fac             : 0.2016
#   P_home_lowrisk        : 0.0993
#   P_L23_highrisk        : 0.3046
#   Sen_traditional       : 0.6275
#   Spec_traditional      : 0.5624
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2265, Target: 0.3500, RelErr: -35.28%
#   P_l23_all              | Sim: 0.4694, Target: 0.3920, RelErr: +19.74%
#   P_l45_all              | Sim: 0.3041, Target: 0.2580, RelErr: +17.86%
#   P_home_anc             | Sim: 0.0398, Target: 0.0700, RelErr: -43.19%
#
# RMSE Loss: 6.179364
# -----------------------------
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 6.6723
# Function value obtained: 6.1794
# Current minimum: 4.4745
# Iteration No: 9 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7190
#   P_l45_fac             : 0.0253
#   P_home_lowrisk        : 0.4227
#   P_L23_highrisk        : 0.1854
#   Sen_traditional       : 0.6185
#   Spec_traditional      : 0.7780
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4396, Target: 0.3500, RelErr: +25.59%
#   P_l23_all              | Sim: 0.3192, Target: 0.3920, RelErr: -18.56%
#   P_l45_all              | Sim: 0.2412, Target: 0.2580, RelErr: -6.52%
#   P_home_anc             | Sim: 0.2203, Target: 0.0700, RelErr: +214.67%
#
# RMSE Loss: 21.708229
# -----------------------------
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 6.6877
# Function value obtained: 21.7082
# Current minimum: 4.4745
# Iteration No: 10 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8227
#   P_l45_fac             : 0.1700
#   P_home_lowrisk        : 0.2895
#   P_L23_highrisk        : 0.2131
#   Sen_traditional       : 0.7884
#   Spec_traditional      : 0.7534
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4391, Target: 0.3500, RelErr: +25.45%
#   P_l23_all              | Sim: 0.2942, Target: 0.3920, RelErr: -24.95%
#   P_l45_all              | Sim: 0.2667, Target: 0.2580, RelErr: +3.38%
#   P_home_anc             | Sim: 0.1374, Target: 0.0700, RelErr: +96.33%
#
# RMSE Loss: 10.276921
# -----------------------------
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 6.6440
# Function value obtained: 10.2769
# Current minimum: 4.4745
# Iteration No: 11 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8358
#   P_l45_fac             : 0.2744
#   P_home_lowrisk        : 0.2975
#   P_L23_highrisk        : 0.3864
#   Sen_traditional       : 0.6821
#   Spec_traditional      : 0.5828
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4347, Target: 0.3500, RelErr: +24.20%
#   P_l23_all              | Sim: 0.3212, Target: 0.3920, RelErr: -18.07%
#   P_l45_all              | Sim: 0.2441, Target: 0.2580, RelErr: -5.38%
#   P_home_anc             | Sim: 0.1183, Target: 0.0700, RelErr: +68.95%
#
# RMSE Loss: 7.546500
# -----------------------------
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 6.6359
# Function value obtained: 7.5465
# Current minimum: 4.4745
# Iteration No: 12 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5426
#   P_l45_fac             : 0.0910
#   P_home_lowrisk        : 0.0177
#   P_L23_highrisk        : 0.1751
#   Sen_traditional       : 0.6185
#   Spec_traditional      : 0.5880
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2432, Target: 0.3500, RelErr: -30.53%
#   P_l23_all              | Sim: 0.4423, Target: 0.3920, RelErr: +12.83%
#   P_l45_all              | Sim: 0.3146, Target: 0.2580, RelErr: +21.92%
#   P_home_anc             | Sim: 0.0076, Target: 0.0700, RelErr: -89.09%
#
# RMSE Loss: 9.754142
# -----------------------------
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 6.6288
# Function value obtained: 9.7541
# Current minimum: 4.4745
# Iteration No: 13 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.3592
#   P_l45_fac             : 0.1074
#   P_home_lowrisk        : 0.3586
#   P_L23_highrisk        : 0.3182
#   Sen_traditional       : 0.6818
#   Spec_traditional      : 0.7779
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2602, Target: 0.3500, RelErr: -25.67%
#   P_l23_all              | Sim: 0.5014, Target: 0.3920, RelErr: +27.91%
#   P_l45_all              | Sim: 0.2384, Target: 0.2580, RelErr: -7.58%
#   P_home_anc             | Sim: 0.1818, Target: 0.0700, RelErr: +159.65%
#
# RMSE Loss: 16.426852
# -----------------------------
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 6.6585
# Function value obtained: 16.4269
# Current minimum: 4.4745
# Iteration No: 14 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7732
#   P_l45_fac             : 0.4583
#   P_home_lowrisk        : 0.4265
#   P_L23_highrisk        : 0.1853
#   Sen_traditional       : 0.5286
#   Spec_traditional      : 0.6112
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4457, Target: 0.3500, RelErr: +27.35%
#   P_l23_all              | Sim: 0.2382, Target: 0.3920, RelErr: -39.23%
#   P_l45_all              | Sim: 0.3161, Target: 0.2580, RelErr: +22.51%
#   P_home_anc             | Sim: 0.1883, Target: 0.0700, RelErr: +168.98%
#
# RMSE Loss: 17.704871
# -----------------------------
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 6.6905
# Function value obtained: 17.7049
# Current minimum: 4.4745
# Iteration No: 15 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7847
#   P_l45_fac             : 0.3363
#   P_home_lowrisk        : 0.2997
#   P_L23_highrisk        : 0.1171
#   Sen_traditional       : 0.6684
#   Spec_traditional      : 0.6149
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4163, Target: 0.3500, RelErr: +18.93%
#   P_l23_all              | Sim: 0.2453, Target: 0.3920, RelErr: -37.43%
#   P_l45_all              | Sim: 0.3385, Target: 0.2580, RelErr: +31.19%
#   P_home_anc             | Sim: 0.1257, Target: 0.0700, RelErr: +79.51%
#
# RMSE Loss: 9.515263
# -----------------------------
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 6.6979
# Function value obtained: 9.5153
# Current minimum: 4.4745
# Iteration No: 16 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9816
#   P_l45_fac             : 0.4260
#   P_home_lowrisk        : 0.3636
#   P_L23_highrisk        : 0.1020
#   Sen_traditional       : 0.5768
#   Spec_traditional      : 0.5121
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5097, Target: 0.3500, RelErr: +45.62%
#   P_l23_all              | Sim: 0.1591, Target: 0.3920, RelErr: -59.41%
#   P_l45_all              | Sim: 0.3312, Target: 0.2580, RelErr: +28.38%
#   P_home_anc             | Sim: 0.1373, Target: 0.0700, RelErr: +96.20%
#
# RMSE Loss: 12.518005
# -----------------------------
#
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 6.6918
# Function value obtained: 12.5180
# Current minimum: 4.4745
# Iteration No: 17 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.8119
#   P_l45_fac             : 0.0643
#   P_home_lowrisk        : 0.2253
#   P_L23_highrisk        : 0.0887
#   Sen_traditional       : 0.7687
#   Spec_traditional      : 0.6426
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4103, Target: 0.3500, RelErr: +17.23%
#   P_l23_all              | Sim: 0.2646, Target: 0.3920, RelErr: -32.50%
#   P_l45_all              | Sim: 0.3251, Target: 0.2580, RelErr: +26.01%
#   P_home_anc             | Sim: 0.0932, Target: 0.0700, RelErr: +33.19%
#
# RMSE Loss: 5.595412
# -----------------------------
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 6.7449
# Function value obtained: 5.5954
# Current minimum: 4.4745
# Iteration No: 18 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7161
#   P_l45_fac             : 0.3508
#   P_home_lowrisk        : 0.0783
#   P_L23_highrisk        : 0.2457
#   Sen_traditional       : 0.6620
#   Spec_traditional      : 0.5609
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3323, Target: 0.3500, RelErr: -5.05%
#   P_l23_all              | Sim: 0.3440, Target: 0.3920, RelErr: -12.25%
#   P_l45_all              | Sim: 0.3237, Target: 0.2580, RelErr: +25.46%
#   P_home_anc             | Sim: 0.0305, Target: 0.0700, RelErr: -56.45%
#
# RMSE Loss: 6.332826
# -----------------------------
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 6.7231
# Function value obtained: 6.3328
# Current minimum: 4.4745
# Iteration No: 19 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9629
#   P_l45_fac             : 0.3034
#   P_home_lowrisk        : 0.3504
#   P_L23_highrisk        : 0.3534
#   Sen_traditional       : 0.6873
#   Spec_traditional      : 0.5887
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.5023, Target: 0.3500, RelErr: +43.52%
#   P_l23_all              | Sim: 0.2590, Target: 0.3920, RelErr: -33.94%
#   P_l45_all              | Sim: 0.2387, Target: 0.2580, RelErr: -7.48%
#   P_home_anc             | Sim: 0.1391, Target: 0.0700, RelErr: +98.68%
#
# RMSE Loss: 11.331571
# -----------------------------
#
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 6.7028
# Function value obtained: 11.3316
# Current minimum: 4.4745
# Iteration No: 20 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.4186
#   P_l45_fac             : 0.2337
#   P_home_lowrisk        : 0.1170
#   P_L23_highrisk        : 0.1724
#   Sen_traditional       : 0.7650
#   Spec_traditional      : 0.5973
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2109, Target: 0.3500, RelErr: -39.75%
#   P_l23_all              | Sim: 0.4245, Target: 0.3920, RelErr: +8.30%
#   P_l45_all              | Sim: 0.3646, Target: 0.2580, RelErr: +41.31%
#   P_home_anc             | Sim: 0.0461, Target: 0.0700, RelErr: -34.20%
#
# RMSE Loss: 6.727311
# -----------------------------
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 6.9200
# Function value obtained: 6.7273
# Current minimum: 4.4745
# Iteration No: 21 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1556
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.6739
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4824, Target: 0.3500, RelErr: +37.84%
#   P_l23_all              | Sim: 0.3191, Target: 0.3920, RelErr: -18.61%
#   P_l45_all              | Sim: 0.1985, Target: 0.2580, RelErr: -23.06%
#   P_home_anc             | Sim: 0.0757, Target: 0.0700, RelErr: +8.18%
#
# RMSE Loss: 4.875151
# -----------------------------
#
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 6.9752
# Function value obtained: 4.8752
# Current minimum: 4.4745
# Iteration No: 22 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.0788
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4647, Target: 0.3500, RelErr: +32.77%
#   P_l23_all              | Sim: 0.3548, Target: 0.3920, RelErr: -9.49%
#   P_l45_all              | Sim: 0.1805, Target: 0.2580, RelErr: -30.02%
#   P_home_anc             | Sim: 0.0441, Target: 0.0700, RelErr: -37.04%
#
# RMSE Loss: 5.863122
# -----------------------------
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 7.0731
# Function value obtained: 5.8631
# Current minimum: 4.4745
# Iteration No: 23 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.0876
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.7479
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4657, Target: 0.3500, RelErr: +33.05%
#   P_l23_all              | Sim: 0.3455, Target: 0.3920, RelErr: -11.86%
#   P_l45_all              | Sim: 0.1888, Target: 0.2580, RelErr: -26.82%
#   P_home_anc             | Sim: 0.0463, Target: 0.0700, RelErr: -33.89%
#
# RMSE Loss: 5.568388
# -----------------------------
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 6.9735
# Function value obtained: 5.5684
# Current minimum: 4.4745
# Iteration No: 24 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 1.0000
#   P_l45_fac             : 0.0260
#   P_home_lowrisk        : 0.1675
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.6394
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4843, Target: 0.3500, RelErr: +38.38%
#   P_l23_all              | Sim: 0.3122, Target: 0.3920, RelErr: -20.35%
#   P_l45_all              | Sim: 0.2034, Target: 0.2580, RelErr: -21.15%
#   P_home_anc             | Sim: 0.0781, Target: 0.0700, RelErr: +11.61%
#
# RMSE Loss: 4.968867
# -----------------------------
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 7.1536
# Function value obtained: 4.9689
# Current minimum: 4.4745
# Iteration No: 25 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7099
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1476
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6216
#   Spec_traditional      : 0.6910
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3515, Target: 0.3500, RelErr: +0.44%
#   P_l23_all              | Sim: 0.4439, Target: 0.3920, RelErr: +13.24%
#   P_l45_all              | Sim: 0.2046, Target: 0.2580, RelErr: -20.71%
#   P_home_anc             | Sim: 0.0698, Target: 0.0700, RelErr: -0.22%
#
# RMSE Loss: 2.458548
# -----------------------------
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 6.9376
# Function value obtained: 2.4585
# Current minimum: 2.4585
# Iteration No: 26 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6955
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1345
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3435, Target: 0.3500, RelErr: -1.85%
#   P_l23_all              | Sim: 0.4589, Target: 0.3920, RelErr: +17.07%
#   P_l45_all              | Sim: 0.1976, Target: 0.2580, RelErr: -23.43%
#   P_home_anc             | Sim: 0.0667, Target: 0.0700, RelErr: -4.71%
#
# RMSE Loss: 2.942399
# -----------------------------
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 7.1069
# Function value obtained: 2.9424
# Current minimum: 2.4585
# Iteration No: 27 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6884
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1576
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.6757
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3461, Target: 0.3500, RelErr: -1.10%
#   P_l23_all              | Sim: 0.4543, Target: 0.3920, RelErr: +15.89%
#   P_l45_all              | Sim: 0.1996, Target: 0.2580, RelErr: -22.65%
#   P_home_anc             | Sim: 0.0768, Target: 0.0700, RelErr: +9.78%
#
# RMSE Loss: 2.936435
# -----------------------------
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 6.9043
# Function value obtained: 2.9364
# Current minimum: 2.4585
# Iteration No: 28 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7413
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1587
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6648
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3638, Target: 0.3500, RelErr: +3.93%
#   P_l23_all              | Sim: 0.4179, Target: 0.3920, RelErr: +6.60%
#   P_l45_all              | Sim: 0.2184, Target: 0.2580, RelErr: -15.37%
#   P_home_anc             | Sim: 0.0670, Target: 0.0700, RelErr: -4.22%
#
# RMSE Loss: 1.769036
# -----------------------------
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 6.9312
# Function value obtained: 1.7690
# Current minimum: 1.7690
# Iteration No: 29 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7487
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1684
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6029
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3662, Target: 0.3500, RelErr: +4.64%
#   P_l23_all              | Sim: 0.4058, Target: 0.3920, RelErr: +3.51%
#   P_l45_all              | Sim: 0.2280, Target: 0.2580, RelErr: -11.63%
#   P_home_anc             | Sim: 0.0650, Target: 0.0700, RelErr: -7.19%
#
# RMSE Loss: 1.485945
# -----------------------------
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 7.0264
# Function value obtained: 1.4859
# Current minimum: 1.4859
# Iteration No: 30 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7604
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1877
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.5000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3690, Target: 0.3500, RelErr: +5.42%
#   P_l23_all              | Sim: 0.3871, Target: 0.3920, RelErr: -1.25%
#   P_l45_all              | Sim: 0.2439, Target: 0.2580, RelErr: -5.45%
#   P_home_anc             | Sim: 0.0610, Target: 0.0700, RelErr: -12.84%
#
# RMSE Loss: 1.502256
# -----------------------------
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 7.0717
# Function value obtained: 1.5023
# Current minimum: 1.4859
# Iteration No: 31 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7530
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1770
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.5567
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3678, Target: 0.3500, RelErr: +5.08%
#   P_l23_all              | Sim: 0.3445, Target: 0.3920, RelErr: -12.13%
#   P_l45_all              | Sim: 0.2878, Target: 0.2580, RelErr: +11.53%
#   P_home_anc             | Sim: 0.0636, Target: 0.0700, RelErr: -9.19%
#
# RMSE Loss: 1.975751
# -----------------------------
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 7.0707
# Function value obtained: 1.9758
# Current minimum: 1.4859
# Iteration No: 32 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7329
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1777
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.5540
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3586, Target: 0.3500, RelErr: +2.47%
#   P_l23_all              | Sim: 0.4061, Target: 0.3920, RelErr: +3.61%
#   P_l45_all              | Sim: 0.2352, Target: 0.2580, RelErr: -8.83%
#   P_home_anc             | Sim: 0.0635, Target: 0.0700, RelErr: -9.28%
#
# RMSE Loss: 1.353165
# -----------------------------
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 7.1360
# Function value obtained: 1.3532
# Current minimum: 1.3532
# Iteration No: 33 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6847
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1860
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.5408
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3380, Target: 0.3500, RelErr: -3.42%
#   P_l23_all              | Sim: 0.4249, Target: 0.3920, RelErr: +8.38%
#   P_l45_all              | Sim: 0.2371, Target: 0.2580, RelErr: -8.10%
#   P_home_anc             | Sim: 0.0649, Target: 0.0700, RelErr: -7.31%
#
# RMSE Loss: 1.418103
# -----------------------------
#
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 7.0910
# Function value obtained: 1.4181
# Current minimum: 1.3532
# Iteration No: 34 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.3731
#   P_l45_fac             : 0.1878
#   P_home_lowrisk        : 0.4841
#   P_L23_highrisk        : 0.3639
#   Sen_traditional       : 0.7974
#   Spec_traditional      : 0.5075
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2535, Target: 0.3500, RelErr: -27.57%
#   P_l23_all              | Sim: 0.4460, Target: 0.3920, RelErr: +13.79%
#   P_l45_all              | Sim: 0.3005, Target: 0.2580, RelErr: +16.46%
#   P_home_anc             | Sim: 0.1590, Target: 0.0700, RelErr: +127.14%
#
# RMSE Loss: 13.185110
# -----------------------------
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 7.0853
# Function value obtained: 13.1851
# Current minimum: 1.3532
# Iteration No: 35 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.3500
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.0100
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.1578, Target: 0.3500, RelErr: -54.92%
#   P_l23_all              | Sim: 0.5156, Target: 0.3920, RelErr: +31.52%
#   P_l45_all              | Sim: 0.3266, Target: 0.2580, RelErr: +26.61%
#   P_home_anc             | Sim: 0.0056, Target: 0.0700, RelErr: -92.03%
#
# RMSE Loss: 11.483313
# -----------------------------
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 7.1852
# Function value obtained: 11.4833
# Current minimum: 1.3532
# Iteration No: 36 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9327
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.0976
#   P_L23_highrisk        : 0.0100
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4383, Target: 0.3500, RelErr: +25.23%
#   P_l23_all              | Sim: 0.2543, Target: 0.3920, RelErr: -35.14%
#   P_l45_all              | Sim: 0.3074, Target: 0.2580, RelErr: +19.16%
#   P_home_anc             | Sim: 0.0484, Target: 0.0700, RelErr: -30.85%
#
# RMSE Loss: 5.648470
# -----------------------------
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 7.0200
# Function value obtained: 5.6485
# Current minimum: 1.3532
# Iteration No: 37 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6975
#   P_l45_fac             : 0.0309
#   P_home_lowrisk        : 0.1780
#   P_L23_highrisk        : 0.3103
#   Sen_traditional       : 0.7865
#   Spec_traditional      : 0.5506
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3431, Target: 0.3500, RelErr: -1.96%
#   P_l23_all              | Sim: 0.3871, Target: 0.3920, RelErr: -1.24%
#   P_l45_all              | Sim: 0.2697, Target: 0.2580, RelErr: +4.54%
#   P_home_anc             | Sim: 0.0634, Target: 0.0700, RelErr: -9.38%
#
# RMSE Loss: 1.067395
# -----------------------------
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 7.2001
# Function value obtained: 1.0674
# Current minimum: 1.0674
# Iteration No: 38 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7260
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1816
#   P_L23_highrisk        : 0.3220
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.5506
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3561, Target: 0.3500, RelErr: +1.74%
#   P_l23_all              | Sim: 0.3802, Target: 0.3920, RelErr: -3.02%
#   P_l45_all              | Sim: 0.2637, Target: 0.2580, RelErr: +2.23%
#   P_home_anc             | Sim: 0.0643, Target: 0.0700, RelErr: -8.13%
#
# RMSE Loss: 0.912069
# -----------------------------
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 7.2182
# Function value obtained: 0.9121
# Current minimum: 0.9121
# Iteration No: 39 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7398
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1982
#   P_L23_highrisk        : 0.2965
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.5000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3620, Target: 0.3500, RelErr: +3.42%
#   P_l23_all              | Sim: 0.3552, Target: 0.3920, RelErr: -9.38%
#   P_l45_all              | Sim: 0.2828, Target: 0.2580, RelErr: +9.61%
#   P_home_anc             | Sim: 0.0643, Target: 0.0700, RelErr: -8.19%
#
# RMSE Loss: 1.609174
# -----------------------------
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 7.1017
# Function value obtained: 1.6092
# Current minimum: 0.9121
# Iteration No: 40 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7347
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1693
#   P_L23_highrisk        : 0.3145
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6093
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3608, Target: 0.3500, RelErr: +3.09%
#   P_l23_all              | Sim: 0.3834, Target: 0.3920, RelErr: -2.20%
#   P_l45_all              | Sim: 0.2558, Target: 0.2580, RelErr: -0.85%
#   P_home_anc             | Sim: 0.0658, Target: 0.0700, RelErr: -6.00%
#
# RMSE Loss: 0.714872
# -----------------------------
#
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 7.0401
# Function value obtained: 0.7149
# Current minimum: 0.7149
# Iteration No: 41 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7676
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1558
#   P_L23_highrisk        : 0.2884
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6689
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3748, Target: 0.3500, RelErr: +7.09%
#   P_l23_all              | Sim: 0.3718, Target: 0.3920, RelErr: -5.16%
#   P_l45_all              | Sim: 0.2534, Target: 0.2580, RelErr: -1.77%
#   P_home_anc             | Sim: 0.0661, Target: 0.0700, RelErr: -5.62%
#
# RMSE Loss: 1.056169
# -----------------------------
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 7.1663
# Function value obtained: 1.0562
# Current minimum: 0.7149
# Iteration No: 42 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7053
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1754
#   P_L23_highrisk        : 0.3147
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6164
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3496, Target: 0.3500, RelErr: -0.11%
#   P_l23_all              | Sim: 0.3958, Target: 0.3920, RelErr: +0.97%
#   P_l45_all              | Sim: 0.2546, Target: 0.2580, RelErr: -1.32%
#   P_home_anc             | Sim: 0.0688, Target: 0.0700, RelErr: -1.75%
#
# RMSE Loss: 0.239689
# -----------------------------
#
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 7.0019
# Function value obtained: 0.2397
# Current minimum: 0.2397
# Iteration No: 43 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6483
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1824
#   P_L23_highrisk        : 0.2979
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6426
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3273, Target: 0.3500, RelErr: -6.49%
#   P_l23_all              | Sim: 0.4173, Target: 0.3920, RelErr: +6.45%
#   P_l45_all              | Sim: 0.2554, Target: 0.2580, RelErr: -1.00%
#   P_home_anc             | Sim: 0.0740, Target: 0.0700, RelErr: +5.72%
#
# RMSE Loss: 1.083740
# -----------------------------
#
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 7.0343
# Function value obtained: 1.0837
# Current minimum: 0.2397
# Iteration No: 44 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.3500
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.2367
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.5000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.1978, Target: 0.3500, RelErr: -43.49%
#   P_l23_all              | Sim: 0.5574, Target: 0.3920, RelErr: +42.19%
#   P_l45_all              | Sim: 0.2449, Target: 0.2580, RelErr: -5.10%
#   P_home_anc             | Sim: 0.0770, Target: 0.0700, RelErr: +9.95%
#
# RMSE Loss: 6.161438
# -----------------------------
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 7.0275
# Function value obtained: 6.1614
# Current minimum: 0.2397
# Iteration No: 45 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7237
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1487
#   P_L23_highrisk        : 0.2220
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3597, Target: 0.3500, RelErr: +2.79%
#   P_l23_all              | Sim: 0.3934, Target: 0.3920, RelErr: +0.35%
#   P_l45_all              | Sim: 0.2469, Target: 0.2580, RelErr: -4.30%
#   P_home_anc             | Sim: 0.0737, Target: 0.0700, RelErr: +5.34%
#
# RMSE Loss: 0.740980
# -----------------------------
#
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 6.9207
# Function value obtained: 0.7410
# Current minimum: 0.2397
# Iteration No: 46 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7906
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1452
#   P_L23_highrisk        : 0.2463
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3880, Target: 0.3500, RelErr: +10.85%
#   P_l23_all              | Sim: 0.3274, Target: 0.3920, RelErr: -16.48%
#   P_l45_all              | Sim: 0.2846, Target: 0.2580, RelErr: +10.32%
#   P_home_anc             | Sim: 0.0725, Target: 0.0700, RelErr: +3.50%
#
# RMSE Loss: 2.254000
# -----------------------------
#
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 7.0257
# Function value obtained: 2.2540
# Current minimum: 0.2397
# Iteration No: 47 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6339
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1488
#   P_L23_highrisk        : 0.1540
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3206, Target: 0.3500, RelErr: -8.41%
#   P_l23_all              | Sim: 0.4127, Target: 0.3920, RelErr: +5.29%
#   P_l45_all              | Sim: 0.2667, Target: 0.2580, RelErr: +3.36%
#   P_home_anc             | Sim: 0.0740, Target: 0.0700, RelErr: +5.64%
#
# RMSE Loss: 1.191156
# -----------------------------
#
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 7.0081
# Function value obtained: 1.1912
# Current minimum: 0.2397
# Iteration No: 48 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6802
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1549
#   P_L23_highrisk        : 0.1855
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3475, Target: 0.3500, RelErr: -0.72%
#   P_l23_all              | Sim: 0.4198, Target: 0.3920, RelErr: +7.09%
#   P_l45_all              | Sim: 0.2327, Target: 0.2580, RelErr: -9.80%
#   P_home_anc             | Sim: 0.0864, Target: 0.0700, RelErr: +23.37%
#
# RMSE Loss: 2.632511
# -----------------------------
#
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 7.0326
# Function value obtained: 2.6325
# Current minimum: 0.2397
# Iteration No: 49 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6660
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1541
#   P_L23_highrisk        : 0.2511
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.7117
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3320, Target: 0.3500, RelErr: -5.14%
#   P_l23_all              | Sim: 0.4107, Target: 0.3920, RelErr: +4.77%
#   P_l45_all              | Sim: 0.2573, Target: 0.2580, RelErr: -0.28%
#   P_home_anc             | Sim: 0.0686, Target: 0.0700, RelErr: -2.00%
#
# RMSE Loss: 0.729940
# -----------------------------
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 6.9955
# Function value obtained: 0.7299
# Current minimum: 0.2397
# Iteration No: 50 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.3500
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.0100
#   P_L23_highrisk        : 0.0100
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.1575, Target: 0.3500, RelErr: -54.99%
#   P_l23_all              | Sim: 0.5295, Target: 0.3920, RelErr: +35.07%
#   P_l45_all              | Sim: 0.3130, Target: 0.2580, RelErr: +21.32%
#   P_home_anc             | Sim: 0.0051, Target: 0.0700, RelErr: -92.76%
#
# RMSE Loss: 11.538331
# -----------------------------
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 7.3433
# Function value obtained: 11.5383
# Current minimum: 0.2397
# Iteration No: 51 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6346
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1630
#   P_L23_highrisk        : 0.2515
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3246, Target: 0.3500, RelErr: -7.27%
#   P_l23_all              | Sim: 0.4368, Target: 0.3920, RelErr: +11.42%
#   P_l45_all              | Sim: 0.2387, Target: 0.2580, RelErr: -7.50%
#   P_home_anc             | Sim: 0.0809, Target: 0.0700, RelErr: +15.64%
#
# RMSE Loss: 2.200422
# -----------------------------
#
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 7.0750
# Function value obtained: 2.2004
# Current minimum: 0.2397
# Iteration No: 52 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7074
#   P_l45_fac             : 0.0100
#   P_home_lowrisk        : 0.1482
#   P_L23_highrisk        : 0.2044
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6964
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3483, Target: 0.3500, RelErr: -0.50%
#   P_l23_all              | Sim: 0.3767, Target: 0.3920, RelErr: -3.90%
#   P_l45_all              | Sim: 0.2750, Target: 0.2580, RelErr: +6.61%
#   P_home_anc             | Sim: 0.0649, Target: 0.0700, RelErr: -7.31%
#
# RMSE Loss: 1.060886
# -----------------------------
#
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 6.9262
# Function value obtained: 1.0609
# Current minimum: 0.2397
# Iteration No: 53 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.9997
#   P_l45_fac             : 0.0394
#   P_home_lowrisk        : 0.1472
#   P_L23_highrisk        : 0.2309
#   Sen_traditional       : 0.7487
#   Spec_traditional      : 0.5304
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4708, Target: 0.3500, RelErr: +34.53%
#   P_l23_all              | Sim: 0.2329, Target: 0.3920, RelErr: -40.59%
#   P_l45_all              | Sim: 0.2963, Target: 0.2580, RelErr: +14.83%
#   P_home_anc             | Sim: 0.0526, Target: 0.0700, RelErr: -24.83%
#
# RMSE Loss: 6.063002
# -----------------------------
#
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 7.0553
# Function value obtained: 6.0630
# Current minimum: 0.2397
# Iteration No: 54 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6463
#   P_l45_fac             : 0.2390
#   P_home_lowrisk        : 0.1947
#   P_L23_highrisk        : 0.2533
#   Sen_traditional       : 0.5061
#   Spec_traditional      : 0.5171
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3274, Target: 0.3500, RelErr: -6.45%
#   P_l23_all              | Sim: 0.3629, Target: 0.3920, RelErr: -7.43%
#   P_l45_all              | Sim: 0.3097, Target: 0.2580, RelErr: +20.03%
#   P_home_anc             | Sim: 0.0770, Target: 0.0700, RelErr: +9.98%
#
# RMSE Loss: 2.444694
# -----------------------------
#
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 7.0463
# Function value obtained: 2.4447
# Current minimum: 0.2397
# Iteration No: 55 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6366
#   P_l45_fac             : 0.2070
#   P_home_lowrisk        : 0.1575
#   P_L23_highrisk        : 0.2477
#   Sen_traditional       : 0.7876
#   Spec_traditional      : 0.6487
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3169, Target: 0.3500, RelErr: -9.46%
#   P_l23_all              | Sim: 0.3811, Target: 0.3920, RelErr: -2.77%
#   P_l45_all              | Sim: 0.3020, Target: 0.2580, RelErr: +17.04%
#   P_home_anc             | Sim: 0.0655, Target: 0.0700, RelErr: -6.37%
#
# RMSE Loss: 2.068615
# -----------------------------
#
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 6.9625
# Function value obtained: 2.0686
# Current minimum: 0.2397
# Iteration No: 56 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.5595
#   P_l45_fac             : 0.1046
#   P_home_lowrisk        : 0.1541
#   P_L23_highrisk        : 0.0180
#   Sen_traditional       : 0.7902
#   Spec_traditional      : 0.7916
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.2894, Target: 0.3500, RelErr: -17.32%
#   P_l23_all              | Sim: 0.3857, Target: 0.3920, RelErr: -1.61%
#   P_l45_all              | Sim: 0.3249, Target: 0.2580, RelErr: +25.94%
#   P_home_anc             | Sim: 0.0768, Target: 0.0700, RelErr: +9.70%
#
# RMSE Loss: 3.270637
# -----------------------------
#
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 7.0009
# Function value obtained: 3.2706
# Current minimum: 0.2397
# Iteration No: 57 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7325
#   P_l45_fac             : 0.2931
#   P_home_lowrisk        : 0.1014
#   P_L23_highrisk        : 0.0899
#   Sen_traditional       : 0.7824
#   Spec_traditional      : 0.7998
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3509, Target: 0.3500, RelErr: +0.25%
#   P_l23_all              | Sim: 0.3314, Target: 0.3920, RelErr: -15.45%
#   P_l45_all              | Sim: 0.3177, Target: 0.2580, RelErr: +23.13%
#   P_home_anc             | Sim: 0.0514, Target: 0.0700, RelErr: -26.61%
#
# RMSE Loss: 3.849591
# -----------------------------
#
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 7.0679
# Function value obtained: 3.8496
# Current minimum: 0.2397
# Iteration No: 58 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6291
#   P_l45_fac             : 0.1386
#   P_home_lowrisk        : 0.1967
#   P_L23_highrisk        : 0.3795
#   Sen_traditional       : 0.5022
#   Spec_traditional      : 0.5016
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3197, Target: 0.3500, RelErr: -8.65%
#   P_l23_all              | Sim: 0.4259, Target: 0.3920, RelErr: +8.64%
#   P_l45_all              | Sim: 0.2544, Target: 0.2580, RelErr: -1.38%
#   P_home_anc             | Sim: 0.0761, Target: 0.0700, RelErr: +8.72%
#
# RMSE Loss: 1.508094
# -----------------------------
#
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 7.1962
# Function value obtained: 1.5081
# Current minimum: 0.2397
# Iteration No: 59 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6595
#   P_l45_fac             : 0.0565
#   P_home_lowrisk        : 0.2024
#   P_L23_highrisk        : 0.3503
#   Sen_traditional       : 0.7856
#   Spec_traditional      : 0.5693
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3325, Target: 0.3500, RelErr: -4.99%
#   P_l23_all              | Sim: 0.4110, Target: 0.3920, RelErr: +4.86%
#   P_l45_all              | Sim: 0.2564, Target: 0.2580, RelErr: -0.60%
#   P_home_anc             | Sim: 0.0746, Target: 0.0700, RelErr: +6.58%
#
# RMSE Loss: 0.960087
# -----------------------------
#
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 7.0716
# Function value obtained: 0.9601
# Current minimum: 0.2397
# ...
#   P_home_anc             | Sim: 0.0699, Target: 0.0700, RelErr: -0.12%
#
# RMSE Loss: 0.143287
# -----------------------------
#
# Iteration No: 181 ended. Search finished for the next optimal point.
# Time taken: 8.3404
# Function value obtained: 0.1433
# Current minimum: 0.1061
# Iteration No: 182 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7051
#   P_l45_fac             : 0.3707
#   P_home_lowrisk        : 0.1403
#   P_L23_highrisk        : 0.3362
#   Sen_traditional       : 0.7615
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3503, Target: 0.3500, RelErr: +0.10%
#   P_l23_all              | Sim: 0.3914, Target: 0.3920, RelErr: -0.14%
#   P_l45_all              | Sim: 0.2582, Target: 0.2580, RelErr: +0.08%
#   P_home_anc             | Sim: 0.0712, Target: 0.0700, RelErr: +1.65%
#
# RMSE Loss: 0.165804
# -----------------------------
#
# Iteration No: 182 ended. Search finished for the next optimal point.
# Time taken: 8.5454
# Function value obtained: 0.1658
# Current minimum: 0.1061
# Iteration No: 183 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7112
#   P_l45_fac             : 0.3492
#   P_home_lowrisk        : 0.1342
#   P_L23_highrisk        : 0.3307
#   Sen_traditional       : 0.7342
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3518, Target: 0.3500, RelErr: +0.51%
#   P_l23_all              | Sim: 0.3939, Target: 0.3920, RelErr: +0.48%
#   P_l45_all              | Sim: 0.2543, Target: 0.2580, RelErr: -1.42%
#   P_home_anc             | Sim: 0.0690, Target: 0.0700, RelErr: -1.48%
#
# RMSE Loss: 0.216576
# -----------------------------
#
# Iteration No: 183 ended. Search finished for the next optimal point.
# Time taken: 8.7051
# Function value obtained: 0.2166
# Current minimum: 0.1061
# Iteration No: 184 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7539
#   P_l45_fac             : 0.3979
#   P_home_lowrisk        : 0.1407
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.6220
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3682, Target: 0.3500, RelErr: +5.21%
#   P_l23_all              | Sim: 0.3818, Target: 0.3920, RelErr: -2.59%
#   P_l45_all              | Sim: 0.2499, Target: 0.2580, RelErr: -3.13%
#   P_home_anc             | Sim: 0.0646, Target: 0.0700, RelErr: -7.76%
#
# RMSE Loss: 1.019446
# -----------------------------
#
# Iteration No: 184 ended. Search finished for the next optimal point.
# Time taken: 8.5289
# Function value obtained: 1.0194
# Current minimum: 0.1061
# Iteration No: 185 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7050
#   P_l45_fac             : 0.3500
#   P_home_lowrisk        : 0.1442
#   P_L23_highrisk        : 0.3296
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3507, Target: 0.3500, RelErr: +0.20%
#   P_l23_all              | Sim: 0.3895, Target: 0.3920, RelErr: -0.63%
#   P_l45_all              | Sim: 0.2598, Target: 0.2580, RelErr: +0.68%
#   P_home_anc             | Sim: 0.0719, Target: 0.0700, RelErr: +2.76%
#
# RMSE Loss: 0.291513
# -----------------------------
#
# Iteration No: 185 ended. Search finished for the next optimal point.
# Time taken: 8.2979
# Function value obtained: 0.2915
# Current minimum: 0.1061
# Iteration No: 186 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7006
#   P_l45_fac             : 0.2838
#   P_home_lowrisk        : 0.1399
#   P_L23_highrisk        : 0.3010
#   Sen_traditional       : 0.7299
#   Spec_traditional      : 0.7763
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3475, Target: 0.3500, RelErr: -0.71%
#   P_l23_all              | Sim: 0.3922, Target: 0.3920, RelErr: +0.06%
#   P_l45_all              | Sim: 0.2603, Target: 0.2580, RelErr: +0.87%
#   P_home_anc             | Sim: 0.0704, Target: 0.0700, RelErr: +0.51%
#
# RMSE Loss: 0.124083
# -----------------------------
#
# Iteration No: 186 ended. Search finished for the next optimal point.
# Time taken: 8.5759
# Function value obtained: 0.1241
# Current minimum: 0.1061
# Iteration No: 187 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7000
#   P_l45_fac             : 0.2690
#   P_home_lowrisk        : 0.1397
#   P_L23_highrisk        : 0.3031
#   Sen_traditional       : 0.7598
#   Spec_traditional      : 0.7772
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3469, Target: 0.3500, RelErr: -0.90%
#   P_l23_all              | Sim: 0.3937, Target: 0.3920, RelErr: +0.43%
#   P_l45_all              | Sim: 0.2595, Target: 0.2580, RelErr: +0.57%
#   P_home_anc             | Sim: 0.0694, Target: 0.0700, RelErr: -0.90%
#
# RMSE Loss: 0.145717
# -----------------------------
#
# Iteration No: 187 ended. Search finished for the next optimal point.
# Time taken: 8.6844
# Function value obtained: 0.1457
# Current minimum: 0.1061
# Iteration No: 188 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7026
#   P_l45_fac             : 0.2869
#   P_home_lowrisk        : 0.1402
#   P_L23_highrisk        : 0.2977
#   Sen_traditional       : 0.7239
#   Spec_traditional      : 0.7775
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3486, Target: 0.3500, RelErr: -0.39%
#   P_l23_all              | Sim: 0.3908, Target: 0.3920, RelErr: -0.31%
#   P_l45_all              | Sim: 0.2606, Target: 0.2580, RelErr: +1.01%
#   P_home_anc             | Sim: 0.0707, Target: 0.0700, RelErr: +0.98%
#
# RMSE Loss: 0.149376
# -----------------------------
#
# Iteration No: 188 ended. Search finished for the next optimal point.
# Time taken: 8.7160
# Function value obtained: 0.1494
# Current minimum: 0.1061
# Iteration No: 189 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7010
#   P_l45_fac             : 0.2913
#   P_home_lowrisk        : 0.1370
#   P_L23_highrisk        : 0.3095
#   Sen_traditional       : 0.7616
#   Spec_traditional      : 0.7829
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3468, Target: 0.3500, RelErr: -0.91%
#   P_l23_all              | Sim: 0.3938, Target: 0.3920, RelErr: +0.46%
#   P_l45_all              | Sim: 0.2594, Target: 0.2580, RelErr: +0.53%
#   P_home_anc             | Sim: 0.0683, Target: 0.0700, RelErr: -2.46%
#
# RMSE Loss: 0.272010
# -----------------------------
#
# Iteration No: 189 ended. Search finished for the next optimal point.
# Time taken: 8.6816
# Function value obtained: 0.2720
# Current minimum: 0.1061
# Iteration No: 190 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.6524
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1279
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.7065
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3238, Target: 0.3500, RelErr: -7.50%
#   P_l23_all              | Sim: 0.4056, Target: 0.3920, RelErr: +3.47%
#   P_l45_all              | Sim: 0.2706, Target: 0.2580, RelErr: +4.90%
#   P_home_anc             | Sim: 0.0648, Target: 0.0700, RelErr: -7.36%
#
# RMSE Loss: 1.209871
# -----------------------------
#
# Iteration No: 190 ended. Search finished for the next optimal point.
# Time taken: 8.5797
# Function value obtained: 1.2099
# Current minimum: 0.1061
# Iteration No: 191 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7092
#   P_l45_fac             : 0.2244
#   P_home_lowrisk        : 0.1424
#   P_L23_highrisk        : 0.2694
#   Sen_traditional       : 0.7249
#   Spec_traditional      : 0.7606
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3509, Target: 0.3500, RelErr: +0.25%
#   P_l23_all              | Sim: 0.3850, Target: 0.3920, RelErr: -1.78%
#   P_l45_all              | Sim: 0.2641, Target: 0.2580, RelErr: +2.36%
#   P_home_anc             | Sim: 0.0702, Target: 0.0700, RelErr: +0.34%
#
# RMSE Loss: 0.298328
# -----------------------------
#
# Iteration No: 191 ended. Search finished for the next optimal point.
# Time taken: 9.0177
# Function value obtained: 0.2983
# Current minimum: 0.1061
# Iteration No: 192 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7108
#   P_l45_fac             : 0.1434
#   P_home_lowrisk        : 0.1564
#   P_L23_highrisk        : 0.2912
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.6052
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3521, Target: 0.3500, RelErr: +0.61%
#   P_l23_all              | Sim: 0.3868, Target: 0.3920, RelErr: -1.32%
#   P_l45_all              | Sim: 0.2611, Target: 0.2580, RelErr: +1.18%
#   P_home_anc             | Sim: 0.0698, Target: 0.0700, RelErr: -0.34%
#
# RMSE Loss: 0.190611
# -----------------------------
#
# Iteration No: 192 ended. Search finished for the next optimal point.
# Time taken: 8.6290
# Function value obtained: 0.1906
# Current minimum: 0.1061
# Iteration No: 193 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7190
#   P_l45_fac             : 0.1714
#   P_home_lowrisk        : 0.1496
#   P_L23_highrisk        : 0.2829
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.6321
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3556, Target: 0.3500, RelErr: +1.61%
#   P_l23_all              | Sim: 0.3827, Target: 0.3920, RelErr: -2.38%
#   P_l45_all              | Sim: 0.2617, Target: 0.2580, RelErr: +1.42%
#   P_home_anc             | Sim: 0.0695, Target: 0.0700, RelErr: -0.69%
#
# RMSE Loss: 0.327693
# -----------------------------
#
# Iteration No: 193 ended. Search finished for the next optimal point.
# Time taken: 8.8265
# Function value obtained: 0.3277
# Current minimum: 0.1061
# Iteration No: 194 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7091
#   P_l45_fac             : 0.1648
#   P_home_lowrisk        : 0.1684
#   P_L23_highrisk        : 0.3303
#   Sen_traditional       : 0.7653
#   Spec_traditional      : 0.6404
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3514, Target: 0.3500, RelErr: +0.40%
#   P_l23_all              | Sim: 0.3861, Target: 0.3920, RelErr: -1.51%
#   P_l45_all              | Sim: 0.2625, Target: 0.2580, RelErr: +1.75%
#   P_home_anc             | Sim: 0.0699, Target: 0.0700, RelErr: -0.16%
#
# RMSE Loss: 0.235778
# -----------------------------
#
# Iteration No: 194 ended. Search finished for the next optimal point.
# Time taken: 8.7099
# Function value obtained: 0.2358
# Current minimum: 0.1061
# Iteration No: 195 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7107
#   P_l45_fac             : 0.2009
#   P_home_lowrisk        : 0.1576
#   P_L23_highrisk        : 0.3204
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6958
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3513, Target: 0.3500, RelErr: +0.36%
#   P_l23_all              | Sim: 0.3864, Target: 0.3920, RelErr: -1.43%
#   P_l45_all              | Sim: 0.2624, Target: 0.2580, RelErr: +1.69%
#   P_home_anc             | Sim: 0.0693, Target: 0.0700, RelErr: -0.96%
#
# RMSE Loss: 0.244433
# -----------------------------
#
# Iteration No: 195 ended. Search finished for the next optimal point.
# Time taken: 8.7033
# Function value obtained: 0.2444
# Current minimum: 0.1061
# Iteration No: 196 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7085
#   P_l45_fac             : 0.1580
#   P_home_lowrisk        : 0.1631
#   P_L23_highrisk        : 0.3149
#   Sen_traditional       : 0.7001
#   Spec_traditional      : 0.6436
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3510, Target: 0.3500, RelErr: +0.30%
#   P_l23_all              | Sim: 0.3871, Target: 0.3920, RelErr: -1.25%
#   P_l45_all              | Sim: 0.2619, Target: 0.2580, RelErr: +1.50%
#   P_home_anc             | Sim: 0.0700, Target: 0.0700, RelErr: -0.02%
#
# RMSE Loss: 0.197587
# -----------------------------
#
# Iteration No: 196 ended. Search finished for the next optimal point.
# Time taken: 8.6496
# Function value obtained: 0.1976
# Current minimum: 0.1061
# Iteration No: 197 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7021
#   P_l45_fac             : 0.1272
#   P_home_lowrisk        : 0.1275
#   P_L23_highrisk        : 0.1262
#   Sen_traditional       : 0.5000
#   Spec_traditional      : 0.8000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3490, Target: 0.3500, RelErr: -0.28%
#   P_l23_all              | Sim: 0.3873, Target: 0.3920, RelErr: -1.19%
#   P_l45_all              | Sim: 0.2636, Target: 0.2580, RelErr: +2.18%
#   P_home_anc             | Sim: 0.0714, Target: 0.0700, RelErr: +2.01%
#
# RMSE Loss: 0.320419
# -----------------------------
#
# Iteration No: 197 ended. Search finished for the next optimal point.
# Time taken: 8.9931
# Function value obtained: 0.3204
# Current minimum: 0.1061
# Iteration No: 198 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7122
#   P_l45_fac             : 0.2122
#   P_home_lowrisk        : 0.1553
#   P_L23_highrisk        : 0.3212
#   Sen_traditional       : 0.6858
#   Spec_traditional      : 0.6684
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3524, Target: 0.3500, RelErr: +0.70%
#   P_l23_all              | Sim: 0.3867, Target: 0.3920, RelErr: -1.36%
#   P_l45_all              | Sim: 0.2609, Target: 0.2580, RelErr: +1.11%
#   P_home_anc             | Sim: 0.0698, Target: 0.0700, RelErr: -0.23%
#
# RMSE Loss: 0.190316
# -----------------------------
#
# Iteration No: 198 ended. Search finished for the next optimal point.
# Time taken: 9.7725
# Function value obtained: 0.1903
# Current minimum: 0.1061
# Iteration No: 199 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7041
#   P_l45_fac             : 0.1592
#   P_home_lowrisk        : 0.1651
#   P_L23_highrisk        : 0.3184
#   Sen_traditional       : 0.6726
#   Spec_traditional      : 0.6277
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3495, Target: 0.3500, RelErr: -0.16%
#   P_l23_all              | Sim: 0.3882, Target: 0.3920, RelErr: -0.98%
#   P_l45_all              | Sim: 0.2624, Target: 0.2580, RelErr: +1.70%
#   P_home_anc             | Sim: 0.0702, Target: 0.0700, RelErr: +0.35%
#
# RMSE Loss: 0.199498
# -----------------------------
#
# Iteration No: 199 ended. Search finished for the next optimal point.
# Time taken: 9.3518
# Function value obtained: 0.1995
# Current minimum: 0.1061
# Iteration No: 200 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_noANC          : 0.7124
#   P_l45_fac             : 0.2407
#   P_home_lowrisk        : 0.2104
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.5000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3524, Target: 0.3500, RelErr: +0.70%
#   P_l23_all              | Sim: 0.3750, Target: 0.3920, RelErr: -4.35%
#   P_l45_all              | Sim: 0.2726, Target: 0.2580, RelErr: +5.66%
#   P_home_anc             | Sim: 0.0689, Target: 0.0700, RelErr: -1.52%
#
# RMSE Loss: 0.733165
# -----------------------------
#
# Iteration No: 200 ended. Search finished for the next optimal point.
# Time taken: 9.4540
# Function value obtained: 0.7332
# Current minimum: 0.1061
#
# ✅ Optimization completed.
# Best Parameters: [0.7123370252389314, 0.31383299434018885, 0.14000884882152664, 0.3173856818206714, 0.8, 0.8]
# Best Loss: 0.10609408093998655
