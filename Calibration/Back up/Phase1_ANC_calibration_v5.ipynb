# %%
import random
import numpy as np
import streamlit as st
import math
from parameters import get_parameters
from global_func import odds_prob


# Initialize parameters
P = {}  # dict to restore probabilities
n = {}  # dict to restore counts
E = {}  # dict to restore effects
S = {}  # dict to restore supplies and capacities
OR = {}  # dict to restore odds ratio
M = {}  # dict to restore maternal outcomes

#known parameters
param = get_parameters()
LB_tot = np.array([23729, 18196, 20709, 5126])
P["highrisk_all"] = 0.26                                              # high risk pregnancies among all live births
P["ANC"] = 0.56
P["Home_noANC"] = 0.706

# Calibration criteria
P["home_all"] = param["home_all_target"]
P["l23_all"] = param["l23_all_target"]
P["l45_all"] = param["l45_all_target"]
P["home_anc"] = param["home_anc_target"]

# %%
random.seed(0)
def f_ANC_LB_effect(P_l45_fac, P_home_lowrisk, P_L23_highrisk, Sen_traditional, Spec_traditional):
    # Initialize parameters

    GA = param['GA_sequence']
    GA_n = len(GA)
    n["GA"] = param["GA_distribution"]
    P["GA"] = n["GA"] / np.sum(n["GA"])
    PT_mask = np.array([1] * 10 + [0] * 8, dtype=bool)
    FT_mask = ~PT_mask
    P["GA"][PT_mask] = P["GA"][PT_mask] * param["PT_scale"]  # scale P[GA|PT] to match kenya level
    P_mult = (1 - np.sum(P["GA"][PT_mask])) / np.sum(P["GA"][FT_mask])
    P["GA"][FT_mask] *= P_mult

    OR["ANC"] = param["OR_preterm_ANC"]
    Preterm_rate = np.sum(P["GA"][PT_mask])  # overall preterm rate

    preterm_anc_noanc = odds_prob(OR["ANC"], Preterm_rate, P["ANC"])
    P["GA_anc"] = P["GA"].copy()
    P_scale_anc = preterm_anc_noanc[0] / Preterm_rate
    P["GA_anc"][PT_mask] *= P_scale_anc
    P_mult = (1 - preterm_anc_noanc[0]) / np.sum(P["GA_anc"][FT_mask])
    P["GA_anc"][FT_mask] *= P_mult

    P["GA_noanc"] = P["GA"].copy()
    P_scale_noanc = preterm_anc_noanc[1] / Preterm_rate
    P["GA_noanc"][PT_mask] *= P_scale_noanc
    P_mult = (1 - preterm_anc_noanc[1]) / np.sum(P["GA_noanc"][FT_mask])
    P["GA_noanc"][FT_mask] *= P_mult

    E["Preterm_LMP"] = np.zeros(3)
    E["Preterm_LMP"][0], E["Preterm_LMP"][1] = param['E_Preterm_LMP'][0], param['E_Preterm_LMP'][1]
    E["Preterm_LMP"][2] = 1 - (E["Preterm_LMP"][0] + E["Preterm_LMP"][1])
    E["Postterm_LMP"] = np.zeros(3)
    E["Postterm_LMP"][0], E["Postterm_LMP"][1] = param['E_Postterm_LMP'][0], param['E_Postterm_LMP'][1]
    E["Postterm_LMP"][2] = 1 - (E["Postterm_LMP"][0] + E["Postterm_LMP"][1])

    P_home_noANC = P["Home_noANC"]
    P_fac_noANC = 1 - P_home_noANC
    P_L45_noANC = P_fac_noANC * P_l45_fac
    P_L23_noANC = P_fac_noANC - P_L45_noANC

    # Initialize counters
    n["highrisk"] = np.zeros(4)                                           #number of high-risk pregnancies by facility levels
    n["ANC"] = np.zeros(4)                                                #number of 4+ANC by facility levels
    n["LB_L"] = np.zeros(4)                                               #number of delivery location by facility levels
    M["PT"] = np.zeros(4)
    M["Postterm"] = np.zeros(4)
    M["GA"] = np.zeros((4, GA_n))  # GA distributions by facility levels

    for k_LB in range(np.sum(LB_tot)):
        i_risk = np.random.binomial(1, P["highrisk_all"])
        i_ANC = np.random.binomial(1, P["ANC"])
        if i_ANC:
            P_GA = P["GA_anc"]
        else:
            P_GA = P["GA_noanc"]
        i_jGA = np.searchsorted(np.cumsum(P_GA), np.random.rand())  # % actual index of GA
        i_GA = GA[i_jGA]  # % actual GA

        if i_GA < 37:
            i_term_status = 0   #% 0 = preterm, 1 = full term, 2 = postterm
        elif i_GA >= 43:
            i_term_status = 2
        else:
            i_term_status = 1

        if i_ANC == 0:
            i_loc = np.random.choice([0, 1, 2], p=[P_home_noANC, P_L23_noANC, P_L45_noANC])
        else:
            # Risk stratification
            if i_risk:
                i_risk_pred = 1 if np.random.random() < Sen_traditional else 0
            else:
                i_risk_pred = 0 if np.random.random() < Spec_traditional else 1

            # Gestational age estimation
            i_preterm_pred = 1 if np.random.random() < E["Preterm_LMP"][i_term_status] else 0
            i_postterm_pred = 1 if np.random.random() < E["Postterm_LMP"][i_term_status] else 0

            if i_risk_pred or i_preterm_pred == 1 or i_postterm_pred == 1:
                i_loc = np.random.choice([0, 1, 2], p=[0, P_L23_highrisk, 1 - P_L23_highrisk])
            else:
                i_loc = np.random.choice([0, 1, 2], p=[P_home_lowrisk, (1 - P_home_lowrisk) * 0.89, (1 - P_home_lowrisk) * 0.11])

        # assume among all live births at L45, 5126/(20709 + 5126) going to L5
        P_l5_l45 = 5126 / (20709 + 5126)
        if i_loc == 2 and np.random.random() < P_l5_l45:
            i_loc = 3

        # restore results
        n["highrisk"][i_loc] += i_risk
        n["ANC"][i_loc]      += i_ANC
        n["LB_L"][i_loc]     += 1
        M["GA"][i_loc, i_jGA] += 1
        M["PT"][i_loc] += i_term_status == 0
        M["Postterm"][i_loc] += i_term_status == 2

    # Predicted outcomes
    P_home_all = n["LB_L"][0] / np.sum(LB_tot)
    P_l23_all = n["LB_L"][1] / np.sum(LB_tot)
    P_l45_all = (n["LB_L"][2] + n["LB_L"][3]) / np.sum(LB_tot)
    P_home_anc = n["ANC"][0] / np.sum(n["ANC"])
    P_l23_anc = n["ANC"][1] / np.sum(n["ANC"])
    P_l45_anc = (n["ANC"][2] + n["ANC"][3]) / np.sum(n["ANC"])
    P_preterm_fac = np.sum(M["PT"][1:]) / np.sum(n["LB_L"][1:])
    P_preterm_home = M["PT"][0] / n["LB_L"][0]
    P_preterm_l23 = M["PT"][1] / n["LB_L"][1]
    P_preterm_l45 = (M["PT"][2] + M["PT"][3]) / n["LB_L"][2:4].sum()

    return P_home_all, P_l23_all, P_l45_all, P_home_anc, P_l23_anc, P_l45_anc, P_preterm_fac, P_preterm_home, P_preterm_l23, P_preterm_l45

# %%
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# Calibration targets
target_values = {
    "P_home_all": P["home_all"],
    "P_l23_all": P["l23_all"],
    "P_l45_all": P["l45_all"],
    "P_home_anc": P["home_anc"],
}

target_weights = {
    "P_home_all": (P["home_all"], 1),   # ±1% tolerance
    "P_l23_all":  (P["l23_all"], 1),
    "P_l45_all":  (P["l45_all"], 1),
    "P_home_anc": (P["home_anc"], 1),
}

def weighted_rmse(df_results, target_weights):
    weighted_errors = []
    for metric, (target, accepted_pct) in target_weights.items():
        simulated = df_results.get(metric, 0)
        error = simulated - target
        accepted_abs_error = target * (accepted_pct / 100)
        if accepted_abs_error == 0:  # safeguard
            continue
        normalized_error = error / accepted_abs_error
        weighted_errors.append(normalized_error**2)
    return math.sqrt(sum(weighted_errors) / len(weighted_errors))

# Define parameter space
param_space = [
    Real(0.1, 0.5, name='P_l45_fac'),
    Real(0.1, 0.5, name='P_home_lowrisk'),
    Real(0.1, 0.4, name='P_L23_highrisk'),
    Real(0.6, 0.8, name='Sen_traditional'),
    Real(0.6, 0.8, name='Spec_traditional')
]

# Seeds for reproducibility
total_runs = 10
seeds = np.random.default_rng(2025).integers(low=0, high=1e6, size=total_runs)

# Track RMSE history
rmse_history = []

@use_named_args(param_space)
def objective(**params):
    # --- Constraint check: Sen must be greater than Spec ---
    if params['Sen_traditional'] <= params['Spec_traditional']:
        print("\n⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.")
        objective.last_df_results = {}
        return 10.0  # Penalty loss

    results = []
    for run in range(total_runs):
        np.random.seed(seeds[run])
        res = f_ANC_LB_effect(
            params['P_l45_fac'],
            params['P_home_lowrisk'],
            params['P_L23_highrisk'],
            params['Sen_traditional'],
            params['Spec_traditional']
        )
        results.append(res)

    # Average across runs
    mean_results = np.mean(results, axis=0)
    df_results = {
        "P_home_all": mean_results[0],
        "P_l23_all": mean_results[1],
        "P_l45_all": mean_results[2],
        "P_home_anc": mean_results[3],
    }

    # Save last results for early stopper
    objective.last_df_results = df_results

    # Weighted RMSE
    rmse = weighted_rmse(df_results, target_weights)

    # Print status
    print("\n--- Calibration Iteration ---")
    print("Parameters:")
    for k, v in params.items():
        print(f"  {k:22s}: {v:.4f}")
    print("\nTarget vs Simulated Outcomes:")
    for k in target_values:
        sim = df_results[k]
        target = target_values[k]
        error = sim - target
        rel_error = error / target
        print(f"  {k:22s} | Sim: {sim:.4f}, Target: {target:.4f}, RelErr: {rel_error:+.2%}")
    print(f"\nRMSE Loss: {rmse:.6f}")
    print("-----------------------------\n")

    return rmse

class EarlyStopper:
    def __init__(self, threshold_rmse=0.6, relative_threshold=0.05):
        self.threshold_rmse = threshold_rmse
        self.relative_threshold = relative_threshold
        self.best_loss = float('inf')
        self.best_params = None
        self.best_df_results = None

    def meets_relative_criteria(self, sim_results):
        for metric, (target, accepted_pct) in target_weights.items():
            sim = sim_results.get(metric, 0)
            rel_error = abs(sim - target) / target
            if rel_error > (accepted_pct / 100):
                return False
        return True

    def meets_param_constraints(self, param_list):
        if param_list is None:
            return False
        names = [d.name for d in param_space]
        p = dict(zip(names, param_list))
        return p['Sen_traditional'] > p['Spec_traditional']

    def __call__(self, *args, **kwargs):
        loss = objective(*args, **kwargs)
        rmse_history.append(loss)

        if loss < self.best_loss:
            self.best_loss = loss
            self.best_params = list(args[0]) if args else None
            self.best_df_results = getattr(objective, "last_df_results", {})

        if (self.best_loss < self.threshold_rmse
            and self.meets_relative_criteria(self.best_df_results)
            and self.meets_param_constraints(self.best_params)):
            print(f"\n⏹️ Early stopping: RMSE={self.best_loss:.6f} and Sen>Spec satisfied.")
            raise StopIteration

        return loss

def save_results(best_params, best_loss, rmse_history, param_space):
    param_names = [dim.name for dim in param_space]
    best_param_dict = dict(zip(param_names, best_params))
    best_param_dict["Best RMSE"] = best_loss
    df_best = pd.DataFrame([best_param_dict])
    df_best.to_csv("best_parameters_ANC_v4.csv", index=False)

    pd.DataFrame({"Iteration": range(1, len(rmse_history)+1), "RMSE": rmse_history}).to_csv("rmse_history_ANC_v4.csv", index=False)

    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(rmse_history)+1), rmse_history, marker='o')
    plt.xlabel("Iteration")
    plt.ylabel("RMSE Loss")
    plt.title("RMSE Loss Over Iterations")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("rmse_plot_ANC_v4.png")
    plt.close()

def optimize_model():
    early_stopper = EarlyStopper(threshold_rmse=0.6, relative_threshold=0.05)
    try:
        result = gp_minimize(
            func=early_stopper,
            dimensions=param_space,
            n_calls=1000,
            random_state=42,
            n_random_starts=20,
            acq_func="EI",
            verbose=True
        )
        print("\n✅ Optimization completed.")
        print("Best Parameters:", result.x)
        print("Best Loss:", result.fun)
        save_results(result.x, result.fun, rmse_history, param_space)
        return result

    except StopIteration:
        print("\n✅ Optimization stopped early.")
        print(f"Best RMSE achieved: {early_stopper.best_loss:.6f}")
        if early_stopper.best_params is not None:
            print("Best Parameters:")
            for name, val in zip([d.name for d in param_space], early_stopper.best_params):
                print(f"  {name:22s}: {val:.4f}")
            save_results(early_stopper.best_params, early_stopper.best_loss, rmse_history, param_space)
        return None

if __name__ == "__main__":
    optimize_model()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.4186
#   P_home_lowrisk        : 0.1734
#   P_L23_highrisk        : 0.3339
#   Sen_traditional       : 0.7194
#   Spec_traditional      : 0.6892
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3544, Target: 0.3500, RelErr: +1.27%
#   P_l23_all              | Sim: 0.3635, Target: 0.3920, RelErr: -7.27%
#   P_l45_all              | Sim: 0.2821, Target: 0.2580, RelErr: +9.33%
#   P_home_anc             | Sim: 0.0783, Target: 0.0700, RelErr: +11.86%
#
# RMSE Loss: 8.399588
# -----------------------------
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 7.1011
# Function value obtained: 8.3996
# Current minimum: 8.3996
# Iteration No: 2 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 3 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 4 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 5 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.2599
#   P_home_lowrisk        : 0.1187
#   P_L23_highrisk        : 0.3921
#   Sen_traditional       : 0.6466
#   Spec_traditional      : 0.6181
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3394, Target: 0.3500, RelErr: -3.03%
#   P_l23_all              | Sim: 0.4076, Target: 0.3920, RelErr: +3.98%
#   P_l45_all              | Sim: 0.2530, Target: 0.2580, RelErr: -1.93%
#   P_home_anc             | Sim: 0.0506, Target: 0.0700, RelErr: -27.73%
#
# RMSE Loss: 14.120079
# -----------------------------
#
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 7.2844
# Function value obtained: 14.1201
# Current minimum: 8.3996
# Iteration No: 6 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 7 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.3721
#   P_home_lowrisk        : 0.2802
#   P_L23_highrisk        : 0.1040
#   Sen_traditional       : 0.7884
#   Spec_traditional      : 0.7127
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3821, Target: 0.3500, RelErr: +9.17%
#   P_l23_all              | Sim: 0.2735, Target: 0.3920, RelErr: -30.22%
#   P_l45_all              | Sim: 0.3444, Target: 0.2580, RelErr: +33.47%
#   P_home_anc             | Sim: 0.1265, Target: 0.0700, RelErr: +80.74%
#
# RMSE Loss: 46.464990
# -----------------------------
#
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 7.3442
# Function value obtained: 46.4650
# Current minimum: 8.3996
# Iteration No: 8 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 0.0007
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 9 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.3440
#   P_home_lowrisk        : 0.4333
#   P_L23_highrisk        : 0.1520
#   Sen_traditional       : 0.6782
#   Spec_traditional      : 0.6364
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4142, Target: 0.3500, RelErr: +18.34%
#   P_l23_all              | Sim: 0.2538, Target: 0.3920, RelErr: -35.25%
#   P_l45_all              | Sim: 0.3320, Target: 0.2580, RelErr: +28.68%
#   P_home_anc             | Sim: 0.1851, Target: 0.0700, RelErr: +164.38%
#
# RMSE Loss: 85.762094
# -----------------------------
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 7.4290
# Function value obtained: 85.7621
# Current minimum: 8.3996
# Iteration No: 10 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.4021
#   P_home_lowrisk        : 0.2701
#   P_L23_highrisk        : 0.1624
#   Sen_traditional       : 0.7135
#   Spec_traditional      : 0.6063
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3722, Target: 0.3500, RelErr: +6.33%
#   P_l23_all              | Sim: 0.2772, Target: 0.3920, RelErr: -29.28%
#   P_l45_all              | Sim: 0.3506, Target: 0.2580, RelErr: +35.90%
#   P_home_anc             | Sim: 0.1095, Target: 0.0700, RelErr: +56.36%
#
# RMSE Loss: 36.614241
# -----------------------------
#
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 7.2023
# Function value obtained: 36.6142
# Current minimum: 8.3996
# Iteration No: 11 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.4369
#   P_home_lowrisk        : 0.2799
#   P_L23_highrisk        : 0.2185
#   Sen_traditional       : 0.7853
#   Spec_traditional      : 0.7455
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3847, Target: 0.3500, RelErr: +9.91%
#   P_l23_all              | Sim: 0.3052, Target: 0.3920, RelErr: -22.14%
#   P_l45_all              | Sim: 0.3101, Target: 0.2580, RelErr: +20.21%
#   P_home_anc             | Sim: 0.1317, Target: 0.0700, RelErr: +88.20%
#
# RMSE Loss: 46.840165
# -----------------------------
#
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 7.4176
# Function value obtained: 46.8402
# Current minimum: 8.3996
# Iteration No: 12 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.2306
#   P_home_lowrisk        : 0.3282
#   P_L23_highrisk        : 0.2563
#   Sen_traditional       : 0.7922
#   Spec_traditional      : 0.7689
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3986, Target: 0.3500, RelErr: +13.90%
#   P_l23_all              | Sim: 0.3348, Target: 0.3920, RelErr: -14.58%
#   P_l45_all              | Sim: 0.2665, Target: 0.2580, RelErr: +3.31%
#   P_home_anc             | Sim: 0.1578, Target: 0.0700, RelErr: +125.39%
#
# RMSE Loss: 63.521448
# -----------------------------
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 7.4623
# Function value obtained: 63.5214
# Current minimum: 8.3996
# Iteration No: 13 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.3989
#   P_home_lowrisk        : 0.3159
#   P_L23_highrisk        : 0.2760
#   Sen_traditional       : 0.7931
#   Spec_traditional      : 0.7214
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3915, Target: 0.3500, RelErr: +11.86%
#   P_l23_all              | Sim: 0.3162, Target: 0.3920, RelErr: -19.34%
#   P_l45_all              | Sim: 0.2923, Target: 0.2580, RelErr: +13.31%
#   P_home_anc             | Sim: 0.1440, Target: 0.0700, RelErr: +105.75%
#
# RMSE Loss: 54.488149
# -----------------------------
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 7.0762
# Function value obtained: 54.4881
# Current minimum: 8.3996
# Iteration No: 14 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 15 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 16 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 17 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 18 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.3664
#   P_home_lowrisk        : 0.3365
#   P_L23_highrisk        : 0.1824
#   Sen_traditional       : 0.7122
#   Spec_traditional      : 0.6766
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3945, Target: 0.3500, RelErr: +12.71%
#   P_l23_all              | Sim: 0.2849, Target: 0.3920, RelErr: -27.31%
#   P_l45_all              | Sim: 0.3206, Target: 0.2580, RelErr: +24.26%
#   P_home_anc             | Sim: 0.1495, Target: 0.0700, RelErr: +113.59%
#
# RMSE Loss: 59.995494
# -----------------------------
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 7.3203
# Function value obtained: 59.9955
# Current minimum: 8.3996
# Iteration No: 19 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 20 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1162
#   P_home_lowrisk        : 0.3843
#   P_L23_highrisk        : 0.1333
#   Sen_traditional       : 0.6879
#   Spec_traditional      : 0.6403
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4025, Target: 0.3500, RelErr: +14.99%
#   P_l23_all              | Sim: 0.2875, Target: 0.3920, RelErr: -26.65%
#   P_l45_all              | Sim: 0.3100, Target: 0.2580, RelErr: +20.14%
#   P_home_anc             | Sim: 0.1643, Target: 0.0700, RelErr: +134.78%
#
# RMSE Loss: 69.830647
# -----------------------------
#
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 7.4116
# Function value obtained: 69.8306
# Current minimum: 8.3996
# Iteration No: 21 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.2000
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 22 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.4119
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6670
#   Spec_traditional      : 0.6002
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4045, Target: 0.3500, RelErr: +15.58%
#   P_l23_all              | Sim: 0.3169, Target: 0.3920, RelErr: -19.17%
#   P_l45_all              | Sim: 0.2786, Target: 0.2580, RelErr: +7.99%
#   P_home_anc             | Sim: 0.1669, Target: 0.0700, RelErr: +138.43%
#
# RMSE Loss: 70.419550
# -----------------------------
#
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 7.5515
# Function value obtained: 70.4196
# Current minimum: 8.3996
# Iteration No: 23 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 0.1847
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 24 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 0.3032
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 25 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 0.1994
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 26 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 0.1602
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 27 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 0.1350
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 28 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 0.2319
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 29 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 0.2168
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 30 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 0.1970
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 31 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.3620
#   P_home_lowrisk        : 0.1096
#   P_L23_highrisk        : 0.3713
#   Sen_traditional       : 0.6869
#   Spec_traditional      : 0.6857
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3387, Target: 0.3500, RelErr: -3.22%
#   P_l23_all              | Sim: 0.3972, Target: 0.3920, RelErr: +1.34%
#   P_l45_all              | Sim: 0.2640, Target: 0.2580, RelErr: +2.33%
#   P_home_anc             | Sim: 0.0504, Target: 0.0700, RelErr: -28.01%
#
# RMSE Loss: 14.159766
# -----------------------------
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 7.2418
# Function value obtained: 14.1598
# Current minimum: 8.3996
# Iteration No: 32 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7313
#   Spec_traditional      : 0.6488
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3353, Target: 0.3500, RelErr: -4.20%
#   P_l23_all              | Sim: 0.3829, Target: 0.3920, RelErr: -2.32%
#   P_l45_all              | Sim: 0.2818, Target: 0.2580, RelErr: +9.22%
#   P_home_anc             | Sim: 0.0430, Target: 0.0700, RelErr: -38.54%
#
# RMSE Loss: 19.956412
# -----------------------------
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 7.4378
# Function value obtained: 19.9564
# Current minimum: 8.3996
# Iteration No: 33 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.1608
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 34 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 0.2029
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 35 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 0.2842
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 36 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 0.1880
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 37 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 0.2874
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 38 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 0.4006
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 39 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 0.3500
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 40 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 40 ended. Search finished for the next optimal point.
# Time taken: 0.3199
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 41 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3326, Target: 0.3500, RelErr: -4.98%
#   P_l23_all              | Sim: 0.3735, Target: 0.3920, RelErr: -4.72%
#   P_l45_all              | Sim: 0.2939, Target: 0.2580, RelErr: +13.92%
#   P_home_anc             | Sim: 0.0385, Target: 0.0700, RelErr: -45.07%
#
# RMSE Loss: 23.833183
# -----------------------------
#
# Iteration No: 41 ended. Search finished for the next optimal point.
# Time taken: 7.6078
# Function value obtained: 23.8332
# Current minimum: 8.3996
# Iteration No: 42 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 42 ended. Search finished for the next optimal point.
# Time taken: 0.3377
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 43 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 43 ended. Search finished for the next optimal point.
# Time taken: 0.3177
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 44 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.3223
#   Sen_traditional       : 0.6145
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3346, Target: 0.3500, RelErr: -4.39%
#   P_l23_all              | Sim: 0.3570, Target: 0.3920, RelErr: -8.92%
#   P_l45_all              | Sim: 0.3083, Target: 0.2580, RelErr: +19.51%
#   P_home_anc             | Sim: 0.0422, Target: 0.0700, RelErr: -39.77%
#
# RMSE Loss: 22.701629
# -----------------------------
#
# Iteration No: 44 ended. Search finished for the next optimal point.
# Time taken: 7.3044
# Function value obtained: 22.7016
# Current minimum: 8.3996
# Iteration No: 45 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 45 ended. Search finished for the next optimal point.
# Time taken: 0.2958
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 46 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 46 ended. Search finished for the next optimal point.
# Time taken: 0.3898
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 47 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 47 ended. Search finished for the next optimal point.
# Time taken: 0.3384
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 48 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 48 ended. Search finished for the next optimal point.
# Time taken: 0.2751
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 49 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.4331
#   P_home_lowrisk        : 0.1338
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.7088
#   Spec_traditional      : 0.6868
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3454, Target: 0.3500, RelErr: -1.32%
#   P_l23_all              | Sim: 0.2972, Target: 0.3920, RelErr: -24.18%
#   P_l45_all              | Sim: 0.3574, Target: 0.2580, RelErr: +38.52%
#   P_home_anc             | Sim: 0.0611, Target: 0.0700, RelErr: -12.70%
#
# RMSE Loss: 23.620504
# -----------------------------
#
# Iteration No: 49 ended. Search finished for the next optimal point.
# Time taken: 7.6976
# Function value obtained: 23.6205
# Current minimum: 8.3996
# Iteration No: 50 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.4255
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.3813
#   Sen_traditional       : 0.7232
#   Spec_traditional      : 0.7067
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3365, Target: 0.3500, RelErr: -3.86%
#   P_l23_all              | Sim: 0.3954, Target: 0.3920, RelErr: +0.87%
#   P_l45_all              | Sim: 0.2681, Target: 0.2580, RelErr: +3.92%
#   P_home_anc             | Sim: 0.0461, Target: 0.0700, RelErr: -34.08%
#
# RMSE Loss: 17.267740
# -----------------------------
#
# Iteration No: 50 ended. Search finished for the next optimal point.
# Time taken: 7.6190
# Function value obtained: 17.2677
# Current minimum: 8.3996
# Iteration No: 51 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 51 ended. Search finished for the next optimal point.
# Time taken: 0.3400
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 52 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 52 ended. Search finished for the next optimal point.
# Time taken: 0.3005
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 53 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.2961
#   P_home_lowrisk        : 0.1988
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7322
#   Spec_traditional      : 0.6940
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3607, Target: 0.3500, RelErr: +3.06%
#   P_l23_all              | Sim: 0.3937, Target: 0.3920, RelErr: +0.43%
#   P_l45_all              | Sim: 0.2456, Target: 0.2580, RelErr: -4.81%
#   P_home_anc             | Sim: 0.0896, Target: 0.0700, RelErr: +27.93%
#
# RMSE Loss: 14.254016
# -----------------------------
#
# Iteration No: 53 ended. Search finished for the next optimal point.
# Time taken: 7.5773
# Function value obtained: 14.2540
# Current minimum: 8.3996
# Iteration No: 54 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 54 ended. Search finished for the next optimal point.
# Time taken: 0.3023
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 55 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 55 ended. Search finished for the next optimal point.
# Time taken: 0.2755
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 56 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1492
#   P_home_lowrisk        : 0.5000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.6162
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4279, Target: 0.3500, RelErr: +22.26%
#   P_l23_all              | Sim: 0.2465, Target: 0.3920, RelErr: -37.12%
#   P_l45_all              | Sim: 0.3256, Target: 0.2580, RelErr: +26.21%
#   P_home_anc             | Sim: 0.2099, Target: 0.0700, RelErr: +199.80%
#
# RMSE Loss: 103.054861
# -----------------------------
#
# Iteration No: 56 ended. Search finished for the next optimal point.
# Time taken: 8.0507
# Function value obtained: 103.0549
# Current minimum: 8.3996
# Iteration No: 57 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 57 ended. Search finished for the next optimal point.
# Time taken: 0.3552
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 58 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 58 ended. Search finished for the next optimal point.
# Time taken: 0.3732
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 59 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 59 ended. Search finished for the next optimal point.
# Time taken: 0.3154
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 60 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 60 ended. Search finished for the next optimal point.
# Time taken: 0.2678
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 61 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 61 ended. Search finished for the next optimal point.
# Time taken: 0.3145
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 62 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 62 ended. Search finished for the next optimal point.
# Time taken: 0.2587
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 63 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.7751
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3328, Target: 0.3500, RelErr: -4.92%
#   P_l23_all              | Sim: 0.3237, Target: 0.3920, RelErr: -17.42%
#   P_l45_all              | Sim: 0.3435, Target: 0.2580, RelErr: +33.13%
#   P_home_anc             | Sim: 0.0393, Target: 0.0700, RelErr: -43.92%
#
# RMSE Loss: 28.956908
# -----------------------------
#
# Iteration No: 63 ended. Search finished for the next optimal point.
# Time taken: 7.5029
# Function value obtained: 28.9569
# Current minimum: 8.3996
# Iteration No: 64 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 64 ended. Search finished for the next optimal point.
# Time taken: 0.3685
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 65 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 65 ended. Search finished for the next optimal point.
# Time taken: 0.3901
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 66 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 66 ended. Search finished for the next optimal point.
# Time taken: 0.3628
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 67 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1615
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.3726
#   Sen_traditional       : 0.6395
#   Spec_traditional      : 0.6360
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3354, Target: 0.3500, RelErr: -4.16%
#   P_l23_all              | Sim: 0.4208, Target: 0.3920, RelErr: +7.35%
#   P_l45_all              | Sim: 0.2437, Target: 0.2580, RelErr: -5.52%
#   P_home_anc             | Sim: 0.0436, Target: 0.0700, RelErr: -37.75%
#
# RMSE Loss: 19.540036
# -----------------------------
#
# Iteration No: 67 ended. Search finished for the next optimal point.
# Time taken: 7.4044
# Function value obtained: 19.5400
# Current minimum: 8.3996
# Iteration No: 68 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 68 ended. Search finished for the next optimal point.
# Time taken: 0.4355
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 69 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 69 ended. Search finished for the next optimal point.
# Time taken: 0.2843
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 70 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 70 ended. Search finished for the next optimal point.
# Time taken: 0.2901
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 71 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 71 ended. Search finished for the next optimal point.
# Time taken: 0.3199
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 72 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 72 ended. Search finished for the next optimal point.
# Time taken: 0.4668
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 73 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 73 ended. Search finished for the next optimal point.
# Time taken: 0.5387
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 74 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 74 ended. Search finished for the next optimal point.
# Time taken: 0.4453
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 75 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 75 ended. Search finished for the next optimal point.
# Time taken: 0.3860
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 76 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 76 ended. Search finished for the next optimal point.
# Time taken: 0.4165
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 77 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 77 ended. Search finished for the next optimal point.
# Time taken: 0.3792
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 78 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 78 ended. Search finished for the next optimal point.
# Time taken: 0.5426
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 79 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 79 ended. Search finished for the next optimal point.
# Time taken: 0.3812
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 80 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 80 ended. Search finished for the next optimal point.
# Time taken: 0.4826
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 81 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 81 ended. Search finished for the next optimal point.
# Time taken: 0.4615
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 82 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 82 ended. Search finished for the next optimal point.
# Time taken: 0.7397
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 83 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 83 ended. Search finished for the next optimal point.
# Time taken: 0.3168
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 84 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 84 ended. Search finished for the next optimal point.
# Time taken: 0.4794
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 85 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 85 ended. Search finished for the next optimal point.
# Time taken: 0.3782
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 86 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 86 ended. Search finished for the next optimal point.
# Time taken: 0.4448
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 87 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 87 ended. Search finished for the next optimal point.
# Time taken: 0.3887
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 88 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 88 ended. Search finished for the next optimal point.
# Time taken: 0.4079
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 89 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 89 ended. Search finished for the next optimal point.
# Time taken: 0.4896
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 90 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 90 ended. Search finished for the next optimal point.
# Time taken: 0.4372
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 91 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 91 ended. Search finished for the next optimal point.
# Time taken: 0.4810
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 92 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 92 ended. Search finished for the next optimal point.
# Time taken: 0.5150
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 93 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 93 ended. Search finished for the next optimal point.
# Time taken: 0.5629
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 94 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 94 ended. Search finished for the next optimal point.
# Time taken: 0.4857
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 95 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 95 ended. Search finished for the next optimal point.
# Time taken: 0.4760
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 96 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 96 ended. Search finished for the next optimal point.
# Time taken: 0.5218
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 97 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 97 ended. Search finished for the next optimal point.
# Time taken: 0.4383
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 98 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.2318
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6199
#   Spec_traditional      : 0.6133
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3661, Target: 0.3500, RelErr: +4.60%
#   P_l23_all              | Sim: 0.3559, Target: 0.3920, RelErr: -9.20%
#   P_l45_all              | Sim: 0.2780, Target: 0.2580, RelErr: +7.74%
#   P_home_anc             | Sim: 0.0979, Target: 0.0700, RelErr: +39.93%
#
# RMSE Loss: 20.975588
# -----------------------------
#
# Iteration No: 98 ended. Search finished for the next optimal point.
# Time taken: 7.6120
# Function value obtained: 20.9756
# Current minimum: 8.3996
# Iteration No: 99 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 99 ended. Search finished for the next optimal point.
# Time taken: 0.5533
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 100 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.5000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7524
#   Spec_traditional      : 0.7005
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4357, Target: 0.3500, RelErr: +24.49%
#   P_l23_all              | Sim: 0.3523, Target: 0.3920, RelErr: -10.14%
#   P_l45_all              | Sim: 0.2120, Target: 0.2580, RelErr: -17.82%
#   P_home_anc             | Sim: 0.2232, Target: 0.0700, RelErr: +218.88%
#
# RMSE Loss: 110.597811
# -----------------------------
#
# Iteration No: 100 ended. Search finished for the next optimal point.
# Time taken: 7.4473
# Function value obtained: 110.5978
# Current minimum: 8.3996
# Iteration No: 101 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 101 ended. Search finished for the next optimal point.
# Time taken: 0.4584
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 102 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 102 ended. Search finished for the next optimal point.
# Time taken: 0.8601
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 103 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1830
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7198
#   Spec_traditional      : 0.6406
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3349, Target: 0.3500, RelErr: -4.32%
#   P_l23_all              | Sim: 0.4236, Target: 0.3920, RelErr: +8.05%
#   P_l45_all              | Sim: 0.2416, Target: 0.2580, RelErr: -6.37%
#   P_home_anc             | Sim: 0.0428, Target: 0.0700, RelErr: -38.90%
#
# RMSE Loss: 20.230599
# -----------------------------
#
# Iteration No: 103 ended. Search finished for the next optimal point.
# Time taken: 7.5804
# Function value obtained: 20.2306
# Current minimum: 8.3996
# Iteration No: 104 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 104 ended. Search finished for the next optimal point.
# Time taken: 0.5622
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 105 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 105 ended. Search finished for the next optimal point.
# Time taken: 0.6485
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 106 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 106 ended. Search finished for the next optimal point.
# Time taken: 0.7138
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 107 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 107 ended. Search finished for the next optimal point.
# Time taken: 0.6004
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 108 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 108 ended. Search finished for the next optimal point.
# Time taken: 0.5217
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 109 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 109 ended. Search finished for the next optimal point.
# Time taken: 0.5303
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 110 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 110 ended. Search finished for the next optimal point.
# Time taken: 0.5615
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 111 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 111 ended. Search finished for the next optimal point.
# Time taken: 0.5441
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 112 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 112 ended. Search finished for the next optimal point.
# Time taken: 0.5775
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 113 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.5000
#   P_home_lowrisk        : 0.3540
#   P_L23_highrisk        : 0.3829
#   Sen_traditional       : 0.6414
#   Spec_traditional      : 0.6314
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3962, Target: 0.3500, RelErr: +13.21%
#   P_l23_all              | Sim: 0.3253, Target: 0.3920, RelErr: -17.01%
#   P_l45_all              | Sim: 0.2784, Target: 0.2580, RelErr: +7.92%
#   P_home_anc             | Sim: 0.1522, Target: 0.0700, RelErr: +117.38%
#
# RMSE Loss: 59.800129
# -----------------------------
#
# Iteration No: 113 ended. Search finished for the next optimal point.
# Time taken: 7.5895
# Function value obtained: 59.8001
# Current minimum: 8.3996
# Iteration No: 114 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 114 ended. Search finished for the next optimal point.
# Time taken: 0.4980
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 115 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 115 ended. Search finished for the next optimal point.
# Time taken: 0.5562
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 116 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 116 ended. Search finished for the next optimal point.
# Time taken: 0.5553
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 117 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 117 ended. Search finished for the next optimal point.
# Time taken: 0.5439
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 118 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 118 ended. Search finished for the next optimal point.
# Time taken: 0.5133
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 119 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 119 ended. Search finished for the next optimal point.
# Time taken: 0.6213
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 120 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 120 ended. Search finished for the next optimal point.
# Time taken: 0.9337
# Function value obtained: 10.0000
# Current minimum: 8.3996
# Iteration No: 121 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.2229
#   P_home_lowrisk        : 0.2705
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.6060
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3754, Target: 0.3500, RelErr: +7.24%
#   P_l23_all              | Sim: 0.3823, Target: 0.3920, RelErr: -2.47%
#   P_l45_all              | Sim: 0.2423, Target: 0.2580, RelErr: -6.07%
#   P_home_anc             | Sim: 0.1144, Target: 0.0700, RelErr: +63.44%
#
# RMSE Loss: 32.093809
# -----------------------------
#
# Iteration No: 121 ended. Search finished for the next optimal point.
# Time taken: 7.5439
# Function value obtained: 32.0938
# Current minimum: 8.3996
# Iteration No: 122 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 122 ended. Search finished for the next optimal point.
# Time taken: 0.5728
# Function value obtained: 10.0000
# Current minimum: 8.3996
# ...
#   P_l23_all              | Sim: 0.3828, Target: 0.3920, RelErr: -2.34%
#   P_l45_all              | Sim: 0.2689, Target: 0.2580, RelErr: +4.21%
#   P_home_anc             | Sim: 0.0667, Target: 0.0700, RelErr: -4.69%
#
# RMSE Loss: 3.370801
# -----------------------------
#
# Iteration No: 294 ended. Search finished for the next optimal point.
# Time taken: 10.0792
# Function value obtained: 3.3708
# Current minimum: 0.7134
# Iteration No: 295 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1681
#   P_L23_highrisk        : 0.2964
#   Sen_traditional       : 0.7778
#   Spec_traditional      : 0.6333
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3495, Target: 0.3500, RelErr: -0.15%
#   P_l23_all              | Sim: 0.3829, Target: 0.3920, RelErr: -2.31%
#   P_l45_all              | Sim: 0.2676, Target: 0.2580, RelErr: +3.72%
#   P_home_anc             | Sim: 0.0684, Target: 0.0700, RelErr: -2.24%
#
# RMSE Loss: 2.460255
# -----------------------------
#
# Iteration No: 295 ended. Search finished for the next optimal point.
# Time taken: 10.5747
# Function value obtained: 2.4603
# Current minimum: 0.7134
# Iteration No: 296 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1721
#   P_L23_highrisk        : 0.3221
#   Sen_traditional       : 0.7767
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3486, Target: 0.3500, RelErr: -0.39%
#   P_l23_all              | Sim: 0.3865, Target: 0.3920, RelErr: -1.40%
#   P_l45_all              | Sim: 0.2649, Target: 0.2580, RelErr: +2.66%
#   P_home_anc             | Sim: 0.0672, Target: 0.0700, RelErr: -3.99%
#
# RMSE Loss: 2.505551
# -----------------------------
#
# Iteration No: 296 ended. Search finished for the next optimal point.
# Time taken: 10.3869
# Function value obtained: 2.5056
# Current minimum: 0.7134
# Iteration No: 297 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1692
#   P_L23_highrisk        : 0.3630
#   Sen_traditional       : 0.7803
#   Spec_traditional      : 0.6130
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3485, Target: 0.3500, RelErr: -0.44%
#   P_l23_all              | Sim: 0.4023, Target: 0.3920, RelErr: +2.63%
#   P_l45_all              | Sim: 0.2492, Target: 0.2580, RelErr: -3.40%
#   P_home_anc             | Sim: 0.0671, Target: 0.0700, RelErr: -4.15%
#
# RMSE Loss: 2.995893
# -----------------------------
#
# Iteration No: 297 ended. Search finished for the next optimal point.
# Time taken: 9.9288
# Function value obtained: 2.9959
# Current minimum: 0.7134
# Iteration No: 298 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 298 ended. Search finished for the next optimal point.
# Time taken: 3.1999
# Function value obtained: 10.0000
# Current minimum: 0.7134
# Iteration No: 299 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1713
#   P_L23_highrisk        : 0.3069
#   Sen_traditional       : 0.7631
#   Spec_traditional      : 0.6134
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3493, Target: 0.3500, RelErr: -0.21%
#   P_l23_all              | Sim: 0.3840, Target: 0.3920, RelErr: -2.05%
#   P_l45_all              | Sim: 0.2668, Target: 0.2580, RelErr: +3.40%
#   P_home_anc             | Sim: 0.0683, Target: 0.0700, RelErr: -2.45%
#
# RMSE Loss: 2.334673
# -----------------------------
#
# Iteration No: 299 ended. Search finished for the next optimal point.
# Time taken: 10.6018
# Function value obtained: 2.3347
# Current minimum: 0.7134
# Iteration No: 300 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1809
#   P_L23_highrisk        : 0.3096
#   Sen_traditional       : 0.7838
#   Spec_traditional      : 0.6144
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3511, Target: 0.3500, RelErr: +0.30%
#   P_l23_all              | Sim: 0.3821, Target: 0.3920, RelErr: -2.53%
#   P_l45_all              | Sim: 0.2669, Target: 0.2580, RelErr: +3.43%
#   P_home_anc             | Sim: 0.0714, Target: 0.0700, RelErr: +1.95%
#
# RMSE Loss: 2.349046
# -----------------------------
#
# Iteration No: 300 ended. Search finished for the next optimal point.
# Time taken: 10.1121
# Function value obtained: 2.3490
# Current minimum: 0.7134
# Iteration No: 301 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1697
#   P_L23_highrisk        : 0.3029
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3474, Target: 0.3500, RelErr: -0.73%
#   P_l23_all              | Sim: 0.3792, Target: 0.3920, RelErr: -3.26%
#   P_l45_all              | Sim: 0.2734, Target: 0.2580, RelErr: +5.95%
#   P_home_anc             | Sim: 0.0650, Target: 0.0700, RelErr: -7.12%
#
# RMSE Loss: 4.932506
# -----------------------------
#
# Iteration No: 301 ended. Search finished for the next optimal point.
# Time taken: 10.4571
# Function value obtained: 4.9325
# Current minimum: 0.7134
# Iteration No: 302 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 302 ended. Search finished for the next optimal point.
# Time taken: 3.4372
# Function value obtained: 10.0000
# Current minimum: 0.7134
# Iteration No: 303 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 303 ended. Search finished for the next optimal point.
# Time taken: 3.1529
# Function value obtained: 10.0000
# Current minimum: 0.7134
# Iteration No: 304 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 304 ended. Search finished for the next optimal point.
# Time taken: 3.6974
# Function value obtained: 10.0000
# Current minimum: 0.7134
# Iteration No: 305 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1959
#   P_L23_highrisk        : 0.2931
#   Sen_traditional       : 0.7155
#   Spec_traditional      : 0.6260
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3563, Target: 0.3500, RelErr: +1.80%
#   P_l23_all              | Sim: 0.3781, Target: 0.3920, RelErr: -3.54%
#   P_l45_all              | Sim: 0.2656, Target: 0.2580, RelErr: +2.95%
#   P_home_anc             | Sim: 0.0810, Target: 0.0700, RelErr: +15.76%
#
# RMSE Loss: 8.259637
# -----------------------------
#
# Iteration No: 305 ended. Search finished for the next optimal point.
# Time taken: 9.9875
# Function value obtained: 8.2596
# Current minimum: 0.7134
# Iteration No: 306 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1595
#   P_L23_highrisk        : 0.3109
#   Sen_traditional       : 0.7305
#   Spec_traditional      : 0.6247
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3478, Target: 0.3500, RelErr: -0.63%
#   P_l23_all              | Sim: 0.3904, Target: 0.3920, RelErr: -0.40%
#   P_l45_all              | Sim: 0.2618, Target: 0.2580, RelErr: +1.46%
#   P_home_anc             | Sim: 0.0657, Target: 0.0700, RelErr: -6.08%
#
# RMSE Loss: 3.149206
# -----------------------------
#
# Iteration No: 306 ended. Search finished for the next optimal point.
# Time taken: 10.4294
# Function value obtained: 3.1492
# Current minimum: 0.7134
# Iteration No: 307 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 307 ended. Search finished for the next optimal point.
# Time taken: 3.3694
# Function value obtained: 10.0000
# Current minimum: 0.7134
# Iteration No: 308 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 308 ended. Search finished for the next optimal point.
# Time taken: 3.0257
# Function value obtained: 10.0000
# Current minimum: 0.7134
# Iteration No: 309 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 309 ended. Search finished for the next optimal point.
# Time taken: 3.1037
# Function value obtained: 10.0000
# Current minimum: 0.7134
# Iteration No: 310 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1616
#   P_L23_highrisk        : 0.3122
#   Sen_traditional       : 0.7592
#   Spec_traditional      : 0.6362
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3483, Target: 0.3500, RelErr: -0.49%
#   P_l23_all              | Sim: 0.3910, Target: 0.3920, RelErr: -0.25%
#   P_l45_all              | Sim: 0.2607, Target: 0.2580, RelErr: +1.04%
#   P_home_anc             | Sim: 0.0667, Target: 0.0700, RelErr: -4.64%
#
# RMSE Loss: 2.395636
# -----------------------------
#
# Iteration No: 310 ended. Search finished for the next optimal point.
# Time taken: 10.4634
# Function value obtained: 2.3956
# Current minimum: 0.7134
# Iteration No: 311 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1642
#   P_L23_highrisk        : 0.2813
#   Sen_traditional       : 0.7743
#   Spec_traditional      : 0.6184
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3479, Target: 0.3500, RelErr: -0.61%
#   P_l23_all              | Sim: 0.3765, Target: 0.3920, RelErr: -3.95%
#   P_l45_all              | Sim: 0.2756, Target: 0.2580, RelErr: +6.83%
#   P_home_anc             | Sim: 0.0655, Target: 0.0700, RelErr: -6.39%
#
# RMSE Loss: 5.084706
# -----------------------------
#
# Iteration No: 311 ended. Search finished for the next optimal point.
# Time taken: 9.9226
# Function value obtained: 5.0847
# Current minimum: 0.7134
# Iteration No: 312 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1726
#   P_L23_highrisk        : 0.3015
#   Sen_traditional       : 0.6955
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3499, Target: 0.3500, RelErr: -0.03%
#   P_l23_all              | Sim: 0.3832, Target: 0.3920, RelErr: -2.25%
#   P_l45_all              | Sim: 0.2670, Target: 0.2580, RelErr: +3.47%
#   P_home_anc             | Sim: 0.0696, Target: 0.0700, RelErr: -0.57%
#
# RMSE Loss: 2.087992
# -----------------------------
#
# Iteration No: 312 ended. Search finished for the next optimal point.
# Time taken: 367.0087
# Function value obtained: 2.0880
# Current minimum: 0.7134
# Iteration No: 313 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1599
#   P_L23_highrisk        : 0.2933
#   Sen_traditional       : 0.7013
#   Spec_traditional      : 0.6128
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3479, Target: 0.3500, RelErr: -0.60%
#   P_l23_all              | Sim: 0.3844, Target: 0.3920, RelErr: -1.94%
#   P_l45_all              | Sim: 0.2677, Target: 0.2580, RelErr: +3.75%
#   P_home_anc             | Sim: 0.0656, Target: 0.0700, RelErr: -6.33%
#
# RMSE Loss: 3.815874
# -----------------------------
#
# Iteration No: 313 ended. Search finished for the next optimal point.
# Time taken: 917.6018
# Function value obtained: 3.8159
# Current minimum: 0.7134
# Iteration No: 314 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1584
#   P_L23_highrisk        : 0.3084
#   Sen_traditional       : 0.7402
#   Spec_traditional      : 0.6504
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3487, Target: 0.3500, RelErr: -0.38%
#   P_l23_all              | Sim: 0.3935, Target: 0.3920, RelErr: +0.37%
#   P_l45_all              | Sim: 0.2579, Target: 0.2580, RelErr: -0.05%
#   P_home_anc             | Sim: 0.0675, Target: 0.0700, RelErr: -3.62%
#
# RMSE Loss: 1.828404
# -----------------------------
#
# Iteration No: 314 ended. Search finished for the next optimal point.
# Time taken: 1063.1805
# Function value obtained: 1.8284
# Current minimum: 0.7134
# Iteration No: 315 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1634
#   P_L23_highrisk        : 0.3216
#   Sen_traditional       : 0.7639
#   Spec_traditional      : 0.6538
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3500, Target: 0.3500, RelErr: +0.01%
#   P_l23_all              | Sim: 0.3957, Target: 0.3920, RelErr: +0.95%
#   P_l45_all              | Sim: 0.2543, Target: 0.2580, RelErr: -1.45%
#   P_home_anc             | Sim: 0.0694, Target: 0.0700, RelErr: -0.85%
#
# RMSE Loss: 0.966552
# -----------------------------
#
# Iteration No: 315 ended. Search finished for the next optimal point.
# Time taken: 522.0263
# Function value obtained: 0.9666
# Current minimum: 0.7134
# Iteration No: 316 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1638
#   P_L23_highrisk        : 0.3234
#   Sen_traditional       : 0.7672
#   Spec_traditional      : 0.6551
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3502, Target: 0.3500, RelErr: +0.06%
#   P_l23_all              | Sim: 0.3962, Target: 0.3920, RelErr: +1.08%
#   P_l45_all              | Sim: 0.2536, Target: 0.2580, RelErr: -1.71%
#   P_home_anc             | Sim: 0.0696, Target: 0.0700, RelErr: -0.54%
#
# RMSE Loss: 1.046287
# -----------------------------
#
# Iteration No: 316 ended. Search finished for the next optimal point.
# Time taken: 10.5807
# Function value obtained: 1.0463
# Current minimum: 0.7134
# Iteration No: 317 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1585
#   P_L23_highrisk        : 0.3213
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6715
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3490, Target: 0.3500, RelErr: -0.29%
#   P_l23_all              | Sim: 0.3973, Target: 0.3920, RelErr: +1.35%
#   P_l45_all              | Sim: 0.2537, Target: 0.2580, RelErr: -1.65%
#   P_home_anc             | Sim: 0.0679, Target: 0.0700, RelErr: -2.96%
#
# RMSE Loss: 1.829418
# -----------------------------
#
# Iteration No: 317 ended. Search finished for the next optimal point.
# Time taken: 11.0347
# Function value obtained: 1.8294
# Current minimum: 0.7134
# Iteration No: 318 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1671
#   P_L23_highrisk        : 0.3145
#   Sen_traditional       : 0.7542
#   Spec_traditional      : 0.6482
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3504, Target: 0.3500, RelErr: +0.12%
#   P_l23_all              | Sim: 0.3926, Target: 0.3920, RelErr: +0.14%
#   P_l45_all              | Sim: 0.2570, Target: 0.2580, RelErr: -0.38%
#   P_home_anc             | Sim: 0.0705, Target: 0.0700, RelErr: +0.76%
#
# RMSE Loss: 0.435452
# -----------------------------
#
#
# ⏹️ Early stopping: RMSE=0.435452 and Sen>Spec satisfied.
#
# ✅ Optimization stopped early.
# Best RMSE achieved: 0.435452
# Best Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1671
#   P_L23_highrisk        : 0.3145
#   Sen_traditional       : 0.7542
#   Spec_traditional      : 0.6482

# %%
# --- Calibration Iteration ---
# Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1671
#   P_L23_highrisk        : 0.3145
#   Sen_traditional       : 0.7542
#   Spec_traditional      : 0.6482
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3504, Target: 0.3500, RelErr: +0.12%
#   P_l23_all              | Sim: 0.3926, Target: 0.3920, RelErr: +0.14%
#   P_l45_all              | Sim: 0.2570, Target: 0.2580, RelErr: -0.38%
#   P_home_anc             | Sim: 0.0705, Target: 0.0700, RelErr: +0.76%
#
# RMSE Loss: 0.435452
# -----------------------------
#
#
# ⏹️ Early stopping: RMSE=0.435452 and Sen>Spec satisfied.
#
# ✅ Optimization stopped early.
# Best RMSE achieved: 0.435452
# Best Parameters:
#   P_l45_fac             : 0.1000
#   P_home_lowrisk        : 0.1671
#   P_L23_highrisk        : 0.3145
#   Sen_traditional       : 0.7542
#   Spec_traditional      : 0.6482
