# %%
import random
import numpy as np
import streamlit as st
import math
from parameters import get_parameters
from global_func import odds_prob


# Initialize parameters
P = {}  # dict to restore probabilities
n = {}  # dict to restore counts
E = {}  # dict to restore effects
S = {}  # dict to restore supplies and capacities
OR = {}  # dict to restore odds ratio
M = {}  # dict to restore maternal outcomes

#known parameters
param = get_parameters()
LB_tot = np.array([23729, 18196, 20709, 5126])
P["highrisk_all"] = 0.26                                              # high risk pregnancies among all live births
P["ANC"] = 0.56
P["Home_noANC"] = 0.706

# Calibration criteria
P["home_all"] = param["home_all_target"] #0.35
P["l23_all"] = param["l23_all_target"] #0.39
P["l45_all"] = param["l45_all_target"] #0.26
P["home_anc"] = param["home_anc_target"] #0.07
P["l23_anc"] = param["l23_anc_target"] #0.490
P["l45_anc"] = param["l45_anc_target"] #0.439

# %%
random.seed(0)
def f_ANC_LB_effect(P_home_lowrisk, P_L23_highrisk, Sen_traditional, Spec_traditional):
    # Initialize parameters

    GA = param['GA_sequence']
    GA_n = len(GA)
    n["GA"] = param["GA_distribution"]
    P["GA"] = n["GA"] / np.sum(n["GA"])
    PT_mask = np.array([1] * 10 + [0] * 8, dtype=bool)
    FT_mask = ~PT_mask
    P["GA"][PT_mask] = P["GA"][PT_mask] * param["PT_scale"]  # scale P[GA|PT] to match kenya level
    P_mult = (1 - np.sum(P["GA"][PT_mask])) / np.sum(P["GA"][FT_mask])
    P["GA"][FT_mask] *= P_mult

    OR["ANC"] = param["OR_preterm_ANC"]
    Preterm_rate = np.sum(P["GA"][PT_mask])  # overall preterm rate

    preterm_anc_noanc = odds_prob(OR["ANC"], Preterm_rate, P["ANC"])
    P["GA_anc"] = P["GA"].copy()
    P_scale_anc = preterm_anc_noanc[0] / Preterm_rate
    P["GA_anc"][PT_mask] *= P_scale_anc
    P_mult = (1 - preterm_anc_noanc[0]) / np.sum(P["GA_anc"][FT_mask])
    P["GA_anc"][FT_mask] *= P_mult

    P["GA_noanc"] = P["GA"].copy()
    P_scale_noanc = preterm_anc_noanc[1] / Preterm_rate
    P["GA_noanc"][PT_mask] *= P_scale_noanc
    P_mult = (1 - preterm_anc_noanc[1]) / np.sum(P["GA_noanc"][FT_mask])
    P["GA_noanc"][FT_mask] *= P_mult

    E["Preterm_LMP"] = np.zeros(3)
    E["Preterm_LMP"][0], E["Preterm_LMP"][1] = param['E_Preterm_LMP'][0], param['E_Preterm_LMP'][1]
    E["Preterm_LMP"][2] = 1 - (E["Preterm_LMP"][0] + E["Preterm_LMP"][1])
    E["Postterm_LMP"] = np.zeros(3)
    E["Postterm_LMP"][0], E["Postterm_LMP"][1] = param['E_Postterm_LMP'][0], param['E_Postterm_LMP'][1]
    E["Postterm_LMP"][2] = 1 - (E["Postterm_LMP"][0] + E["Postterm_LMP"][1])

    P_home_noANC = P["Home_noANC"]
    P_l45_fac = 0.11 #assume is the probability of living cloest to L4/5
    P_fac_noANC = 1 - P_home_noANC  #0.294
    P_L45_noANC = P_fac_noANC * P_l45_fac  #0.294 * 0.11 = 0.032
    P_L23_noANC = P_fac_noANC - P_L45_noANC #0.294 - 0.032 = 0.262

    # Initialize counters
    n["highrisk"] = np.zeros(4)                                           #number of high-risk pregnancies by facility levels
    n["ANC"] = np.zeros(4)                                                #number of 4+ANC by facility levels
    n["LB_L"] = np.zeros(4)                                               #number of delivery location by facility levels
    M["PT"] = np.zeros(4)
    M["Postterm"] = np.zeros(4)
    M["GA"] = np.zeros((4, GA_n))  # GA distributions by facility levels

    for k_LB in range(np.sum(LB_tot)):
        i_risk = np.random.binomial(1, P["highrisk_all"])
        i_ANC = np.random.binomial(1, P["ANC"])
        if i_ANC:
            P_GA = P["GA_anc"]
        else:
            P_GA = P["GA_noanc"]
        i_jGA = np.searchsorted(np.cumsum(P_GA), np.random.rand())  # % actual index of GA
        i_GA = GA[i_jGA]  # % actual GA

        if i_GA < 37:
            i_term_status = 0   #% 0 = preterm, 1 = full term, 2 = postterm
        elif i_GA >= 43:
            i_term_status = 2
        else:
            i_term_status = 1

        if i_ANC == 0:
            i_loc = np.random.choice([0, 1, 2], p=[P_home_noANC, P_L23_noANC, P_L45_noANC])
        else:
            # Risk stratification
            if i_risk:
                i_risk_pred = 1 if np.random.random() < Sen_traditional else 0
            else:
                i_risk_pred = 0 if np.random.random() < Spec_traditional else 1

            # Gestational age estimation
            i_preterm_pred = 1 if np.random.random() < E["Preterm_LMP"][i_term_status] else 0
            i_postterm_pred = 1 if np.random.random() < E["Postterm_LMP"][i_term_status] else 0

            if i_risk_pred or i_preterm_pred == 1 or i_postterm_pred == 1:
                i_loc = np.random.choice([0, 1, 2], p=[0, P_L23_highrisk, 1 - P_L23_highrisk])
            else:
                i_loc = np.random.choice([0, 1, 2], p=[P_home_lowrisk, (1 - P_home_lowrisk) * 0.89, (1 - P_home_lowrisk) * 0.11])

        # assume among all live births at L45, 5126/(20709 + 5126) going to L5
        P_l5_l45 = 5126 / (20709 + 5126)
        if i_loc == 2 and np.random.random() < P_l5_l45:
            i_loc = 3

        # restore results
        n["highrisk"][i_loc] += i_risk
        n["ANC"][i_loc]      += i_ANC
        n["LB_L"][i_loc]     += 1
        M["GA"][i_loc, i_jGA] += 1
        M["PT"][i_loc] += i_term_status == 0
        M["Postterm"][i_loc] += i_term_status == 2

    # Predicted outcomes
    P_home_all = n["LB_L"][0] / np.sum(LB_tot)
    P_l23_all = n["LB_L"][1] / np.sum(LB_tot)
    P_l45_all = (n["LB_L"][2] + n["LB_L"][3]) / np.sum(LB_tot)
    P_home_anc = n["ANC"][0] / np.sum(n["ANC"])
    P_l23_anc = n["ANC"][1] / np.sum(n["ANC"])
    P_l45_anc = (n["ANC"][2] + n["ANC"][3]) / np.sum(n["ANC"])
    P_preterm_fac = np.sum(M["PT"][1:]) / np.sum(n["LB_L"][1:])
    P_preterm_home = M["PT"][0] / n["LB_L"][0]
    P_preterm_l23 = M["PT"][1] / n["LB_L"][1]
    P_preterm_l45 = (M["PT"][2] + M["PT"][3]) / n["LB_L"][2:4].sum()

    return P_home_all, P_l23_all, P_l45_all, P_home_anc, P_l23_anc, P_l45_anc, P_preterm_fac, P_preterm_home, P_preterm_l23, P_preterm_l45

# %%
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# Calibration targets
target_values = {
    "P_home_all": P["home_all"],
    "P_l23_all": P["l23_all"],
    "P_l45_all": P["l45_all"],
    "P_home_anc": P["home_anc"],
    "P_l23_anc": P["l23_anc"],
    "P_l45_anc": P["l45_anc"],
}

# Tolerance percentages for each target
target_weights = {
    "P_home_all": (P["home_all"], 5),   # ±5% tolerance
    "P_l23_all":  (P["l23_all"], 5),
    "P_l45_all":  (P["l45_all"], 5),
    "P_home_anc": (P["home_anc"], 5),
    "P_l23_anc": (P["l23_anc"], 5),
    "P_l45_anc": (P["l45_anc"], 5),
}

def weighted_rmse(df_results, target_weights):
    weighted_errors = []
    for metric, (target, accepted_pct) in target_weights.items():
        simulated = df_results.get(metric, 0)
        error = simulated - target
        accepted_abs_error = target * (accepted_pct / 100)
        if accepted_abs_error == 0:  # safeguard
            continue
        normalized_error = error / accepted_abs_error
        weighted_errors.append(normalized_error**2)
    return math.sqrt(sum(weighted_errors) / len(weighted_errors))

# Define parameter space
param_space = [
    Real(0.1, 0.5, name='P_home_lowrisk'),
    Real(0.1, 0.4, name='P_L23_highrisk'),
    Real(0.6, 0.8, name='Sen_traditional'),
    Real(0.6, 0.8, name='Spec_traditional')
]

# Seeds for reproducibility
total_runs = 10
seeds = np.random.default_rng(2025).integers(low=0, high=1e6, size=total_runs)

# Track RMSE history
rmse_history = []

@use_named_args(param_space)
def objective(**params):
    # --- Constraint check: Sen must be greater than Spec ---
    if params['Sen_traditional'] <= params['Spec_traditional']:
        print("\n⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.")
        objective.last_df_results = {}
        return 10.0  # Penalty loss

    results = []
    for run in range(total_runs):
        np.random.seed(seeds[run])
        res = f_ANC_LB_effect(
            params['P_home_lowrisk'],
            params['P_L23_highrisk'],
            params['Sen_traditional'],
            params['Spec_traditional']
        )
        results.append(res)

    # Average across runs
    mean_results = np.mean(results, axis=0)
    df_results = {
        "P_home_all": mean_results[0],
        "P_l23_all": mean_results[1],
        "P_l45_all": mean_results[2],
        "P_home_anc": mean_results[3],
        "P_l23_anc": mean_results[4],
        "P_l45_anc": mean_results[5],
    }

    # Save last results for early stopper
    objective.last_df_results = df_results

    # Weighted RMSE
    rmse = weighted_rmse(df_results, target_weights)

    # Print status
    print("\n--- Calibration Iteration ---")
    print("Parameters:")
    for k, v in params.items():
        print(f"  {k:22s}: {v:.4f}")
    print("\nTarget vs Simulated Outcomes:")
    for k in target_values:
        sim = df_results[k]
        target = target_values[k]
        error = sim - target
        rel_error = error / target
        print(f"  {k:22s} | Sim: {sim:.4f}, Target: {target:.4f}, RelErr: {rel_error:+.2%}")
    print(f"\nRMSE Loss: {rmse:.6f}")
    print("-----------------------------\n")

    return rmse

class EarlyStopper:
    def __init__(self, threshold_rmse=0.1, relative_threshold=0.05):
        self.threshold_rmse = threshold_rmse
        self.relative_threshold = relative_threshold
        self.best_loss = float('inf')
        self.best_params = None
        self.best_df_results = None

    def meets_relative_criteria(self, sim_results):
        for metric, (target, accepted_pct) in target_weights.items():
            sim = sim_results.get(metric, 0)
            rel_error = abs(sim - target) / target
            if rel_error > (accepted_pct / 100):
                return False
        return True

    def meets_param_constraints(self, param_list):
        if param_list is None:
            return False
        names = [d.name for d in param_space]
        p = dict(zip(names, param_list))
        return p['Sen_traditional'] > p['Spec_traditional']

    def __call__(self, *args, **kwargs):
        loss = objective(*args, **kwargs)
        rmse_history.append(loss)

        if loss < self.best_loss:
            self.best_loss = loss
            self.best_params = list(args[0]) if args else None
            self.best_df_results = getattr(objective, "last_df_results", {})

        if (self.best_loss < self.threshold_rmse
            and self.meets_relative_criteria(self.best_df_results)
            and self.meets_param_constraints(self.best_params)):
            print(f"\n⏹️ Early stopping: RMSE={self.best_loss:.6f} and Sen>Spec satisfied.")
            raise StopIteration

        return loss

def save_results(best_params, best_loss, rmse_history, param_space):
    param_names = [dim.name for dim in param_space]
    best_param_dict = dict(zip(param_names, best_params))
    best_param_dict["Best RMSE"] = best_loss
    df_best = pd.DataFrame([best_param_dict])
    df_best.to_csv("best_parameters_ANC_v7.csv", index=False)

    pd.DataFrame({"Iteration": range(1, len(rmse_history)+1), "RMSE": rmse_history}).to_csv("rmse_history_ANC_v7.csv", index=False)

    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(rmse_history)+1), rmse_history, marker='o')
    plt.xlabel("Iteration")
    plt.ylabel("RMSE Loss")
    plt.title("RMSE Loss Over Iterations")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("rmse_plot_ANC_v7.png")
    plt.close()

def optimize_model():
    early_stopper = EarlyStopper(threshold_rmse=0.1, relative_threshold=0.05)
    try:
        result = gp_minimize(
            func=early_stopper,
            dimensions=param_space,
            n_calls=1000,
            random_state=42,
            n_random_starts=20,
            acq_func="EI",
            verbose=True
        )
        print("\n✅ Optimization completed.")
        print("Best Parameters:", result.x)
        print("Best Loss:", result.fun)
        save_results(result.x, result.fun, rmse_history, param_space)
        return result

    except StopIteration:
        print("\n✅ Optimization stopped early.")
        print(f"Best RMSE achieved: {early_stopper.best_loss:.6f}")
        if early_stopper.best_params is not None:
            print("Best Parameters:")
            for name, val in zip([d.name for d in param_space], early_stopper.best_params):
                print(f"  {name:22s}: {val:.4f}")
            save_results(early_stopper.best_params, early_stopper.best_loss, rmse_history, param_space)
        return None

if __name__ == "__main__":
    optimize_model()
# Out:
# Iteration No: 1 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.4186
#   P_L23_highrisk        : 0.1550
#   Sen_traditional       : 0.7559
#   Spec_traditional      : 0.7194
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4187, Target: 0.3500, RelErr: +19.63%
#   P_l23_all              | Sim: 0.2941, Target: 0.3920, RelErr: -24.96%
#   P_l45_all              | Sim: 0.2872, Target: 0.2580, RelErr: +11.30%
#   P_home_anc             | Sim: 0.1923, Target: 0.0700, RelErr: +174.74%
#   P_l23_anc              | Sim: 0.3194, Target: 0.4900, RelErr: -34.83%
#   P_l45_anc              | Sim: 0.4883, Target: 0.4390, RelErr: +11.24%
#
# RMSE Loss: 14.834710
# -----------------------------
#
# Iteration No: 1 ended. Evaluation done at random point.
# Time taken: 6.7513
# Function value obtained: 14.8347
# Current minimum: 14.8347
# Iteration No: 2 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.2783
#   P_L23_highrisk        : 0.1300
#   Sen_traditional       : 0.6918
#   Spec_traditional      : 0.6667
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3802, Target: 0.3500, RelErr: +8.62%
#   P_l23_all              | Sim: 0.3137, Target: 0.3920, RelErr: -19.98%
#   P_l45_all              | Sim: 0.3061, Target: 0.2580, RelErr: +18.66%
#   P_home_anc             | Sim: 0.1238, Target: 0.0700, RelErr: +76.83%
#   P_l23_anc              | Sim: 0.3540, Target: 0.4900, RelErr: -27.76%
#   P_l45_anc              | Sim: 0.5223, Target: 0.4390, RelErr: +18.97%
#
# RMSE Loss: 7.236325
# -----------------------------
#
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 6.7184
# Function value obtained: 7.2363
# Current minimum: 7.2363
# Iteration No: 3 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 7.2363
# Iteration No: 4 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.4754
#   P_L23_highrisk        : 0.1002
#   Sen_traditional       : 0.7984
#   Spec_traditional      : 0.7235
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.4317, Target: 0.3500, RelErr: +23.34%
#   P_l23_all              | Sim: 0.2632, Target: 0.3920, RelErr: -32.86%
#   P_l45_all              | Sim: 0.3051, Target: 0.2580, RelErr: +18.26%
#   P_home_anc             | Sim: 0.2159, Target: 0.0700, RelErr: +208.49%
#   P_l23_anc              | Sim: 0.2640, Target: 0.4900, RelErr: -46.11%
#   P_l45_anc              | Sim: 0.5200, Target: 0.4390, RelErr: +18.45%
#
# RMSE Loss: 17.868871
# -----------------------------
#
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 6.8438
# Function value obtained: 17.8689
# Current minimum: 7.2363
# Iteration No: 5 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 0.0009
# Function value obtained: 10.0000
# Current minimum: 7.2363
# Iteration No: 6 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.2599
#   P_L23_highrisk        : 0.1140
#   Sen_traditional       : 0.7948
#   Spec_traditional      : 0.6466
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3707, Target: 0.3500, RelErr: +5.90%
#   P_l23_all              | Sim: 0.3032, Target: 0.3920, RelErr: -22.66%
#   P_l45_all              | Sim: 0.3262, Target: 0.2580, RelErr: +26.42%
#   P_home_anc             | Sim: 0.1070, Target: 0.0700, RelErr: +52.87%
#   P_l23_anc              | Sim: 0.3355, Target: 0.4900, RelErr: -31.53%
#   P_l45_anc              | Sim: 0.5575, Target: 0.4390, RelErr: +26.99%
#
# RMSE Loss: 6.199040
# -----------------------------
#
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 7.3797
# Function value obtained: 6.1990
# Current minimum: 6.1990
# Iteration No: 7 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 6.1990
# Iteration No: 8 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.2867
#   P_L23_highrisk        : 0.3580
#   Sen_traditional       : 0.7361
#   Spec_traditional      : 0.6901
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3827, Target: 0.3500, RelErr: +9.36%
#   P_l23_all              | Sim: 0.3843, Target: 0.3920, RelErr: -1.95%
#   P_l45_all              | Sim: 0.2329, Target: 0.2580, RelErr: -9.72%
#   P_home_anc             | Sim: 0.1287, Target: 0.0700, RelErr: +83.83%
#   P_l23_anc              | Sim: 0.4807, Target: 0.4900, RelErr: -1.91%
#   P_l45_anc              | Sim: 0.3907, Target: 0.4390, RelErr: -11.01%
#
# RMSE Loss: 6.994398
# -----------------------------
#
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 6.5959
# Function value obtained: 6.9944
# Current minimum: 6.1990
# Iteration No: 9 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1053
#   P_L23_highrisk        : 0.3827
#   Sen_traditional       : 0.7127
#   Spec_traditional      : 0.6771
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3375, Target: 0.3500, RelErr: -3.58%
#   P_l23_all              | Sim: 0.4316, Target: 0.3920, RelErr: +10.11%
#   P_l45_all              | Sim: 0.2309, Target: 0.2580, RelErr: -10.51%
#   P_home_anc             | Sim: 0.0475, Target: 0.0700, RelErr: -32.19%
#   P_l23_anc              | Sim: 0.5653, Target: 0.4900, RelErr: +15.38%
#   P_l45_anc              | Sim: 0.3872, Target: 0.4390, RelErr: -11.80%
#
# RMSE Loss: 3.303739
# -----------------------------
#
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 6.5356
# Function value obtained: 3.3037
# Current minimum: 3.3037
# Iteration No: 10 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 3.3037
# Iteration No: 11 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 0.0002
# Function value obtained: 10.0000
# Current minimum: 3.3037
# Iteration No: 12 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1729
#   P_L23_highrisk        : 0.3266
#   Sen_traditional       : 0.6850
#   Spec_traditional      : 0.6416
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3530, Target: 0.3500, RelErr: +0.85%
#   P_l23_all              | Sim: 0.3960, Target: 0.3920, RelErr: +1.03%
#   P_l45_all              | Sim: 0.2510, Target: 0.2580, RelErr: -2.72%
#   P_home_anc             | Sim: 0.0749, Target: 0.0700, RelErr: +6.93%
#   P_l23_anc              | Sim: 0.5018, Target: 0.4900, RelErr: +2.40%
#   P_l45_anc              | Sim: 0.4234, Target: 0.4390, RelErr: -3.56%
#
# RMSE Loss: 0.710158
# -----------------------------
#
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 6.7375
# Function value obtained: 0.7102
# Current minimum: 0.7102
# Iteration No: 13 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.3271
#   P_L23_highrisk        : 0.1094
#   Sen_traditional       : 0.7685
#   Spec_traditional      : 0.6900
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3914, Target: 0.3500, RelErr: +11.84%
#   P_l23_all              | Sim: 0.2963, Target: 0.3920, RelErr: -24.41%
#   P_l45_all              | Sim: 0.3123, Target: 0.2580, RelErr: +21.03%
#   P_home_anc             | Sim: 0.1441, Target: 0.0700, RelErr: +105.84%
#   P_l23_anc              | Sim: 0.3232, Target: 0.4900, RelErr: -34.05%
#   P_l45_anc              | Sim: 0.5328, Target: 0.4390, RelErr: +21.36%
#
# RMSE Loss: 9.659241
# -----------------------------
#
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 6.7136
# Function value obtained: 9.6592
# Current minimum: 0.7102
# Iteration No: 14 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.2581
#   P_L23_highrisk        : 0.3780
#   Sen_traditional       : 0.7455
#   Spec_traditional      : 0.6653
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3736, Target: 0.3500, RelErr: +6.73%
#   P_l23_all              | Sim: 0.3944, Target: 0.3920, RelErr: +0.61%
#   P_l45_all              | Sim: 0.2320, Target: 0.2580, RelErr: -10.06%
#   P_home_anc             | Sim: 0.1116, Target: 0.0700, RelErr: +59.49%
#   P_l23_anc              | Sim: 0.4991, Target: 0.4900, RelErr: +1.86%
#   P_l45_anc              | Sim: 0.3892, Target: 0.4390, RelErr: -11.33%
#
# RMSE Loss: 5.045208
# -----------------------------
#
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 6.6965
# Function value obtained: 5.0452
# Current minimum: 0.7102
# Iteration No: 15 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.3282
#   P_L23_highrisk        : 0.2563
#   Sen_traditional       : 0.7922
#   Spec_traditional      : 0.7689
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3988, Target: 0.3500, RelErr: +13.95%
#   P_l23_all              | Sim: 0.3507, Target: 0.3920, RelErr: -10.55%
#   P_l45_all              | Sim: 0.2505, Target: 0.2580, RelErr: -2.90%
#   P_home_anc             | Sim: 0.1578, Target: 0.0700, RelErr: +125.36%
#   P_l23_anc              | Sim: 0.4200, Target: 0.4900, RelErr: -14.30%
#   P_l45_anc              | Sim: 0.4223, Target: 0.4390, RelErr: -3.81%
#
# RMSE Loss: 10.407962
# -----------------------------
#
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 6.7777
# Function value obtained: 10.4080
# Current minimum: 0.7102
# Iteration No: 16 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 0.7102
# Iteration No: 17 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.3428
#   P_L23_highrisk        : 0.1828
#   Sen_traditional       : 0.6593
#   Spec_traditional      : 0.6331
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3934, Target: 0.3500, RelErr: +12.40%
#   P_l23_all              | Sim: 0.3138, Target: 0.3920, RelErr: -19.95%
#   P_l45_all              | Sim: 0.2928, Target: 0.2580, RelErr: +13.49%
#   P_home_anc             | Sim: 0.1475, Target: 0.0700, RelErr: +110.72%
#   P_l23_anc              | Sim: 0.3541, Target: 0.4900, RelErr: -27.74%
#   P_l45_anc              | Sim: 0.4984, Target: 0.4390, RelErr: +13.53%
#
# RMSE Loss: 9.642308
# -----------------------------
#
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 6.5843
# Function value obtained: 9.6423
# Current minimum: 0.7102
# Iteration No: 18 started. Evaluating function at random point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1063
#   P_L23_highrisk        : 0.2270
#   Sen_traditional       : 0.6790
#   Spec_traditional      : 0.6587
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3372, Target: 0.3500, RelErr: -3.65%
#   P_l23_all              | Sim: 0.3825, Target: 0.3920, RelErr: -2.42%
#   P_l45_all              | Sim: 0.2803, Target: 0.2580, RelErr: +8.64%
#   P_home_anc             | Sim: 0.0471, Target: 0.0700, RelErr: -32.72%
#   P_l23_anc              | Sim: 0.4771, Target: 0.4900, RelErr: -2.63%
#   P_l45_anc              | Sim: 0.4758, Target: 0.4390, RelErr: +8.38%
#
# RMSE Loss: 2.876775
# -----------------------------
#
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 6.7601
# Function value obtained: 2.8768
# Current minimum: 0.7102
# Iteration No: 19 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 0.0003
# Function value obtained: 10.0000
# Current minimum: 0.7102
# Iteration No: 20 started. Evaluating function at random point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 0.1116
# Function value obtained: 10.0000
# Current minimum: 0.7102
# Iteration No: 21 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 21 ended. Search finished for the next optimal point.
# Time taken: 0.1669
# Function value obtained: 10.0000
# Current minimum: 0.7102
# Iteration No: 22 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 22 ended. Search finished for the next optimal point.
# Time taken: 0.1660
# Function value obtained: 10.0000
# Current minimum: 0.7102
# Iteration No: 23 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1456
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7149
#   Spec_traditional      : 0.6011
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3437, Target: 0.3500, RelErr: -1.79%
#   P_l23_all              | Sim: 0.4196, Target: 0.3920, RelErr: +7.03%
#   P_l45_all              | Sim: 0.2367, Target: 0.2580, RelErr: -8.27%
#   P_home_anc             | Sim: 0.0586, Target: 0.0700, RelErr: -16.29%
#   P_l23_anc              | Sim: 0.5439, Target: 0.4900, RelErr: +11.01%
#   P_l45_anc              | Sim: 0.3975, Target: 0.4390, RelErr: -9.46%
#
# RMSE Loss: 1.994988
# -----------------------------
#
# Iteration No: 23 ended. Search finished for the next optimal point.
# Time taken: 6.8395
# Function value obtained: 1.9950
# Current minimum: 0.7102
# Iteration No: 24 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1603
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.7048
#   Spec_traditional      : 0.6418
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3492, Target: 0.3500, RelErr: -0.23%
#   P_l23_all              | Sim: 0.4216, Target: 0.3920, RelErr: +7.55%
#   P_l45_all              | Sim: 0.2292, Target: 0.2580, RelErr: -11.15%
#   P_home_anc             | Sim: 0.0686, Target: 0.0700, RelErr: -2.04%
#   P_l23_anc              | Sim: 0.5474, Target: 0.4900, RelErr: +11.71%
#   P_l45_anc              | Sim: 0.3840, Target: 0.4390, RelErr: -12.52%
#
# RMSE Loss: 1.787576
# -----------------------------
#
# Iteration No: 24 ended. Search finished for the next optimal point.
# Time taken: 6.9064
# Function value obtained: 1.7876
# Current minimum: 0.7102
# Iteration No: 25 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3327, Target: 0.3500, RelErr: -4.94%
#   P_l23_all              | Sim: 0.4245, Target: 0.3920, RelErr: +8.29%
#   P_l45_all              | Sim: 0.2428, Target: 0.2580, RelErr: -5.89%
#   P_home_anc             | Sim: 0.0388, Target: 0.0700, RelErr: -44.61%
#   P_l23_anc              | Sim: 0.5529, Target: 0.4900, RelErr: +12.83%
#   P_l45_anc              | Sim: 0.4083, Target: 0.4390, RelErr: -6.98%
#
# RMSE Loss: 3.942147
# -----------------------------
#
# Iteration No: 25 ended. Search finished for the next optimal point.
# Time taken: 6.9643
# Function value obtained: 3.9421
# Current minimum: 0.7102
# Iteration No: 26 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1347
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.7217
#   Spec_traditional      : 0.6322
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3427, Target: 0.3500, RelErr: -2.10%
#   P_l23_all              | Sim: 0.3268, Target: 0.3920, RelErr: -16.64%
#   P_l45_all              | Sim: 0.3306, Target: 0.2580, RelErr: +28.13%
#   P_home_anc             | Sim: 0.0568, Target: 0.0700, RelErr: -18.86%
#   P_l23_anc              | Sim: 0.3775, Target: 0.4900, RelErr: -22.96%
#   P_l45_anc              | Sim: 0.5657, Target: 0.4390, RelErr: +28.86%
#
# RMSE Loss: 4.311273
# -----------------------------
#
# Iteration No: 26 ended. Search finished for the next optimal point.
# Time taken: 6.7840
# Function value obtained: 4.3113
# Current minimum: 0.7102
# Iteration No: 27 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1609
#   P_L23_highrisk        : 0.2873
#   Sen_traditional       : 0.7102
#   Spec_traditional      : 0.6221
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3482, Target: 0.3500, RelErr: -0.52%
#   P_l23_all              | Sim: 0.3820, Target: 0.3920, RelErr: -2.56%
#   P_l45_all              | Sim: 0.2699, Target: 0.2580, RelErr: +4.60%
#   P_home_anc             | Sim: 0.0666, Target: 0.0700, RelErr: -4.92%
#   P_l23_anc              | Sim: 0.4762, Target: 0.4900, RelErr: -2.81%
#   P_l45_anc              | Sim: 0.4572, Target: 0.4390, RelErr: +4.15%
#
# RMSE Loss: 0.717933
# -----------------------------
#
# Iteration No: 27 ended. Search finished for the next optimal point.
# Time taken: 6.8376
# Function value obtained: 0.7179
# Current minimum: 0.7102
# Iteration No: 28 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1616
#   P_L23_highrisk        : 0.2925
#   Sen_traditional       : 0.6909
#   Spec_traditional      : 0.6220
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3486, Target: 0.3500, RelErr: -0.39%
#   P_l23_all              | Sim: 0.3846, Target: 0.3920, RelErr: -1.89%
#   P_l45_all              | Sim: 0.2668, Target: 0.2580, RelErr: +3.40%
#   P_home_anc             | Sim: 0.0675, Target: 0.0700, RelErr: -3.51%
#   P_l23_anc              | Sim: 0.4808, Target: 0.4900, RelErr: -1.88%
#   P_l45_anc              | Sim: 0.4516, Target: 0.4390, RelErr: +2.88%
#
# RMSE Loss: 0.512466
# -----------------------------
#
# Iteration No: 28 ended. Search finished for the next optimal point.
# Time taken: 6.9293
# Function value obtained: 0.5125
# Current minimum: 0.5125
# Iteration No: 29 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1627
#   P_L23_highrisk        : 0.2968
#   Sen_traditional       : 0.6945
#   Spec_traditional      : 0.6349
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3494, Target: 0.3500, RelErr: -0.18%
#   P_l23_all              | Sim: 0.3876, Target: 0.3920, RelErr: -1.12%
#   P_l45_all              | Sim: 0.2630, Target: 0.2580, RelErr: +1.95%
#   P_home_anc             | Sim: 0.0690, Target: 0.0700, RelErr: -1.49%
#   P_l23_anc              | Sim: 0.4862, Target: 0.4900, RelErr: -0.77%
#   P_l45_anc              | Sim: 0.4448, Target: 0.4390, RelErr: +1.33%
#
# RMSE Loss: 0.253749
# -----------------------------
#
# Iteration No: 29 ended. Search finished for the next optimal point.
# Time taken: 6.9047
# Function value obtained: 0.2537
# Current minimum: 0.2537
# Iteration No: 30 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1697
#   P_L23_highrisk        : 0.2758
#   Sen_traditional       : 0.6950
#   Spec_traditional      : 0.6412
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3514, Target: 0.3500, RelErr: +0.41%
#   P_l23_all              | Sim: 0.3801, Target: 0.3920, RelErr: -3.03%
#   P_l45_all              | Sim: 0.2685, Target: 0.2580, RelErr: +4.06%
#   P_home_anc             | Sim: 0.0728, Target: 0.0700, RelErr: +4.03%
#   P_l23_anc              | Sim: 0.4725, Target: 0.4900, RelErr: -3.56%
#   P_l45_anc              | Sim: 0.4546, Target: 0.4390, RelErr: +3.56%
#
# RMSE Loss: 0.670365
# -----------------------------
#
# Iteration No: 30 ended. Search finished for the next optimal point.
# Time taken: 6.9043
# Function value obtained: 0.6704
# Current minimum: 0.2537
# Iteration No: 31 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1394
#   P_L23_highrisk        : 0.3072
#   Sen_traditional       : 0.6954
#   Spec_traditional      : 0.6299
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3439, Target: 0.3500, RelErr: -1.74%
#   P_l23_all              | Sim: 0.3951, Target: 0.3920, RelErr: +0.78%
#   P_l45_all              | Sim: 0.2610, Target: 0.2580, RelErr: +1.17%
#   P_home_anc             | Sim: 0.0591, Target: 0.0700, RelErr: -15.53%
#   P_l23_anc              | Sim: 0.4995, Target: 0.4900, RelErr: +1.95%
#   P_l45_anc              | Sim: 0.4413, Target: 0.4390, RelErr: +0.53%
#
# RMSE Loss: 1.291855
# -----------------------------
#
# Iteration No: 31 ended. Search finished for the next optimal point.
# Time taken: 6.8191
# Function value obtained: 1.2919
# Current minimum: 0.2537
# Iteration No: 32 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1945
#   P_L23_highrisk        : 0.2854
#   Sen_traditional       : 0.6989
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3547, Target: 0.3500, RelErr: +1.35%
#   P_l23_all              | Sim: 0.3722, Target: 0.3920, RelErr: -5.04%
#   P_l45_all              | Sim: 0.2730, Target: 0.2580, RelErr: +5.83%
#   P_home_anc             | Sim: 0.0781, Target: 0.0700, RelErr: +11.57%
#   P_l23_anc              | Sim: 0.4588, Target: 0.4900, RelErr: -6.36%
#   P_l45_anc              | Sim: 0.4630, Target: 0.4390, RelErr: +5.48%
#
# RMSE Loss: 1.330646
# -----------------------------
#
# Iteration No: 32 ended. Search finished for the next optimal point.
# Time taken: 6.9140
# Function value obtained: 1.3306
# Current minimum: 0.2537
# Iteration No: 33 started. Searching for the next optimal point.
#
# ⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.
# Iteration No: 33 ended. Search finished for the next optimal point.
# Time taken: 0.2195
# Function value obtained: 10.0000
# Current minimum: 0.2537
# Iteration No: 34 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1800
#   P_L23_highrisk        : 0.3007
#   Sen_traditional       : 0.7074
#   Spec_traditional      : 0.6372
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3532, Target: 0.3500, RelErr: +0.91%
#   P_l23_all              | Sim: 0.3850, Target: 0.3920, RelErr: -1.80%
#   P_l45_all              | Sim: 0.2619, Target: 0.2580, RelErr: +1.50%
#   P_home_anc             | Sim: 0.0759, Target: 0.0700, RelErr: +8.48%
#   P_l23_anc              | Sim: 0.4815, Target: 0.4900, RelErr: -1.74%
#   P_l45_anc              | Sim: 0.4426, Target: 0.4390, RelErr: +0.82%
#
# RMSE Loss: 0.738759
# -----------------------------
#
# Iteration No: 34 ended. Search finished for the next optimal point.
# Time taken: 6.7929
# Function value obtained: 0.7388
# Current minimum: 0.2537
# Iteration No: 35 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1568
#   P_L23_highrisk        : 0.1973
#   Sen_traditional       : 0.6734
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3468, Target: 0.3500, RelErr: -0.92%
#   P_l23_all              | Sim: 0.3513, Target: 0.3920, RelErr: -10.39%
#   P_l45_all              | Sim: 0.3019, Target: 0.2580, RelErr: +17.03%
#   P_home_anc             | Sim: 0.0647, Target: 0.0700, RelErr: -7.56%
#   P_l23_anc              | Sim: 0.4207, Target: 0.4900, RelErr: -14.14%
#   P_l45_anc              | Sim: 0.5146, Target: 0.4390, RelErr: +17.21%
#
# RMSE Loss: 2.519395
# -----------------------------
#
# Iteration No: 35 ended. Search finished for the next optimal point.
# Time taken: 6.9622
# Function value obtained: 2.5194
# Current minimum: 0.2537
# Iteration No: 36 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1000
#   P_L23_highrisk        : 0.1000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3323, Target: 0.3500, RelErr: -5.05%
#   P_l23_all              | Sim: 0.3205, Target: 0.3920, RelErr: -18.24%
#   P_l45_all              | Sim: 0.3472, Target: 0.2580, RelErr: +34.58%
#   P_home_anc             | Sim: 0.0388, Target: 0.0700, RelErr: -44.53%
#   P_l23_anc              | Sim: 0.3659, Target: 0.4900, RelErr: -25.32%
#   P_l45_anc              | Sim: 0.5952, Target: 0.4390, RelErr: +35.59%
#
# RMSE Loss: 6.024868
# -----------------------------
#
# Iteration No: 36 ended. Search finished for the next optimal point.
# Time taken: 6.8678
# Function value obtained: 6.0249
# Current minimum: 0.2537
# Iteration No: 37 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.2192
#   P_L23_highrisk        : 0.4000
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3580, Target: 0.3500, RelErr: +2.30%
#   P_l23_all              | Sim: 0.4020, Target: 0.3920, RelErr: +2.55%
#   P_l45_all              | Sim: 0.2400, Target: 0.2580, RelErr: -6.99%
#   P_home_anc             | Sim: 0.0838, Target: 0.0700, RelErr: +19.72%
#   P_l23_anc              | Sim: 0.5128, Target: 0.4900, RelErr: +4.65%
#   P_l45_anc              | Sim: 0.4034, Target: 0.4390, RelErr: -8.11%
#
# RMSE Loss: 1.892234
# -----------------------------
#
# Iteration No: 37 ended. Search finished for the next optimal point.
# Time taken: 6.7699
# Function value obtained: 1.8922
# Current minimum: 0.2537
# Iteration No: 38 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1868
#   P_L23_highrisk        : 0.3068
#   Sen_traditional       : 0.7584
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3517, Target: 0.3500, RelErr: +0.50%
#   P_l23_all              | Sim: 0.3785, Target: 0.3920, RelErr: -3.44%
#   P_l45_all              | Sim: 0.2697, Target: 0.2580, RelErr: +4.55%
#   P_home_anc             | Sim: 0.0730, Target: 0.0700, RelErr: +4.26%
#   P_l23_anc              | Sim: 0.4700, Target: 0.4900, RelErr: -4.08%
#   P_l45_anc              | Sim: 0.4570, Target: 0.4390, RelErr: +4.11%
#
# RMSE Loss: 0.750389
# -----------------------------
#
# Iteration No: 38 ended. Search finished for the next optimal point.
# Time taken: 7.0340
# Function value obtained: 0.7504
# Current minimum: 0.2537
# Iteration No: 39 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1880
#   P_L23_highrisk        : 0.2869
#   Sen_traditional       : 0.8000
#   Spec_traditional      : 0.6000
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3511, Target: 0.3500, RelErr: +0.31%
#   P_l23_all              | Sim: 0.3693, Target: 0.3920, RelErr: -5.80%
#   P_l45_all              | Sim: 0.2796, Target: 0.2580, RelErr: +8.38%
#   P_home_anc             | Sim: 0.0717, Target: 0.0700, RelErr: +2.49%
#   P_l23_anc              | Sim: 0.4537, Target: 0.4900, RelErr: -7.42%
#   P_l45_anc              | Sim: 0.4746, Target: 0.4390, RelErr: +8.11%
#
# RMSE Loss: 1.240714
# -----------------------------
#
# Iteration No: 39 ended. Search finished for the next optimal point.
# Time taken: 6.8954
# Function value obtained: 1.2407
# Current minimum: 0.2537
# Iteration No: 40 started. Searching for the next optimal point.
#
# --- Calibration Iteration ---
# Parameters:
#   P_home_lowrisk        : 0.1692
#   P_L23_highrisk        : 0.3255
#   Sen_traditional       : 0.7641
#   Spec_traditional      : 0.6306
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3501, Target: 0.3500, RelErr: +0.02%
#   P_l23_all              | Sim: 0.3915, Target: 0.3920, RelErr: -0.12%
#   P_l45_all              | Sim: 0.2584, Target: 0.2580, RelErr: +0.15%
#   P_home_anc             | Sim: 0.0697, Target: 0.0700, RelErr: -0.49%
#   P_l23_anc              | Sim: 0.4937, Target: 0.4900, RelErr: +0.76%
#   P_l45_anc              | Sim: 0.4366, Target: 0.4390, RelErr: -0.54%
#
# RMSE Loss: 0.087077
# -----------------------------
#
#
# ⏹️ Early stopping: RMSE=0.087077 and Sen>Spec satisfied.
#
# ✅ Optimization stopped early.
# Best RMSE achieved: 0.087077
# Best Parameters:
#   P_home_lowrisk        : 0.1692
#   P_L23_highrisk        : 0.3255
#   Sen_traditional       : 0.7641
#   Spec_traditional      : 0.6306

# %%
# --- Calibration Iteration ---
# param_space = [
#     Real(0.1, 0.5, name='P_home_lowrisk'),
#     Real(0.1, 0.4, name='P_L23_highrisk'),
#     Real(0.6, 0.8, name='Sen_traditional'),
#     Real(0.6, 0.8, name='Spec_traditional')
# ]

# Parameters:
#   P_home_lowrisk        : 0.1692
#   P_L23_highrisk        : 0.3255
#   Sen_traditional       : 0.7641
#   Spec_traditional      : 0.6306
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3501, Target: 0.3500, RelErr: +0.02%
#   P_l23_all              | Sim: 0.3915, Target: 0.3920, RelErr: -0.12%
#   P_l45_all              | Sim: 0.2584, Target: 0.2580, RelErr: +0.15%
#   P_home_anc             | Sim: 0.0697, Target: 0.0700, RelErr: -0.49%
#   P_l23_anc              | Sim: 0.4937, Target: 0.4900, RelErr: +0.76%
#   P_l45_anc              | Sim: 0.4366, Target: 0.4390, RelErr: -0.54%
#
# RMSE Loss: 0.087077
# -----------------------------
#
#
# ⏹️ Early stopping: RMSE=0.087077 and Sen>Spec satisfied.
#
# ✅ Optimization stopped early.
# Best RMSE achieved: 0.087077
# Best Parameters:
#   P_home_lowrisk        : 0.1692
#   P_L23_highrisk        : 0.3255
#   Sen_traditional       : 0.7641
#   Spec_traditional      : 0.6306

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV if needed
rmse_df = pd.read_csv("rmse_history_ANC_v7.csv")

# Plot
plt.figure(figsize=(12, 5))
plt.plot(rmse_df['Iteration'], rmse_df['RMSE'], marker='o', label='Weighted RMSE')
plt.axhline(y=0.1, color='red', linestyle='--', label='Tolerance Threshold (RMSE=0.1)')

# Add labels and title
final_rmse = rmse_df['RMSE'].iloc[-1]
plt.title(f"Optimization Progress (Final RMSE: {final_rmse:.3f})")
plt.xlabel("Iteration")
plt.ylabel("Weighted RMSE")
plt.legend()
plt.grid(True)

# Save the plot
plt.savefig("rmse_ANC.png", dpi=300)

# Show plot
plt.tight_layout()
plt.show()
