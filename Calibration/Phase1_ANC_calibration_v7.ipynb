# %%
import sys
sys.path.append("..")

from parameters import get_parameters
from global_func import odds_prob

# %%
import random
import numpy as np
import streamlit as st
import math


# Initialize parameters
P = {}  # dict to restore probabilities
n = {}  # dict to restore counts
E = {}  # dict to restore effects
S = {}  # dict to restore supplies and capacities
OR = {}  # dict to restore odds ratio
M = {}  # dict to restore maternal outcomes

#known parameters
param = get_parameters()
# LB_tot = np.array([23729, 18196, 20709, 5126])
LB_tot = np.array([843, 485, 1448, 668]) # FIX
# P["highrisk_all"] = 0.26                                              # high risk pregnancies among all live births
# # P["ANC"] = 0.56
# P["ANC"] = 0.604
# P["Home_noANC"] = 0.132
# # P["Home_noANC"] = 0.4

# Calibration criteria - FIX ALL
# P["home_all"] = param["home_all_target"] #0.35
P["home_all"] = 0.0588
# P["l23_all"] = param["l23_all_target"] #0.39
P["l23_all"] = 0.2297
# P["l45_all"] = param["l45_all_target"] #0.26
P["l45_all"] = 1 - P["home_all"] - P["l23_all"]
# P["home_anc"] = param["home_anc_target"] #0.07
P["home_anc"] = 0.0173
# P["l23_anc"] = param["l23_anc_target"] #0.490
P["l23_anc"] = 0.1701
# P["l45_anc"] = param["l45_anc_target"] #0.439
P["l45_anc"] = 0.8126

# Fixed parameters (from DHS)
P["ANC"] = 0.6298
P["Home_noANC"] = 0.1295
P["L23_noANC"] = 0.3310
P["L45_noANC"] = 0.5179
P["highrisk_all"] = 0.26  # Keep or update from literature

# %%
random.seed(0)
# Install
# pip install optuna optuna-dashboard

import optuna

def objective_optuna(trial):
    # Proper constraint handling - sample Sen first, then Spec with upper bound
    Sen_traditional = trial.suggest_float('Sen_traditional', 0.5, 0.9)
    Spec_traditional = trial.suggest_float('Spec_traditional', 0.3, Sen_traditional - 0.05)
    P_home_lowrisk = trial.suggest_float('P_home_lowrisk', 0.01, 0.6)
    P_L23_highrisk = trial.suggest_float('P_L23_highrisk', 0.01, 0.5)
    
    results = []
    for run in range(total_runs):
        np.random.seed(seeds[run])
        res = f_ANC_LB_effect(
            P_home_lowrisk,
            P_L23_highrisk,
            Sen_traditional,
            Spec_traditional
        )
        results.append(res)
    
    mean_results = np.mean(results, axis=0)
    df_results = {
        "P_home_all": mean_results[0],
        "P_l23_all": mean_results[1],
        "P_l45_all": mean_results[2],
        "P_home_anc": mean_results[3],
        "P_l23_anc": mean_results[4],
        "P_l45_anc": mean_results[5],
    }
    
    rmse = weighted_rmse(df_results, target_weights)
    
    # Store for analysis
    for k, v in df_results.items():
        trial.set_user_attr(k, v)
    
    # Print progress
    print(f"\nTrial {trial.number}: RMSE={rmse:.4f}")
    print(f"  Sen={Sen_traditional:.3f}, Spec={Spec_traditional:.3f}")
    print(f"  P_home_lowrisk={P_home_lowrisk:.3f}, P_L23_highrisk={P_L23_highrisk:.3f}")
    
    return rmse

# Create study with SQLite storage (allows resuming)
study = optuna.create_study(
    study_name="anc_calibration_v11",
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=42, multivariate=True),
    storage="sqlite:///optuna_anc_v5.db",
    load_if_exists=True
)

# Add callback for early stopping
def early_stopping_callback(study, trial):
    if study.best_value < 0.1:  # RMSE threshold
        study.stop()

study.optimize(
    objective_optuna, 
    n_trials=500,
    callbacks=[early_stopping_callback],
    show_progress_bar=True
)

# Results
print("\n" + "="*50)
print("OPTIMIZATION COMPLETE")
print("="*50)
print(f"Best RMSE: {study.best_value:.6f}")
print("Best Parameters:")
for k, v in study.best_params.items():
    print(f"  {k}: {v:.4f}")

# Save results
df_trials = study.trials_dataframe()
# df_trials.to_csv("optuna_trials_v8.csv", index=False)
# Out:
# /var/folders/k4/vwg070jx71d7yl8qzjlbf0cm0000gn/T/ipykernel_67520/2057493364.py:52: ExperimentalWarning: Argument ``multivariate`` is an experimental feature. The interface can change in the future.
#   sampler=optuna.samplers.TPESampler(seed=42, multivariate=True),
# [I 2026-06-08 17:37:35,583] A new study created in RDB with name: anc_calibration_v11
#   0%|          | 0/500 [00:00<?, ?it/s]
# Trial 0: RMSE=76.5461
#   Sen=0.650, Spec=0.585
#   P_home_lowrisk=0.442, P_L23_highrisk=0.303
# [I 2026-06-08 17:37:35,984] Trial 0 finished with value: 76.5460908836054 and parameters: {'Sen_traditional': 0.649816047538945, 'Spec_traditional': 0.5850394056865504, 'P_home_lowrisk': 0.441876425668729, 'P_L23_highrisk': 0.30334265725654797}. Best is trial 0 with value: 76.5460908836054.
#
# Trial 1: RMSE=13.9385
#   Sen=0.562, Spec=0.333
#   P_home_lowrisk=0.044, P_L23_highrisk=0.434
# [I 2026-06-08 17:37:36,377] Trial 1 finished with value: 13.938489771231966 and parameters: {'Sen_traditional': 0.5624074561769746, 'Spec_traditional': 0.33313439924216015, 'P_home_lowrisk': 0.04426933117923768, 'P_L23_highrisk': 0.4344263114297182}. Best is trial 1 with value: 13.938489771231966.
#
# Trial 2: RMSE=16.2349
#   Sen=0.740, Spec=0.576
#   P_home_lowrisk=0.022, P_L23_highrisk=0.485
# [I 2026-06-08 17:37:36,793] Trial 2 finished with value: 16.234949846272826 and parameters: {'Sen_traditional': 0.7404460046972835, 'Spec_traditional': 0.5764641090361724, 'P_home_lowrisk': 0.02214485163452344, 'P_L23_highrisk': 0.48525582755937724}. Best is trial 1 with value: 13.938489771231966.
#
# Trial 3: RMSE=6.5782
#   Sen=0.833, Spec=0.403
#   P_home_lowrisk=0.117, P_L23_highrisk=0.100
# [I 2026-06-08 17:37:37,193] Trial 3 finished with value: 6.578226076827713 and parameters: {'Sen_traditional': 0.8329770563201687, 'Spec_traditional': 0.4025549186170363, 'P_home_lowrisk': 0.11727673065218935, 'P_L23_highrisk': 0.09986820982818256}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 4: RMSE=33.9094
#   Sen=0.622, Spec=0.443
#   P_home_lowrisk=0.265, P_L23_highrisk=0.153
# [I 2026-06-08 17:37:37,586] Trial 4 finished with value: 33.90943172046328 and parameters: {'Sen_traditional': 0.621696897183815, 'Spec_traditional': 0.4425746942517298, 'P_home_lowrisk': 0.2648475609988483, 'P_L23_highrisk': 0.15270227869704053}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 5: RMSE=15.1071
#   Sen=0.745, Spec=0.355
#   P_home_lowrisk=0.182, P_L23_highrisk=0.190
# [I 2026-06-08 17:37:37,980] Trial 5 finished with value: 15.107100987935434 and parameters: {'Sen_traditional': 0.7447411578889518, 'Spec_traditional': 0.3550639680721871, 'P_home_lowrisk': 0.18236534263577872, 'P_L23_highrisk': 0.18951730321390894}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 6: RMSE=17.5494
#   Sen=0.682, Spec=0.561
#   P_home_lowrisk=0.128, P_L23_highrisk=0.262
# [I 2026-06-08 17:37:38,366] Trial 6 finished with value: 17.54943740984969 and parameters: {'Sen_traditional': 0.6824279936868144, 'Spec_traditional': 0.5610144695369952, 'P_home_lowrisk': 0.12780753147343224, 'P_L23_highrisk': 0.2619748748226697}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 7: RMSE=34.0068
#   Sen=0.737, Spec=0.318
#   P_home_lowrisk=0.368, P_L23_highrisk=0.094
# [I 2026-06-08 17:37:38,750] Trial 7 finished with value: 34.00679284512217 and parameters: {'Sen_traditional': 0.736965827544817, 'Spec_traditional': 0.3179747223979922, 'P_home_lowrisk': 0.36845146262184864, 'P_L23_highrisk': 0.09355682060677284}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 8: RMSE=91.5930
#   Sen=0.526, Spec=0.467
#   P_home_lowrisk=0.580, P_L23_highrisk=0.406
# [I 2026-06-08 17:37:39,129] Trial 8 finished with value: 91.59297815119709 and parameters: {'Sen_traditional': 0.5260206371941119, 'Spec_traditional': 0.46702343689160886, 'P_home_lowrisk': 0.57972289951399, 'P_L23_highrisk': 0.40611470057706595}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 9: RMSE=44.6714
#   Sen=0.622, Spec=0.327
#   P_home_lowrisk=0.414, P_L23_highrisk=0.226
# [I 2026-06-08 17:37:39,513] Trial 9 finished with value: 44.67143880045323 and parameters: {'Sen_traditional': 0.6218455076693483, 'Spec_traditional': 0.3265517254172039, 'P_home_lowrisk': 0.41369748564217257, 'P_L23_highrisk': 0.22567472193240465}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 10: RMSE=18.1691
#   Sen=0.872, Spec=0.806
#   P_home_lowrisk=0.112, P_L23_highrisk=0.049
# [I 2026-06-08 17:37:39,901] Trial 10 finished with value: 18.16910476882457 and parameters: {'Sen_traditional': 0.8719652806576009, 'Spec_traditional': 0.8060647101403479, 'P_home_lowrisk': 0.11206694477998058, 'P_L23_highrisk': 0.04856790295195216}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 11: RMSE=15.2116
#   Sen=0.536, Spec=0.401
#   P_home_lowrisk=0.062, P_L23_highrisk=0.476
# [I 2026-06-08 17:37:40,287] Trial 11 finished with value: 15.211648667278215 and parameters: {'Sen_traditional': 0.5360806948567489, 'Spec_traditional': 0.40140827439714805, 'P_home_lowrisk': 0.06225969096553675, 'P_L23_highrisk': 0.47555470360130914}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 12: RMSE=21.9552
#   Sen=0.875, Spec=0.312
#   P_home_lowrisk=0.300, P_L23_highrisk=0.212
# [I 2026-06-08 17:37:40,670] Trial 12 finished with value: 21.955163812328315 and parameters: {'Sen_traditional': 0.8749142359433565, 'Spec_traditional': 0.3116046689775052, 'P_home_lowrisk': 0.30025192024492015, 'P_L23_highrisk': 0.21212348416988036}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 13: RMSE=41.6809
#   Sen=0.727, Spec=0.434
#   P_home_lowrisk=0.323, P_L23_highrisk=0.491
# [I 2026-06-08 17:37:41,056] Trial 13 finished with value: 41.68094143815749 and parameters: {'Sen_traditional': 0.727183495180203, 'Spec_traditional': 0.4343117322204872, 'P_home_lowrisk': 0.3229367055200144, 'P_L23_highrisk': 0.49075011714516065}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 14: RMSE=8.6799
#   Sen=0.521, Spec=0.381
#   P_home_lowrisk=0.014, P_L23_highrisk=0.224
# [I 2026-06-08 17:37:41,433] Trial 14 finished with value: 8.679857355177253 and parameters: {'Sen_traditional': 0.5214150312621776, 'Spec_traditional': 0.3810302862293415, 'P_home_lowrisk': 0.014496394372597456, 'P_L23_highrisk': 0.22442142579398075}. Best is trial 3 with value: 6.578226076827713.
#
# Trial 15: RMSE=2.7877
#   Sen=0.568, Spec=0.388
#   P_home_lowrisk=0.045, P_L23_highrisk=0.114
# [I 2026-06-08 17:37:41,829] Trial 15 finished with value: 2.787700099641903 and parameters: {'Sen_traditional': 0.5678564615473292, 'Spec_traditional': 0.3883946260487831, 'P_home_lowrisk': 0.04459308310075585, 'P_L23_highrisk': 0.11403980593305937}. Best is trial 15 with value: 2.787700099641903.
#
# Trial 16: RMSE=6.3875
#   Sen=0.620, Spec=0.410
#   P_home_lowrisk=0.015, P_L23_highrisk=0.019
# [I 2026-06-08 17:37:42,228] Trial 16 finished with value: 6.387497645471714 and parameters: {'Sen_traditional': 0.6195134351118474, 'Spec_traditional': 0.41021001407233465, 'P_home_lowrisk': 0.015041294977699037, 'P_L23_highrisk': 0.019080387715007224}. Best is trial 15 with value: 2.787700099641903.
#
# Trial 17: RMSE=6.5459
#   Sen=0.561, Spec=0.399
#   P_home_lowrisk=0.013, P_L23_highrisk=0.013
# [I 2026-06-08 17:37:42,608] Trial 17 finished with value: 6.5459178533288425 and parameters: {'Sen_traditional': 0.5613350771024023, 'Spec_traditional': 0.39913739857814406, 'P_home_lowrisk': 0.013395039830634689, 'P_L23_highrisk': 0.013464531322639172}. Best is trial 15 with value: 2.787700099641903.
#
# Trial 18: RMSE=17.7384
#   Sen=0.702, Spec=0.482
#   P_home_lowrisk=0.151, P_L23_highrisk=0.017
# [I 2026-06-08 17:37:43,020] Trial 18 finished with value: 17.73836579439111 and parameters: {'Sen_traditional': 0.7020995436125724, 'Spec_traditional': 0.48203593855523763, 'P_home_lowrisk': 0.15148148729103472, 'P_L23_highrisk': 0.0174454479698133}. Best is trial 15 with value: 2.787700099641903.
#
# Trial 19: RMSE=28.8587
#   Sen=0.555, Spec=0.368
#   P_home_lowrisk=0.256, P_L23_highrisk=0.047
# [I 2026-06-08 17:37:43,405] Trial 19 finished with value: 28.858666141401255 and parameters: {'Sen_traditional': 0.5552275915657114, 'Spec_traditional': 0.368486068509167, 'P_home_lowrisk': 0.25618808237464535, 'P_L23_highrisk': 0.04740304293309776}. Best is trial 15 with value: 2.787700099641903.
#
# Trial 20: RMSE=9.5123
#   Sen=0.579, Spec=0.434
#   P_home_lowrisk=0.107, P_L23_highrisk=0.159
# [I 2026-06-08 17:37:43,813] Trial 20 finished with value: 9.512314481991112 and parameters: {'Sen_traditional': 0.5789095554264845, 'Spec_traditional': 0.4335062685270858, 'P_home_lowrisk': 0.10653711670252047, 'P_L23_highrisk': 0.15945589813660555}. Best is trial 15 with value: 2.787700099641903.
#
# Trial 21: RMSE=1.1224
#   Sen=0.517, Spec=0.398
#   P_home_lowrisk=0.058, P_L23_highrisk=0.041
# [I 2026-06-08 17:37:44,235] Trial 21 finished with value: 1.122361089666458 and parameters: {'Sen_traditional': 0.5171374735053754, 'Spec_traditional': 0.39820438697291627, 'P_home_lowrisk': 0.05840573109384853, 'P_L23_highrisk': 0.04063932309176503}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 22: RMSE=6.9188
#   Sen=0.641, Spec=0.399
#   P_home_lowrisk=0.012, P_L23_highrisk=0.093
# [I 2026-06-08 17:37:44,635] Trial 22 finished with value: 6.918819225308271 and parameters: {'Sen_traditional': 0.6408664177399352, 'Spec_traditional': 0.3992706030133771, 'P_home_lowrisk': 0.01229403273019044, 'P_L23_highrisk': 0.09277613721566214}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 23: RMSE=7.8237
#   Sen=0.526, Spec=0.381
#   P_home_lowrisk=0.106, P_L23_highrisk=0.016
# [I 2026-06-08 17:37:45,043] Trial 23 finished with value: 7.823693367341715 and parameters: {'Sen_traditional': 0.5260200538486198, 'Spec_traditional': 0.38056592615799767, 'P_home_lowrisk': 0.10639066633797276, 'P_L23_highrisk': 0.015624561720952397}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 24: RMSE=4.0509
#   Sen=0.564, Spec=0.413
#   P_home_lowrisk=0.076, P_L23_highrisk=0.133
# [I 2026-06-08 17:37:45,454] Trial 24 finished with value: 4.0509163190444974 and parameters: {'Sen_traditional': 0.5640591306891589, 'Spec_traditional': 0.4126764089133967, 'P_home_lowrisk': 0.07576920794482792, 'P_L23_highrisk': 0.13314108000988245}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 25: RMSE=4.4664
#   Sen=0.519, Spec=0.420
#   P_home_lowrisk=0.077, P_L23_highrisk=0.129
# [I 2026-06-08 17:37:45,852] Trial 25 finished with value: 4.466419825867375 and parameters: {'Sen_traditional': 0.5187641599784749, 'Spec_traditional': 0.41961639004726364, 'P_home_lowrisk': 0.07664052061864346, 'P_L23_highrisk': 0.12892211514298457}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 26: RMSE=18.2833
#   Sen=0.528, Spec=0.370
#   P_home_lowrisk=0.178, P_L23_highrisk=0.185
# [I 2026-06-08 17:37:46,251] Trial 26 finished with value: 18.283333437525656 and parameters: {'Sen_traditional': 0.5275479267644104, 'Spec_traditional': 0.37027973603157105, 'P_home_lowrisk': 0.17820976723252563, 'P_L23_highrisk': 0.18541744515437225}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 27: RMSE=10.5967
#   Sen=0.630, Spec=0.482
#   P_home_lowrisk=0.108, P_L23_highrisk=0.166
# [I 2026-06-08 17:37:46,645] Trial 27 finished with value: 10.59670063460856 and parameters: {'Sen_traditional': 0.6300811131626539, 'Spec_traditional': 0.48150443380044977, 'P_home_lowrisk': 0.10797710071339886, 'P_L23_highrisk': 0.1660884604651207}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 28: RMSE=5.2177
#   Sen=0.512, Spec=0.409
#   P_home_lowrisk=0.023, P_L23_highrisk=0.121
# [I 2026-06-08 17:37:47,052] Trial 28 finished with value: 5.217705487144977 and parameters: {'Sen_traditional': 0.5119579648864461, 'Spec_traditional': 0.4091934442446925, 'P_home_lowrisk': 0.022514193730321534, 'P_L23_highrisk': 0.12121730639509361}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 29: RMSE=106.1593
#   Sen=0.789, Spec=0.677
#   P_home_lowrisk=0.564, P_L23_highrisk=0.229
# [I 2026-06-08 17:37:47,463] Trial 29 finished with value: 106.15927424615417 and parameters: {'Sen_traditional': 0.7885879965461792, 'Spec_traditional': 0.6770321164931898, 'P_home_lowrisk': 0.5643930254662304, 'P_L23_highrisk': 0.22937510265388564}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 30: RMSE=83.2380
#   Sen=0.791, Spec=0.534
#   P_home_lowrisk=0.558, P_L23_highrisk=0.449
# [I 2026-06-08 17:37:47,862] Trial 30 finished with value: 83.23804634809628 and parameters: {'Sen_traditional': 0.7907859007152179, 'Spec_traditional': 0.5338987813351967, 'P_home_lowrisk': 0.5576874021506858, 'P_L23_highrisk': 0.44899408082617276}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 31: RMSE=12.9235
#   Sen=0.522, Spec=0.424
#   P_home_lowrisk=0.132, P_L23_highrisk=0.095
# [I 2026-06-08 17:37:48,290] Trial 31 finished with value: 12.923527753768088 and parameters: {'Sen_traditional': 0.5217394331406142, 'Spec_traditional': 0.42397323415537896, 'P_home_lowrisk': 0.1324958185707012, 'P_L23_highrisk': 0.09520287674884785}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 32: RMSE=9.9907
#   Sen=0.515, Spec=0.414
#   P_home_lowrisk=0.119, P_L23_highrisk=0.121
# [I 2026-06-08 17:37:48,681] Trial 32 finished with value: 9.990690894897869 and parameters: {'Sen_traditional': 0.5145425438992873, 'Spec_traditional': 0.41395738435883095, 'P_home_lowrisk': 0.11861999854574581, 'P_L23_highrisk': 0.12097823128177383}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 33: RMSE=4.3812
#   Sen=0.560, Spec=0.435
#   P_home_lowrisk=0.064, P_L23_highrisk=0.167
# [I 2026-06-08 17:37:49,068] Trial 33 finished with value: 4.3811749170093215 and parameters: {'Sen_traditional': 0.5595401061478378, 'Spec_traditional': 0.43512471478229475, 'P_home_lowrisk': 0.06361186783982485, 'P_L23_highrisk': 0.16694978449639483}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 34: RMSE=5.7361
#   Sen=0.587, Spec=0.452
#   P_home_lowrisk=0.041, P_L23_highrisk=0.207
# [I 2026-06-08 17:37:49,462] Trial 34 finished with value: 5.736057151582541 and parameters: {'Sen_traditional': 0.587402754629364, 'Spec_traditional': 0.4516854257336071, 'P_home_lowrisk': 0.04104349731707466, 'P_L23_highrisk': 0.2065438933316326}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 35: RMSE=35.9792
#   Sen=0.508, Spec=0.394
#   P_home_lowrisk=0.270, P_L23_highrisk=0.452
# [I 2026-06-08 17:37:49,849] Trial 35 finished with value: 35.97921689770053 and parameters: {'Sen_traditional': 0.5082912923872042, 'Spec_traditional': 0.39363209661178244, 'P_home_lowrisk': 0.26996925038478936, 'P_L23_highrisk': 0.4523020028705167}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 36: RMSE=14.2879
#   Sen=0.819, Spec=0.511
#   P_home_lowrisk=0.116, P_L23_highrisk=0.330
# [I 2026-06-08 17:37:50,243] Trial 36 finished with value: 14.287863457721052 and parameters: {'Sen_traditional': 0.8191133113234224, 'Spec_traditional': 0.510842198274926, 'P_home_lowrisk': 0.11638221574974922, 'P_L23_highrisk': 0.32991348795988473}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 37: RMSE=19.7473
#   Sen=0.622, Spec=0.446
#   P_home_lowrisk=0.177, P_L23_highrisk=0.104
# [I 2026-06-08 17:37:50,634] Trial 37 finished with value: 19.74728531364507 and parameters: {'Sen_traditional': 0.6221587487615646, 'Spec_traditional': 0.4461000941480792, 'P_home_lowrisk': 0.17711387132661932, 'P_L23_highrisk': 0.10369097080220976}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 38: RMSE=5.6360
#   Sen=0.586, Spec=0.362
#   P_home_lowrisk=0.022, P_L23_highrisk=0.107
# [I 2026-06-08 17:37:51,035] Trial 38 finished with value: 5.63599390195274 and parameters: {'Sen_traditional': 0.5862280875214485, 'Spec_traditional': 0.36179974046344515, 'P_home_lowrisk': 0.02176065629908839, 'P_L23_highrisk': 0.10711580158900771}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 39: RMSE=67.3806
#   Sen=0.887, Spec=0.586
#   P_home_lowrisk=0.436, P_L23_highrisk=0.110
# [I 2026-06-08 17:37:51,436] Trial 39 finished with value: 67.38057699193155 and parameters: {'Sen_traditional': 0.8867608176409048, 'Spec_traditional': 0.5864489748086185, 'P_home_lowrisk': 0.436456877897091, 'P_L23_highrisk': 0.11004966331659374}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 40: RMSE=45.9499
#   Sen=0.721, Spec=0.485
#   P_home_lowrisk=0.338, P_L23_highrisk=0.304
# [I 2026-06-08 17:37:51,833] Trial 40 finished with value: 45.94988571771013 and parameters: {'Sen_traditional': 0.7210234133075905, 'Spec_traditional': 0.48490187533616813, 'P_home_lowrisk': 0.337791417261294, 'P_L23_highrisk': 0.3041653477439557}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 41: RMSE=7.6798
#   Sen=0.530, Spec=0.428
#   P_home_lowrisk=0.100, P_L23_highrisk=0.122
# [I 2026-06-08 17:37:52,223] Trial 41 finished with value: 7.679844897551808 and parameters: {'Sen_traditional': 0.5297994157378204, 'Spec_traditional': 0.42769479659914234, 'P_home_lowrisk': 0.1004954892781192, 'P_L23_highrisk': 0.12224577635871706}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 42: RMSE=21.2703
#   Sen=0.580, Spec=0.422
#   P_home_lowrisk=0.173, P_L23_highrisk=0.293
# [I 2026-06-08 17:37:52,619] Trial 42 finished with value: 21.27027827335513 and parameters: {'Sen_traditional': 0.5795894942964998, 'Spec_traditional': 0.4221263730142931, 'P_home_lowrisk': 0.1728132613764521, 'P_L23_highrisk': 0.2927722648062714}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 43: RMSE=64.3855
#   Sen=0.517, Spec=0.411
#   P_home_lowrisk=0.459, P_L23_highrisk=0.065
# [I 2026-06-08 17:37:53,007] Trial 43 finished with value: 64.38545434319286 and parameters: {'Sen_traditional': 0.5171407948975183, 'Spec_traditional': 0.4105076000971918, 'P_home_lowrisk': 0.4593305339249621, 'P_L23_highrisk': 0.06544424207879082}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 44: RMSE=1.9092
#   Sen=0.515, Spec=0.399
#   P_home_lowrisk=0.045, P_L23_highrisk=0.086
# [I 2026-06-08 17:37:53,403] Trial 44 finished with value: 1.9091892693019437 and parameters: {'Sen_traditional': 0.5149990941157958, 'Spec_traditional': 0.3986862962332353, 'P_home_lowrisk': 0.045462412580293265, 'P_L23_highrisk': 0.0856842249301416}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 45: RMSE=5.8696
#   Sen=0.528, Spec=0.387
#   P_home_lowrisk=0.017, P_L23_highrisk=0.072
# [I 2026-06-08 17:37:53,808] Trial 45 finished with value: 5.869563674682644 and parameters: {'Sen_traditional': 0.5278068376129984, 'Spec_traditional': 0.38705281553482984, 'P_home_lowrisk': 0.01670638056526908, 'P_L23_highrisk': 0.0721253429662892}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 46: RMSE=8.5524
#   Sen=0.597, Spec=0.361
#   P_home_lowrisk=0.126, P_L23_highrisk=0.118
# [I 2026-06-08 17:37:54,227] Trial 46 finished with value: 8.552444437239645 and parameters: {'Sen_traditional': 0.5967511342615164, 'Spec_traditional': 0.36088581867805464, 'P_home_lowrisk': 0.12581214539934463, 'P_L23_highrisk': 0.11833174572986511}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 47: RMSE=58.8151
#   Sen=0.666, Spec=0.356
#   P_home_lowrisk=0.517, P_L23_highrisk=0.395
# [I 2026-06-08 17:37:54,612] Trial 47 finished with value: 58.81513208295991 and parameters: {'Sen_traditional': 0.6658313612926888, 'Spec_traditional': 0.3558213500236362, 'P_home_lowrisk': 0.5173685345645881, 'P_L23_highrisk': 0.39517137592616025}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 48: RMSE=114.7471
#   Sen=0.899, Spec=0.833
#   P_home_lowrisk=0.523, P_L23_highrisk=0.353
# [I 2026-06-08 17:37:54,998] Trial 48 finished with value: 114.74711863935165 and parameters: {'Sen_traditional': 0.8989879313923894, 'Spec_traditional': 0.8327268017579924, 'P_home_lowrisk': 0.5234627917643694, 'P_L23_highrisk': 0.35330499788817726}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 49: RMSE=7.1010
#   Sen=0.548, Spec=0.394
#   P_home_lowrisk=0.017, P_L23_highrisk=0.173
# [I 2026-06-08 17:37:55,387] Trial 49 finished with value: 7.100973765915077 and parameters: {'Sen_traditional': 0.5484834728691249, 'Spec_traditional': 0.39418363427802317, 'P_home_lowrisk': 0.017418468359538218, 'P_L23_highrisk': 0.17257400414313906}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 50: RMSE=8.5923
#   Sen=0.516, Spec=0.396
#   P_home_lowrisk=0.113, P_L23_highrisk=0.064
# [I 2026-06-08 17:37:55,789] Trial 50 finished with value: 8.592291909389973 and parameters: {'Sen_traditional': 0.5155004403807749, 'Spec_traditional': 0.3959629755722853, 'P_home_lowrisk': 0.11326556694200712, 'P_L23_highrisk': 0.06439597481938131}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 51: RMSE=6.7956
#   Sen=0.502, Spec=0.414
#   P_home_lowrisk=0.071, P_L23_highrisk=0.224
# [I 2026-06-08 17:37:56,175] Trial 51 finished with value: 6.795628240304556 and parameters: {'Sen_traditional': 0.5016609508437149, 'Spec_traditional': 0.4142255743615343, 'P_home_lowrisk': 0.07148091542908443, 'P_L23_highrisk': 0.22384327088709377}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 52: RMSE=5.2082
#   Sen=0.505, Spec=0.420
#   P_home_lowrisk=0.018, P_L23_highrisk=0.046
# [I 2026-06-08 17:37:56,582] Trial 52 finished with value: 5.208178699683886 and parameters: {'Sen_traditional': 0.5049118598486648, 'Spec_traditional': 0.4196082388195454, 'P_home_lowrisk': 0.018268532832575717, 'P_L23_highrisk': 0.04616323024891931}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 53: RMSE=9.2203
#   Sen=0.564, Spec=0.442
#   P_home_lowrisk=0.105, P_L23_highrisk=0.138
# [I 2026-06-08 17:37:56,967] Trial 53 finished with value: 9.220330615486137 and parameters: {'Sen_traditional': 0.5637700549621448, 'Spec_traditional': 0.4420743830765656, 'P_home_lowrisk': 0.10534921605926192, 'P_L23_highrisk': 0.13777983177854286}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 54: RMSE=16.6844
#   Sen=0.877, Spec=0.315
#   P_home_lowrisk=0.135, P_L23_highrisk=0.483
# [I 2026-06-08 17:37:57,363] Trial 54 finished with value: 16.6844263413773 and parameters: {'Sen_traditional': 0.8774950346365643, 'Spec_traditional': 0.31484540302289904, 'P_home_lowrisk': 0.13476187178384563, 'P_L23_highrisk': 0.48301796836269106}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 55: RMSE=10.8673
#   Sen=0.586, Spec=0.438
#   P_home_lowrisk=0.124, P_L23_highrisk=0.087
# [I 2026-06-08 17:37:57,779] Trial 55 finished with value: 10.867344900404603 and parameters: {'Sen_traditional': 0.586359791914088, 'Spec_traditional': 0.4384631201418225, 'P_home_lowrisk': 0.12357952556423653, 'P_L23_highrisk': 0.08733658540285485}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 56: RMSE=6.0672
#   Sen=0.593, Spec=0.394
#   P_home_lowrisk=0.021, P_L23_highrisk=0.148
# [I 2026-06-08 17:37:58,241] Trial 56 finished with value: 6.067242036455068 and parameters: {'Sen_traditional': 0.5926395351553492, 'Spec_traditional': 0.3935057494519206, 'P_home_lowrisk': 0.02144072978439882, 'P_L23_highrisk': 0.14833050556053312}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 57: RMSE=78.0451
#   Sen=0.613, Spec=0.446
#   P_home_lowrisk=0.549, P_L23_highrisk=0.168
# [I 2026-06-08 17:37:58,668] Trial 57 finished with value: 78.04510662412683 and parameters: {'Sen_traditional': 0.6130055190115873, 'Spec_traditional': 0.4455510195751031, 'P_home_lowrisk': 0.5487757082598033, 'P_L23_highrisk': 0.16822898800138225}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 58: RMSE=14.9049
#   Sen=0.508, Spec=0.404
#   P_home_lowrisk=0.147, P_L23_highrisk=0.159
# [I 2026-06-08 17:37:59,105] Trial 58 finished with value: 14.904921807862396 and parameters: {'Sen_traditional': 0.5075173915346328, 'Spec_traditional': 0.4036002213483351, 'P_home_lowrisk': 0.14678180869177349, 'P_L23_highrisk': 0.158840481016927}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 59: RMSE=2.2340
#   Sen=0.510, Spec=0.403
#   P_home_lowrisk=0.052, P_L23_highrisk=0.120
# [I 2026-06-08 17:37:59,516] Trial 59 finished with value: 2.234031465795643 and parameters: {'Sen_traditional': 0.509752805048693, 'Spec_traditional': 0.40276338992450167, 'P_home_lowrisk': 0.052344203257593196, 'P_L23_highrisk': 0.12010314896266897}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 60: RMSE=6.4152
#   Sen=0.505, Spec=0.386
#   P_home_lowrisk=0.017, P_L23_highrisk=0.135
# [I 2026-06-08 17:37:59,902] Trial 60 finished with value: 6.4152182115371525 and parameters: {'Sen_traditional': 0.5047136997648272, 'Spec_traditional': 0.38558638063645945, 'P_home_lowrisk': 0.017456587670623747, 'P_L23_highrisk': 0.13490410227406366}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 61: RMSE=4.5186
#   Sen=0.505, Spec=0.407
#   P_home_lowrisk=0.082, P_L23_highrisk=0.076
# [I 2026-06-08 17:38:00,289] Trial 61 finished with value: 4.518563889117708 and parameters: {'Sen_traditional': 0.5045791103012167, 'Spec_traditional': 0.40666262568183453, 'P_home_lowrisk': 0.08213746013882353, 'P_L23_highrisk': 0.07605243480157048}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 62: RMSE=1.8227
#   Sen=0.575, Spec=0.410
#   P_home_lowrisk=0.048, P_L23_highrisk=0.098
# [I 2026-06-08 17:38:00,688] Trial 62 finished with value: 1.8227361889839522 and parameters: {'Sen_traditional': 0.5751843472901854, 'Spec_traditional': 0.4100311276287426, 'P_home_lowrisk': 0.048105687807011924, 'P_L23_highrisk': 0.09841685587520844}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 63: RMSE=2.1572
#   Sen=0.573, Spec=0.385
#   P_home_lowrisk=0.064, P_L23_highrisk=0.026
# [I 2026-06-08 17:38:01,101] Trial 63 finished with value: 2.157192685407732 and parameters: {'Sen_traditional': 0.5731063704572772, 'Spec_traditional': 0.38528591862867456, 'P_home_lowrisk': 0.06414087804690938, 'P_L23_highrisk': 0.025808859768013323}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 64: RMSE=5.2044
#   Sen=0.585, Spec=0.367
#   P_home_lowrisk=0.096, P_L23_highrisk=0.036
# [I 2026-06-08 17:38:01,492] Trial 64 finished with value: 5.204416072358099 and parameters: {'Sen_traditional': 0.5845819670521938, 'Spec_traditional': 0.36708662834715333, 'P_home_lowrisk': 0.0955893653869013, 'P_L23_highrisk': 0.03596910066693032}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 65: RMSE=2.7429
#   Sen=0.583, Spec=0.383
#   P_home_lowrisk=0.048, P_L23_highrisk=0.014
# [I 2026-06-08 17:38:01,878] Trial 65 finished with value: 2.742875526427858 and parameters: {'Sen_traditional': 0.5827944063320607, 'Spec_traditional': 0.3833040083098386, 'P_home_lowrisk': 0.04836829126087128, 'P_L23_highrisk': 0.014336153925412622}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 66: RMSE=3.0908
#   Sen=0.677, Spec=0.342
#   P_home_lowrisk=0.060, P_L23_highrisk=0.019
# [I 2026-06-08 17:38:02,264] Trial 66 finished with value: 3.0908019630059975 and parameters: {'Sen_traditional': 0.676808272757268, 'Spec_traditional': 0.3419350840152543, 'P_home_lowrisk': 0.060405030411298376, 'P_L23_highrisk': 0.01913658688994238}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 67: RMSE=7.0932
#   Sen=0.603, Spec=0.353
#   P_home_lowrisk=0.112, P_L23_highrisk=0.023
# [I 2026-06-08 17:38:02,667] Trial 67 finished with value: 7.093214383584334 and parameters: {'Sen_traditional': 0.6033763648547806, 'Spec_traditional': 0.3526567379551584, 'P_home_lowrisk': 0.11243617416234807, 'P_L23_highrisk': 0.022573814439145773}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 68: RMSE=6.0474
#   Sen=0.577, Spec=0.376
#   P_home_lowrisk=0.018, P_L23_highrisk=0.019
# [I 2026-06-08 17:38:03,071] Trial 68 finished with value: 6.047444046219113 and parameters: {'Sen_traditional': 0.5773589282692323, 'Spec_traditional': 0.37606924847108425, 'P_home_lowrisk': 0.017712396596607352, 'P_L23_highrisk': 0.01873065870450839}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 69: RMSE=9.7638
#   Sen=0.515, Spec=0.386
#   P_home_lowrisk=0.119, P_L23_highrisk=0.016
# [I 2026-06-08 17:38:03,468] Trial 69 finished with value: 9.763750129729754 and parameters: {'Sen_traditional': 0.5154920914925346, 'Spec_traditional': 0.3859675543680037, 'P_home_lowrisk': 0.11920305321666019, 'P_L23_highrisk': 0.01575618339026713}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 70: RMSE=2.4913
#   Sen=0.564, Spec=0.382
#   P_home_lowrisk=0.050, P_L23_highrisk=0.013
# [I 2026-06-08 17:38:03,865] Trial 70 finished with value: 2.4912849539287047 and parameters: {'Sen_traditional': 0.5637385821982271, 'Spec_traditional': 0.3824135065485211, 'P_home_lowrisk': 0.05025149669631683, 'P_L23_highrisk': 0.013014271041343728}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 71: RMSE=6.6820
#   Sen=0.564, Spec=0.381
#   P_home_lowrisk=0.013, P_L23_highrisk=0.021
# [I 2026-06-08 17:38:04,264] Trial 71 finished with value: 6.682005527022175 and parameters: {'Sen_traditional': 0.563991790220706, 'Spec_traditional': 0.3812667609296217, 'P_home_lowrisk': 0.013422243591854718, 'P_L23_highrisk': 0.020787616200525934}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 72: RMSE=2.9012
#   Sen=0.613, Spec=0.369
#   P_home_lowrisk=0.064, P_L23_highrisk=0.011
# [I 2026-06-08 17:38:04,651] Trial 72 finished with value: 2.9012069826856695 and parameters: {'Sen_traditional': 0.6132096210742414, 'Spec_traditional': 0.36870938652501184, 'P_home_lowrisk': 0.06361768941329143, 'P_L23_highrisk': 0.010702545275053096}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 73: RMSE=3.7643
#   Sen=0.571, Spec=0.387
#   P_home_lowrisk=0.081, P_L23_highrisk=0.034
# [I 2026-06-08 17:38:05,046] Trial 73 finished with value: 3.7643398557619294 and parameters: {'Sen_traditional': 0.5709618713965907, 'Spec_traditional': 0.38671083850062943, 'P_home_lowrisk': 0.08058480112217316, 'P_L23_highrisk': 0.034193045743873926}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 74: RMSE=4.7745
#   Sen=0.571, Spec=0.387
#   P_home_lowrisk=0.024, P_L23_highrisk=0.055
# [I 2026-06-08 17:38:05,474] Trial 74 finished with value: 4.774519029980823 and parameters: {'Sen_traditional': 0.5709540259631307, 'Spec_traditional': 0.38681118036583356, 'P_home_lowrisk': 0.024399240473532355, 'P_L23_highrisk': 0.055234180369046884}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 75: RMSE=20.3471
#   Sen=0.574, Spec=0.393
#   P_home_lowrisk=0.189, P_L23_highrisk=0.014
# [I 2026-06-08 17:38:05,863] Trial 75 finished with value: 20.34706886462786 and parameters: {'Sen_traditional': 0.5741807316425825, 'Spec_traditional': 0.39283226635377627, 'P_home_lowrisk': 0.18929167159104549, 'P_L23_highrisk': 0.014156497805976095}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 76: RMSE=5.8187
#   Sen=0.637, Spec=0.346
#   P_home_lowrisk=0.021, P_L23_highrisk=0.101
# [I 2026-06-08 17:38:06,253] Trial 76 finished with value: 5.818693805453409 and parameters: {'Sen_traditional': 0.6372541677191654, 'Spec_traditional': 0.34635709304863643, 'P_home_lowrisk': 0.021399282288498613, 'P_L23_highrisk': 0.10058091728594462}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 77: RMSE=2.9138
#   Sen=0.512, Spec=0.393
#   P_home_lowrisk=0.039, P_L23_highrisk=0.013
# [I 2026-06-08 17:38:06,653] Trial 77 finished with value: 2.9138432830106584 and parameters: {'Sen_traditional': 0.5117123640659116, 'Spec_traditional': 0.3927171252264175, 'P_home_lowrisk': 0.03911241833991587, 'P_L23_highrisk': 0.013142308260062602}. Best is trial 21 with value: 1.122361089666458.
#
# Trial 78: RMSE=1.0456
#   Sen=0.573, Spec=0.390
#   P_home_lowrisk=0.054, P_L23_highrisk=0.087
# [I 2026-06-08 17:38:07,056] Trial 78 finished with value: 1.0456286366584442 and parameters: {'Sen_traditional': 0.5732072625946546, 'Spec_traditional': 0.3903300879231089, 'P_home_lowrisk': 0.054343188869990997, 'P_L23_highrisk': 0.08664796860405613}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 79: RMSE=4.6144
#   Sen=0.612, Spec=0.373
#   P_home_lowrisk=0.096, P_L23_highrisk=0.069
# [I 2026-06-08 17:38:07,451] Trial 79 finished with value: 4.614412409579989 and parameters: {'Sen_traditional': 0.6124159240306973, 'Spec_traditional': 0.3728167254536061, 'P_home_lowrisk': 0.09646930791733285, 'P_L23_highrisk': 0.06881281895444544}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 80: RMSE=50.4726
#   Sen=0.705, Spec=0.312
#   P_home_lowrisk=0.512, P_L23_highrisk=0.048
# [I 2026-06-08 17:38:07,841] Trial 80 finished with value: 50.47259043720075 and parameters: {'Sen_traditional': 0.7050456841999041, 'Spec_traditional': 0.3123978617001314, 'P_home_lowrisk': 0.5118743648202574, 'P_L23_highrisk': 0.048174917941418594}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 81: RMSE=7.0629
#   Sen=0.546, Spec=0.398
#   P_home_lowrisk=0.011, P_L23_highrisk=0.108
# [I 2026-06-08 17:38:08,235] Trial 81 finished with value: 7.062865040624555 and parameters: {'Sen_traditional': 0.5464679128388319, 'Spec_traditional': 0.3978988906051844, 'P_home_lowrisk': 0.011207532917424844, 'P_L23_highrisk': 0.10844193062835804}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 82: RMSE=25.5888
#   Sen=0.888, Spec=0.304
#   P_home_lowrisk=0.339, P_L23_highrisk=0.372
# [I 2026-06-08 17:38:08,621] Trial 82 finished with value: 25.58877854834317 and parameters: {'Sen_traditional': 0.8882755990317022, 'Spec_traditional': 0.3041770730396567, 'P_home_lowrisk': 0.3386015030074623, 'P_L23_highrisk': 0.37155656795797054}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 83: RMSE=4.3563
#   Sen=0.596, Spec=0.398
#   P_home_lowrisk=0.030, P_L23_highrisk=0.094
# [I 2026-06-08 17:38:09,008] Trial 83 finished with value: 4.356310140965333 and parameters: {'Sen_traditional': 0.5957345120277043, 'Spec_traditional': 0.398183408487469, 'P_home_lowrisk': 0.02993844258560772, 'P_L23_highrisk': 0.09393240163025747}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 84: RMSE=9.4238
#   Sen=0.574, Spec=0.391
#   P_home_lowrisk=0.123, P_L23_highrisk=0.049
# [I 2026-06-08 17:38:09,403] Trial 84 finished with value: 9.42377669013225 and parameters: {'Sen_traditional': 0.5744992018406023, 'Spec_traditional': 0.39075511919950323, 'P_home_lowrisk': 0.12288356715491217, 'P_L23_highrisk': 0.0491725528735078}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 85: RMSE=26.9998
#   Sen=0.624, Spec=0.362
#   P_home_lowrisk=0.234, P_L23_highrisk=0.461
# [I 2026-06-08 17:38:09,795] Trial 85 finished with value: 26.999752839054466 and parameters: {'Sen_traditional': 0.624341237697793, 'Spec_traditional': 0.36219526826638015, 'P_home_lowrisk': 0.2340201064745186, 'P_L23_highrisk': 0.4606512654585795}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 86: RMSE=57.8639
#   Sen=0.518, Spec=0.403
#   P_home_lowrisk=0.418, P_L23_highrisk=0.335
# [I 2026-06-08 17:38:10,200] Trial 86 finished with value: 57.86393052499399 and parameters: {'Sen_traditional': 0.5180755844513862, 'Spec_traditional': 0.40323230489655515, 'P_home_lowrisk': 0.4181923446556382, 'P_L23_highrisk': 0.33453237160074634}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 87: RMSE=6.5636
#   Sen=0.572, Spec=0.407
#   P_home_lowrisk=0.013, P_L23_highrisk=0.093
# [I 2026-06-08 17:38:10,586] Trial 87 finished with value: 6.563609788913538 and parameters: {'Sen_traditional': 0.5720655694192246, 'Spec_traditional': 0.40666526863248587, 'P_home_lowrisk': 0.013283070125733772, 'P_L23_highrisk': 0.09325016968270054}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 88: RMSE=9.6534
#   Sen=0.545, Spec=0.381
#   P_home_lowrisk=0.123, P_L23_highrisk=0.025
# [I 2026-06-08 17:38:10,977] Trial 88 finished with value: 9.65338536718736 and parameters: {'Sen_traditional': 0.5446108787475202, 'Spec_traditional': 0.38064021271208875, 'P_home_lowrisk': 0.1231857202581284, 'P_L23_highrisk': 0.02475683440179703}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 89: RMSE=3.8919
#   Sen=0.557, Spec=0.411
#   P_home_lowrisk=0.079, P_L23_highrisk=0.092
# [I 2026-06-08 17:38:11,362] Trial 89 finished with value: 3.8918675807272916 and parameters: {'Sen_traditional': 0.5566920644052901, 'Spec_traditional': 0.4105955692946553, 'P_home_lowrisk': 0.0791802577073312, 'P_L23_highrisk': 0.0919200094458162}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 90: RMSE=5.0640
#   Sen=0.507, Spec=0.383
#   P_home_lowrisk=0.084, P_L23_highrisk=0.011
# [I 2026-06-08 17:38:11,749] Trial 90 finished with value: 5.063982536072083 and parameters: {'Sen_traditional': 0.506694554683543, 'Spec_traditional': 0.38342624826162874, 'P_home_lowrisk': 0.08359466781078306, 'P_L23_highrisk': 0.011064418393031225}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 91: RMSE=9.2593
#   Sen=0.616, Spec=0.358
#   P_home_lowrisk=0.131, P_L23_highrisk=0.020
# [I 2026-06-08 17:38:12,161] Trial 91 finished with value: 9.259299609933802 and parameters: {'Sen_traditional': 0.6162898795498633, 'Spec_traditional': 0.35844290879581575, 'P_home_lowrisk': 0.1307791925340241, 'P_L23_highrisk': 0.020497011078855362}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 92: RMSE=11.3838
#   Sen=0.596, Spec=0.358
#   P_home_lowrisk=0.139, P_L23_highrisk=0.011
# [I 2026-06-08 17:38:12,591] Trial 92 finished with value: 11.383756241447799 and parameters: {'Sen_traditional': 0.5964059929107728, 'Spec_traditional': 0.3580425932726717, 'P_home_lowrisk': 0.1393249869517074, 'P_L23_highrisk': 0.011141334432615465}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 93: RMSE=2.9038
#   Sen=0.588, Spec=0.373
#   P_home_lowrisk=0.043, P_L23_highrisk=0.033
# [I 2026-06-08 17:38:12,998] Trial 93 finished with value: 2.9038160527044137 and parameters: {'Sen_traditional': 0.5881340345903985, 'Spec_traditional': 0.3727055116099315, 'P_home_lowrisk': 0.043262168111791656, 'P_L23_highrisk': 0.03339140957156663}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 94: RMSE=4.9694
#   Sen=0.602, Spec=0.424
#   P_home_lowrisk=0.022, P_L23_highrisk=0.036
# [I 2026-06-08 17:38:13,388] Trial 94 finished with value: 4.9694226085208255 and parameters: {'Sen_traditional': 0.6016704202918914, 'Spec_traditional': 0.4236951440319851, 'P_home_lowrisk': 0.021635334879952433, 'P_L23_highrisk': 0.035662308310985845}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 95: RMSE=11.2671
#   Sen=0.676, Spec=0.452
#   P_home_lowrisk=0.123, P_L23_highrisk=0.155
# [I 2026-06-08 17:38:13,789] Trial 95 finished with value: 11.26708371410302 and parameters: {'Sen_traditional': 0.676467939454882, 'Spec_traditional': 0.4518823344422687, 'P_home_lowrisk': 0.12306172165987081, 'P_L23_highrisk': 0.15523742665556367}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 96: RMSE=2.4581
#   Sen=0.511, Spec=0.384
#   P_home_lowrisk=0.046, P_L23_highrisk=0.103
# [I 2026-06-08 17:38:14,195] Trial 96 finished with value: 2.45810717686844 and parameters: {'Sen_traditional': 0.5112372494919493, 'Spec_traditional': 0.38388273081964, 'P_home_lowrisk': 0.0458044355848491, 'P_L23_highrisk': 0.10299905128599722}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 97: RMSE=2.3324
#   Sen=0.507, Spec=0.393
#   P_home_lowrisk=0.066, P_L23_highrisk=0.111
# [I 2026-06-08 17:38:14,601] Trial 97 finished with value: 2.3323875174967457 and parameters: {'Sen_traditional': 0.5072521033285387, 'Spec_traditional': 0.39349829299888006, 'P_home_lowrisk': 0.06581609101068997, 'P_L23_highrisk': 0.11111183481651549}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 98: RMSE=13.9551
#   Sen=0.502, Spec=0.394
#   P_home_lowrisk=0.143, P_L23_highrisk=0.157
# [I 2026-06-08 17:38:15,002] Trial 98 finished with value: 13.955138717165822 and parameters: {'Sen_traditional': 0.5023931417477862, 'Spec_traditional': 0.39388023410997486, 'P_home_lowrisk': 0.1434658421286391, 'P_L23_highrisk': 0.15687071816067266}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 99: RMSE=5.8960
#   Sen=0.811, Spec=0.498
#   P_home_lowrisk=0.081, P_L23_highrisk=0.177
# [I 2026-06-08 17:38:15,397] Trial 99 finished with value: 5.8960435175292165 and parameters: {'Sen_traditional': 0.8113472041607058, 'Spec_traditional': 0.49770877278479886, 'P_home_lowrisk': 0.08110931434154689, 'P_L23_highrisk': 0.17670981033354494}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 100: RMSE=3.9206
#   Sen=0.509, Spec=0.398
#   P_home_lowrisk=0.040, P_L23_highrisk=0.149
# [I 2026-06-08 17:38:15,811] Trial 100 finished with value: 3.920620454612543 and parameters: {'Sen_traditional': 0.5090267479779801, 'Spec_traditional': 0.39778945032661683, 'P_home_lowrisk': 0.03996607433767408, 'P_L23_highrisk': 0.14949310540007166}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 101: RMSE=4.1592
#   Sen=0.504, Spec=0.389
#   P_home_lowrisk=0.028, P_L23_highrisk=0.085
# [I 2026-06-08 17:38:16,203] Trial 101 finished with value: 4.159229362891382 and parameters: {'Sen_traditional': 0.5040556429626525, 'Spec_traditional': 0.3889265545378177, 'P_home_lowrisk': 0.02826978473235067, 'P_L23_highrisk': 0.08451743265098267}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 102: RMSE=8.2797
#   Sen=0.529, Spec=0.406
#   P_home_lowrisk=0.108, P_L23_highrisk=0.112
# [I 2026-06-08 17:38:16,601] Trial 102 finished with value: 8.279682959960024 and parameters: {'Sen_traditional': 0.5290690315548648, 'Spec_traditional': 0.4062782887294393, 'P_home_lowrisk': 0.10823750925513544, 'P_L23_highrisk': 0.11183087952092287}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 103: RMSE=4.4589
#   Sen=0.501, Spec=0.385
#   P_home_lowrisk=0.030, P_L23_highrisk=0.121
# [I 2026-06-08 17:38:16,994] Trial 103 finished with value: 4.458944469793134 and parameters: {'Sen_traditional': 0.5006399957938517, 'Spec_traditional': 0.38519709849898065, 'P_home_lowrisk': 0.0304552292436927, 'P_L23_highrisk': 0.12084934056567107}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 104: RMSE=9.1450
#   Sen=0.532, Spec=0.407
#   P_home_lowrisk=0.115, P_L23_highrisk=0.095
# [I 2026-06-08 17:38:17,383] Trial 104 finished with value: 9.144961628655498 and parameters: {'Sen_traditional': 0.5316897253150599, 'Spec_traditional': 0.4068750621836087, 'P_home_lowrisk': 0.11478008876304048, 'P_L23_highrisk': 0.0952434306874928}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 105: RMSE=12.9404
#   Sen=0.585, Spec=0.415
#   P_home_lowrisk=0.136, P_L23_highrisk=0.151
# [I 2026-06-08 17:38:17,772] Trial 105 finished with value: 12.940408320112072 and parameters: {'Sen_traditional': 0.5851052067661601, 'Spec_traditional': 0.4154522948802861, 'P_home_lowrisk': 0.13594772274991052, 'P_L23_highrisk': 0.15063370557290462}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 106: RMSE=2.6982
#   Sen=0.554, Spec=0.381
#   P_home_lowrisk=0.043, P_L23_highrisk=0.103
# [I 2026-06-08 17:38:18,187] Trial 106 finished with value: 2.698213923007438 and parameters: {'Sen_traditional': 0.5537356891065115, 'Spec_traditional': 0.3807695653903394, 'P_home_lowrisk': 0.04334833912386589, 'P_L23_highrisk': 0.10298484827323653}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 107: RMSE=23.5371
#   Sen=0.502, Spec=0.383
#   P_home_lowrisk=0.211, P_L23_highrisk=0.064
# [I 2026-06-08 17:38:18,575] Trial 107 finished with value: 23.53713872486044 and parameters: {'Sen_traditional': 0.5020498198687249, 'Spec_traditional': 0.38271637137387654, 'P_home_lowrisk': 0.21089693904000736, 'P_L23_highrisk': 0.06387381312412357}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 108: RMSE=4.5237
#   Sen=0.548, Spec=0.376
#   P_home_lowrisk=0.027, P_L23_highrisk=0.094
# [I 2026-06-08 17:38:18,963] Trial 108 finished with value: 4.523723277523491 and parameters: {'Sen_traditional': 0.5482552335171487, 'Spec_traditional': 0.37579125877658964, 'P_home_lowrisk': 0.026967132154156862, 'P_L23_highrisk': 0.09407226738478519}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 109: RMSE=6.4643
#   Sen=0.512, Spec=0.385
#   P_home_lowrisk=0.014, P_L23_highrisk=0.010
# [I 2026-06-08 17:38:19,360] Trial 109 finished with value: 6.464305028774431 and parameters: {'Sen_traditional': 0.5116155171485404, 'Spec_traditional': 0.38522134021459137, 'P_home_lowrisk': 0.014177287416992, 'P_L23_highrisk': 0.010472743485707611}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 110: RMSE=10.9540
#   Sen=0.503, Spec=0.393
#   P_home_lowrisk=0.128, P_L23_highrisk=0.133
# [I 2026-06-08 17:38:19,754] Trial 110 finished with value: 10.954046594773468 and parameters: {'Sen_traditional': 0.5030664430797506, 'Spec_traditional': 0.39335908213751725, 'P_home_lowrisk': 0.12764863757257155, 'P_L23_highrisk': 0.13348718934772458}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 111: RMSE=3.7784
#   Sen=0.601, Spec=0.356
#   P_home_lowrisk=0.066, P_L23_highrisk=0.176
# [I 2026-06-08 17:38:20,193] Trial 111 finished with value: 3.778420815624674 and parameters: {'Sen_traditional': 0.6014747783051461, 'Spec_traditional': 0.3558983273566863, 'P_home_lowrisk': 0.06647946585134351, 'P_L23_highrisk': 0.176429974235181}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 112: RMSE=14.6089
#   Sen=0.689, Spec=0.435
#   P_home_lowrisk=0.076, P_L23_highrisk=0.456
# [I 2026-06-08 17:38:20,591] Trial 112 finished with value: 14.608930345160669 and parameters: {'Sen_traditional': 0.6892782752193597, 'Spec_traditional': 0.4348791321276564, 'P_home_lowrisk': 0.07601585729896565, 'P_L23_highrisk': 0.45591961841948275}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 113: RMSE=5.6035
#   Sen=0.587, Spec=0.415
#   P_home_lowrisk=0.021, P_L23_highrisk=0.139
# [I 2026-06-08 17:38:21,004] Trial 113 finished with value: 5.603517471377456 and parameters: {'Sen_traditional': 0.5872251189935213, 'Spec_traditional': 0.4147172931590896, 'P_home_lowrisk': 0.021436359959869155, 'P_L23_highrisk': 0.13865338161553475}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 114: RMSE=2.4754
#   Sen=0.540, Spec=0.381
#   P_home_lowrisk=0.071, P_L23_highrisk=0.110
# [I 2026-06-08 17:38:21,435] Trial 114 finished with value: 2.475353789449071 and parameters: {'Sen_traditional': 0.5401411927593848, 'Spec_traditional': 0.3805613379478972, 'P_home_lowrisk': 0.07082444486431828, 'P_L23_highrisk': 0.1103714350957207}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 115: RMSE=6.1483
#   Sen=0.552, Spec=0.383
#   P_home_lowrisk=0.099, P_L23_highrisk=0.131
# [I 2026-06-08 17:38:21,835] Trial 115 finished with value: 6.14831662017926 and parameters: {'Sen_traditional': 0.551988309512497, 'Spec_traditional': 0.38325890849902083, 'P_home_lowrisk': 0.09909150786853435, 'P_L23_highrisk': 0.13059563894813273}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 116: RMSE=4.4295
#   Sen=0.503, Spec=0.379
#   P_home_lowrisk=0.034, P_L23_highrisk=0.147
# [I 2026-06-08 17:38:22,257] Trial 116 finished with value: 4.429474747808304 and parameters: {'Sen_traditional': 0.5027416174187849, 'Spec_traditional': 0.3792104879993817, 'P_home_lowrisk': 0.033503919533942855, 'P_L23_highrisk': 0.14747955644506283}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 117: RMSE=8.0190
#   Sen=0.538, Spec=0.380
#   P_home_lowrisk=0.114, P_L23_highrisk=0.075
# [I 2026-06-08 17:38:22,642] Trial 117 finished with value: 8.018963756897913 and parameters: {'Sen_traditional': 0.5384873388601712, 'Spec_traditional': 0.3802663410408671, 'P_home_lowrisk': 0.11354900350617973, 'P_L23_highrisk': 0.0747695236325088}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 118: RMSE=5.8875
#   Sen=0.560, Spec=0.410
#   P_home_lowrisk=0.093, P_L23_highrisk=0.089
# [I 2026-06-08 17:38:23,033] Trial 118 finished with value: 5.887518901161401 and parameters: {'Sen_traditional': 0.5604145865633251, 'Spec_traditional': 0.4103392634752263, 'P_home_lowrisk': 0.09309277922604703, 'P_L23_highrisk': 0.08942583893540025}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 119: RMSE=4.5697
#   Sen=0.522, Spec=0.379
#   P_home_lowrisk=0.027, P_L23_highrisk=0.098
# [I 2026-06-08 17:38:23,446] Trial 119 finished with value: 4.569748822423214 and parameters: {'Sen_traditional': 0.5217158950680469, 'Spec_traditional': 0.37923589271679664, 'P_home_lowrisk': 0.027070081319404575, 'P_L23_highrisk': 0.09834408124057119}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 120: RMSE=11.0250
#   Sen=0.509, Spec=0.398
#   P_home_lowrisk=0.129, P_L23_highrisk=0.083
# [I 2026-06-08 17:38:23,855] Trial 120 finished with value: 11.024985823973442 and parameters: {'Sen_traditional': 0.5088919174784644, 'Spec_traditional': 0.39806181390765444, 'P_home_lowrisk': 0.128540678508536, 'P_L23_highrisk': 0.08344343330761354}. Best is trial 78 with value: 1.0456286366584442.
#
# Trial 121: RMSE=3.3756
#   Sen=0.565, Spec=0.365
#   P_home_lowrisk=0.038, P_L23_highrisk=0.107
# ...
#
# Trial 461: RMSE=1.2367
#   Sen=0.647, Spec=0.383
#   P_home_lowrisk=0.068, P_L23_highrisk=0.063
# [I 2026-06-08 17:40:44,093] Trial 461 finished with value: 1.2366645383946817 and parameters: {'Sen_traditional': 0.647092030933693, 'Spec_traditional': 0.38252808625022877, 'P_home_lowrisk': 0.06759196054400633, 'P_L23_highrisk': 0.06288070686181471}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 462: RMSE=3.3020
#   Sen=0.663, Spec=0.358
#   P_home_lowrisk=0.053, P_L23_highrisk=0.018
# [I 2026-06-08 17:40:44,513] Trial 462 finished with value: 3.302032985406405 and parameters: {'Sen_traditional': 0.6627988051285818, 'Spec_traditional': 0.3581723622236812, 'P_home_lowrisk': 0.05279022156139217, 'P_L23_highrisk': 0.01783946191211322}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 463: RMSE=1.1567
#   Sen=0.603, Spec=0.364
#   P_home_lowrisk=0.061, P_L23_highrisk=0.058
# [I 2026-06-08 17:40:44,906] Trial 463 finished with value: 1.156705919730611 and parameters: {'Sen_traditional': 0.6034600429870108, 'Spec_traditional': 0.36440066860701537, 'P_home_lowrisk': 0.06141423498573664, 'P_L23_highrisk': 0.0584583435366206}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 464: RMSE=1.6112
#   Sen=0.597, Spec=0.361
#   P_home_lowrisk=0.071, P_L23_highrisk=0.056
# [I 2026-06-08 17:40:45,319] Trial 464 finished with value: 1.6112452824497772 and parameters: {'Sen_traditional': 0.5974607237349554, 'Spec_traditional': 0.3609803861998716, 'P_home_lowrisk': 0.07115812986214157, 'P_L23_highrisk': 0.05636051098542281}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 465: RMSE=4.7305
#   Sen=0.565, Spec=0.371
#   P_home_lowrisk=0.072, P_L23_highrisk=0.191
# [I 2026-06-08 17:40:45,710] Trial 465 finished with value: 4.730461251589093 and parameters: {'Sen_traditional': 0.5647923306565317, 'Spec_traditional': 0.37114698564805154, 'P_home_lowrisk': 0.07226288261904014, 'P_L23_highrisk': 0.190969998269226}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 466: RMSE=1.8127
#   Sen=0.578, Spec=0.366
#   P_home_lowrisk=0.065, P_L23_highrisk=0.121
# [I 2026-06-08 17:40:46,119] Trial 466 finished with value: 1.8127421754658235 and parameters: {'Sen_traditional': 0.5784654392386497, 'Spec_traditional': 0.3663550301159969, 'P_home_lowrisk': 0.0654553463560296, 'P_L23_highrisk': 0.12064277823466582}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 467: RMSE=6.5807
#   Sen=0.555, Spec=0.372
#   P_home_lowrisk=0.013, P_L23_highrisk=0.084
# [I 2026-06-08 17:40:46,523] Trial 467 finished with value: 6.580650550418491 and parameters: {'Sen_traditional': 0.5548901644842612, 'Spec_traditional': 0.3719561355344397, 'P_home_lowrisk': 0.01343010459347467, 'P_L23_highrisk': 0.08436101333006399}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 468: RMSE=6.2895
#   Sen=0.629, Spec=0.344
#   P_home_lowrisk=0.018, P_L23_highrisk=0.028
# [I 2026-06-08 17:40:46,946] Trial 468 finished with value: 6.289535733658272 and parameters: {'Sen_traditional': 0.6287637227523099, 'Spec_traditional': 0.3439517140656822, 'P_home_lowrisk': 0.01795617863635382, 'P_L23_highrisk': 0.027819877787297456}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 469: RMSE=5.5793
#   Sen=0.642, Spec=0.336
#   P_home_lowrisk=0.103, P_L23_highrisk=0.023
# [I 2026-06-08 17:40:47,345] Trial 469 finished with value: 5.579254937487226 and parameters: {'Sen_traditional': 0.6421758223383534, 'Spec_traditional': 0.33617784313227855, 'P_home_lowrisk': 0.10296828683989817, 'P_L23_highrisk': 0.02291357440268495}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 470: RMSE=13.7732
#   Sen=0.552, Spec=0.370
#   P_home_lowrisk=0.155, P_L23_highrisk=0.118
# [I 2026-06-08 17:40:47,776] Trial 470 finished with value: 13.77317372562999 and parameters: {'Sen_traditional': 0.5516139199146967, 'Spec_traditional': 0.37006534477749115, 'P_home_lowrisk': 0.15478932308756221, 'P_L23_highrisk': 0.11785034906744063}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 471: RMSE=7.4032
#   Sen=0.599, Spec=0.373
#   P_home_lowrisk=0.112, P_L23_highrisk=0.027
# [I 2026-06-08 17:40:48,227] Trial 471 finished with value: 7.403153293663502 and parameters: {'Sen_traditional': 0.5988660757708648, 'Spec_traditional': 0.37326800370538343, 'P_home_lowrisk': 0.11159773547044613, 'P_L23_highrisk': 0.027407403680139795}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 472: RMSE=5.3790
#   Sen=0.605, Spec=0.353
#   P_home_lowrisk=0.023, P_L23_highrisk=0.059
# [I 2026-06-08 17:40:48,652] Trial 472 finished with value: 5.379023384657486 and parameters: {'Sen_traditional': 0.6053321116246532, 'Spec_traditional': 0.35279914594940937, 'P_home_lowrisk': 0.022764305528411785, 'P_L23_highrisk': 0.058524103783116246}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 473: RMSE=5.8195
#   Sen=0.529, Spec=0.378
#   P_home_lowrisk=0.101, P_L23_highrisk=0.069
# [I 2026-06-08 17:40:49,049] Trial 473 finished with value: 5.819473700435178 and parameters: {'Sen_traditional': 0.5287634366129998, 'Spec_traditional': 0.37791028727800974, 'P_home_lowrisk': 0.10050119362447434, 'P_L23_highrisk': 0.06919680819482582}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 474: RMSE=4.3185
#   Sen=0.611, Spec=0.351
#   P_home_lowrisk=0.096, P_L23_highrisk=0.104
# [I 2026-06-08 17:40:49,459] Trial 474 finished with value: 4.318453671986278 and parameters: {'Sen_traditional': 0.6108423239875601, 'Spec_traditional': 0.3512154453118337, 'P_home_lowrisk': 0.09569193510371485, 'P_L23_highrisk': 0.10358953010102448}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 475: RMSE=14.7714
#   Sen=0.624, Spec=0.380
#   P_home_lowrisk=0.165, P_L23_highrisk=0.131
# [I 2026-06-08 17:40:49,848] Trial 475 finished with value: 14.771427387666238 and parameters: {'Sen_traditional': 0.6240961955399568, 'Spec_traditional': 0.3798082986185366, 'P_home_lowrisk': 0.1652700427283879, 'P_L23_highrisk': 0.13135573423483146}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 476: RMSE=1.6833
#   Sen=0.615, Spec=0.346
#   P_home_lowrisk=0.054, P_L23_highrisk=0.099
# [I 2026-06-08 17:40:50,264] Trial 476 finished with value: 1.6833252891956583 and parameters: {'Sen_traditional': 0.6154126206273984, 'Spec_traditional': 0.34574600801300376, 'P_home_lowrisk': 0.054475433734289494, 'P_L23_highrisk': 0.09891085108928417}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 477: RMSE=2.7809
#   Sen=0.608, Spec=0.375
#   P_home_lowrisk=0.080, P_L23_highrisk=0.057
# [I 2026-06-08 17:40:50,675] Trial 477 finished with value: 2.7809448324054453 and parameters: {'Sen_traditional': 0.6078944259741338, 'Spec_traditional': 0.374788502738636, 'P_home_lowrisk': 0.08034575509612042, 'P_L23_highrisk': 0.05711689800484537}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 478: RMSE=5.0879
#   Sen=0.792, Spec=0.308
#   P_home_lowrisk=0.111, P_L23_highrisk=0.029
# [I 2026-06-08 17:40:51,065] Trial 478 finished with value: 5.087872120527287 and parameters: {'Sen_traditional': 0.7918751625441992, 'Spec_traditional': 0.3078718230978797, 'P_home_lowrisk': 0.11065573065644183, 'P_L23_highrisk': 0.029061752435262475}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 479: RMSE=5.3717
#   Sen=0.574, Spec=0.382
#   P_home_lowrisk=0.024, P_L23_highrisk=0.129
# [I 2026-06-08 17:40:51,463] Trial 479 finished with value: 5.371688482743127 and parameters: {'Sen_traditional': 0.5743657607534624, 'Spec_traditional': 0.3818743311206281, 'P_home_lowrisk': 0.02444347300381986, 'P_L23_highrisk': 0.12858566931610654}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 480: RMSE=4.5202
#   Sen=0.635, Spec=0.339
#   P_home_lowrisk=0.098, P_L23_highrisk=0.138
# [I 2026-06-08 17:40:51,868] Trial 480 finished with value: 4.520162151059488 and parameters: {'Sen_traditional': 0.6346973854853609, 'Spec_traditional': 0.3387697253330537, 'P_home_lowrisk': 0.09805821019740384, 'P_L23_highrisk': 0.13840541119431918}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 481: RMSE=5.5723
#   Sen=0.636, Spec=0.391
#   P_home_lowrisk=0.104, P_L23_highrisk=0.060
# [I 2026-06-08 17:40:52,284] Trial 481 finished with value: 5.5722818063060435 and parameters: {'Sen_traditional': 0.635644600638266, 'Spec_traditional': 0.3905321989454657, 'P_home_lowrisk': 0.10396216354989832, 'P_L23_highrisk': 0.060178209934653726}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 482: RMSE=7.2415
#   Sen=0.650, Spec=0.338
#   P_home_lowrisk=0.011, P_L23_highrisk=0.099
# [I 2026-06-08 17:40:52,679] Trial 482 finished with value: 7.241471230943371 and parameters: {'Sen_traditional': 0.6497743851806492, 'Spec_traditional': 0.3375676475268454, 'P_home_lowrisk': 0.010530082421393389, 'P_L23_highrisk': 0.09862541373402017}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 483: RMSE=58.1222
#   Sen=0.708, Spec=0.584
#   P_home_lowrisk=0.348, P_L23_highrisk=0.174
# [I 2026-06-08 17:40:53,072] Trial 483 finished with value: 58.122196353753274 and parameters: {'Sen_traditional': 0.7075993265125109, 'Spec_traditional': 0.5844815615456372, 'P_home_lowrisk': 0.3484826064022511, 'P_L23_highrisk': 0.17369615156765122}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 484: RMSE=4.8014
#   Sen=0.536, Spec=0.368
#   P_home_lowrisk=0.087, P_L23_highrisk=0.026
# [I 2026-06-08 17:40:53,467] Trial 484 finished with value: 4.801391596708038 and parameters: {'Sen_traditional': 0.5355645981709349, 'Spec_traditional': 0.36826018609300387, 'P_home_lowrisk': 0.0874321056423744, 'P_L23_highrisk': 0.026194959063180118}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 485: RMSE=6.2791
#   Sen=0.568, Spec=0.361
#   P_home_lowrisk=0.109, P_L23_highrisk=0.085
# [I 2026-06-08 17:40:53,857] Trial 485 finished with value: 6.279060323276444 and parameters: {'Sen_traditional': 0.5682217324129296, 'Spec_traditional': 0.36080957045616113, 'P_home_lowrisk': 0.10907662445169927, 'P_L23_highrisk': 0.08514461382098903}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 486: RMSE=10.9956
#   Sen=0.620, Spec=0.387
#   P_home_lowrisk=0.139, P_L23_highrisk=0.067
# [I 2026-06-08 17:40:54,263] Trial 486 finished with value: 10.995596062903772 and parameters: {'Sen_traditional': 0.6200390669933452, 'Spec_traditional': 0.386999038756318, 'P_home_lowrisk': 0.13894820863395405, 'P_L23_highrisk': 0.06720823179856872}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 487: RMSE=7.0712
#   Sen=0.685, Spec=0.323
#   P_home_lowrisk=0.012, P_L23_highrisk=0.061
# [I 2026-06-08 17:40:54,656] Trial 487 finished with value: 7.071175435960558 and parameters: {'Sen_traditional': 0.6848003450853377, 'Spec_traditional': 0.32321420311907556, 'P_home_lowrisk': 0.011740317870373121, 'P_L23_highrisk': 0.06069910514760066}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 488: RMSE=18.6387
#   Sen=0.756, Spec=0.659
#   P_home_lowrisk=0.099, P_L23_highrisk=0.497
# [I 2026-06-08 17:40:55,071] Trial 488 finished with value: 18.638696372601085 and parameters: {'Sen_traditional': 0.7557467619288208, 'Spec_traditional': 0.6593008769356368, 'P_home_lowrisk': 0.09901792239179069, 'P_L23_highrisk': 0.49657969170686483}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 489: RMSE=7.8577
#   Sen=0.630, Spec=0.388
#   P_home_lowrisk=0.112, P_L23_highrisk=0.011
# [I 2026-06-08 17:40:55,506] Trial 489 finished with value: 7.857696959519833 and parameters: {'Sen_traditional': 0.6303540551057039, 'Spec_traditional': 0.3883825291659053, 'P_home_lowrisk': 0.1116696956777807, 'P_L23_highrisk': 0.011342098735739}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 490: RMSE=4.7277
#   Sen=0.501, Spec=0.355
#   P_home_lowrisk=0.087, P_L23_highrisk=0.027
# [I 2026-06-08 17:40:55,900] Trial 490 finished with value: 4.7276683195839695 and parameters: {'Sen_traditional': 0.501497735252786, 'Spec_traditional': 0.35509173422146806, 'P_home_lowrisk': 0.08668226091093956, 'P_L23_highrisk': 0.0265665596650232}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 491: RMSE=14.7582
#   Sen=0.700, Spec=0.304
#   P_home_lowrisk=0.203, P_L23_highrisk=0.055
# [I 2026-06-08 17:40:56,318] Trial 491 finished with value: 14.758197368244266 and parameters: {'Sen_traditional': 0.6995132438010695, 'Spec_traditional': 0.3042638458770299, 'P_home_lowrisk': 0.2028642339660351, 'P_L23_highrisk': 0.05485880774871398}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 492: RMSE=4.7295
#   Sen=0.624, Spec=0.391
#   P_home_lowrisk=0.085, P_L23_highrisk=0.150
# [I 2026-06-08 17:40:56,750] Trial 492 finished with value: 4.729520471448428 and parameters: {'Sen_traditional': 0.6238214966877133, 'Spec_traditional': 0.39135533636059167, 'P_home_lowrisk': 0.08453558951722459, 'P_L23_highrisk': 0.150400446727109}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 493: RMSE=7.7458
#   Sen=0.678, Spec=0.329
#   P_home_lowrisk=0.013, P_L23_highrisk=0.169
# [I 2026-06-08 17:40:57,164] Trial 493 finished with value: 7.745845717487622 and parameters: {'Sen_traditional': 0.6779643292895546, 'Spec_traditional': 0.3292021658682313, 'P_home_lowrisk': 0.012726985541360855, 'P_L23_highrisk': 0.1693374066800173}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 494: RMSE=53.8219
#   Sen=0.775, Spec=0.476
#   P_home_lowrisk=0.406, P_L23_highrisk=0.328
# [I 2026-06-08 17:40:57,569] Trial 494 finished with value: 53.82192902654542 and parameters: {'Sen_traditional': 0.7750765571153464, 'Spec_traditional': 0.4762836514347193, 'P_home_lowrisk': 0.40639934545462764, 'P_L23_highrisk': 0.32806646220876545}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 495: RMSE=1.6489
#   Sen=0.625, Spec=0.358
#   P_home_lowrisk=0.054, P_L23_highrisk=0.079
# [I 2026-06-08 17:40:57,985] Trial 495 finished with value: 1.6489469233541234 and parameters: {'Sen_traditional': 0.6249262334776349, 'Spec_traditional': 0.35783519148006915, 'P_home_lowrisk': 0.05380570699380673, 'P_L23_highrisk': 0.07908216347871455}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 496: RMSE=6.5766
#   Sen=0.614, Spec=0.384
#   P_home_lowrisk=0.015, P_L23_highrisk=0.091
# [I 2026-06-08 17:40:58,392] Trial 496 finished with value: 6.576580124319378 and parameters: {'Sen_traditional': 0.613612190958019, 'Spec_traditional': 0.3844300914462609, 'P_home_lowrisk': 0.015349919024360774, 'P_L23_highrisk': 0.09102452684526614}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 497: RMSE=5.2428
#   Sen=0.724, Spec=0.306
#   P_home_lowrisk=0.118, P_L23_highrisk=0.056
# [I 2026-06-08 17:40:58,804] Trial 497 finished with value: 5.24279984893148 and parameters: {'Sen_traditional': 0.7241224867134657, 'Spec_traditional': 0.3062292300493165, 'P_home_lowrisk': 0.11759775820140542, 'P_L23_highrisk': 0.05558177997321494}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 498: RMSE=24.4213
#   Sen=0.845, Spec=0.474
#   P_home_lowrisk=0.218, P_L23_highrisk=0.170
# [I 2026-06-08 17:40:59,203] Trial 498 finished with value: 24.42129188267657 and parameters: {'Sen_traditional': 0.8451754561853985, 'Spec_traditional': 0.47436068222766953, 'P_home_lowrisk': 0.21832155554895058, 'P_L23_highrisk': 0.17034296347869163}. Best is trial 237 with value: 0.40219507866446735.
#
# Trial 499: RMSE=3.6457
#   Sen=0.558, Spec=0.361
#   P_home_lowrisk=0.084, P_L23_highrisk=0.113
# [I 2026-06-08 17:40:59,603] Trial 499 finished with value: 3.6456624452994744 and parameters: {'Sen_traditional': 0.5575049275568361, 'Spec_traditional': 0.36081533651441766, 'P_home_lowrisk': 0.08439278941073804, 'P_L23_highrisk': 0.11285214899859129}. Best is trial 237 with value: 0.40219507866446735.
#
# ==================================================
# OPTIMIZATION COMPLETE
# ==================================================
# Best RMSE: 0.402195
# Best Parameters:
#   Sen_traditional: 0.6530
#   Spec_traditional: 0.3591
#   P_home_lowrisk: 0.0669
#   P_L23_highrisk: 0.0953

# %%
# # Calibration criteria
# # P["home_all"] = param["home_all_target"] #0.35
# P["home_all"] = 0.24
# # P["l23_all"] = param["l23_all_target"] #0.39
# P["l23_all"] = 0.26
# # P["l45_all"] = param["l45_all_target"] #0.26
# P["l45_all"] = 0.49
# # P["home_anc"] = param["home_anc_target"] #0.07
# P["home_anc"] = 0.026
# # P["l23_anc"] = param["l23_anc_target"] #0.490
# P["l23_anc"] = 0.18
# # P["l45_anc"] = param["l45_anc_target"] #0.439
# P["l45_anc"] = 0.79

# %%
df_trials.sort_values("value", inplace=True)
df_trials.iloc[0:1].values
# Out:
# array([[237, 0.40219507866446735,
#         Timestamp('2026-06-08 17:39:12.549073'),
#         Timestamp('2026-06-08 17:39:12.979266'),
#         Timedelta('0 days 00:00:00.430193'), 0.09534113732970033,
#         0.06685671045062526, 0.6530462942125022, 0.35905762589516127,
#         0.059436701509872236, 0.017278076435233526, 0.24001161440185834,
#         0.17134141389298974, 0.7005516840882695, 0.8113805096717768,
#         'COMPLETE']], dtype=object)

# %%
random.seed(0)
def f_ANC_LB_effect(P_home_lowrisk, P_L23_highrisk, Sen_traditional, Spec_traditional):
    # Initialize parameters

    GA = param['GA_sequence']
    GA_n = len(GA)
    n["GA"] = param["GA_distribution"]
    P["GA"] = n["GA"] / np.sum(n["GA"])
    PT_mask = np.array([1] * 10 + [0] * 8, dtype=bool)
    FT_mask = ~PT_mask
    P["GA"][PT_mask] = P["GA"][PT_mask] * param["PT_scale"]  # scale P[GA|PT] to match kenya level
    P_mult = (1 - np.sum(P["GA"][PT_mask])) / np.sum(P["GA"][FT_mask])
    P["GA"][FT_mask] *= P_mult

    OR["ANC"] = param["OR_preterm_ANC"]
    Preterm_rate = np.sum(P["GA"][PT_mask])  # overall preterm rate

    preterm_anc_noanc = odds_prob(OR["ANC"], Preterm_rate, P["ANC"])
    P["GA_anc"] = P["GA"].copy()
    P_scale_anc = preterm_anc_noanc[0] / Preterm_rate
    P["GA_anc"][PT_mask] *= P_scale_anc
    P_mult = (1 - preterm_anc_noanc[0]) / np.sum(P["GA_anc"][FT_mask])
    P["GA_anc"][FT_mask] *= P_mult

    P["GA_noanc"] = P["GA"].copy()
    P_scale_noanc = preterm_anc_noanc[1] / Preterm_rate
    P["GA_noanc"][PT_mask] *= P_scale_noanc
    P_mult = (1 - preterm_anc_noanc[1]) / np.sum(P["GA_noanc"][FT_mask])
    P["GA_noanc"][FT_mask] *= P_mult

    E["Preterm_LMP"] = np.zeros(3)
    E["Preterm_LMP"][0], E["Preterm_LMP"][1] = param['E_Preterm_LMP'][0], param['E_Preterm_LMP'][1]
    E["Preterm_LMP"][2] = 1 - (E["Preterm_LMP"][0] + E["Preterm_LMP"][1])
    E["Postterm_LMP"] = np.zeros(3)
    E["Postterm_LMP"][0], E["Postterm_LMP"][1] = param['E_Postterm_LMP'][0], param['E_Postterm_LMP'][1]
    E["Postterm_LMP"][2] = 1 - (E["Postterm_LMP"][0] + E["Postterm_LMP"][1])

    P_home_noANC = P["Home_noANC"]
    # P_l45_fac = 0.11 #assume is the probability of living cloest to L4/5
    P_l45_fac = 0.6
    P_fac_noANC = 1 - P_home_noANC  #0.294
    P_L45_noANC = P_fac_noANC * P_l45_fac  #0.294 * 0.11 = 0.032
    P_L23_noANC = P_fac_noANC - P_L45_noANC #0.294 - 0.032 = 0.262

    # Initialize counters
    n["highrisk"] = np.zeros(4)                                           #number of high-risk pregnancies by facility levels
    n["ANC"] = np.zeros(4)                                                #number of 4+ANC by facility levels
    n["LB_L"] = np.zeros(4)                                               #number of delivery location by facility levels
    M["PT"] = np.zeros(4)
    M["Postterm"] = np.zeros(4)
    M["GA"] = np.zeros((4, GA_n))  # GA distributions by facility levels

    for k_LB in range(np.sum(LB_tot)):
        i_risk = np.random.binomial(1, P["highrisk_all"])
        i_ANC = np.random.binomial(1, P["ANC"])
        if i_ANC:
            P_GA = P["GA_anc"]
        else:
            P_GA = P["GA_noanc"]
        i_jGA = np.searchsorted(np.cumsum(P_GA), np.random.rand())  # % actual index of GA
        i_GA = GA[i_jGA]  # % actual GA

        if i_GA < 37:
            i_term_status = 0   #% 0 = preterm, 1 = full term, 2 = postterm
        elif i_GA >= 43:
            i_term_status = 2
        else:
            i_term_status = 1

        if i_ANC == 0:
            i_loc = np.random.choice([0, 1, 2], p=[P_home_noANC, P_L23_noANC, P_L45_noANC])
        else:
            # Risk stratification
            if i_risk:
                i_risk_pred = 1 if np.random.random() < Sen_traditional else 0
            else:
                i_risk_pred = 0 if np.random.random() < Spec_traditional else 1

            # Gestational age estimation
            i_preterm_pred = 1 if np.random.random() < E["Preterm_LMP"][i_term_status] else 0
            i_postterm_pred = 1 if np.random.random() < E["Postterm_LMP"][i_term_status] else 0

            if i_risk_pred or i_preterm_pred == 1 or i_postterm_pred == 1:
                i_loc = np.random.choice([0, 1, 2], p=[0, P_L23_highrisk, 1 - P_L23_highrisk])
            else:
                i_loc = np.random.choice([0, 1, 2], p=[P_home_lowrisk, (1 - P_home_lowrisk) * (1-P_l45_fac), (1 - P_home_lowrisk) * P_l45_fac])

        # assume among all live births at L45, 5126/(20709 + 5126) going to L5
        P_l5_l45 = 668 / (1448 + 668)
        if i_loc == 2 and np.random.random() < P_l5_l45:
            i_loc = 3

        # restore results
        n["highrisk"][i_loc] += i_risk
        n["ANC"][i_loc]      += i_ANC
        n["LB_L"][i_loc]     += 1
        M["GA"][i_loc, i_jGA] += 1
        M["PT"][i_loc] += i_term_status == 0
        M["Postterm"][i_loc] += i_term_status == 2

    # Predicted outcomes
    P_home_all = n["LB_L"][0] / np.sum(LB_tot)
    P_l23_all = n["LB_L"][1] / np.sum(LB_tot)
    P_l45_all = (n["LB_L"][2] + n["LB_L"][3]) / np.sum(LB_tot)
    P_home_anc = n["ANC"][0] / np.sum(n["ANC"])
    P_l23_anc = n["ANC"][1] / np.sum(n["ANC"])
    P_l45_anc = (n["ANC"][2] + n["ANC"][3]) / np.sum(n["ANC"])
    P_preterm_fac = np.sum(M["PT"][1:]) / np.sum(n["LB_L"][1:])
    P_preterm_home = M["PT"][0] / n["LB_L"][0]
    P_preterm_l23 = M["PT"][1] / n["LB_L"][1]
    P_preterm_l45 = (M["PT"][2] + M["PT"][3]) / n["LB_L"][2:4].sum()

    return P_home_all, P_l23_all, P_l45_all, P_home_anc, P_l23_anc, P_l45_anc, P_preterm_fac, P_preterm_home, P_preterm_l23, P_preterm_l45

# %%
from skopt import gp_minimize
from skopt.space import Real
from skopt.utils import use_named_args
import numpy as np
import pandas as pd
import math
import matplotlib.pyplot as plt

# Calibration targets
target_values = {
    "P_home_all": P["home_all"],
    "P_l23_all": P["l23_all"],
    "P_l45_all": P["l45_all"],
    "P_home_anc": P["home_anc"],
    "P_l23_anc": P["l23_anc"],
    "P_l45_anc": P["l45_anc"],
}

# Tolerance percentages for each target
target_weights = {
    "P_home_all": (P["home_all"], 5),   # ±5% tolerance
    "P_l23_all":  (P["l23_all"], 5),
    "P_l45_all":  (P["l45_all"], 5),
    "P_home_anc": (P["home_anc"], 5),
    "P_l23_anc": (P["l23_anc"], 5),
    "P_l45_anc": (P["l45_anc"], 5),
}

def weighted_rmse(df_results, target_weights):
    weighted_errors = []
    for metric, (target, accepted_pct) in target_weights.items():
        simulated = df_results.get(metric, 0)
        error = simulated - target
        accepted_abs_error = target * (accepted_pct / 100)
        if accepted_abs_error == 0:  # safeguard
            continue
        normalized_error = error / accepted_abs_error
        weighted_errors.append(normalized_error**2)
    return math.sqrt(sum(weighted_errors) / len(weighted_errors))

# Define parameter space
param_space = [
    Real(0.01, 0.5, name='P_home_lowrisk'),
    Real(0.01, 0.4, name='P_L23_highrisk'),
    Real(0.6, 0.8, name='Sen_traditional'),
    Real(0.6, 0.8, name='Spec_traditional')
]

# Seeds for reproducibility
total_runs = 10
seeds = np.random.default_rng(2025).integers(low=0, high=1e6, size=total_runs)

# Track RMSE history
rmse_history = []

@use_named_args(param_space)
def objective(**params):
    # --- Constraint check: Sen must be greater than Spec ---
    if params['Sen_traditional'] <= params['Spec_traditional']:
        print("\n⚠️ Constraint violated: Sen_traditional <= Spec_traditional. Returning penalty.")
        objective.last_df_results = {}
        return 10.0  # Penalty loss

    results = []
    for run in range(total_runs):
        np.random.seed(seeds[run])
        res = f_ANC_LB_effect(
            params['P_home_lowrisk'],
            params['P_L23_highrisk'],
            params['Sen_traditional'],
            params['Spec_traditional']
        )
        results.append(res)

    # Average across runs
    mean_results = np.mean(results, axis=0)
    df_results = {
        "P_home_all": mean_results[0],
        "P_l23_all": mean_results[1],
        "P_l45_all": mean_results[2],
        "P_home_anc": mean_results[3],
        "P_l23_anc": mean_results[4],
        "P_l45_anc": mean_results[5],
    }

    # Save last results for early stopper
    objective.last_df_results = df_results

    # Weighted RMSE
    rmse = weighted_rmse(df_results, target_weights)

    # Print status
    print("\n--- Calibration Iteration ---")
    print("Parameters:")
    for k, v in params.items():
        print(f"  {k:22s}: {v:.4f}")
    print("\nTarget vs Simulated Outcomes:")
    for k in target_values:
        sim = df_results[k]
        target = target_values[k]
        error = sim - target
        rel_error = error / target
        print(f"  {k:22s} | Sim: {sim:.4f}, Target: {target:.4f}, RelErr: {rel_error:+.2%}")
    print(f"\nRMSE Loss: {rmse:.6f}")
    print("-----------------------------\n")

    return rmse

class EarlyStopper:
    def __init__(self, threshold_rmse=0.1, relative_threshold=0.05):
        self.threshold_rmse = threshold_rmse
        self.relative_threshold = relative_threshold
        self.best_loss = float('inf')
        self.best_params = None
        self.best_df_results = None

    def meets_relative_criteria(self, sim_results):
        for metric, (target, accepted_pct) in target_weights.items():
            sim = sim_results.get(metric, 0)
            rel_error = abs(sim - target) / target
            if rel_error > (accepted_pct / 100):
                return False
        return True

    def meets_param_constraints(self, param_list):
        if param_list is None:
            return False
        names = [d.name for d in param_space]
        p = dict(zip(names, param_list))
        return p['Sen_traditional'] > p['Spec_traditional']

    def __call__(self, *args, **kwargs):
        loss = objective(*args, **kwargs)
        rmse_history.append(loss)

        if loss < self.best_loss:
            self.best_loss = loss
            self.best_params = list(args[0]) if args else None
            self.best_df_results = getattr(objective, "last_df_results", {})

        if (self.best_loss < self.threshold_rmse
            and self.meets_relative_criteria(self.best_df_results)
            and self.meets_param_constraints(self.best_params)):
            print(f"\n⏹️ Early stopping: RMSE={self.best_loss:.6f} and Sen>Spec satisfied.")
            raise StopIteration

        return loss

def save_results(best_params, best_loss, rmse_history, param_space):
    param_names = [dim.name for dim in param_space]
    best_param_dict = dict(zip(param_names, best_params))
    best_param_dict["Best RMSE"] = best_loss
    df_best = pd.DataFrame([best_param_dict])
    df_best.to_csv("best_parameters_ANC_v7.csv", index=False)

    pd.DataFrame({"Iteration": range(1, len(rmse_history)+1), "RMSE": rmse_history}).to_csv("rmse_history_ANC_v7.csv", index=False)

    plt.figure(figsize=(10, 6))
    plt.plot(range(1, len(rmse_history)+1), rmse_history, marker='o')
    plt.xlabel("Iteration")
    plt.ylabel("RMSE Loss")
    plt.title("RMSE Loss Over Iterations")
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("rmse_plot_ANC_v7.png")
    plt.close()

def optimize_model():
    early_stopper = EarlyStopper(threshold_rmse=0.1, relative_threshold=0.05)
    try:
        result = gp_minimize(
            func=early_stopper,
            dimensions=param_space,
            n_calls=1000,
            random_state=42,
            n_random_starts=20,
            acq_func="EI",
            verbose=True
        )
        print("\n✅ Optimization completed.")
        print("Best Parameters:", result.x)
        print("Best Loss:", result.fun)
        save_results(result.x, result.fun, rmse_history, param_space)
        return result

    except StopIteration:
        print("\n✅ Optimization stopped early.")
        print(f"Best RMSE achieved: {early_stopper.best_loss:.6f}")
        if early_stopper.best_params is not None:
            print("Best Parameters:")
            for name, val in zip([d.name for d in param_space], early_stopper.best_params):
                print(f"  {name:22s}: {val:.4f}")
            save_results(early_stopper.best_params, early_stopper.best_loss, rmse_history, param_space)
        return None

# if __name__ == "__main__":
#     optimize_model()

# %%
# --- Calibration Iteration ---
# param_space = [
#     Real(0.1, 0.5, name='P_home_lowrisk'),
#     Real(0.1, 0.4, name='P_L23_highrisk'),
#     Real(0.6, 0.8, name='Sen_traditional'),
#     Real(0.6, 0.8, name='Spec_traditional')
# ]

# Parameters:
#   P_home_lowrisk        : 0.1692
#   P_L23_highrisk        : 0.3255
#   Sen_traditional       : 0.7641
#   Spec_traditional      : 0.6306
#
# Target vs Simulated Outcomes:
#   P_home_all             | Sim: 0.3501, Target: 0.3500, RelErr: +0.02%
#   P_l23_all              | Sim: 0.3915, Target: 0.3920, RelErr: -0.12%
#   P_l45_all              | Sim: 0.2584, Target: 0.2580, RelErr: +0.15%
#   P_home_anc             | Sim: 0.0697, Target: 0.0700, RelErr: -0.49%
#   P_l23_anc              | Sim: 0.4937, Target: 0.4900, RelErr: +0.76%
#   P_l45_anc              | Sim: 0.4366, Target: 0.4390, RelErr: -0.54%
#
# RMSE Loss: 0.087077
# -----------------------------
#
#
# ⏹️ Early stopping: RMSE=0.087077 and Sen>Spec satisfied.
#
# ✅ Optimization stopped early.
# Best RMSE achieved: 0.087077
# Best Parameters:
#   P_home_lowrisk        : 0.1692
#   P_L23_highrisk        : 0.3255
#   Sen_traditional       : 0.7641
#   Spec_traditional      : 0.6306

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

# Load your CSV if needed
rmse_df = pd.read_csv("rmse_history_ANC_v7.csv")

# Plot
plt.figure(figsize=(12, 5))
plt.plot(rmse_df['Iteration'], rmse_df['RMSE'], marker='o', label='Weighted RMSE')
plt.axhline(y=0.1, color='red', linestyle='--', label='Tolerance Threshold (RMSE=0.1)')

# Add labels and title
final_rmse = rmse_df['RMSE'].iloc[-1]
plt.title(f"Optimization Progress (Final RMSE: {final_rmse:.3f})")
plt.xlabel("Iteration")
plt.ylabel("Weighted RMSE")
plt.legend()
plt.grid(True)

# Save the plot
plt.savefig("rmse_ANC.png", dpi=300)

# Show plot
plt.tight_layout()
plt.show()
